# %%
from gettext import install

import nltk

with open('tokxt.txt', 'r', encoding='utf-8') as f:
    text = f.read()

tokens = nltk.word_tokenize(text)

with open('output_tokens_nltk.txt', 'w', encoding='utf-8') as out_f:
    for token in tokens:
        out_f.write(token + '\n')

# %%
import warnings
import logging
logging.getLogger('stanza').setLevel(logging.WARNING)
warnings.filterwarnings("ignore")

import stanza

stanza.download('ru')

nlp = stanza.Pipeline('ru', processors='tokenize')

with open('tokxt.txt', 'r', encoding='utf-8') as f:
    text = f.read()

doc = nlp(text)

with open('output_tokens_stanza.txt', 'w', encoding='utf-8') as out_f:
    for sentence in doc.sentences:
        for token in sentence.tokens:
            out_f.write(token.text + '\n')

# %%
from razdel import tokenize

with open('tokxt.txt', 'r', encoding='utf-8') as f:
    text = f.read()

tokens = list(tokenize(text))

with open('output_tokens_razdel.txt', 'w', encoding='utf-8') as out_f:
    for token in tokens:
        out_f.write(token.text + '\n')

# %%
from segtok.tokenizer import word_tokenizer

with open('tokxt.txt', 'r', encoding='utf-8') as f:
    text = f.read()

tokens = list(word_tokenizer(text))

with open('output_tokens_segtok.txt', 'w', encoding='utf-8') as out_f:
    for token in tokens:
        out_f.write(token + '\n')

# %%
import spacy

nlp = spacy.load('ru_core_news_sm')

with open('tokxt.txt', 'r', encoding='utf-8') as f:
    text = f.read()

doc = nlp(text)

with open('output_tokens_spacy_ru.txt', 'w', encoding='utf-8') as out_f:
    for token in doc:
        out_f.write(token.text + '\n')

# %%
from mosestokenizer import MosesTokenizer

tokenizer = MosesTokenizer(lang='ru')

with open('tokxt.txt', 'r', encoding='utf-8') as f:
    text = f.read()

text = text.replace('\n', ' ')

tokens = tokenizer(text)

with open('output_tokens_mosestokenizer.txt', 'w', encoding='utf-8') as out_f:
    for token in tokens:
        out_f.write(token + '\n')

# %%
from pymorphy2.tokenizers import simple_word_tokenize

with open('tokxt.txt', 'r', encoding='utf-8') as f:
    text = f.read()

tokens = simple_word_tokenize(text)

with open('output_tokens_pymorphy2.txt', 'w', encoding='utf-8') as out_f:
    for token in tokens:
        out_f.write(token + '\n')

# %%
import pandas as pd

# Функция для чтения и очистки токенов из файла
def read_tokens(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        tokens = f.readlines()
    return [token.strip() for token in tokens]

# Список файлов, которые ты хочешь объединить в таблицу
file_paths = [
    'output_tokens_stanza.txt',
    'output_tokens_spacy_ru.txt',
    'output_tokens_nltk.txt'
]

all_tokens = []

# Чтение данных из каждого файла
for file_path in file_paths:
    tokens = read_tokens(file_path)
    all_tokens.extend(tokens)

# Создание таблицы (DataFrame)
df = pd.DataFrame(all_tokens, columns=['Token'])
df.index.name = 'Index'

# Вывод первых строк таблицы
print(df.head())
# Out:
#           Token
# Index
# 0        ﻿Когда
# 1             я
# 2         писал
# 3           эти
# 4      страницы

# %%
# Вывод всей таблицы
print(df)

# %%
import pandas as pd

# Функция для чтения токенов из файла
def read_tokens(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        tokens = f.readlines()
    return [token.strip() for token in tokens]

# Укажи пути к файлам для каждой библиотеки
file_paths = {
    'nltk': 'output_tokens_nltk.txt',
    'stanza': 'output_tokens_stanza.txt',
    'spacy': 'output_tokens_spacy_ru.txt',
    'pymorphy2': 'output_tokens_pymorphy2.txt',
    'mosestokenizer': 'output_tokens_mosestokenizer.txt',
    'razdel': 'output_tokens_razdel.txt',
    'segtok': 'output_tokens_segtok.txt'
}

# Чтение токенов из всех файлов
token_data = {}
max_length = 0

# Считываем токены из каждого файла и находим максимальную длину списка
for library, file_path in file_paths.items():
    tokens = read_tokens(file_path)
    token_data[library] = tokens
    max_length = max(max_length, len(tokens))  # Определяем максимальную длину

# Выровняем длины списков, заполнив недостающие значения пустыми строками
for library in token_data:
    tokens = token_data[library]
    if len(tokens) < max_length:
        tokens.extend([''] * (max_length - len(tokens)))  # Добавляем пустые строки
    token_data[library] = tokens

# Создание DataFrame из выровненных токенов
df = pd.DataFrame(token_data)

# Настройка pandas для вывода всех строк
pd.set_option('display.max_rows', None)

# Вывод всей таблицы
print(df.head(100))

# Вывод таблицы с фиксированной шириной колонок
print('{:20}\t{:20}\t{:20}\t{:20}\t{:20}\t{:20}\t{:20}'.format('nltk', 'razdel', 'segtok', 'spacy', 'pymorphy3', 'moses', 'ud'))
for tk in zip(df['nltk'], df['razdel'], df['segtok'], df['spacy'], df['pymorphy3'], df['moses'], df['ud']):
    print('{:20}\t{:20}\t{:20}\t{:20}\t{:20}\t{:20}\t{:20}'.format(*tk))
# Out:
#                nltk           stanza            spacy        pymorphy2  \
# 0            ﻿Когда           ﻿Когда           ﻿Когда                ﻿
# 1                 я                я                я            Когда
# 2             писал            писал            писал                я
# 3               эти              эти              эти            писал
# 4          страницы         страницы         страницы              эти
# 5                 -                -                -         страницы
# 6            вернее           вернее           вернее                -
# 7                 ,                ,                ,           вернее
# 8           большую          большую          большую                ,
# 9                их               их               их          большую
# 10            часть            часть            часть               их
# 11                ,                ,                ,            часть
# 12                -                -                -                ,
# 13                я                я                я                -
# 14              жил              жил              жил                я
# 15             один             один                               жил
# 16                в                в             один             один
# 17             лесу             лесу                                 в
# 18                ,                ,                в             лесу
# 19               на               на                                 ,
# 20       расстоянии       расстоянии                                на
# 21             мили             мили             лесу       расстоянии
# 22               от               от                ,             мили
# 23       ближайшего       ближайшего               на               от
# 24            жилья            жилья       расстоянии       ближайшего
# 25                ,                ,             мили            жилья
# 26                в                в               от                ,
# 27             доме             доме       ближайшего                в
# 28                ,                ,            жилья             доме
# 29          который          который                ,                ,
# 30              сам              сам                в          который
# 31         построил         построил             доме              сам
# 32               на               на                ,         построил
# 33           берегу           берегу          который               на
# 34      Уолденского      Уолденского              сам           берегу
# 35            пруда            пруда         построил      Уолденского
# 36                в                в                             пруда
# 37         Конкорде         Конкорде                                 в
# 38                ,                ,               на         Конкорде
# 39                в                в           берегу                ,
# 40            штате            штате      Уолденского                в
# 41      Массачусетс      Массачусетс            пруда            штате
# 42                ,                ,                в      Массачусетс
# 43                и                и         Конкорде                ,
# 44          добывал          добывал                ,                и
# 45       пропитание       пропитание                в          добывал
# 46    исключительно    исключительно                        пропитание
# 47           трудом           трудом            штате    исключительно
# 48            своих            своих                            трудом
# 49              рук              рук      Массачусетс            своих
# 50                .                .                ,              рук
# 51              Так              Так                                 .
# 52                я                я                и              Так
# 53           прожил           прожил                                 я
# 54              два              два          добывал           прожил
# 55             года             года                               два
# 56                и                и                              года
# 57              два              два       пропитание                и
# 58           месяца           месяца    исключительно              два
# 59                .                .           трудом           месяца
# 60           Сейчас           Сейчас            своих                .
# 61                я                я              рук           Сейчас
# 62            снова            снова                .                я
# 63        временный        временный              Так            снова
# 64           житель           житель                я        временный
# 65  цивилизованного  цивилизованного           прожил           житель
# 66             мира             мира                   цивилизованного
# 67                .                .              два             мира
# 68                Я                Я                                 .
# 69               не               не             года                Я
# 70             стал             стал                                не
# 71               бы               бы                и             стал
# 72       навязывать       навязывать                                бы
# 73         читателю         читателю              два       навязывать
# 74             всех             всех                          читателю
# 75             этих             этих                              всех
# 76     подробностей     подробностей           месяца             этих
# 77                ,                ,                .     подробностей
# 78             если             если           Сейчас                ,
# 79               бы               бы                я             если
# 80               не               не            снова               бы
# 81      настойчивые      настойчивые        временный               не
# 82        расспросы        расспросы           житель      настойчивые
# 83             моих             моих  цивилизованного        расспросы
# 84         земляков         земляков             мира             моих
# 85                о                о                .         земляков
# 86             моей             моей                                 о
# 87        тогдашней        тогдашней                              моей
# 88            жизни            жизни                Я        тогдашней
# 89                ,                ,               не            жизни
# 90                -                -             стал                ,
# 91        расспросы        расспросы               бы                -
# 92                ,                ,       навязывать        расспросы
# 93          которые          которые         читателю                ,
# 94             иные             иные             всех          которые
# 95          назвали          назвали             этих             иные
# 96               бы               бы                           назвали
# 97      неуместными      неуместными     подробностей               бы
# 98                ,                ,                ,      неуместными
# 99               но               но                                 ,
#
#      mosestokenizer           razdel           segtok
# 0                 ﻿           ﻿Когда                ﻿
# 1             Когда                я            Когда
# 2                 я            писал                я
# 3             писал              эти            писал
# 4               эти         страницы              эти
# 5          страницы                -         страницы
# 6                 -           вернее                -
# 7            вернее                ,           вернее
# 8                 ,          большую                ,
# 9           большую               их          большую
# 10               их            часть               их
# 11            часть                ,            часть
# 12                ,                -                ,
# 13                -                я                -
# 14                я              жил                я
# 15              жил             один              жил
# 16             один                в             один
# 17                в             лесу                в
# 18             лесу                ,             лесу
# 19                ,               на                ,
# 20               на       расстоянии               на
# 21       расстоянии             мили       расстоянии
# 22             мили               от             мили
# 23               от       ближайшего               от
# 24       ближайшего            жилья       ближайшего
# 25            жилья                ,            жилья
# 26                ,                в                ,
# 27                в             доме                в
# 28             доме                ,             доме
# 29                ,          который                ,
# 30          который              сам          который
# 31              сам         построил              сам
# 32         построил               на         построил
# 33               на           берегу               на
# 34           берегу      Уолденского           берегу
# 35      Уолденского            пруда      Уолденского
# 36            пруда                в            пруда
# 37                в         Конкорде                в
# 38         Конкорде                ,         Конкорде
# 39                ,                в                ,
# 40                в            штате                в
# 41            штате      Массачусетс            штате
# 42      Массачусетс                ,      Массачусетс
# 43                ,                и                ,
# 44                и          добывал                и
# 45          добывал       пропитание          добывал
# 46       пропитание    исключительно       пропитание
# 47    исключительно           трудом    исключительно
# 48           трудом            своих           трудом
# 49            своих              рук            своих
# 50              рук                .             рук.
# 51                .              Так              Так
# 52              Так                я                я
# 53                я           прожил           прожил
# 54           прожил              два              два
# 55              два             года             года
# 56             года                и                и
# 57                и              два              два
# 58              два           месяца          месяца.
# 59           месяца                .           Сейчас
# 60                .           Сейчас                я
# 61           Сейчас                я            снова
# 62                я            снова        временный
# 63            снова        временный           житель
# 64        временный           житель  цивилизованного
# 65           житель  цивилизованного            мира.
# 66  цивилизованного             мира                Я
# 67             мира                .               не
# 68                .                Я             стал
# 69                Я               не               бы
# 70               не             стал       навязывать
# 71             стал               бы         читателю
# 72               бы       навязывать             всех
# 73       навязывать         читателю             этих
# 74         читателю             всех     подробностей
# 75             всех             этих                ,
# 76             этих     подробностей             если
# 77     подробностей                ,               бы
# 78                ,             если               не
# 79             если               бы      настойчивые
# 80               бы               не        расспросы
# 81               не      настойчивые             моих
# 82      настойчивые        расспросы         земляков
# 83        расспросы             моих                о
# 84             моих         земляков             моей
# 85         земляков                о        тогдашней
# 86                о             моей            жизни
# 87             моей        тогдашней                ,
# 88        тогдашней            жизни                -
# 89            жизни                ,        расспросы
# 90                ,                -                ,
# 91                -        расспросы          которые
# 92        расспросы                ,             иные
# 93                ,          которые          назвали
# 94          которые             иные               бы
# 95             иные          назвали      неуместными
# 96          назвали               бы                ,
# 97               бы      неуместными               но
# 98      неуместными                ,          которые
# 99                ,               но              мне
# nltk                	razdel              	segtok              	spacy               	pymorphy3           	moses               	ud
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PycharmProjects/pythonProject/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pymorphy3'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 48
#      46 # Вывод таблицы с фиксированной шириной колонок
#      47 print('{:20}\t{:20}\t{:20}\t{:20}\t{:20}\t{:20}\t{:20}'.format('nltk', 'razdel', 'segtok', 'spacy', 'pymorphy3', 'moses', 'ud'))
# ---> 48 for tk in zip(df['nltk'], df['razdel'], df['segtok'], df['spacy'], df['pymorphy3'], df['moses'], df['ud']):
#      49     print('{:20}\t{:20}\t{:20}\t{:20}\t{:20}\t{:20}\t{:20}'.format(*tk))
#
# File ~/PycharmProjects/pythonProject/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/PycharmProjects/pythonProject/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'pymorphy3'

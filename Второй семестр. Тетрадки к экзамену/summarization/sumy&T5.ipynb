# %%
import os
import pandas as pd

# %%
years = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]

# %%
path = "C:\\Users\\sasha\\Desktop\\opiskelu\\Семантические анализаторы\\Суммаризация\\articles"

# %%
texts = []

# %%
for root, dirs, files in os.walk(path):
  for file in files:
      if 'annotation' not in file:
        with open(os.path.join(root,file), 'r', encoding='utf-8')as f:
          text = f.read()
          name = str(file[:-4])
          year = str(file[-8:-4])
          texts += [(name, text, year)]

# %%
texts[:1]
# Out:
# [('Belkin_IMS_2024_rus',
#   '1. Введение По  мере  стремительного  развития  Интернета новый  вид  приобретают  и  различные онлайн-платформы,  социальные  сети,  форумы  и  т.д.  Некоторые  подобные  площадки агрегируют  отзывы  интернет-пользователей,  описывающие  какой-либо  товар  или заведение. Отзыв  представляет  собой  текст  произвольной  длины,  написанный  пользователем  и выражающий его личное отношение к тому или иному объекту. Часто платформы дают возможность оценивать степень удовлетворенности в баллах от 1 до 5.Пользовательский  фидбек  может  быть  очень  ценным  источником  информации  для организаций,  направленных на  предоставление  различных  услуг  людям[1].  В  отзывах пользователи могут указывать на неочевидные проблемы, недостатки или несоответствие действительности информации, указанной на сайте организации. Это может помочь быстро выявить и своевременно устранить недочеты. Большое количество положительных отзывов влияет на приток новых клиентов, так как люди в первую очередь обращают внимание на рейтинг и оценки. Также, положительные отзывы могут быть использованы в рекламных целях, демонстрируя их на сайте или в социальных сетях. С другой стороны, отзывы могут помочь в оценке конкурентных заведений или товаров, например, понять сильные и слабые стороны, выявить новые тренды и возможности для роста. Эффективными инструментами изучения пользовательских отзывов являются анализ тональности и тематическое моделирование [2]. Тематическое моделирование позволяет выделить  ключевые  темы  и  проблемы,  которые  обсуждаются  в  отзывах  [3].  Вдобавок, можно  сравнивать  различные  группы  пользователей  и  выявлять  их  потребности  и предпочтения. В свою очередь, анализ тональности комментариев и отзывов помогает понять то, какие эмоции  выражают  пользователи.  Обученный  на  достаточно  большом  объеме  данных алгоритм анализа тональности поможет исследовать данные, не имеющие таких же оценок или  меток,  как  на  онлайн-платформах.  Существует  множество  традиционных  и современных  способов  сбора  отзывов,  которые  используются  в  настоящее  время.  К традиционным можно отнести бумажные формы для отзывов, как, например, книги жалоб и предложений или заполнение опросных листов [4]. Среди современных способов можно выделить электронные опросы, мониторинг социальных медиа и телефонные интервью. Такие данные не содержат конкретной метрики, говорящей об эмоциональном отношении опрошенного. В таких случаях и может пригодиться модель анализа тональности. Особенно важно понимать потребности и опыт пациентов в сфере здравоохранения, так как их мнение является ключевым показателем качества. Интернет дал людям возможность выражать свои мнения на  различных платформах, что создало большой объем данных, исследование которых может выявить тенденции, не замеченные ранее, в медицинских услугах. Исследователи из Имперского колледжа Лондона собрали комментарии пациентов с сайта NHS Choices за 2008, 2009 и 2011 годы (13802 текста) и применили методы анализа тональности [5]. Данные за 2010 год (6412 комментариев) использовались для проверки точности  предсказания.  Целью  было  обучение  модели  машинного  обучения  для автоматического   определения   рекомендаций пациентов,   чистоты   медицинского учреждения  и  уважительного  отношения.  Алгоритм  классифицировал  комментарии  на основе  примеров  и  проверял  точность  предсказания,  сравнивая  результаты  с  оценками пациентов  по  шкале  Ликерта.  Исследование  показало  высокую  точность  предсказаний, подтверждая соответствие прогнозов результатам опросов. В  другом  исследовании  группа  ученых  собрала  корпус  данных  с  сайта Otzovik, состоящий  из  1,4  миллиона  пользовательских  отзывов  на  русском  языке  о  здоровье  и лекарствах, а также 500 подробно аннотированных отзывов [6]. Корпус называется RuDReC и находится в публичном доступе. Ученые затем использовали эти тексты для обучения моделей Multi-BERT, RuBERT и RuDR-BERT, сравнив их способность извлекать из отзывов пользо ...
#   '_rus')]

# %%
df = pd.DataFrame(texts, columns=['names', 'texts', 'years'])

df
# Out:
#                       names  \
# 0       Belkin_IMS_2024_rus
# 1   Bogomolova_IMS_2013_rus
# 2   Filchenkov_IMS_2014_rus
# 3    Khokhlova_IMS_2017_rus
# 4   Martynenko_IMS_2018_rus
# 5     Masevich_IMS_2016_rus
# 6     Mengliev_IMS_2021_rus
# 7     Perminov_IMS_2019_rus
# 8        Rogov_IMS_2020_rus
# 9        Salin_IMS_2015_rus
# 10           Tatur_IMS_2023
# 11          Vissio_IMS_2022
#
#                                                 texts years
# 0   1. Введение По  мере  стремительного  развития...  _rus
# 1   УИС РОССИЯ: эксперимент по реализации онтологи...  _rus
# 2   Компаративный анализ методологических основ за...  _rus
# 3   Сопоставительный анализ статистических мер\nна...  _rus
# 4   Методологические проблемы создания Компьютерно...  _rus
# 5   Методы корпусной лингвистики в исторических\nи...  _rus
# 6   Структура и единицы морфоанализатора узбекског...  _rus
# 7   Интеграция инструментов и сервисов для оценки ...  _rus
# 8   Применение деревьев решений для анализа сильны...  _rus
# 9   Семантическая сегментация веб-гипертекста на\n...  _rus
# 10  Выявление скрытых закономерностей в реакции об...  2023
# 11  Выделение русских заимствований в якутских тек...  2022

# %% [markdown]
# Sumy

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lex_rank import LexRankSummarizer

import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sasha\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
summarizer = LexRankSummarizer()

# %%
abstracts = []

# %%
for text in df.texts:
  doc = text
  parser = PlaintextParser.from_string(doc, Tokenizer('russian'))
  summary = summarizer(parser.document, 3)
  abstracts.append([str(sentence) for sentence in summary])

# %%
abstracts[:10]
# Out:
# [['Существует  множество  традиционных  и современных  способов  сбора  отзывов,  которые  используются  в  настоящее  время.',
#   'Исследователи из Имперского колледжа Лондона собрали комментарии пациентов с сайта NHS Choices за 2008, 2009 и 2011 годы (13802 текста) и применили методы анализа тональности [5].',
#   'Эти данные будут  использованы  для  обучения  модели  анализа  тональности.'],
#  ['Анализ онтологии как системы организации знаний дан в работе [2].',
#   'Были обработаны формы федерального статистического наблюдения за 2008-2011 годы.',
#   'Заключение По грантам РГНФ в рамках проекта УИС РОССИЯ разработана основа онтологии предметной области «государственное управление» для содержательной интеграции статистических показателей и аналитических документов.'],
#  ['В целях настоящей работы мы выделим два типа протестов, которые условно назовем стихийные и организованные Стихийные протесты (например, события в Бирюлово в 2012 году) отличаются тем, что протест возникает спонтанно как ответ на какой-либо информационный повод (обычно, происшествие), очаг возникновения локализуется вне социальных сетей, которые, хотя и могут выступать инструментом для координации и мобилизации, не играют существенной роли в моменте образования протеста.',
#   'Результаты: больше всего свидетельств с пользу репрезентативности выделено для организованных протестов, для стихийных протестов нет релевантной информации, а для выборов заведомо известно, что репрезентативность отсутствует.',
#   'Именно этот критерий, на наш взгляд, является определяющим для решения задачи предсказания протеста и ее сложности по сравнению с задачей предсказания выборов 6.'],
#  ['для',
#   '4.1 Мера MI Отличительной особенностью меры MI оказалось то, что по сравнению с другими мерами она выделила наибольшее количество сочетаний с числительными и местоимениями.',
#   'Так же в отличие от взаимной информации зафиксировано большое число сочетаний с существительными (23,4% vs 15,7%).'],
#  ['Теоретические предпосылки Теоретическими предпосылками создания Антологии являются три источника: теория совокупности выдающегося русского статистика начала ХХ века А. А. Чупрова, статистические представления русского писателя и ученого А. А. Белого о массовом создании словарей русских писателей и системные представления выдающегося представителя русской формальной школы Ю. Н. Тынянова.',
#   'После составления списка авторов каталогизируются их произведения.',
#   'В основе проекта лежат идеи русской формальной школы и прежде всего системные идеи Ю. Н. Тынянова, обеспечивающие представительность авторов и их произведений на основе объективных формальных критериев.'],
#  ['исследования.',
#   'Мы',
#   'В графиках частотного поведения десяти самых частотных (по НЧСРЛ) существительных русского языка колебания кривых незначительны.'],
#  ['Особенности морфологического анализа узбекского языка Моделирование и аранжировка грамматическоих форм узбекского языка.',
#   'билан.',
#   'Вспомогательные слова, выражающие грамматическое значение, представлены как суффиксом, так и словом.'],
#  ['В связи с этим W3C предоставляет список различных инструментов для оценки атрибутов качества [3].',
#   'На данный момент их количество уже также превысило сотню, при этом ни один их них не является универсальным, что не упрощает задачу.',
#   'Она состоит из следующих элементов: стратегия (Strategy), рамки (Scope), структура (Structure), компоновку (Composition) и поверхность (Surface).'],
#  ['Для решения задачи атрибуции текстов хорошо зарекомендовали себя следующие математические методы [12; 13; 14]: нейронные сети, деревья решений, машина опорных векторов (SVG), метод k-средних, метод QSUM, байесовский классификатор, марковские цепи, метод главных компонент, дискриминантный анализ, генетические алгоритмы, статистические критерии (хи-квадрат Пирсона, критерий Стьюдента, Колмогорова-Смирнова) и др. Среди этих методов интеллектуального анализа данных деревья решений выделяются тем, что они просты в понимании и интерпретации, а также не требуют специальной предварительной обработки данных.',
#   'Анализ этих фрагментов показывает, что среди неверно классифицированных фрагментов статей, которые принадлежат другим авторам (не Фёдору Михайловичу Достоевскому), есть и те, что расположены в начале или в конце текста, то есть в его сильных позициях.',
#   'В тексте «Письмо к редактору», автором которого является Я. П. Полонский, («Время», 1863, № 3, код 13) последние три фрагмента имеют другое распределение.'],
#  ['При этом чаще всего веб-документы анализируются как простые текстовые документы, а свойства самого гипертекста не используются, равно как и не используется статистика переходов в нем. Исходя из результатов проведенного анализа исследований в областях кластерного анализа, интеллектуального анализа данных, моделирования гипертекста, веб-аналитики и семантического веба, в данной статье предлагается использование статистики переходов в гипертекстовой структуре и разработка на данной основе моделей и методов семантической кластеризации данной структуры.',
#   'В разработке и проектировании веб-сайтов, разработанные модели и методы могут применяться для решения задач реинжиниринга веб-сайта, реализации рекомендательных механизмов, оптимизации логической структуры веб-сайта с учетом поведения пользователей.',
#   'Предложен метод семантической кластеризации, в котором статистика переходов используется для определения весов в алгоритмах графовой кластеризации, что позволяет эффективно применять данные методы для семантической кластеризации гипертекста.']]

# %%
annotations = []

# %%
for abstr in enumerate(abstracts, start=1):
  print(f'Аннотация статьи {abstr[0]}:')
  annotation = str(' '.join(abstr[1]))
  annotations.append(annotation)
  print(annotation, '\n\n')
# Out:
# Аннотация статьи 1:
# Существует  множество  традиционных  и современных  способов  сбора  отзывов,  которые  используются  в  настоящее  время. Исследователи из Имперского колледжа Лондона собрали комментарии пациентов с сайта NHS Choices за 2008, 2009 и 2011 годы (13802 текста) и применили методы анализа тональности [5]. Эти данные будут  использованы  для  обучения  модели  анализа  тональности.
#
#
# Аннотация статьи 2:
# Анализ онтологии как системы организации знаний дан в работе [2]. Были обработаны формы федерального статистического наблюдения за 2008-2011 годы. Заключение По грантам РГНФ в рамках проекта УИС РОССИЯ разработана основа онтологии предметной области «государственное управление» для содержательной интеграции статистических показателей и аналитических документов.
#
#
# Аннотация статьи 3:
# В целях настоящей работы мы выделим два типа протестов, которые условно назовем стихийные и организованные Стихийные протесты (например, события в Бирюлово в 2012 году) отличаются тем, что протест возникает спонтанно как ответ на какой-либо информационный повод (обычно, происшествие), очаг возникновения локализуется вне социальных сетей, которые, хотя и могут выступать инструментом для координации и мобилизации, не играют существенной роли в моменте образования протеста. Результаты: больше всего свидетельств с пользу репрезентативности выделено для организованных протестов, для стихийных протестов нет релевантной информации, а для выборов заведомо известно, что репрезентативность отсутствует. Именно этот критерий, на наш взгляд, является определяющим для решения задачи предсказания протеста и ее сложности по сравнению с задачей предсказания выборов 6.
#
#
# Аннотация статьи 4:
# для 4.1 Мера MI Отличительной особенностью меры MI оказалось то, что по сравнению с другими мерами она выделила наибольшее количество сочетаний с числительными и местоимениями. Так же в отличие от взаимной информации зафиксировано большое число сочетаний с существительными (23,4% vs 15,7%).
#
#
# Аннотация статьи 5:
# Теоретические предпосылки Теоретическими предпосылками создания Антологии являются три источника: теория совокупности выдающегося русского статистика начала ХХ века А. А. Чупрова, статистические представления русского писателя и ученого А. А. Белого о массовом создании словарей русских писателей и системные представления выдающегося представителя русской формальной школы Ю. Н. Тынянова. После составления списка авторов каталогизируются их произведения. В основе проекта лежат идеи русской формальной школы и прежде всего системные идеи Ю. Н. Тынянова, обеспечивающие представительность авторов и их произведений на основе объективных формальных критериев.
#
#
# Аннотация статьи 6:
# исследования. Мы В графиках частотного поведения десяти самых частотных (по НЧСРЛ) существительных русского языка колебания кривых незначительны.
#
#
# Аннотация статьи 7:
# Особенности морфологического анализа узбекского языка Моделирование и аранжировка грамматическоих форм узбекского языка. билан. Вспомогательные слова, выражающие грамматическое значение, представлены как суффиксом, так и словом.
#
#
# Аннотация статьи 8:
# В связи с этим W3C предоставляет список различных инструментов для оценки атрибутов качества [3]. На данный момент их количество уже также превысило сотню, при этом ни один их них не является универсальным, что не упрощает задачу. Она состоит из следующих элементов: стратегия (Strategy), рамки (Scope), структура (Structure), компоновку (Composition) и поверхность (Surface).
#
#
# Аннотация статьи 9:
# Для решения задачи атрибуции текстов хорошо зарекомендовали себя следующие математические методы [12; 13; 14]: нейронные сети, деревья решений, машина опорных векторов (SVG), метод k-средних, метод QSUM, байесовский классификатор, марковские цепи, метод главных компонент, дискриминантный анализ, генетические алгоритмы, статистические критерии (хи-квадрат Пирсона, критерий Стьюдента, Колмогорова-Смирнова) и др. Среди этих методов интеллектуального анализа данных деревья решений выделяются тем, что они просты в понимании и интерпретации, а также не требуют специальной предварительной обработки данных. Анализ этих фрагментов показывает, что среди неверно классифицированных фрагментов статей, которые принадлежат другим авторам (не Фёдору Михайловичу Достоевскому), есть и те, что расположены в начале или в конце текста, то есть в его сильных позициях. В тексте «Письмо к редактору», автором которого является Я. П. Полонский, («Время», 1863, № 3, код 13) последние три фрагмента имеют другое распределение.
#
#
# Аннотация статьи 10:
# При этом чаще всего веб-документы анализируются как простые текстовые документы, а свойства самого гипертекста не используются, равно как и не используется статистика переходов в нем. Исходя из результатов проведенного анализа исследований в областях кластерного анализа, интеллектуального анализа данных, моделирования гипертекста, веб-аналитики и семантического веба, в данной статье предлагается использование статистики переходов в гипертекстовой структуре и разработка на данной основе моделей и методов семантической кластеризации данной структуры. В разработке и проектировании веб-сайтов, разработанные модели и методы могут применяться для решения задач реинжиниринга веб-сайта, реализации рекомендательных механизмов, оптимизации логической структуры веб-сайта с учетом поведения пользователей. Предложен метод семантической кластеризации, в котором статистика переходов используется для определения весов в алгоритмах графовой кластеризации, что позволяет эффективно применять данные методы для семантической кластеризации гипертекста.
#
#
# Аннотация статьи 11:
# Сравнение средних значений соответствия оценок запоминаемость и благозвучие, соответствие и понятность, благозвучие и выразительность, соответствие и запоминаемость среди всех сфер, аптек, магазинов продуктов и магазинов одежды 4. Рассмотрим среднее значение соответствия оценок запоминаемости и благозвучия после группировки в сферах «Аптеки», «Санатории» (в которые входят санатории и базы отдыха), и «Взрослые поликлиники». В сфере санаториев также используются синонимы к слову природа – 52 нейминга из 70.
#
#
# Аннотация статьи 12:
# Основная задача LI на основе N-грамм состоит в том, чтобы сгенерировать набор частотных профилей N-грамм для каждого языка, который необходимо идентифицировать. В процессе обучения модели на выборке с уникальными словоформами были извлечены 14262 различных 3-граммы. Извлеченные 3-граммы Количество	Покрытие всех 3-грамм Из якутских словоформ	6552	45% Из русских заимствований	11857	83% Рис. 1.

# %%
annots = pd.DataFrame(annotations, columns=['annotations_sumy'])

# %%
sumy = pd.concat([df, annots], join='outer', axis=1)
sumy
# Out:
#                       names  \
# 0       Belkin_IMS_2024_rus
# 1   Bogomolova_IMS_2013_rus
# 2   Filchenkov_IMS_2014_rus
# 3    Khokhlova_IMS_2017_rus
# 4   Martynenko_IMS_2018_rus
# 5     Masevich_IMS_2016_rus
# 6     Mengliev_IMS_2021_rus
# 7     Perminov_IMS_2019_rus
# 8        Rogov_IMS_2020_rus
# 9        Salin_IMS_2015_rus
# 10           Tatur_IMS_2023
# 11          Vissio_IMS_2022
#
#                                                 texts years  \
# 0   1. Введение По  мере  стремительного  развития...  _rus
# 1   УИС РОССИЯ: эксперимент по реализации онтологи...  _rus
# 2   Компаративный анализ методологических основ за...  _rus
# 3   Сопоставительный анализ статистических мер\nна...  _rus
# 4   Методологические проблемы создания Компьютерно...  _rus
# 5   Методы корпусной лингвистики в исторических\nи...  _rus
# 6   Структура и единицы морфоанализатора узбекског...  _rus
# 7   Интеграция инструментов и сервисов для оценки ...  _rus
# 8   Применение деревьев решений для анализа сильны...  _rus
# 9   Семантическая сегментация веб-гипертекста на\n...  _rus
# 10  Выявление скрытых закономерностей в реакции об...  2023
# 11  Выделение русских заимствований в якутских тек...  2022
#
#                                      annotations_sumy
# 0   Существует  множество  традиционных  и совреме...
# 1   Анализ онтологии как системы организации знани...
# 2   В целях настоящей работы мы выделим два типа п...
# 3   для 4.1 Мера MI Отличительной особенностью мер...
# 4   Теоретические предпосылки Теоретическими предп...
# 5   исследования. Мы В графиках частотного поведен...
# 6   Особенности морфологического анализа узбекског...
# 7   В связи с этим W3C предоставляет список различ...
# 8   Для решения задачи атрибуции текстов хорошо за...
# 9   При этом чаще всего веб-документы анализируютс...
# 10  Сравнение средних значений соответствия оценок...
# 11  Основная задача LI на основе N-грамм состоит в...

# %% [markdown]
# T5

# %%
from transformers import AutoModelForSeq2SeqLM, T5TokenizerFast

# %%
import torch
from transformers import AutoTokenizer, AutoModelWithLMHead, T5ForConditionalGeneration

# %% [markdown]
# RuT5-base-sum

# %%
model_name = "IlyaGusev/rut5_base_sum_gazeta"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/279 [00:00<?, ?B/s]
# C:\Users\sasha\anaconda3\envs\py39\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\sasha\.cache\huggingface\hub\models--IlyaGusev--rut5_base_sum_gazeta. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# spiece.model:   0%|          | 0.00/828k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/766 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/977M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/977M [00:00<?, ?B/s]

# %%
for i, text in enumerate (df.texts[:10]):
  article_text = text
  input_ids = tokenizer([article_text], max_length=600, add_special_tokens=True, padding="max_length", truncation=True, return_tensors="pt")["input_ids"]
  output_ids = model.generate(input_ids=input_ids, no_repeat_ngram_size=4)[0]
  summary = tokenizer.decode(output_ids, skip_special_tokens=True)
  print(f'Аннотация текста {i+1}:\n {summary}\n\n')
# Out:
# Аннотация текста 1:
#  Пользователи интернет-платформы, социальные сети, форумы и т.д. дают возможность оценивать степень удовлетворенности в баллах от 1 до 5, а также выяснить, какие эмоции выражают пользователи.
#
#
# Аннотация текста 2:
#  Российские ученые и исследователи проводят эксперимент по реализации онтологии предметной области «государственное управление» для поиска в базах данных и по аналитическим публикациям.
#
#
# Аннотация текста 3:
#  Задача прогнозирования исходов выборов и протестов по цифровым следам пользователей в социальных сетях является фундаментальной научной задачей политологии. В данной работе будет проведен компаративный анализ методологических основ двух указанных задач, на основе чего будут указаны потенциальные трудности и ограничения, связанные с прогнозированием протестной активности.
#
#
# Аннотация текста 4:
#  Статистические метрики позволяют вычислять силу связанности словосочетаний в текстах. Это позволяет вычислить устойчивость лексических единиц, позволяющих расположить их на шкале.
#
#
# Аннотация текста 5:
#  Компьютерная антология русского рассказа как языковой ресурс для исследования языка и стиля русской художественной прозы в эпоху революционных перемен (первой трети XX века).
#
#
# Аннотация текста 6:
#  Методы корпусной лингвистики в исторических и культурологических исследованиях можно рассматривать как вариант контент-анализа большого массива текстов.
#
#
# Аннотация текста 7:
#  Структура и единицы морфоанализатора узбекского языка можно представить в виде следующей схемы. Основные компоненты МА могут сильно варьироваться в зависимости от языка и от конкретной реализации.
#
#
# Аннотация текста 8:
#  Интеграция инструментов и сервисов для оценки веб-интерфейсов пользователя и выявления юзабилити рисков в Новосибирском государственном техническом университете. В данной работе рассматриваются разновидности пользовательских интерфейсов, которые представляют собой совокупность средств и методов для взаимодействия пользователя с вычислительными устройствами.
#
#
# Аннотация текста 9:
#  В работе «Атрибуция произведений Ф. М. Достоевского» представлены деревьев решений для анализа сильных позиций текста на фоне массива текстов художественной литературы.
#
#
# Аннотация текста 10:
#  Саратовский государственный технический университет им. Ю.А. Гагарина опубликовал исследования в области кластеризации гипертекстовых документов на основе дискретных математических моделей. Для решения этих задач наиболее просто применить методы непосредственного определения ключевых слов и понятий текста.

# %%
annotations_t5 = []

for text in df.texts:
  article_text = text
  input_ids = tokenizer([article_text], max_length=600, add_special_tokens=True, padding="max_length", truncation=True, return_tensors="pt")["input_ids"]
  output_ids = model.generate(input_ids=input_ids, min_length=50, max_length=250, no_repeat_ngram_size=4)[0]
  summary = tokenizer.decode(output_ids, skip_special_tokens=True)
  print(f'Аннотация текста:\n {summary}\n\n')
  annotations_t5.append(str(''.join(summary)))
# Out:
# Аннотация текста:
#  Пользователи интернет-платформы, социальные сети, форумы и т.д. дают возможность оценивать степень удовлетворенности в баллах от 1 до 5, а также выяснить, какие эмоции выражают пользователи.
#
#
# Аннотация текста:
#  Российские ученые и исследователи проводят эксперимент по реализации онтологии предметной области «государственное управление» для поиска в базах данных и по аналитическим публикациям. Эксперты считают, что такой подход стимулирует научные исследования и повышает эффективность государственного управления.
#
#
# Аннотация текста:
#  Задача прогнозирования исходов выборов и протестов по цифровым следам пользователей в социальных сетях является фундаментальной научной задачей политологии. В данной работе будет проведен компаративный анализ методологических основ двух указанных задач, на основе чего будут указаны потенциальные трудности и ограничения, связанные с прогнозированием протестной активности.
#
#
# Аннотация текста:
#  Статистические метрики позволяют вычислять силу связанности словосочетаний в текстах. Это позволяет вычислить устойчивость лексических единиц, позволяющих расположить их на шкале.
#
#
# Аннотация текста:
#  Компьютерная антология русского рассказа как языковой ресурс для исследования языка и стиля русской художественной прозы в эпоху революционных перемен (первой трети XX века) — одна из самых драматических эпох русской истории.
#
#
# Аннотация текста:
#  Методы корпусной лингвистики в исторических и культурологических исследованиях можно рассматривать как вариант контент-анализа большого массива текстов, используя математический аппарат для интерпретации выявленных числовых закономерностей.
#
#
# Аннотация текста:
#  Структура и единицы морфоанализатора узбекского языка можно представить в виде следующей схемы. Основные компоненты МА могут сильно варьироваться в зависимости от языка и от конкретной реализации.
#
#
# Аннотация текста:
#  Интеграция инструментов и сервисов для оценки веб-интерфейсов пользователя и выявления юзабилити рисков в Новосибирском государственном техническом университете. В данной работе рассматриваются разновидности пользовательских интерфейсов, которые представляют собой совокупность средств и методов для взаимодействия пользователя с вычислительными устройствами.
#
#
# Аннотация текста:
#  В работе «Атрибуция произведений Ф. М. Достоевского» представлены деревьев решений для анализа сильных позиций текста на фоне массива текстов художественной литературы. Это позволит определить, какие особенности воплощаются в произведениях конкретного автора.
#
#
# Аннотация текста:
#  Саратовский государственный технический университет им. Ю.А. Гагарина опубликовал исследования в области кластеризации гипертекстовых документов на основе дискретных математических моделей. Для решения этих задач наиболее просто применить методы непосредственного определения ключевых слов и понятий текста.
#
#
# Аннотация текста:
#  Название бренда является одним из возможных способов привлечения внимания клиента к компании, а также может вызывать ассоциации, чувства и атмосферу. Название является базовым атрибутом маркетинга, который оказывает прямое влияние на возможность выхода торговой марки на рынок и успешность ее продвижения.
#
#
# Аннотация текста:
#  Введение русских заимствований в якутских текстах — одна из основных источников новых терминов и имен собственных в якутском языке. Однако, по мнению авторов, русский язык до сих пор является важным источником новых имен собственных.

# %%
annots_t5 = pd.DataFrame(annotations_t5, columns=['annotations_t5'])

# %%
full = pd.concat([sumy, annots_t5], join='outer', axis=1)
full
# Out:
#                   names                                              texts  \
# 0       Adrova_IMS_2013  Исследование алгоритмов хеширования, используе...
# 1   Balakshina_IMS_2014  Перспективы развития электронного взаимодейств...
# 2    Erkimbaev_IMS_2015  Онтология предметной области «Наноматериалы\nи...
# 3  Godgildieva_IMS_2016  Создание словаря валентностей русского языка\n...
# 4    Khokhlova_IMS_2017  Сопоставительный анализ статистических мер\nна...
# 5   Martynenko_IMS_2018  Методологические проблемы создания Компьютерно...
# 6     Perminov_IMS_2019  Интеграция инструментов и сервисов для оценки ...
# 7     Sokolova_IMS_2020  К вопросу о формировании набора отношений для ...
# 8       Vissio_IMS_2022  Выделение русских заимствований в якутских тек...
# 9    Vybornaya_IMS_2024  1. ВведениеДанная статья основана на результат...
#
#   years                                   annotations_sumy  \
# 0  2013  Анализ времени работы стандартных алгоритмов х...
# 1  2014  Основной целью разработки УФЭБС являлась станд...
# 2  2015  В качестве альтернативы для нано-объектов можн...
# 3  2016  Более того, Теньер разделил глаголы на группы ...
# 4  2017  для 4.1 Мера MI Отличительной особенностью мер...
# 5  2018  Теоретические предпосылки Теоретическими предп...
# 6  2019  В связи с этим W3C предоставляет список различ...
# 7  2020  Обобщение типов похожих риторических отношений...
# 8  2022  Основная задача LI на основе N-грамм состоит в...
# 9  2024  При  этом  как  каузатив,  так и квалификатив ...
#
#                                       annotations_t5
# 0  Для решения проблемы хранения пароля пользоват...
# 1  Взаимодействие между кредитными организациями ...
# 2  Онтология предметной области «Наноматериалы и ...
# 3  Создание словаря валентностей русского языка н...
# 4  Статистические метрики позволяют вычислять сил...
# 5  Компьютерная антология русского рассказа как я...
# 6  Интеграция инструментов и сервисов для оценки ...
# 7  Корпусы с дискурсивной разметкой текста станов...
# 8  Введение русских заимствований в якутских текс...
# 9  Предлоги и предложные конструкции могут быть п...

# %%
full.to_csv('summarization.csv')

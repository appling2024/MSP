# %% [markdown]
# Выбрать данные (существительные из ЛСГ названий инструментов, речевых действий или названий эмоций)
#
#
# https://disk.yandex.ru/d/xkUyYOby_vRxig
#
#
#
# И/ИЛИ теги семантических ролей в проекте FrameBank
# GitHub - olesar/framebank: Russian FrameBank offline resources
#
# Изучить формат разметки
#
# Написать код для выполнения следующих операций:
#
# а) поиск контекстов по заданному токену (например, взглядом)
#
# б) поиск контекстов по заданной лемме (например, взгляд)
#
# в) поиск контекстов по заданному семантическому тегу (например, r:concr) и/или комбинации тегов  (например, r:concr t:tool)
#
# г) поиск контекстов по заданному тегу семантической роли (например, framebank/framebank_roles.txt at master · olesar/framebank · GitHub)
#
# д) подсчет частотности токенов, лемм, тегов, комбинаций тегов
#
# е) вывод результатов в ячейку или сохранение в файл

# %%
#скачиваем корпус с Гитхаба
import requests

url = 'https://raw.githubusercontent.com/olesar/framebank/refs/heads/master/framebank_anno_ex_items.txt'
file_name = 'framebank_anno_ex_items.txt'

response = requests.get(url)

if response.status_code == 200:
  with open('framebank_anno_ex_items.txt', 'wb') as file:
    file.write(response.content)
  print('+')
else:
  print('-')
# Out:
# +

# %%
import pandas as pd
import random

# %%
with open('nozhnitsy.txt', 'r', encoding = 'utf-8') as f: #здесь мы выбираем конкретный файл с данными nozhnitsy.txt (кодировку поменяли)
  file = f.read()

parts = file.split('<w><ana')

with open('output.txt', 'w', encoding='utf-8') as f:
    for i in enumerate(parts):
        f.write(f"{i}\n")

# %% [markdown]
# Поиск по токену

# %%
#import pandas as pd
#import random

def load_data(file_path):
  data = pd.read_csv(file_path, sep='\t')
  return data

def find_by_token(data, token): #поиск по токену
  filtered_data = data[data['WordDep'] == token]
  return filtered_data

def main():
    file_path = '/content/framebank_anno_ex_items.txt'
    token_to_search = input()
    print(f'Токен для поиска: {token_to_search}')

    data_token = load_data(file_path)

    results_token = find_by_token(data_token, token_to_search)

    if results_token.empty:
        print(f'Не найдено словоупотреблений с токеном: {token_to_search}')
    else:
      print(f'Найденные словоупотребления с токеном: "{token_to_search}":')
      print(results_token)
      print(f'\nВсего найдено словоупотреблений: {len(results_token)}')

      output_file_path = 'results_token.txt'  # Путь к итоговому файлу, можно изменить
      results_token.to_csv(output_file_path, sep='\t', index=False)  # Сохраняем результаты
      #print(f'Результаты сохранены в файл: {output_file_path}')

if __name__ == "__main__":
    main()
# Out:
# зубы
# Токен для поиска: зубы
# Найденные словоупотребления с токеном: "зубы":
#        ConstrIndex  ExIndex  Place                       PhraseGen WordDep  \
# 1            11467    35300      2                            зубы    зубы
# 1351          1064   106458      3                            зубы    зубы
# 6461         11542    41378      1                            зубы    зубы
# 30412        18449   137616      3  великолепные американские зубы    зубы
# 87002        11312   106357      3                            зубы    зубы
# 87005        11312   106360      3                            зубы    зубы
# 87008        11312   106363      3                            зубы    зубы
# 87050        11312   106383      3                            зубы    зубы
# 87053        11312   106384      3                            зубы    зубы
# 87062        11312   106398      3                            зубы    зубы
# 87098        11312   106425      3                            зубы    зубы
# 87101        11312   106426      3                            зубы    зубы
# 87119        11313   106374      3                            зубы    зубы
# 87123        11313   106407      3                            зубы    зубы
# 87135        11313   106424      3                            зубы    зубы
# 87143        11314   106344      3                            зубы    зубы
# 87159        11314   106415      3                            зубы    зубы
# 97437        11537    36501      3                            зубы    зубы
# 97440        11537    36531      3                      новые зубы    зубы
#
#        Form                        Role                    Rank  \
# 1         S           носитель признака  Контролер согласования
# 1351   Sacc       потенциальный пациенс                  Объект
# 6461   Snom                       агенс           Несобственный
# 30412  Sacc  ситуация в фокусе - стимул                  Объект
# 87002  Sacc                     пациенс                  Объект
# 87005  Sacc                     пациенс                  Объект
# 87008  Sacc                     пациенс                  Объект
# 87050  Sacc                     пациенс                  Объект
# 87053  Sacc                     пациенс                  Объект
# 87062  Sacc                     пациенс                  Объект
# 87098  Sacc                     пациенс                  Объект
# 87101  Sacc                     пациенс                  Объект
# 87119  Sacc                     пациенс                  Объект
# 87123  Sacc                     пациенс                  Объект
# 87135  Sacc                     пациенс                  Объект
# 87143  Sacc                     пациенс                  Объект
# 87159  Sacc                     пациенс                  Объект
# 97437  Sacc                        тема                  Объект
# 97440  Snom                        тема                 Субъект
#
#                   Sem          Rea  ConstrExId ItemExIndex  \
# 1                   -  стандартный        1452        5164
# 1351   неодушевленный  стандартный       29263       81313
# 6461       часть тела    сочинение        4092       13227
# 30412               -  стандартный       16964      115431
# 87002               -  стандартный       27724       76582
# 87005               -  стандартный       27727       76591
# 87008               -  стандартный       27729       76597
# 87050               -  стандартный       27747       76652
# 87053               -  стандартный       27748       76655
# 87062               -  стандартный       27761       76695
# 87098               -  стандартный       27805       76848
# 87101               -  стандартный       27806       76851
# 87119               -  стандартный       27738       76624
# 87123               -  стандартный       27787       76782
# 87135               -  стандартный       27804       76844
# 87143               -  стандартный       27713       76546
# 87159               -  стандартный       27796       76817
# 97437  неодушевленный  стандартный        2677       99660
# 97440  неодушевленный  стандартный        2708      100062
#
#                                               KeyLexemes
# 1      адъективные_конструкции,близкий,верный,достове...
# 1351                                      беречь,сберечь
# 6461                                          брызгаться
# 30412                 демонстрировать,продемонстрировать
# 87002                                  почистить,чистить
# 87005                                  почистить,чистить
# 87008                                  почистить,чистить
# 87050                                  почистить,чистить
# 87053                                  почистить,чистить
# 87062                                  почистить,чистить
# 87098                                  почистить,чистить
# 87101                                  почистить,чистить
# 87119                                  почистить,чистить
# 87123                                  почистить,чистить
# 87135                                  почистить,чистить
# 87143                                  почистить,чистить
# 87159                                  почистить,чистить
# 97437                                        прорезаться
# 97440                                        прорезаться
#
# Всего найдено словоупотреблений: 19
# <ipython-input-25-0f0e1d8250e1>:5: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, sep='\t')

# %% [markdown]
# поиск контекстов по заданной лемме (например, взгляд)

# %%
with open('nozhnitsy.txt', 'r', encoding = 'utf-8') as f: #здесь мы выбираем конкретный файл с данными nozhnitsy.txt (кодировку поменяли)
  file = f.read()

parts = file.split('<w><ana')

with open('output.txt', 'w', encoding='utf-8') as f:
    for i in enumerate(parts):
        f.write(f"{i}\n")

# %%
def search_corpus(file_path, search_lemma):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    results = []

    for index, line in enumerate(lines):
        if search_lemma in line:
            results.append(f"{index + 1}: {line.strip()}")

    if results:
        print("Найденные словоупотребления:")
        for result in results:
            print(result)
    else:
        print("Словоупотребления с такой леммой не найдены.")

    print(f'\nВсего найдено словоупотреблений: {len(results)}')

    #сохранение в файл
    with open('results_lemma.txt', 'w', encoding='utf-8') as f:
        f.write(result)


file_path = 'output.txt'
search_lemma = "lex='Вырезать' " #тег вводим вручную

search_corpus(file_path, search_lemma)
# Out:
# Найденные словоупотребления:
# 2: (1, " lex='Вырезать' gr='V,norm=(sg,partcp,brev,m,ipf,pass,praes|pl,indic,1p,ipf,praes,act,indic)' sem='t:impact ca:caus d:pref der:v'/>Вырезаем</w> ")
# 4472: (4471, " lex='Вырезать' gr='V,norm=(praet,pl,indic,pf,act,indic|praet,pl,indic,ipf,act,indic)' sem='t:impact ca:caus d:pref der:v'/>Вырезали</w> \t")
# 9655: (9654, " lex='Вырезать' gr='V,norm=(gen,sg,partcp,m,ipf,praes,plen,act|gen,sg,partcp,n,ipf,praes,plen,act|acc,sg,partcp,m,ipf,anim,praes,plen,act)' sem='t:impact ca:caus d:pref der:v'/>Вырезающего</w> - ")
# 12065: (12064, " lex='Вырезать' gr='V,norm=praet,pl,indic,ipf,med,indic' sem='t:impact ca:caus d:pref der:v'/>Вырезались</w> ")
#
# Всего найдено словоупотреблений: 4

# %% [markdown]
# Поиск контекстов по заданному тегу семантической роли

# %%
import pandas as pd
import random

def load_data(file_path):
  data = pd.read_csv(file_path, sep='\t')
  return data

def find_by_role(data, role): #поиск контекстов по заданному семантической роли (например, атрибут)
  filtered_data = data[data['Role'] == role]
  return filtered_data

def main():
    file_path = '/content/framebank_anno_ex_items.txt'
    role_to_search = input()
    print(f'Роль для поиска: {role_to_search}')

    data_role = load_data(file_path)

    results_role = find_by_role(data_role, role_to_search)

    if results_role.empty:
        print(f'Не найдено словоупотреблений с ролью: {role_to_search}')
    else:
      print(f'Найденные словоупотребления с ролью "{role_to_search}":')
      print(results_role)
      print(f'\nВсего найдено словоупотреблений: {len(results_role)}')

      output_file_path = 'results_role.txt'  # Путь к итоговому файлу, можно изменить
      results_role.to_csv(output_file_path, sep='\t', index=False)  # Сохраняем результаты
      #print(f'Результаты сохранены в файл: {output_file_path}')

if __name__ == "__main__":
    main()
# Out:
# обладаемое
# Роль для поиска: обладаемое
# Найденные словоупотребления с ролью "обладаемое":
#     ConstrIndex  ExIndex  Place PhraseGen  WordDep  Form        Role  \
# 14        11538    40978      3   «львов»  «львов»  Sgen  обладаемое
#
#          Rank Sem          Rea  ConstrExId ItemExIndex KeyLexemes
# 14  Периферия   -  стандартный        3286       91965     алкать
#
# Всего найдено словоупотреблений: 1
# <ipython-input-30-5f12a0e69ee8>:5: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, sep='\t')

# %% [markdown]
# Поиск контекстов по заданному семантическому тегу (например, r:concr) и/или комбинации тегов  (например, r:concr t:tool)

# %%
def search_corpus(file_path, search_tag):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    results = []

    for index, line in enumerate(lines):
        if search_tag in line:
            results.append(f"{index + 1}: {line.strip()}")

    if results:
        print("Найденные словоупотребления:")
        for result in results:
            print(result)
    else:
        print("Словоупотребления с таким тегом не найдены.")

    print(f'\nВсего найдено словоупотреблений: {len(results)}')

    #сохранение в файл
    with open('results_tag.txt', 'w', encoding='utf-8') as f:
        f.write(result)


file_path = 'output.txt'
search_tag = "sem='r:concr pt:qtm pc:stuff top:stripe d:dim der:s " #тег вводим вручную

search_corpus(file_path, search_tag)
# Out:
# Найденные словоупотребления:
# 138: (137, " lex='полоска' gr='S,f,inan,norm=nom,sg' sem='r:concr pt:qtm pc:stuff top:stripe d:dim der:s '/>полоска</w> ")
# 10051: (10050, " lex='полоска' gr='S,f,inan,norm=acc,sg' sem='r:concr pt:qtm pc:stuff top:stripe d:dim der:s '/>полоску</w> ")
#
# Всего найдено словоупотреблений: 2

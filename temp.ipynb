# %%
import nltk

# %%
from nltk import word_tokenize

# %%
with open('белые ночи.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
len(text), len(text.split())
# Out:
# (11861, 1907)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
tokenized_text_nltk = word_tokenize(text, language='russian')
tokenized_text_nltk
# Out:
# ['Была',
#  'чудная',
#  'ночь',
#  ',',
#  'такая',
#  'ночь',
#  ',',
#  'которая',
#  'разве',
#  'только',
#  'и',
#  'может',
#  'быть',
#  'тогда',
#  ',',
#  'когда',
#  'мы',
#  'молоды',
#  ',',
#  'любезный',
#  'читатель',
#  '.',
#  'Небо',
#  'было',
#  'такое',
#  'звездное',
#  ',',
#  'такое',
#  'светлое',
#  'небо',
#  ',',
#  'что',
#  ',',
#  'взглянув',
#  'на',
#  'него',
#  ',',
#  'невольно',
#  'нужно',
#  'было',
#  'спросить',
#  'себя',
#  ':',
#  'неужели',
#  'же',
#  'могут',
#  'жить',
#  'под',
#  'таким',
#  'небом',
#  'разные',
#  'сердитые',
#  'и',
#  'капризные',
#  'люди',
#  '?',
#  'Это',
#  'тоже',
#  'молодой',
#  'вопрос',
#  ',',
#  'любезный',
#  'читатель',
#  ',',
#  'очень',
#  'молодой',
#  ',',
#  'но',
#  'пошли',
#  'его',
#  'вам',
#  'господь',
#  'чаще',
#  'на',
#  'душу',
#  '!',
#  '..',
#  'Говоря',
#  'о',
#  'капризных',
#  'и',
#  'разных',
#  'сердитых',
#  'господах',
#  ',',
#  'я',
#  'не',
#  'мог',
#  'не',
# ...

# %%
tokenized_nltk = []
for token in tokenize(text):
    tokenized_nltk.append(token.text)

# %%
with open('tokenized_nltk.txt', 'w', encoding='utf-8') as f:
    for token in tokenized_nltk:
        f.write(token)
        f.write('\n')

# %%
import razdel

# %%
import stanza
stanza.download('ru')
# Out:
# ...
# 2024-09-16 16:23:20 INFO: Downloaded file to C:\Users\User\stanza_resources\resources.json
# 2024-09-16 16:23:20 INFO: Downloading default packages for language: ru (Russian) ...
# 2024-09-16 16:23:24 INFO: File exists: C:\Users\User\stanza_resources\ru\default.zip
# 2024-09-16 16:23:32 INFO: Finished downloading models and saved to C:\Users\User\stanza_resources

# %%
nlp = stanza.Pipeline(lang='ru', processors='tokenize', verborse=False)
# Out:
# 2024-09-16 16:23:32 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# 2024-09-16 16:23:33 INFO: Downloaded file to C:\Users\User\stanza_resources\resources.json
# 2024-09-16 16:23:33 INFO: Loading these models for language: ru (Russian):
# ...
# | Processor | Package   |
# -------------------------
# | tokenize  | syntagrus |
# ...
#
# 2024-09-16 16:23:33 INFO: Using device: cpu
# 2024-09-16 16:23:33 INFO: Loading: tokenize
# ...

# %%
tokenized_text=nlp.process(text)

# %%
tokens_stanza = []
for token in nlp(text).iter_tokens():
    tokens_stanza.append(token.text)

# %%
tokenized_stanza = []
for token in nlp(text).iter_tokens():
    tokenized_stanza.append(token.text)

# %%
with open('tokenized_stanza.txt', 'w', encoding='utf-8') as f:
    for token in tokenized_stanza:
        f.write(token)
        f.write('\n')

# %%
from razdel import tokenize

# %%
tokenized_razdel = []
for token in tokenize(text):
    tokenized_razdel.append(token.text)

# %%
with open('tokenized_razdel.txt', 'w', encoding='utf-8') as f:
    for token in tokenized_razdel:
        f.write(token)
        f.write('\n')

# %%
# !pip install segtok

# %%
from segtok.tokenizer import web_tokenizer

# %%
tokenized_segtok = web_tokenizer(text)

# %%
with open('tokenized_segtok.txt', 'w', encoding='utf-8') as f:
    for token in tokenized_segtok:
        f.write(token)
        f.write('\n')

# %%
import spacy

# %%
import spacy
nlp = spacy.load('ru_core_news_sm')

# %%
doc = nlp(text)
with open('tokenized_spacy.txt', 'w', encoding='utf-8') as f:
    for token in doc:
        f.write(token.text)
        f.write('\n')

# %%
tokenized_spacy = []
for token in doc:
    tokenized_spacy.append(token.text)

# %%
pip install pymorphy3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymorphy3.tokenizers import simple_word_tokenize
tokenize_pymorphy3 = simple_word_tokenize(text)

# %%
with open('tokenize_pymorphy3.txt', 'w', encoding='utf-8') as f:
    for token in tokenize_pymorphy3:
        f.write(token)
        f.write('\n')

# %%
lens = [len(tokenized_nltk), len(tokenized_razdel), len(tokenized_segtok), len(tokenized_spacy), len(tokenize_pymorphy3), len(tokenized_stanza)]

# %%
m = max(lens)
print(m)
print([m-1 for l in lens])
# Out:
# 2384
# [2383, 2383, 2383, 2383, 2383, 2383]

# %% [markdown]
# # Загружаем текст из файла

# %%
with open('brusov.txt', encoding='windows-1251') as f:
    brusov_text = f.read()

# %%
import pandas as pd

# %% [markdown]
# # Pymorphy3

# %%
from pymorphy3 import MorphAnalyzer

# %%
morph = MorphAnalyzer()

# %%
from pymorphy3.tokenizers import simple_word_tokenize

# %%
morph = MorphAnalyzer()

# %%
brusov_tokenized_pymorphy = simple_word_tokenize(brusov_text)
brusov_tokenized_pymorphy
# Out:
# ['В',
#  '.',
#  'Я',
#  '.',
#  'БРЮСОВ',
#  'На',
#  'пруду',
#  'Ты',
#  'белых',
#  'лебедей',
#  'кормила',
#  ',',
#  'Откинув',
#  'тяжесть',
#  'черных',
#  'кос',
#  '…',
#  'Я',
#  'рядом',
#  'плыл',
#  ';',
#  'сошлись',
#  'кормила',
#  ';',
#  'Закатный',
#  'луч',
#  'был',
#  'странно-кос',
#  '.',
#  'По',
#  'небу',
#  'полосы',
#  'синели',
#  ',',
#  'Вечеровой',
#  'багрец',
#  'кроя',
#  ';',
#  'В',
#  'цветах',
#  'черемух',
#  'и',
#  'синели',
#  'Скрывались',
#  'водные',
#  'края',
#  '.',
#  'Все',
#  'формы',
#  'были',
#  'строго-четки',
#  ',',
#  'Миг',
#  'ранил',
#  'сердце',
#  'сотней',
#  'жал',
#  '…',
#  'Я',
#  ',',
#  'как',
#  'аскет',
#  'сжимает',
#  'четки',
#  ',',
#  'В',
#  'руке',
#  'весло',
#  'невольно',
#  'жал',
#  '.',
#  'Вдруг',
#  'лебедей',
#  'метнулась',
#  'пара',
#  '…',
#  'Не',
#  'знаю',
#  ',',
#  'чья',
#  'была',
#  'вина',
#  '…',
#  'Закат',
#  'замлел',
#  'за',
#  'дымкой',
#  'пара',
#  ',',
#  'Алея',
#  ',',
#  'как',
#  'поток',
#  'вина',
#  '.',
#  'Была',
#  'то',
#  'правда',
#  'ли',
#  ',',
#  'мечта',
#  'ли',
#  ',',
#  '—',
#  'Уста',
#  'двоих',
#  'слились',
#  'в',
#  'одно',
#  '.',
#  'Две',
#  'лодки',
#  ',',
#  'как',
#  'и',
#  'мы',
#  ',',
#  'мечтали',
#  ',',
#  'Как',
#  'будто',
#  'вонзены',
#  'во',
#  'дно',
#  '.',
#  'Я',
#  'свято',
#  'помню',
#  'эту',
#  'встречу',
#  ':',
#  'Пруд',
#  ',',
#  'берег',
#  ',',
#  'неба',
#  'яркий',
#  'плат',
#  '…',
#  'Миг',
#  'тот',
#  'же',
#  'если',
#  'вновь',
#  'я',
#  'встречу',
#  ',',
#  '—',
#  'И',
#  'жизнь',
#  'ничтожная',
#  'из',
#  'плат',
#  '!',
#  '12',
#  'декабря',
#  '1914']

# %%
brusov_tokenized_pymorphy = simple_word_tokenize(brusov_text)
for token in brusov_tokenized_pymorphy:
    parsed_token = morph.parse(token)
    print('{:3}\t{:10}\t{:50}'.format(len(parsed_token), parsed_token[0].word, parsed_token[0].tag._str))
# Out:
#  37	в         	PREP
#   1	.         	PNCT
#  25	я         	NPRO,1per sing,nomn
#   1	.         	PNCT
#   3	брюсов    	NOUN,anim,masc,Sgtm,Surn sing,nomn
#   3	на        	PREP
#   2	пруду     	NOUN,inan,masc sing,datv
#   1	ты        	NPRO,2per sing,nomn
#  20	белых     	ADJF,Qual plur,gent
#   2	лебедей   	NOUN,anim,masc plur,gent
#   4	кормила   	VERB,impf,tran femn,sing,past,indc
#   1	,         	PNCT
#   1	откинув   	GRND,perf,tran past
#   2	тяжесть   	NOUN,inan,femn sing,accs
#  18	чёрных    	ADJF,Qual plur,gent
#   4	кос       	NOUN,inan,femn plur,gent
#   1	…         	PNCT
#  25	я         	NPRO,1per sing,nomn
#   2	рядом     	ADVB,Prdx
#   1	плыл      	VERB,impf,intr masc,sing,past,indc
#   1	;         	PNCT
#   2	сошлись   	VERB,perf,intr plur,past,indc
#   4	кормила   	VERB,impf,tran femn,sing,past,indc
#   1	;         	PNCT
#   2	закатный  	ADJF,Qual masc,sing,nomn
#   2	луч       	NOUN,inan,masc sing,nomn
#   1	был       	VERB,impf,intr masc,sing,past,indc
#   5	странно-кос	ADJS,Qual neut,sing
#   1	.         	PNCT
#  19	по        	PREP
#   2	небу      	NOUN,inan,neut sing,datv
#   3	полосы    	NOUN,inan,femn sing,gent
#   6	синели    	NOUN,inan,femn sing,gent
#   1	,         	PNCT
#   9	вечеровой 	NOUN,anim,femn,Sgtm,Surn sing,gent
#   2	багрец    	NOUN,inan,masc sing,nomn
#   3	кроя      	NOUN,inan,masc sing,gent
#   1	;         	PNCT
#  37	в         	PREP
#   3	цветах    	NOUN,anim,femn,Name plur,loct
#   1	черёмух   	NOUN,inan,femn plur,gent
#  15	и         	CONJ
#   6	синели    	NOUN,inan,femn sing,gent
#   1	скрывались	VERB,impf,intr plur,past,indc
#   2	водные    	ADJF,Qual inan,plur,accs
#   3	края      	NOUN,inan,masc sing,gent
#   1	.         	PNCT
#   5	всё       	PRCL
#   3	формы     	NOUN,inan,femn sing,gent
#   6	были      	VERB,impf,intr plur,past,indc
#   3	строго-чётки	NOUN,inan,GNdr,Pltm plur,nomn
#   1	,         	PNCT
#   2	миг       	NOUN,inan,masc sing,accs
#   2	ранил     	VERB,perf,tran masc,sing,past,indc
#   3	сердце    	NOUN,inan,neut sing,accs
#   1	сотней    	NOUN,inan,femn sing,ablt
#   3	жал       	NOUN,inan,neut plur,gent
#   1	…         	PNCT
#  25	я         	NPRO,1per sing,nomn
#   1	,         	PNCT
#   3	как       	CONJ
#   1	аскет     	NOUN,anim,masc sing,nomn
#   1	сжимает   	VERB,impf,tran sing,3per,pres,indc
#   3	чётки     	NOUN,inan,GNdr,Pltm plur,nomn
#   1	,         	PNCT
#  37	в         	PREP
#   2	руке      	NOUN,inan,femn sing,loct
#   2	весло     	NOUN,inan,neut sing,nomn
#   2	невольно  	ADVB
#   3	жал       	NOUN,inan,neut plur,gent
#   1	.         	PNCT
#   1	вдруг     	ADVB
#   2	лебедей   	NOUN,anim,masc plur,gent
#   1	метнулась 	VERB,perf,intr femn,sing,past,indc
#   3	пара      	NOUN,inan,femn sing,nomn
#   1	…         	PNCT
#   1	не        	PRCL
#   1	знаю      	VERB,impf,tran sing,1per,pres,indc
#   1	,         	PNCT
#   1	чья       	ADJF,Apro femn,sing,nomn
#   1	была      	VERB,impf,intr femn,sing,past,indc
#   4	вина      	NOUN,inan,neut sing,gent
#   1	…         	PNCT
#   2	закат     	NOUN,inan,masc sing,nomn
#   1	замлел    	VERB,perf,intr masc,sing,past,indc
#   1	за        	PREP
#   1	дымкой    	NOUN,inan,femn sing,ablt
#   3	пара      	NOUN,inan,femn sing,nomn
#   1	,         	PNCT
#   5	алея      	GRND,impf,intr pres
#   1	,         	PNCT
#   3	как       	CONJ
#   2	поток     	NOUN,inan,masc sing,nomn
#   4	вина      	NOUN,inan,neut sing,gent
#   1	.         	PNCT
#   1	была      	VERB,impf,intr femn,sing,past,indc
#   4	то        	CONJ
#   3	правда    	PRCL
#  20	ли        	CONJ
#   1	,         	PNCT
#   1	мечта     	NOUN,inan,femn sing,nomn
#  20	ли        	CONJ
#   1	,         	PNCT
#   1	—         	PNCT
#   3	уста      	NOUN,inan,GNdr,Pltm plur,accs
#   3	двоих     	NUMR,Coll anim,accs
#   1	слились   	VERB,perf,intr plur,past,indc
#  13	в         	PREP
#   2	одно      	ADJF,Apro,Anum neut,sing,accs
#   1	.         	PNCT
#   2	две       	NUMR inan,femn,accs
#   3	лодки     	NOUN,inan,femn plur,nomn
#   1	,         	PNCT
#   3	как       	CONJ
#  15	и         	CONJ
#   1	мы        	NPRO,1per plur,nomn
#   1	,         	PNCT
#   1	мечтали   	VERB,impf,intr plur,past,indc
#   1	,         	PNCT
#   3	как       	CONJ
#   3	будто     	CONJ
#   1	вонзены   	PRTS,perf,past,pssv plur
#   1	во        	PREP Vpre
#   2	дно       	NOUN,inan,neut sing,accs
#   1	.         	PNCT
#  25	я         	NPRO,1per sing,nomn
#   1	свято     	ADJS,Qual neut,sing
#   1	помню     	VERB,impf,tran sing,1per,pres,indc
#   1	эту       	ADJF,Subx,Apro,Anph femn,sing,accs
#   2	встречу   	NOUN,inan,femn sing,accs
#   1	:         	PNCT
#   2	пруд      	NOUN,inan,masc sing,accs
#   1	,         	PNCT
#   3	берег     	NOUN,inan,masc sing,nomn
#   1	,         	PNCT
#   4	неба      	NOUN,inan,neut sing,gent
#   2	яркий     	ADJF,Qual masc,sing,nomn
#   3	плат      	NOUN,inan,femn plur,gent
#   1	…         	PNCT
#   2	миг       	NOUN,inan,masc sing,accs
#   2	тот       	ADJF,Subx,Apro,Anph masc,sing,nomn
#   2	же        	PRCL
#   1	если      	CONJ
#   1	вновь     	ADVB
#   1	я         	NPRO,1per sing,nomn
#   2	встречу   	NOUN,inan,femn sing,accs
#   1	,         	PNCT
#   1	—         	PNCT
#  39	и         	CONJ
#   2	жизнь     	NOUN,inan,femn sing,accs
#   1	ничтожная 	ADJF,Qual femn,sing,nomn
#   3	из        	PREP
#   3	плат      	NOUN,inan,femn plur,gent
#   1	!         	PNCT
#   1	12        	NUMB,intg
#   1	декабря   	NOUN,inan,masc sing,gent
#   1	1914      	NUMB,intg

# %%
brusov_tokenized_pymorphy = simple_word_tokenize(brusov_text)
brusov_pymorphy = []
for token in brusov_tokenized_pymorphy:
    parsed_token = morph.parse(token)
    brusov_pymorphy.append((parsed_token[0].word, parsed_token[0].tag._str))

# %%
brusov_pymorphy[:10]
# Out:
# [('в', 'PREP'),
#  ('.', 'PNCT'),
#  ('я', 'NPRO,1per sing,nomn'),
#  ('.', 'PNCT'),
#  ('брюсов', 'NOUN,anim,masc,Sgtm,Surn sing,nomn'),
#  ('на', 'PREP'),
#  ('пруду', 'NOUN,inan,masc sing,datv'),
#  ('ты', 'NPRO,2per sing,nomn'),
#  ('белых', 'ADJF,Qual plur,gent'),
#  ('лебедей', 'NOUN,anim,masc plur,gent')]

# %%
df = pd.DataFrame(brusov_pymorphy, columns=['token', 'tag'])
df.to_excel('brusov_pymorphy.xlsx', index=False)

# %%
df
# Out:
#        token                                 tag
# 0          в                                PREP
# 1          .                                PNCT
# 2          я                 NPRO,1per sing,nomn
# 3          .                                PNCT
# 4     брюсов  NOUN,anim,masc,Sgtm,Surn sing,nomn
# ..       ...                                 ...
# 152     плат            NOUN,inan,femn plur,gent
# 153        !                                PNCT
# 154       12                           NUMB,intg
# 155  декабря            NOUN,inan,masc sing,gent
# 156     1914                           NUMB,intg
#
# [157 rows x 2 columns]

# %% [markdown]
# # spacy

# %% [markdown]
# ## Скачиваем модель

# %%
! python -m spacy download ru_core_news_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ru-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.7.0/ru_core_news_sm-3.7.0-py3-none-any.whl (15.3 MB)
#      ---------------------------------------- 0.0/15.3 MB ? eta -:--:--
#      ---- ----------------------------------- 1.8/15.3 MB 14.3 MB/s eta 0:00:01
#      ----------- ---------------------------- 4.5/15.3 MB 11.2 MB/s eta 0:00:01
#      --------------- ------------------------ 5.8/15.3 MB 9.3 MB/s eta 0:00:02
#      --------------- ------------------------ 6.0/15.3 MB 8.8 MB/s eta 0:00:02
#      ----------------- ---------------------- 6.8/15.3 MB 6.9 MB/s eta 0:00:02
#      -------------------- ------------------- 7.9/15.3 MB 6.3 MB/s eta 0:00:02
#      ---------------------- ----------------- 8.7/15.3 MB 6.0 MB/s eta 0:00:02
#      ------------------------- -------------- 9.7/15.3 MB 5.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 10.7/15.3 MB 5.7 MB/s eta 0:00:01
#      ------------------------------ --------- 11.5/15.3 MB 5.6 MB/s eta 0:00:01
#      -------------------------------- ------- 12.6/15.3 MB 5.5 MB/s eta 0:00:01
#      ----------------------------------- ---- 13.4/15.3 MB 5.4 MB/s eta 0:00:01
#      ------------------------------------- -- 14.4/15.3 MB 5.2 MB/s eta 0:00:01
#      ---------------------------------------  15.2/15.3 MB 5.3 MB/s eta 0:00:01
#      ---------------------------------------- 15.3/15.3 MB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from ru-core-news-sm==3.7.0) (3.7.6)
# Requirement already satisfied: pymorphy3>=1.0.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from ru-core-news-sm==3.7.0) (2.0.2)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.7.0) (0.7.2)
# Requirement already satisfied: pymorphy3-dicts-ru in c:\users\андрей\appdata\roaming\python\python310\site-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.7.0) (2.4.417150.4580142)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in c:\program files\python310\lib\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (58.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: colorama in c:\users\андрей\appdata\roaming\python\python310\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in c:\users\андрей\appdata\roaming\python\python310\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\андрей\appdata\roaming\python\python310\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ru-core-news-sm==3.7.0) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')

# %% [markdown]
# ## Размечаем

# %%
import spacy

# %%
nlp = spacy.load('ru_core_news_sm')

# %%
doc = nlp(brusov_text)
brusov_spacy = []
for token in doc:
    print(token.text, token.pos_, token.morph)
    brusov_spacy.append((token.text, token.pos_, token.morph))
# Out:
# В. PROPN Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# Я. PROPN Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# БРЮСОВ PROPN Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
#
#
#  SPACE
# На ADP
# пруду NOUN Animacy=Inan|Case=Loc|Gender=Masc|Number=Sing
#
#  SPACE
# Ты PRON Case=Nom|Number=Sing|Person=Second
# белых ADJ Case=Gen|Degree=Pos|Number=Plur
# лебедей NOUN Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur
# кормила VERB Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# , PUNCT
#
#  SPACE
# Откинув VERB Aspect=Perf|Tense=Past|VerbForm=Conv|Voice=Act
# тяжесть NOUN Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing
# черных ADJ Case=Gen|Degree=Pos|Number=Plur
# кос NOUN Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur
# … PUNCT
#
#  SPACE
# Я PRON Case=Nom|Number=Sing|Person=First
# рядом ADV Degree=Pos
# плыл VERB Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# ; PUNCT
# сошлись VERB Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Mid
# кормила VERB Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# ; PUNCT
#
#  SPACE
# Закатный VERB Aspect=Perf|Case=Nom|Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass
# луч NOUN Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# был AUX Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# странно ADJ Degree=Pos
# - NOUN Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing
# кос PROPN Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# . PUNCT
#
#  SPACE
# По ADP
# небу NOUN Animacy=Inan|Case=Dat|Gender=Neut|Number=Sing
# полосы NOUN Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# синели NOUN Animacy=Anim|Case=Nom|Gender=Masc|Number=Plur
# , PUNCT
#
#  SPACE
# Вечеровой ADJ Case=Nom|Degree=Pos|Gender=Masc|Number=Sing
# багрец NOUN Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# кроя NOUN Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# ; PUNCT
#
#  SPACE
# В ADP
# цветах NOUN Animacy=Inan|Case=Loc|Gender=Masc|Number=Plur
# черемух NOUN Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# и CCONJ
# синели NOUN Animacy=Anim|Case=Nom|Gender=Masc|Number=Plur
#
#  SPACE
# Скрывались VERB Aspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Mid
# водные ADJ Case=Nom|Degree=Pos|Number=Plur
# края NOUN Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur
# . PUNCT
#
#  SPACE
# Все DET Case=Nom|Number=Plur
# формы NOUN Animacy=Inan|Case=Nom|Gender=Fem|Number=Plur
# были AUX Aspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act
# строго ADV Degree=Pos
# - ADV Degree=Pos
# четки NOUN Animacy=Inan|Case=Nom|Gender=Fem|Number=Plur
# , PUNCT
#
#  SPACE
# Миг PROPN Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# ранил VERB Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# сердце NOUN Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing
# сотней NOUN Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing
# жал VERB Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# … PUNCT
#
#  SPACE
# Я PRON Case=Nom|Number=Sing|Person=First
# , PUNCT
# как SCONJ
# аскет NOUN Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# сжимает VERB Aspect=Imp|Mood=Ind|Number=Sing|Person=Third|Tense=Pres|VerbForm=Fin|Voice=Act
# четки NOUN Animacy=Inan|Case=Nom|Gender=Fem|Number=Plur
# , PUNCT
#
#  SPACE
# В ADP
# руке NOUN Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing
# весло VERB Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# невольно ADV Degree=Pos
# жал VERB Aspect=Imp|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# . PUNCT
#
#  SPACE
# Вдруг ADV Degree=Pos
# лебедей NOUN Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur
# метнулась VERB Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Mid
# пара NOUN Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing
# … PUNCT
#
#  SPACE
# Не PART Polarity=Neg
# знаю VERB Aspect=Imp|Mood=Ind|Number=Sing|Person=First|Tense=Pres|VerbForm=Fin|Voice=Act
# , PUNCT
# чья DET Case=Nom|Gender=Fem|Number=Sing
# была AUX Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# вина NOUN Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing
# … PUNCT
#
#  SPACE
# Закат PROPN Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# замлел VERB Aspect=Perf|Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# за ADP
# дымкой NOUN Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing
# пара NOUN Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# , PUNCT
#
#  SPACE
# Алея PROPN Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing
# , PUNCT
# как SCONJ
# поток NOUN Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# вина NOUN Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
# . PUNCT
#
#  SPACE
# Была AUX Aspect=Imp|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act
# то PRON Animacy=Inan|Case=Nom|Gender=Neut|Number=Sing
# правда NOUN Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing
# ли PART
# , PUNCT
# мечта NOUN Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing
# ли PART
# , PUNCT
# — PUNCT
#
#  SPACE
# Уста PROPN Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing
# двоих NUM Case=Gen
# слились VERB Aspect=Perf|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Mid
# в ADP
# одно NUM Case=Acc|Gender=Neut|Number=Sing
# . PUNCT
#
#  SPACE
# Две NUM Case=Nom|Gender=Fem
# лодки NOUN Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing
# , PUNCT
# как SCONJ
# и PART
# мы PRON Case=Nom|Number=Plur|Person=First
# , PUNCT
# мечтали VERB Aspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin|Voice=Act
# , PUNCT
#
#  SPACE
# Как ADV Degree=Pos
# будто PART
# вонзены VERB Aspect=Perf|Number=Plur|StyleVariant=Short|Tense=Past|VerbForm=Part|Voice=Pass
# во ADP
# дно NOUN Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing
# . PUNCT
#
#  SPACE
# Я PRON Case=Nom|Number=Sing|Person=First
# свято ADV Degree=Pos
# помню VERB Aspect=Imp|Mood=Ind|Number=Sing|Person=First|Tense=Pres|VerbForm=Fin|Voice=Act
# эту DET Case=Acc|Gender=Fem|Number=Sing
# встречу NOUN Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing
# : PUNCT
#
#  SPACE
# Пруд NOUN Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# , PUNCT
# берег NOUN Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# , PUNCT
# неба NOUN Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing
# яркий ADJ Case=Nom|Degree=Pos|Gender=Masc|Number=Sing
# плат NOUN Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing
# … PUNCT
#
#  SPACE
# Миг PROPN Animacy=Anim|Case=Nom|Gender=Masc|Number=Sing
# тот DET Case=Nom|Gender=Masc|Number=Sing
# же PART
# если SCONJ
# вновь ADV Degree=Pos
# я PRON Case=Nom|Number=Sing|Person=First
# встречу VERB Aspect=Perf|Mood=Ind|Number=Sing|Person=First|Tense=Fut|VerbForm=Fin|Voice=Act
# , PUNCT
# — PUNCT
#
#  SPACE
# И CCONJ
# жизнь NOUN Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing
# ничтожная VERB Aspect=Perf|Case=Nom|Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass
# из ADP
# плат NOUN Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur
# ! PUNCT
#
#  SPACE
# 12 ADJ
# декабря NOUN Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing
# 1914 ADJ
#
#  SPACE

# %%
df = pd.DataFrame(brusov_spacy, columns=['token', 'pos',  'tag'])
df.to_excel('brusov_spacy.xlsx', index=False)

# %% [markdown]
# # Pymystem

# %%
! pip install pymystem3

# %%
from pymystem3 import Mystem
analyzer_no_disamb = Mystem()
analyzer_with_disamb = Mystem(disambiguation=True)

# %%
brusov_mystem = []
doc_no_disamb = analyzer_no_disamb.analyze(brusov_text)
doc_with_disamb = analyzer_with_disamb.analyze(brusov_text)

# %%
doc_no_disamb[3:10]
# Out:
# [{'text': '. '},
#  {'analysis': [{'lex': 'брюсов',
#     'wt': 0.9998791671,
#     'gr': 'S,фам,муж,од=им,ед'}],
#   'text': 'БРЮСОВ'},
#  {'text': '\n'},
#  {'text': '\n'},
#  {'analysis': [{'lex': 'на', 'wt': 0.9989522965, 'gr': 'PR='}], 'text': 'На'},
#  {'text': ' '},
#  {'analysis': [{'lex': 'пруд', 'wt': 1, 'gr': 'S,муж,неод=(дат,ед|местн,ед)'}],
#   'text': 'пруду'}]

# %%
brusov_pymystem = []
for i in range(len(doc_no_disamb)):
    has_ana = doc_no_disamb[i].get('analysis') # return None if not present
    if has_ana:
        text = doc_no_disamb[i].get('text')
        ana_no_disamb = doc_no_disamb[i].get('analysis')[0]
        gr_no_disamb = ana_no_disamb.get('gr')
        
        ana_with_disamb = doc_with_disamb[i].get('analysis')[0]
        gr_with_disamb = ana_with_disamb.get('gr')
        brusov_pymystem.append((text, gr_no_disamb, gr_with_disamb))

# %%
df = pd.DataFrame(brusov_pymystem, columns=['token', 'gr_no_disamb', 'gr_with_disamb'])
df.to_excel('brusov_pymystem.xlsx', index=False)

# %% [markdown]
# # Stanza

# %%
import stanza
nlp = stanza.Pipeline(lang='ru', processors='tokenize,pos', verbose=False)

# %%
brusov_stanza = []
doc = nlp(brusov_text)
for sentence in doc.sentences:
    for word in sentence.words:
        brusov_stanza.append((word.text, word.upos, word.feats))

# %%
df = pd.DataFrame(brusov_stanza, columns=['text', 'upos', 'feats'])
df.to_excel('brusov_stanza.xlsx', index=False)

# %% [markdown]
# # UDPipe

# %%
from ufal.udpipe import Model, Pipeline
model = Model.load('russian-ud-2.0-170801.udpipe')
pipeline = Pipeline(model, 'tokenize', Pipeline.DEFAULT, Pipeline.DEFAULT, 'conllu')

# %%
analyzed = pipeline.process(brusov_text)
brusov_ud = []
for i, sent in enumerate(analyzed.split('\n\n')):
    for j, token in enumerate(sent.split('\n')):
        if (not token.startswith('#')) and token:
            brusov_ud.append(token.split('\t')[1:6])

# %%
brusov_ud[12]

# %%
df = pd.DataFrame(brusov_ud, columns=['text', 'lemma', 'pos1', 'pos2', 'morph'])
df.to_excel('brusov_ud.xlsx', index=False)

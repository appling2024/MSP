# %%
# 0. Корзина исчезла из списка.
# 1. Второй с конца предмет тоже исчез.
# 2. К багажу добавилась подозрительная сумка.
# 3. Список выстроился по алфавиту.
# 4. Поскольку собачонка ушла жить к доброй уборщице, вместо нее добавился большой
#вокзальный пёс.
#(здесь надо узнать номер собачонки и по этому номеру поместить пса)
# 5. Подозрительную сумку изъяли милиционеры.
# 6. Поскольку обнаружили пропажу корзины, добавили к предметам корзину цветов.
# 7. Список выстроился в обратном порядке — от последнего к первому.
# 8. Последним пунктом добавился поощрительный подарок от транспортной компании.
#(придумайте, какой именно, например, сварочный аппарат, но это мой вариант,
#придумайте свой)
list
luggage=['диван','чемодан','саквояж','картина','корзина','картонка','маленькая собачонка']
luggage.remove('корзина')
print('Корзина исчезла из списка.', luggage)
luggage.remove('картонка')
print('Второй с конца предмет тоже исчез.', luggage)
luggage.append('подозрительная сумка')
print('К багажу добавилась подозрительная сумка.', luggage)
luggage.sort()
print('Список выстроился по алфавиту.', luggage)
dog = luggage.index('маленькая собачонка')
luggage[dog]='большой вокзальный пёс'
print('Поскольку собачонка ушла жить к доброй уборщице, вместо нее добавился большой вокзальный пёс.', luggage)
luggage.remove('подозрительная сумка')
print('Подозрительную сумку изъяли милиционеры.', luggage)
luggage.append('корзина цветов')
print('Поскольку обнаружили пропажу корзины, добавили к предметам корзину цветов.', luggage)
luggage.reverse()
print('Список выстроился в обратном порядке — от последнего к первому.', luggage)
luggage.append('шапка')
print('Последним пунктом добавился поощрительный подарок от транспортной компании.', luggage)
for item in luggage:
    print('Элемент багажа:', item)
for index, item in enumerate(luggage, start=1):
    print('Элемен багажа', index ,':', item)
# Out:
# Корзина исчезла из списка. ['диван', 'чемодан', 'саквояж', 'картина', 'картонка', 'маленькая собачонка']
# Второй с конца предмет тоже исчез. ['диван', 'чемодан', 'саквояж', 'картина', 'маленькая собачонка']
# К багажу добавилась подозрительная сумка. ['диван', 'чемодан', 'саквояж', 'картина', 'маленькая собачонка', 'подозрительная сумка']
# Список выстроился по алфавиту. ['диван', 'картина', 'маленькая собачонка', 'подозрительная сумка', 'саквояж', 'чемодан']
# Поскольку собачонка ушла жить к доброй уборщице, вместо нее добавился большой вокзальный пёс. ['диван', 'картина', 'большой вокзальный пёс', 'подозрительная сумка', 'саквояж', 'чемодан']
# Подозрительную сумку изъяли милиционеры. ['диван', 'картина', 'большой вокзальный пёс', 'саквояж', 'чемодан']
# Поскольку обнаружили пропажу корзины, добавили к предметам корзину цветов. ['диван', 'картина', 'большой вокзальный пёс', 'саквояж', 'чемодан', 'корзина цветов']
# ...

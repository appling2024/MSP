# %% [markdown]
# Написание правил для разбора ФИО и имен в разных вариациях в парсере NLTK4RUSSIAN:
# это варианты
#
# Иван Иванович Иванов
#
# Иван Иванов
#
#  И.Иванов
#
#   И.И.Иванов в разных падежных формах.
#
# (2 участник) Мурашко, Кадочникова

# %% [markdown]
# ![имена.png](data:image/png;base64,...)

# %% [markdown]
# ![изображение.png](data:image/png;base64,...)

# %%
pip install pymorphy3
# Out:
# Collecting pymorphy3
#   Downloading pymorphy3-2.0.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting dawg-python>=0.7.1 (from pymorphy3)
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting pymorphy3-dicts-ru (from pymorphy3)
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl.metadata (2.0 kB)
# Downloading pymorphy3-2.0.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.4 MB/s eta 0:00:00
# Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 47.8 MB/s eta 0:00:00
# Installing collected packages: pymorphy3-dicts-ru, dawg-python, pymorphy3
# Successfully installed dawg-python-0.7.2 pymorphy3-2.0.2 pymorphy3-dicts-ru-2.4.417150.4580142

# %%
import nltk
nltk.download('punkt_tab')
from nltk import *
import pymorphy3 as pm
import codecs
import re
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
## загружаем PyMorphy3
m = pm.MorphAnalyzer()
## открываем (создаем)файл с грамматикой, куда будут записываться правила
f = codecs.open(r'my_test.fcfg', mode= "w", encoding = "utf-8")
rules = codecs.open(r'rules.txt', mode= "r", encoding = "utf-8")
## записываем правила, которые вручную делаем (некоторые на основе правил из АОТ)
for rule in rules:
    f.writelines(rules)

rules.close()
f.close()

# %%
#Пишем правило разбора

# %% [markdown]
# Что нужно исправить?
#
# Исправь регулярное выражение, в нём проблема
#
# Посмотри, почему выводит несколько раз и почему не разбирает дальше

# %%
def find_initials(name):
    #f = codecs.open("my_test.fcfg", mode= "a", encoding = "utf-8")
    regex_init = re.compile(r'[А-ЯЁа-яё]?[а-яё]{0,1}\.?[А-ЯЁа-яё]?[а-яё]{0,1}\.')  # Регулярное выражение для поиска инициалов
    name = str(name)
    match = regex_init.match(name)
    if match:
        initials = match.group()  # Получаем инициалы из совпадения
        #f.write(f"NOUN[initials.  '{initials}' ] -> '{initials}'" ) #Выводим отдельно
        return True
    else:
        return None

f.close()
#name = input('Введите инициалы: ')
#find_initials(name)

# %%
def pm2fcfg (phrase): ## phrase - это словосочетание, которое мы разбираем
    f = codecs.open("my_test.fcfg", mode= "a", encoding = "utf-8")
    for x in phrase:
        a = m.parse(x) ## a - список возможных вариантов морфологического разбора слова, предлагаемых пайморфи
        ## от части речи зависит, какие признаки отправляются в грамматику, осюда условия
        for y in a:
            #print(y)
            if (y.tag.POS == "NOUN") or (y.tag.POS == "ADJF") or (y.tag.POS == "PRTF"):
                strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
            elif (y.tag.POS == "ADJS") or (y.tag.POS == "PRTS"):
                strk = str(y.tag.POS) + "[G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
            elif (y.tag.POS == "NUMR"):
                strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
            elif (y.tag.POS == "ADVB") or (y.tag.POS == "GRND") or (y.tag.POS == "COMP") or (y.tag.POS == "PRED") or (y.tag.POS == "PRCL") or (y.tag.POS == "INTJ"):
                strk = str(y.tag.POS) + "[NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
            elif (y.tag.POS == "PREP") or (y.tag.POS == "CONJ"):
                strk = str(y.tag.POS) + "[NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
                break
            elif (y.tag.POS == "NPRO") & (y.normal_form != "это")& (y.normal_form != "нечего"):
                if ((y.tag.person[0] == "3") & (y.tag.number == "sing")):
                    strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", PER=" + str(y.tag.person)[0] + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                else:
                    strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", NUM=" + str(y.tag.number) + ", PER=" + str(y.tag.person)[0] + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
            elif (y.tag.POS == "VERB")  or (y.tag.POS == "INFN"):
                if (y.tag.tense == "past"):
                    strk = str(y.tag.POS) + "[TR=" + str(y.tag.transitivity) + ", TENSE=" + str(y.tag.tense) + ", G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", PER=" + "0" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                elif (y.tag.POS == "INFN"):
                    strk = str(y.tag.POS) + "[TR=" + str(y.tag.transitivity) + ", TENSE=0, G=0, NUM=0, PER=0, NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                else:
                    strk = str(y.tag.POS) + "[TR=" + str(y.tag.transitivity) + ", TENSE=" + str(y.tag.tense) + ", G=" + "0" + ", NUM=" + str(y.tag.number) + ", PER=" + str(y.tag.person)[0] + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
    f.close()

# %%
def init_and_else(word): #простейшая функция
  f = codecs.open("my_test.fcfg", mode= "a", encoding = "utf-8")
  if find_initials(word) == True:
      f.write(f"NOUN[initials.  '{word}' ] -> '{word}'\n" )
  else:
      word = word_tokenize(word)
      pm2fcfg(word)

  f.close()

# %%
text = input("введите предложение для разбора: ") ## сюда пишется словосочетание для разбора, после ввода нажать ENTER
# Out:
# введите предложение для разбора: А.С. Пушкин

# %%
#text = text.lower()
print(text)
# Out:
# А.С. Пушкин

# %%
words = word_tokenize(text) ## разбиваем словосочетание на токены
print(words)
for word in words:
  print(word)
  print(m.parse(word))
  init_and_else(word)
# Out:
# ['А.С', '.', 'Пушкин']
# А.С
# [Parse(word='а.с', tag=OpencorporaTag('UNKN'), normal_form='а.с', score=1.0, methods_stack=((UnknAnalyzer(), 'А.С'),))]
# .
# [Parse(word='.', tag=OpencorporaTag('PNCT'), normal_form='.', score=1.0, methods_stack=((PunctuationAnalyzer(score=0.9), '.'),))]
# Пушкин
# [Parse(word='пушкин', tag=OpencorporaTag('NOUN,anim,masc,Sgtm,Surn sing,nomn'), normal_form='пушкин', score=0.666666, methods_stack=((DictionaryAnalyzer(), 'пушкин', 37, 0),)), Parse(word='пушкин', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,nomn'), normal_form='пушкин', score=0.222222, methods_stack=((DictionaryAnalyzer(), 'пушкин', 33, 0),)), Parse(word='пушкин', tag=OpencorporaTag('NOUN,inan,masc,Geox sing,accs'), normal_form='пушкин', score=0.111111, methods_stack=((DictionaryAnalyzer(), 'пушкин', 33, 3),))]

# %% [markdown]
# # **Дальше глупые пробы, чисто для истории**

# %%
def surname(name):
  f = codecs.open("my_test.txt", mode= "a", encoding = "utf-8")
  for x in name:
    a = m.parse(x)
    print(a)
    for y in a:
      y = str(y)
      if y in regex_init.match(y):
        strk = str(y.tag.POS == 'Initials') + str(y.normal_form) + "' -> '" + str(y.word) + "'\n"
        f.writelines(strk)
        #print(strk)
      elif y in regex_init_with_surname.match(y):
        strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
        f.writelines(strk)
        #print(strk)
      elif y in regex_name_with_surname.match(y):
        strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
        f.writelines(strk)
        #print(strk)
      elif y in regex_name_and_possible_initials_with_surname.match(y):
        strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
        f.writelines(strk)
        #print(strk)
      else:
        f.writelines(y) #строка для проверки ошибок

  f.close()

# %%
def name_case(name):
  f = codecs.open("my_test.fcfg", mode= "a", encoding = "utf-8")
  for x in name:
    a = m.parse(x)
    print(a)
    for y in a:
      if (y.tag.POS == "NOUN"):
        strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
        f.writelines(strk)
      elif (y.tag.POS == 'UNKN' and y.normal_form == regex.match(y.normal_form)): #Если неизвестен и по регулярке совпадает, но всё равно не записывает в файл
        strk = str(y.tag.POS =="initials") + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
        f.writelines(strk)





    ##########################################################################

# %%
#Со всеми правилами

def pm2fcfg (phrase): ## phrase - это словосочетание, которое мы разбираем
    f = codecs.open("my_test.fcfg", mode= "a", encoding = "utf-8")
    for x in phrase:
        a = m.parse(x) ## a - список возможных вариантов морфологического разбора слова, предлагаемых пайморфи
        ## от части речи зависит, какие признаки отправляются в грамматику, осюда условия
        for y in a:
            #print(y)
            if (y.tag.POS == "NOUN") or (y.tag.POS == "ADJF") or (y.tag.POS == "PRTF"):
                strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
            elif (y.tag.POS == "ADJS") or (y.tag.POS == "PRTS"):
                strk = str(y.tag.POS) + "[G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
            elif (y.tag.POS == "NUMR"):
                strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
            elif (y.tag.POS == "ADVB") or (y.tag.POS == "GRND") or (y.tag.POS == "COMP") or (y.tag.POS == "PRED") or (y.tag.POS == "PRCL") or (y.tag.POS == "INTJ"):
                strk = str(y.tag.POS) + "[NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
            elif (y.tag.POS == "PREP") or (y.tag.POS == "CONJ"):
                strk = str(y.tag.POS) + "[NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
                break
            elif (y.tag.POS == "NPRO") & (y.normal_form != "это")& (y.normal_form != "нечего"):
                if ((y.tag.person[0] == "3") & (y.tag.number == "sing")):
                    strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", PER=" + str(y.tag.person)[0] + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                else:
                    strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", NUM=" + str(y.tag.number) + ", PER=" + str(y.tag.person)[0] + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
            elif (y.tag.POS == "VERB")  or (y.tag.POS == "INFN"):
                if (y.tag.tense == "past"):
                    strk = str(y.tag.POS) + "[TR=" + str(y.tag.transitivity) + ", TENSE=" + str(y.tag.tense) + ", G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", PER=" + "0" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                elif (y.tag.POS == "INFN"):
                    strk = str(y.tag.POS) + "[TR=" + str(y.tag.transitivity) + ", TENSE=0, G=0, NUM=0, PER=0, NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                else:
                    strk = str(y.tag.POS) + "[TR=" + str(y.tag.transitivity) + ", TENSE=" + str(y.tag.tense) + ", G=" + "0" + ", NUM=" + str(y.tag.number) + ", PER=" + str(y.tag.person)[0] + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
            '''else:
              y = str(y)
              if y in regex_init.match(y):
                strk = str(y.tag.POS == 'Initials') + str(y.normal_form) + "' -> '" + str(y.word) + "'\n"
                f.writelines(strk)
              elif y in regex_init_with_surname.match(y):
                strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
              elif y in regex_name_with_surname.match(y):
                strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)
              elif y in regex_name_and_possible_initials_with_surname.match(y):
                strk = str(y.tag.POS) + "[C=" + str(y.tag.case) + ", G=" + str(y.tag.gender) + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
                f.writelines(strk)'''
f.close()

# %%
def name_case(name):
  f = codecs.open("test1.fcfg", mode= "a", encoding = "utf-8")
  for x in name:
    a = m.parse(x) ## a - список возможных вариантов морфологического разбора слова, предлагаемых пайморфи
    print(a)
    for y in a:
      if (y.tag.POS == "NOUN" and y.tag == "Surn sing"):
        if y.endsWith('ов'):
          strk = str(y.tag.POS) + "[C=" + str(y.tag.case == "nomn") + ", G=" + str(y.tag.gender == "masc") + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
          f.writelines(strk)
        elif y.endswith('ова'):
          strk = str(y.tag.POS) + "[C=" + str(y.tag.case == "accs") + ", G=" + str(y.tag.gender == "masc") + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
          f.writelines(strk)
        elif y.endswith('овым'):
          strk = str(y.tag.POS) + "[C=" + str(y.tag.case == "loct") + ", G=" + str(y.tag.gender == "masc") + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
          f.writelines(strk)
        elif y.endswith('ову'):
          strk = str(y.tag.POS) + "[C=" + str(y.tag.case == "datv") + ", G=" + str(y.tag.gender == "masc") + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
          f.writelines(strk)
        elif y.endsWith('ова'):
          strk = str(y.tag.POS) + "[C=" + str(y.tag.case == "nomn") + ", G=" + str(y.tag.gender == "femn") + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
          f.writelines(strk)
        elif y.endsWith('овой'):
          strk = str(y.tag.POS) + "[C=" + str(y.tag.case == "loct") + ", G=" + str(y.tag.gender == "femn") + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
          f.writelines(strk)
        elif y.endswith('ову'):
          strk = str(y.tag.POS) + "[C=" + str(y.tag.case == "accs") + ", G=" + str(y.tag.gender == "masc") + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
          f.writelines(strk)
        elif y.endswith('ове'):
          strk = str(y.tag.POS) + "[C=" + str(y.tag.case == "datv") + ", G=" + str(y.tag.gender == "masc") + ", NUM=" + str(y.tag.number) + ", PER=3" + ", NF=u'" + str(y.normal_form) + "'] -> '" + str(y.word) + "'\n"
          f.writelines(strk)

# %%
#name_case(words)
#surname(words)
#find_initials(text)
#pm2fcfg(text)
#init_and_else(word)
#pm2fcfg(word)

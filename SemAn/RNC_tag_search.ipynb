# %% [markdown]
# <a href="https://colab.research.google.com/github/appling2024/MSP/blob/Liza_L/SemAn/RNC_tag_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - сем. разметка
# - корпуса с сем.разметкой
# - разметка в НКРЯ

# %% [markdown]
# ![Снимок экрана 2025-06-19 212335.png](data:image/png;base64,...)

# %%
import re

words = []
sent = []
tags = []
tags_full = []

def lines_func(name):
  with open(f'{name}.txt','r',encoding='windows-1251') as f:

    lines = []
    #убираем лишние символы
    for line in f:
      line = re.sub('<\/?w?>|\\t|<|\n','',line)
      lines.append(line)

    #создаем списки слов и тэгов
    for line in lines:
      words = []
      tags = []
      line = line.split('ana ')
      for i,elem in enumerate(line):
        if i == 0:
          continue
        else:
          line1 = elem.split('/>')
          tags.append(line1[0])
          words.append(line1[-1])
      tags_full.append(tags)
      sent.append(words)

def context(tag):
  index = dict()
  #достаем индексы из списка тэгов
  for i,tags in enumerate(tags_full):
    for j,t in enumerate(tags):
      if tag in t:
        index[i] = j

  #по индексам находим слово и контекст
  for i,words in enumerate(sent):
    for j,word in enumerate(words):
      if j == index.get(i):
        print()
        print(word, tag)
        string = ''
        for k in words:
          string += k
        print(string)

lines_func('britva')
context('r:concr t:tool:instr d:dim der:s')
# Out:
# щипчики  r:concr t:tool:instr d:dim der:s
# В Брауне щипчики расположены в шахматном порядке+насадка для новичков+бритва, а в Филипсе щипчики по другому расположены, более густо и они продолговатые.
#
# кисточкой  r:concr t:tool:instr d:dim der:s
# Нам все в нем нравилось, как он молниеносно и густо намыливает кисточкой щеки с подбородком, как взмахивает перед носом у клиента весьма небезопасной бритвой, скоблит щетину, спрыскивает, намасливает и рассказывает что-то  , рассказывает, то делая страшные глаза, то разражаясь гомерическим хохотом.
#
# кисточку  r:concr t:tool:instr d:dim der:s
# спокойно говорил дядя Юзя, бережно вынимая из чемодана электробритву "Харьков", одеколон "Тройной", кисточку для взбивания пены и запасной станок с коробочкой бритв "Балтика" на случай, если электричество отключат и побриться будет  нельзя.
#
# лопатка,  r:concr t:tool:instr d:dim der:s
# ...

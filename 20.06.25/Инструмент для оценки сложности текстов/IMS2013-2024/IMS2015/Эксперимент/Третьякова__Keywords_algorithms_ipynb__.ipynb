# %%
import os

# %%
#путь к папке с корпусом (лемматизированный корпус)
path = "corpus***"
dirs = os.listdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-b60595d4273a> in <cell line: 3>()
#       1 #путь к папке с корпусом (лемматизированный корпус)
#       2 path = "corpus***"
# ----> 3 dirs = os.listdir(path)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'corpus***'

# %%
i = 0
# словарь с именем файла и меткой класса (например, название рубрики или значение тональности)
dict_score = {}

# %%
for file in dirs:
    #есть нетекстовые файлы
    if (file[-4:] == '.txt'):
        with open(path + '/' + file, 'r', encoding='utf-8') as readfile:
            for line in readfile:
                list_words = line.split()
                # последним токеном в файле идёт оценка = для текстов отзывов
                dict_score[file] = list_words[len(list_words)-1]
                # формируем файл для анализа
                with open('reviews_for_work.txt', 'a', encoding='utf-8') as wfile:
                    # первым токеном в файле идёт номер файла, он не нужен
                    wfile.write(' '.join(list_words[1:len(list_words) - 1]) + '\n')
                    i += 1

# %%
print(f'files: {i}')

# %%
print(f'dict_score: {len(dict_score)}')

# %%
import re
import math
import pandas as pd
import nltk

# %%
with open('100cities.txt', 'r', encoding='utf-8') as file:
    f = file.read()

# %%
with open('Alexeeva_IMS_2015_rus_lem.txt', 'r', encoding='utf-8') as file:
    f = file.read()

# %%
text_words_2 = re.findall(r'[а-яёА-ЯЁ]+', f)

text_words_1 = []
for i in text_words_2:
    k = i.lower()
    text_words_1.append(k)

text_words_2
# Out:
# ['лексический',
#  'ресурс',
#  'для',
#  'анализ',
#  'тональность',
#  'социально',
#  'политический',
#  'текст',
#  'на',
#  'русский',
#  'язык',
#  'с',
#  'в',
#  'алексеева',
#  'с',
#  'н',
#  'кольцов',
#  'о',
#  'ю',
#  'кольцов',
#  'национальный',
#  'исследовательский',
#  'университет',
#  'высокий',
#  'школа',
#  'экономики',
#  'санкт',
#  'петербург',
#  'введение',
#  'тональный',
#  'анализ',
#  'сентимент',
#  'анализ',
#  'или',
#  'автоматизированный',
#  'анализ',
#  'эмоциональный',
#  'окрашенность',
#  'текст',
#  'плохо',
#  'хорошо',
#  'нравиться',
#  'не',
#  'нравиться',
#  'и',
#  'др',
#  'можно',
#  'отнести',
#  'к',
#  'область',
#  'компьютерный',
#  'лингвистики',
#  'однако',
#  'задача',
#  'он',
#  'применения',
#  'в',
#  'основном',
#  'лежать',
#  'за',
#  'предел',
#  'собственно',
#  'лингвистика',
#  'они',
#  'можно',
#  'разделить',
#  'на',
#  'два',
#  'обширный',
#  'области',
#  'маркетинг',
#  'в',
#  'первый',
#  'очередь',
#  'как',
#  'анализ',
#  'отзыв',
#  'на',
#  'товар',
#  'и',
#  'услуги',
#  'и',
#  'социология',
#  'политология',
#  'последний',
#  'включает',
#  'во',
#  'первых',
#  'анализ',
#  'текст',
#  'сми',
#  'для',
#  'выявление',
#  'того',
#  'как',
#  'тот',
#  'или',
#  'иной',
#  'социально',
#  'значимый',
#  'вопрос',
#  'преподноситься',
#  'аудитория',
#  'и',
#  'соответственно',
#  'какой',
#  'отклик',
#  'можно',
#  'ожидать',
#  'на',
#  'они',
#  'от',
#  'публики',
#  'во',
#  'вторых',
#  'это',
#  'исследование',
#  'текст',
#  'социальный',
#  'медиа',
#  'блогов',
#  'социальный',
#  'сетей',
#  'форумов',
#  'а',
#  'также',
#  'другой',
#  'пользовательский',
#  'контент',
#  'с',
#  'цель',
#  'выявление',
#  'общественный',
#  'мнение',
#  'или',
#  'более',
#  'точно',
#  'он',
#  'части',
#  'представить',
#  'в',
#  'интернете',
#  'этот',
#  'последний',
#  'компонент',
#  'являться',
#  'главный',
#  'целевой',
#  'область',
#  'знание',
#  'настоящий',
#  'проекта',
#  'в',
#  'второй',
#  'очередь',
#  'проект',
#  'обращать',
#  'внимание',
#  'на',
#  'анализ',
#  'сми',
#  'на',
#  'сегодняшний',
#  'день',
#  'существовать',
#  'два',
#  'основный',
#  'подход',
#  'к',
#  'автоматический',
#  'определение',
#  'тональность',
#  'текстов',
#  'словарный',
#  'и',
#  'не',
#  'использовать',
#  'словарь',
#  'последний',
#  'применять',
#  'различный',
#  'метод',
#  'автоматический',
#  'классификация',
#  'на',
#  'основа',
#  'обучать',
#  'коллекций',
#  'удобный',
#  'тогда',
#  'когда',
#  'такой',
#  'коллекция',
#  'доступный',
#  'в',
#  'избыток',
#  'напр',
#  'отзыв',
#  'на',
#  'товар',
#  'с',
#  'общий',
#  'позитивный',
#  'негативный',
#  'оценка',
#  'товара',
#  'в',
#  'англоязычный',
#  'сфера',
#  'создать',
#  'большой',
#  'количество',
#  'текстовый',
#  'коллекция',
#  'среди',
#  'который',
#  'особо',
#  'можно',
#  'выделить',
#  'университет',
#  'глазго',
#  'который',
#  'сконцентрировать',
#  'на',
#  'блог',
#  'разный',
#  'тематики',
#  'в',
#  'русский',
#  'сегменте',
#  'насколько',
#  'мы',
#  'известно',
#  'в',
#  'свободный',
#  'доступ',
#  'находиться',
#  'только',
#  'коллекция',
#  'прямой',
#  'и',
#  'косвенный',
#  'речь',
#  'новостной',
#  'текстов',
#  'создать',
#  'ромип',
#  'но',
#  'она',
#  'непригодный',
#  'к',
#  'исследование',
#  'эмоциональный',
#  'составлять',
#  'текст',
#  'блогов',
#  'в',
#  'отсутствие',
#  'необходимый',
#  'количество',
#  'коллекция',
#  'текст',
#  'с',
#  'проставить',
#  'тональный',
#  'окраска',
#  'мы',
#  'обратиться',
#  'к',
#  'словарный',
#  'подходу',
#  'для',
#  'английский',
#  'язык',
#  'словарный',
#  'подход',
#  'успешно',
#  'применяться',
#  'в',
#  'система',
#  'создать',
#  'м',
#  'фелвол',
#  'в',
#  'университет',
#  'вулверхемптон',
#  'великобритания',
#  'данный',
#  'по',
#  'специально',
#  'предназначить',
#  'для',
#  'анализ',
#  'социальный',
#  'медиа',
#  'кроме',
#  'того',
#  'в',
#  'английский',
#  'сегмент',
#  'доступный',
#  'обширный',
#  'словари',
#  'такой',
#  'как',
#  'и',
#  'для',
#  'русский',
#  'язык',
#  'мы',
#  'известный',
#  'словарь',
#  'и',
#  'четверкин',
#  'и',
#  'н',
#  'лукашевич',
#  'представлять',
#  'себя',
#  'список',
#  'из',
#  'оценочный',
#  'слов',
#  'извлечь',
#  'из',
#  'коллекция',
#  'отзыв',
#  'в',
#  'несколько',
#  'предметный',
#  'область',
#  'фильмы',
#  'книги',
#  'игры',
#  'телефоны',
#  'камеры',
#  'словарь',
#  'быть',
#  'разработать',
#  'исследователь',
#  'для',
#  'соревнование',
#  'ромип',
#  'по',
#  'тональный',
#  'анализ',
#  'отзывов',
#  'как',
#  'видно',
#  'из',
#  'описания',
#  'он',
#  'создать',
#  'прежде',
#  'весь',
#  'для',
#  'выявление',
#  'предпочтение',
#  'в',
#  'маркетинговый',
#  'исследованиях',
#  'а',
#  'не',
#  'для',
#  'анализ',
#  'общественный',
#  'мнение',
#  'в',
#  'текст',
#  'социально',
#  'политический',
#  'направленности',
#  'такой',
#  'образом',
#  'цель',
#  'данный',
#  'исследование',
#  'являться',
#  'разработка',
#  'тональный',
#  'словарь',
#  'и',
#  'краудсорсинговый',
#  'веб',
#  'ресурс',
#  'для',
#  'создание',
#  'инструмент',
#  'сентимент',
#  'анализа',
#  'тональный',
#  'словарь',
#  'это',
#  'список',
#  'слов',
#  'каждый',
#  'из',
#  'который',
#  'присвоить',
#  'вес',
#  'описывать',
#  'он',
#  'эмоциональный',
#  'окраску',
#  'такой',
#  'словарь',
#  'использоваться',
#  'в',
#  'программный',
#  'обеспечении',
#  'который',
#  'находить',
#  'соответствующий',
#  'слово',
#  'в',
#  'текст',
#  'и',
#  'на',
#  'основа',
#  'усреднение',
#  'они',
#  'вес',
#  'определять',
#  'общий',
#  'тональность',
#  'текста',
#  'точность',
#  'качество',
#  'работа',
#  'такой',
#  'по',
#  'и',
#  'такой',
#  'словарь',
#  'проверяться',
#  'путём',
#  'сравнение',
#  'он',
#  'результат',
#  'с',
#  'результат',
#  'работа',
#  'людей',
#  'тогда',
#  'как',
#  'создавать',
#  'веб',
#  'ресурс',
#  'применимый',
#  'для',
#  'любой',
#  'вид',
#  'тональный',
#  'разметки',
#  'словарь',
#  'в',
#  'данный',
#  'проект',
#  'создаваться',
#  'и',
#  'настраивается',
#  'специально',
#  'для',
#  'анализ',
#  'пользовательский',
#  'интернет',
#  'контент',
#  'социально',
#  'политический',
#  'содержания',
#  'конечный',
#  'цель',
#  'использование',
#  'такой',
#  'словарь',
#  'в',
#  'дальнейший',
#  'являться',
#  'изучение',
#  'общественный',
#  'мнение',
#  'интернет',
#  'аудитории',
#  'разработка',
#  'тональный',
#  'словарь',
#  'составление',
#  'тональный',
#  'словарь',
#  'какой',
#  'либо',
#  'язык',
#  'требовать',
#  'вычленение',
#  'эмоционально',
#  'окрасить',
#  'слово',
#  'из',
#  'весь',
#  'слово',
#  'данный',
#  'языка',
#  'что',
#  'в',
#  'полный',
#  'объём',
#  'невыполнимо',
#  'поскольку',
#  'любой',
#  'развитый',
#  'язык',
#  'насчитывать',
#  'несколько',
#  'сотня',
#  'тысяча',
#  'слов',
#  'здесь',
#  'возможно',
#  'несколько',
#  'альтернативный',
#  'стратегий',
#  'использование',
#  'уже',
#  'накопить',
#  'знание',
#  'о',
#  'язык',
#  'создание',
#  'собственных',
#  'опора',
#  'на',
#  'мнение',
#  'эксперт',
#  'сбор',
#  'представление',
#  'о',
#  'язык',
#  'простых',
#  'носителей',
#  'в',
#  'дать',
#  'работа',
#  'быть',
#  'выбрать',
#  'сочетание',
#  'этот',
#  'стратегий',
#  'на',
#  'первый',
#  'этап',
#  'собираться',
#  'прототип',
#  'словаря',
#  'куда',
#  'с',
#  'запасом',
#  'включаться',
#  'потенциально',
#  'окрасить',
#  'слова',
#  'на',
#  'второй',
#  'этап',
#  'прототип',
#  'размечаться',
#  'добровольцами',
#  'по',
#  'три',
#  'человек',
#  'на',
#  'каждый',
#  'слово',
#  'прототип',
#  'словаря',
#  'потенциально',
#  'окрасить',
#  'слова',
#  'без',
#  'привязка',
#  'к',
#  'текст',
#  'социально',
#  'политический',
#  'направленности',
#  'на',
#  'первый',
#  'этап',
#  'мы',
#  'использовать',
#  'уже',
#  'иметься',
#  'сведение',
#  'о',
#  'тональный',
#  'окрасить',
#  'словах',
#  'в',
#  'сила',
#  'того',
#  'что',
#  'оценочный',
#  'значение',
#  'частый',
#  'весь',
#  'выражаться',
#  'в',
#  'язык',
#  'при',
#  'помощь',
#  'признаковый',
#  'слово',
#  'прилагательное',
#  'и',
#  'наречий',
#  'мы',
#  'начать',
#  'поиск',
#  'потенциально',
#  'окрасить',
#  'слово',
#  'с',
#  'частотный',
#  'словарь',
#  'прилагательных',
#  'создать',
#  'лаборатория',
#  'цифровой',
#  'общество',
#  'на',
#  'основа',
#  'обширный',
#  'коллекция',
#  'русскоязычный',
#  'текст',
#  'фэйсбук',
#  'в',
#  'рамка',
#  'сотрудничество',
#  'с',
#  'лаборатория',
#  'интернет',
#  'исследование',
#  'линис',
#  'ниу',
#  'вшэ',
#  'данный',
#  'список',
#  'содержать',
#  'прилагательных',
#  'встретиться',
#  'в',
#  'коллекция',
#  'не',
#  'менее',
#  'раз',
#  'получить',
#  'прилагательное',
#  'быть',
#  'разметить',
#  'три',
#  'кодировщик',
#  'линиса',
#  'с',
#  'точка',
#  'зрение',
#  'наличие',
#  'эмоциональный',
#  'компонент',
#  'по',
#  'список',
#  'на',
#  'каждый',
#  'кодировщика',
#  'в',
#  'конец',
#  'мы',
#  'получить',
#  'список',
#  'из',
#  'прилагательных',
#  'который',
#  'кодировщик',
#  'посчитать',
#  'отрицательно',
#  'положительный',
#  'окрасить',
#  'или',
#  'передавать',
#  'усиление',
#  'уменьшение',
#  'эмоции',
#  'затем',
#  'словарь',
#  'прилагательное',
#  'из',
#  'социальный',
#  'сеть',
#  'фэйсбук',
#  'быть',
#  'дополнить',
#  'следующий',
#  'данными',
#  'наречий',
#  'получить',
#  'из',
#  'прилагательных',
#  'уже',
#  'содержаться',
#  'в',
#  'списке',
#  'добавление',
#  'наречие',
#  'быть',
#  'сделать',
#  'автоматически',
#  'от',
#  'прилагательное',
#  'отрезаться',
#  'окончание',
#  'ий',
#  'ый',
#  'ой',
#  'и',
#  'добавляться',
#  'окончание',
#  'наречие',
#  'о',
#  'е',
#  'и',
#  'затем',
#  'получить',
#  'слово',
#  'проверяться',
#  'при',
#  'помощь',
#  'морфоанализатор',
#  'если',
#  'слово',
#  'присутствовать',
#  'в',
#  'словаре',
#  'использовать',
#  'в',
#  'анализатор',
#  'т',
#  'е',
#  'быть',
#  'реальный',
#  'наречием',
#  'оно',
#  'добавляться',
#  'в',
#  'список',
#  'словарь',
#  'и',
#  'четверкин',
#  'и',
#  'н',
#  'лукашевич',
#  'словарь',
#  'находиться',
#  'в',
#  'свободный',
#  'доступ',
#  'по',
#  'адресу',
#  'междометие',
#  'быть',
#  'взять',
#  'из',
#  'объяснительный',
#  'словарь',
#  'русский',
#  'язык',
#  'слово',
#  'быть',
#  'добавить',
#  'из',
#  'словаря',
#  'составить',
#  'ю',
#  'в',
#  'павлов',
#  'на',
#  'основа',
#  'перевод',
#  'англоязычный',
#  'словаря',
#  'поставлять',
#  'с',
#  'по',
#  'программа',
#  'оценка',
#  'сила',
#  'положительный',
#  'и',
#  'отрицательный',
#  'настроений',
#  'ориентировать',
#  'на',
#  'работа',
#  'с',
#  'краткий',
#  'интернет',
#  'сообщениями',
#  'публиковать',
#  'в',
#  'социальный',
#  'сеть',
#  'который',
#  'в',
#  'многий',
#  'отношение',
#  'сходный',
#  'с',
#  'текст',
#  'блогосферы',
#  'в',
#  'первый',
#  'очередь',
#  'с',
#  'комментарий',
#  'к',
#  'постам',
#  'такой',
#  'образом',
#  'предварительный',
#  'итоговый',
#  'словарь',
#  'потенциально',
#  'окрасить',
#  'тональный',
#  'слов',
#  'составить',
#  'из',
#  'различный',
#  'источник',
#  'состоять',
#  'из',
#  'лексический',
#  'единиц',
#  'включая',
#  'повторяться',
#  'слова',
#  'тональный',
#  'словарь',
#  'ориентировать',
#  'на',
#  'текст',
#  'социальный',
#  'медиа',
#  'дать',
#  'блог',
#  'платформа',
#  'живой',
#  'журнал',
#  'на',
#  'это',
#  'этап',
#  'быть',
#  'сформировать',
#  'коллекция',
#  'документов',
#  'посвятить',
#  'социально',
#  'политический',
#  'тематике',
#  'использовать',
#  'в',
#  'данный',
#  'проект',
#  'с',
#  'три',
#  'целями',
#  'как',
#  'источник',
#  'специфичный',
#  'для',
#  'дать',
#  'предметный',
#  'область',
#  'тональный',
#  'слов',
#  'как',
#  'источник',
#  'контекст',
#  'этот',
#  'слов',
#  'облегчать',
#  'разметка',
#  'особенно',
#  'в',
#  'случай',
#  'полисемии',
#  'и',
#  'как',
#  'источник',
#  'тестовый',
#  'коллекции',
#  'на',
#  'который',
#  'быть',
#  'проверяться',
#  'качество',
#  'словарь',
#  'и',
#  'который',
#  'быть',
#  'размечаться',
#  'в',
#  'год',
#  'на',
#  'вебресурсе',
#  'в',
#  'качество',
#  'источник',
#  'данные',
#  'использоваться',
#  'запись',
#  'блог',
#  'платформа',
#  'живой',
#  'журнал',
#  'в',
#  'линиса',
#  'быть',
#  'разработать',
#  'программный',
#  'обеспечение',
#  'позволять',
#  'закачивать',
#  'пост',
#  'и',
#  'комментарий',
#  'из',
#  'живой',
#  'журнала',
#  'на',
#  'протяжение',
#  'год',
#  'с',
#  'март',
#  'по',
#  'март',
#  'в',
#  'лаборатория',
#  'вестись',
#  'постоянный',
#  'еженедельный',
#  'закачка',
#  'пост',
#  'и',
#  'комментарий',
#  'самый',
#  'популярный',
#  'блогер',
#  'из',
#  'живой',
#  'журнал',
#  'по',
#  'рейтинг',
#  'социальный',
#  'капитал',
#  'предоставлять',
#  'жж',
#  'в',
#  'реляционный',
#  'база',
#  'в',
#  'дать',
#  'работа',
#  'быть',
#  'использовать',
#  'пост',
#  'за',
#  'весь',
#  'год',
#  'в',
#  'размер',
#  'порядок',
#  'млн',
#  'единиц',
#  'период',
#  'в',
#  'один',
#  'год',
#  'быть',
#  'взять',
#  'для',
#  'того',
#  'чтобы',
#  'компенсировать',
#  'наличие',
#  'узкий',
#  'событийно',
#  'зависимый',
#  'тем',
#  'который',
#  'мочь',
#  'бы',
#  ...]

# %%
text_words_1
# Out:
# ['лексический',
#  'ресурс',
#  'для',
#  'анализ',
#  'тональность',
#  'социально',
#  'политический',
#  'текст',
#  'на',
#  'русский',
#  'язык',
#  'с',
#  'в',
#  'алексеева',
#  'с',
#  'н',
#  'кольцов',
#  'о',
#  'ю',
#  'кольцов',
#  'национальный',
#  'исследовательский',
#  'университет',
#  'высокий',
#  'школа',
#  'экономики',
#  'санкт',
#  'петербург',
#  'введение',
#  'тональный',
#  'анализ',
#  'сентимент',
#  'анализ',
#  'или',
#  'автоматизированный',
#  'анализ',
#  'эмоциональный',
#  'окрашенность',
#  'текст',
#  'плохо',
#  'хорошо',
#  'нравиться',
#  'не',
#  'нравиться',
#  'и',
#  'др',
#  'можно',
#  'отнести',
#  'к',
#  'область',
#  'компьютерный',
#  'лингвистики',
#  'однако',
#  'задача',
#  'он',
#  'применения',
#  'в',
#  'основном',
#  'лежать',
#  'за',
#  'предел',
#  'собственно',
#  'лингвистика',
#  'они',
#  'можно',
#  'разделить',
#  'на',
#  'два',
#  'обширный',
#  'области',
#  'маркетинг',
#  'в',
#  'первый',
#  'очередь',
#  'как',
#  'анализ',
#  'отзыв',
#  'на',
#  'товар',
#  'и',
#  'услуги',
#  'и',
#  'социология',
#  'политология',
#  'последний',
#  'включает',
#  'во',
#  'первых',
#  'анализ',
#  'текст',
#  'сми',
#  'для',
#  'выявление',
#  'того',
#  'как',
#  'тот',
#  'или',
#  'иной',
#  'социально',
#  'значимый',
#  'вопрос',
#  'преподноситься',
#  'аудитория',
#  'и',
#  'соответственно',
#  'какой',
#  'отклик',
#  'можно',
#  'ожидать',
#  'на',
#  'они',
#  'от',
#  'публики',
#  'во',
#  'вторых',
#  'это',
#  'исследование',
#  'текст',
#  'социальный',
#  'медиа',
#  'блогов',
#  'социальный',
#  'сетей',
#  'форумов',
#  'а',
#  'также',
#  'другой',
#  'пользовательский',
#  'контент',
#  'с',
#  'цель',
#  'выявление',
#  'общественный',
#  'мнение',
#  'или',
#  'более',
#  'точно',
#  'он',
#  'части',
#  'представить',
#  'в',
#  'интернете',
#  'этот',
#  'последний',
#  'компонент',
#  'являться',
#  'главный',
#  'целевой',
#  'область',
#  'знание',
#  'настоящий',
#  'проекта',
#  'в',
#  'второй',
#  'очередь',
#  'проект',
#  'обращать',
#  'внимание',
#  'на',
#  'анализ',
#  'сми',
#  'на',
#  'сегодняшний',
#  'день',
#  'существовать',
#  'два',
#  'основный',
#  'подход',
#  'к',
#  'автоматический',
#  'определение',
#  'тональность',
#  'текстов',
#  'словарный',
#  'и',
#  'не',
#  'использовать',
#  'словарь',
#  'последний',
#  'применять',
#  'различный',
#  'метод',
#  'автоматический',
#  'классификация',
#  'на',
#  'основа',
#  'обучать',
#  'коллекций',
#  'удобный',
#  'тогда',
#  'когда',
#  'такой',
#  'коллекция',
#  'доступный',
#  'в',
#  'избыток',
#  'напр',
#  'отзыв',
#  'на',
#  'товар',
#  'с',
#  'общий',
#  'позитивный',
#  'негативный',
#  'оценка',
#  'товара',
#  'в',
#  'англоязычный',
#  'сфера',
#  'создать',
#  'большой',
#  'количество',
#  'текстовый',
#  'коллекция',
#  'среди',
#  'который',
#  'особо',
#  'можно',
#  'выделить',
#  'университет',
#  'глазго',
#  'который',
#  'сконцентрировать',
#  'на',
#  'блог',
#  'разный',
#  'тематики',
#  'в',
#  'русский',
#  'сегменте',
#  'насколько',
#  'мы',
#  'известно',
#  'в',
#  'свободный',
#  'доступ',
#  'находиться',
#  'только',
#  'коллекция',
#  'прямой',
#  'и',
#  'косвенный',
#  'речь',
#  'новостной',
#  'текстов',
#  'создать',
#  'ромип',
#  'но',
#  'она',
#  'непригодный',
#  'к',
#  'исследование',
#  'эмоциональный',
#  'составлять',
#  'текст',
#  'блогов',
#  'в',
#  'отсутствие',
#  'необходимый',
#  'количество',
#  'коллекция',
#  'текст',
#  'с',
#  'проставить',
#  'тональный',
#  'окраска',
#  'мы',
#  'обратиться',
#  'к',
#  'словарный',
#  'подходу',
#  'для',
#  'английский',
#  'язык',
#  'словарный',
#  'подход',
#  'успешно',
#  'применяться',
#  'в',
#  'система',
#  'создать',
#  'м',
#  'фелвол',
#  'в',
#  'университет',
#  'вулверхемптон',
#  'великобритания',
#  'данный',
#  'по',
#  'специально',
#  'предназначить',
#  'для',
#  'анализ',
#  'социальный',
#  'медиа',
#  'кроме',
#  'того',
#  'в',
#  'английский',
#  'сегмент',
#  'доступный',
#  'обширный',
#  'словари',
#  'такой',
#  'как',
#  'и',
#  'для',
#  'русский',
#  'язык',
#  'мы',
#  'известный',
#  'словарь',
#  'и',
#  'четверкин',
#  'и',
#  'н',
#  'лукашевич',
#  'представлять',
#  'себя',
#  'список',
#  'из',
#  'оценочный',
#  'слов',
#  'извлечь',
#  'из',
#  'коллекция',
#  'отзыв',
#  'в',
#  'несколько',
#  'предметный',
#  'область',
#  'фильмы',
#  'книги',
#  'игры',
#  'телефоны',
#  'камеры',
#  'словарь',
#  'быть',
#  'разработать',
#  'исследователь',
#  'для',
#  'соревнование',
#  'ромип',
#  'по',
#  'тональный',
#  'анализ',
#  'отзывов',
#  'как',
#  'видно',
#  'из',
#  'описания',
#  'он',
#  'создать',
#  'прежде',
#  'весь',
#  'для',
#  'выявление',
#  'предпочтение',
#  'в',
#  'маркетинговый',
#  'исследованиях',
#  'а',
#  'не',
#  'для',
#  'анализ',
#  'общественный',
#  'мнение',
#  'в',
#  'текст',
#  'социально',
#  'политический',
#  'направленности',
#  'такой',
#  'образом',
#  'цель',
#  'данный',
#  'исследование',
#  'являться',
#  'разработка',
#  'тональный',
#  'словарь',
#  'и',
#  'краудсорсинговый',
#  'веб',
#  'ресурс',
#  'для',
#  'создание',
#  'инструмент',
#  'сентимент',
#  'анализа',
#  'тональный',
#  'словарь',
#  'это',
#  'список',
#  'слов',
#  'каждый',
#  'из',
#  'который',
#  'присвоить',
#  'вес',
#  'описывать',
#  'он',
#  'эмоциональный',
#  'окраску',
#  'такой',
#  'словарь',
#  'использоваться',
#  'в',
#  'программный',
#  'обеспечении',
#  'который',
#  'находить',
#  'соответствующий',
#  'слово',
#  'в',
#  'текст',
#  'и',
#  'на',
#  'основа',
#  'усреднение',
#  'они',
#  'вес',
#  'определять',
#  'общий',
#  'тональность',
#  'текста',
#  'точность',
#  'качество',
#  'работа',
#  'такой',
#  'по',
#  'и',
#  'такой',
#  'словарь',
#  'проверяться',
#  'путём',
#  'сравнение',
#  'он',
#  'результат',
#  'с',
#  'результат',
#  'работа',
#  'людей',
#  'тогда',
#  'как',
#  'создавать',
#  'веб',
#  'ресурс',
#  'применимый',
#  'для',
#  'любой',
#  'вид',
#  'тональный',
#  'разметки',
#  'словарь',
#  'в',
#  'данный',
#  'проект',
#  'создаваться',
#  'и',
#  'настраивается',
#  'специально',
#  'для',
#  'анализ',
#  'пользовательский',
#  'интернет',
#  'контент',
#  'социально',
#  'политический',
#  'содержания',
#  'конечный',
#  'цель',
#  'использование',
#  'такой',
#  'словарь',
#  'в',
#  'дальнейший',
#  'являться',
#  'изучение',
#  'общественный',
#  'мнение',
#  'интернет',
#  'аудитории',
#  'разработка',
#  'тональный',
#  'словарь',
#  'составление',
#  'тональный',
#  'словарь',
#  'какой',
#  'либо',
#  'язык',
#  'требовать',
#  'вычленение',
#  'эмоционально',
#  'окрасить',
#  'слово',
#  'из',
#  'весь',
#  'слово',
#  'данный',
#  'языка',
#  'что',
#  'в',
#  'полный',
#  'объём',
#  'невыполнимо',
#  'поскольку',
#  'любой',
#  'развитый',
#  'язык',
#  'насчитывать',
#  'несколько',
#  'сотня',
#  'тысяча',
#  'слов',
#  'здесь',
#  'возможно',
#  'несколько',
#  'альтернативный',
#  'стратегий',
#  'использование',
#  'уже',
#  'накопить',
#  'знание',
#  'о',
#  'язык',
#  'создание',
#  'собственных',
#  'опора',
#  'на',
#  'мнение',
#  'эксперт',
#  'сбор',
#  'представление',
#  'о',
#  'язык',
#  'простых',
#  'носителей',
#  'в',
#  'дать',
#  'работа',
#  'быть',
#  'выбрать',
#  'сочетание',
#  'этот',
#  'стратегий',
#  'на',
#  'первый',
#  'этап',
#  'собираться',
#  'прототип',
#  'словаря',
#  'куда',
#  'с',
#  'запасом',
#  'включаться',
#  'потенциально',
#  'окрасить',
#  'слова',
#  'на',
#  'второй',
#  'этап',
#  'прототип',
#  'размечаться',
#  'добровольцами',
#  'по',
#  'три',
#  'человек',
#  'на',
#  'каждый',
#  'слово',
#  'прототип',
#  'словаря',
#  'потенциально',
#  'окрасить',
#  'слова',
#  'без',
#  'привязка',
#  'к',
#  'текст',
#  'социально',
#  'политический',
#  'направленности',
#  'на',
#  'первый',
#  'этап',
#  'мы',
#  'использовать',
#  'уже',
#  'иметься',
#  'сведение',
#  'о',
#  'тональный',
#  'окрасить',
#  'словах',
#  'в',
#  'сила',
#  'того',
#  'что',
#  'оценочный',
#  'значение',
#  'частый',
#  'весь',
#  'выражаться',
#  'в',
#  'язык',
#  'при',
#  'помощь',
#  'признаковый',
#  'слово',
#  'прилагательное',
#  'и',
#  'наречий',
#  'мы',
#  'начать',
#  'поиск',
#  'потенциально',
#  'окрасить',
#  'слово',
#  'с',
#  'частотный',
#  'словарь',
#  'прилагательных',
#  'создать',
#  'лаборатория',
#  'цифровой',
#  'общество',
#  'на',
#  'основа',
#  'обширный',
#  'коллекция',
#  'русскоязычный',
#  'текст',
#  'фэйсбук',
#  'в',
#  'рамка',
#  'сотрудничество',
#  'с',
#  'лаборатория',
#  'интернет',
#  'исследование',
#  'линис',
#  'ниу',
#  'вшэ',
#  'данный',
#  'список',
#  'содержать',
#  'прилагательных',
#  'встретиться',
#  'в',
#  'коллекция',
#  'не',
#  'менее',
#  'раз',
#  'получить',
#  'прилагательное',
#  'быть',
#  'разметить',
#  'три',
#  'кодировщик',
#  'линиса',
#  'с',
#  'точка',
#  'зрение',
#  'наличие',
#  'эмоциональный',
#  'компонент',
#  'по',
#  'список',
#  'на',
#  'каждый',
#  'кодировщика',
#  'в',
#  'конец',
#  'мы',
#  'получить',
#  'список',
#  'из',
#  'прилагательных',
#  'который',
#  'кодировщик',
#  'посчитать',
#  'отрицательно',
#  'положительный',
#  'окрасить',
#  'или',
#  'передавать',
#  'усиление',
#  'уменьшение',
#  'эмоции',
#  'затем',
#  'словарь',
#  'прилагательное',
#  'из',
#  'социальный',
#  'сеть',
#  'фэйсбук',
#  'быть',
#  'дополнить',
#  'следующий',
#  'данными',
#  'наречий',
#  'получить',
#  'из',
#  'прилагательных',
#  'уже',
#  'содержаться',
#  'в',
#  'списке',
#  'добавление',
#  'наречие',
#  'быть',
#  'сделать',
#  'автоматически',
#  'от',
#  'прилагательное',
#  'отрезаться',
#  'окончание',
#  'ий',
#  'ый',
#  'ой',
#  'и',
#  'добавляться',
#  'окончание',
#  'наречие',
#  'о',
#  'е',
#  'и',
#  'затем',
#  'получить',
#  'слово',
#  'проверяться',
#  'при',
#  'помощь',
#  'морфоанализатор',
#  'если',
#  'слово',
#  'присутствовать',
#  'в',
#  'словаре',
#  'использовать',
#  'в',
#  'анализатор',
#  'т',
#  'е',
#  'быть',
#  'реальный',
#  'наречием',
#  'оно',
#  'добавляться',
#  'в',
#  'список',
#  'словарь',
#  'и',
#  'четверкин',
#  'и',
#  'н',
#  'лукашевич',
#  'словарь',
#  'находиться',
#  'в',
#  'свободный',
#  'доступ',
#  'по',
#  'адресу',
#  'междометие',
#  'быть',
#  'взять',
#  'из',
#  'объяснительный',
#  'словарь',
#  'русский',
#  'язык',
#  'слово',
#  'быть',
#  'добавить',
#  'из',
#  'словаря',
#  'составить',
#  'ю',
#  'в',
#  'павлов',
#  'на',
#  'основа',
#  'перевод',
#  'англоязычный',
#  'словаря',
#  'поставлять',
#  'с',
#  'по',
#  'программа',
#  'оценка',
#  'сила',
#  'положительный',
#  'и',
#  'отрицательный',
#  'настроений',
#  'ориентировать',
#  'на',
#  'работа',
#  'с',
#  'краткий',
#  'интернет',
#  'сообщениями',
#  'публиковать',
#  'в',
#  'социальный',
#  'сеть',
#  'который',
#  'в',
#  'многий',
#  'отношение',
#  'сходный',
#  'с',
#  'текст',
#  'блогосферы',
#  'в',
#  'первый',
#  'очередь',
#  'с',
#  'комментарий',
#  'к',
#  'постам',
#  'такой',
#  'образом',
#  'предварительный',
#  'итоговый',
#  'словарь',
#  'потенциально',
#  'окрасить',
#  'тональный',
#  'слов',
#  'составить',
#  'из',
#  'различный',
#  'источник',
#  'состоять',
#  'из',
#  'лексический',
#  'единиц',
#  'включая',
#  'повторяться',
#  'слова',
#  'тональный',
#  'словарь',
#  'ориентировать',
#  'на',
#  'текст',
#  'социальный',
#  'медиа',
#  'дать',
#  'блог',
#  'платформа',
#  'живой',
#  'журнал',
#  'на',
#  'это',
#  'этап',
#  'быть',
#  'сформировать',
#  'коллекция',
#  'документов',
#  'посвятить',
#  'социально',
#  'политический',
#  'тематике',
#  'использовать',
#  'в',
#  'данный',
#  'проект',
#  'с',
#  'три',
#  'целями',
#  'как',
#  'источник',
#  'специфичный',
#  'для',
#  'дать',
#  'предметный',
#  'область',
#  'тональный',
#  'слов',
#  'как',
#  'источник',
#  'контекст',
#  'этот',
#  'слов',
#  'облегчать',
#  'разметка',
#  'особенно',
#  'в',
#  'случай',
#  'полисемии',
#  'и',
#  'как',
#  'источник',
#  'тестовый',
#  'коллекции',
#  'на',
#  'который',
#  'быть',
#  'проверяться',
#  'качество',
#  'словарь',
#  'и',
#  'который',
#  'быть',
#  'размечаться',
#  'в',
#  'год',
#  'на',
#  'вебресурсе',
#  'в',
#  'качество',
#  'источник',
#  'данные',
#  'использоваться',
#  'запись',
#  'блог',
#  'платформа',
#  'живой',
#  'журнал',
#  'в',
#  'линиса',
#  'быть',
#  'разработать',
#  'программный',
#  'обеспечение',
#  'позволять',
#  'закачивать',
#  'пост',
#  'и',
#  'комментарий',
#  'из',
#  'живой',
#  'журнала',
#  'на',
#  'протяжение',
#  'год',
#  'с',
#  'март',
#  'по',
#  'март',
#  'в',
#  'лаборатория',
#  'вестись',
#  'постоянный',
#  'еженедельный',
#  'закачка',
#  'пост',
#  'и',
#  'комментарий',
#  'самый',
#  'популярный',
#  'блогер',
#  'из',
#  'живой',
#  'журнал',
#  'по',
#  'рейтинг',
#  'социальный',
#  'капитал',
#  'предоставлять',
#  'жж',
#  'в',
#  'реляционный',
#  'база',
#  'в',
#  'дать',
#  'работа',
#  'быть',
#  'использовать',
#  'пост',
#  'за',
#  'весь',
#  'год',
#  'в',
#  'размер',
#  'порядок',
#  'млн',
#  'единиц',
#  'период',
#  'в',
#  'один',
#  'год',
#  'быть',
#  'взять',
#  'для',
#  'того',
#  'чтобы',
#  'компенсировать',
#  'наличие',
#  'узкий',
#  'событийно',
#  'зависимый',
#  'тем',
#  'который',
#  'мочь',
#  'бы',
#  ...]

# %%
with open('swl.txt', 'r', encoding='utf8') as swl:
    swlist = []  # список стоп-слов из файла
    for i in swl:
        i = i.replace('\n','')
        swlist.append(i)
        # print(swlist)

len(swlist)
# Out:
# 941

# %%
text_words = []
for i in text_words_1:
    #i = morph.parse(i)[0].normal_form
    if i not in swlist:
        text_words.append(i)

text_words
# Out:
# ['лексический',
#  'ресурс',
#  'анализ',
#  'тональность',
#  'социально',
#  'политический',
#  'текст',
#  'русский',
#  'язык',
#  'алексеева',
#  'н',
#  'кольцов',
#  'ю',
#  'кольцов',
#  'национальный',
#  'исследовательский',
#  'университет',
#  'высокий',
#  'школа',
#  'экономики',
#  'санкт',
#  'петербург',
#  'введение',
#  'тональный',
#  'анализ',
#  'сентимент',
#  'анализ',
#  'автоматизированный',
#  'анализ',
#  'эмоциональный',
#  'окрашенность',
#  'текст',
#  'плохо',
#  'нравиться',
#  'нравиться',
#  'др',
#  'можно',
#  'отнести',
#  'область',
#  'компьютерный',
#  'лингвистики',
#  'задача',
#  'применения',
#  'основном',
#  'лежать',
#  'предел',
#  'лингвистика',
#  'можно',
#  'разделить',
#  'обширный',
#  'области',
#  'маркетинг',
#  'очередь',
#  'анализ',
#  'отзыв',
#  'товар',
#  'услуги',
#  'социология',
#  'политология',
#  'последний',
#  'включает',
#  'первых',
#  'анализ',
#  'текст',
#  'сми',
#  'выявление',
#  'того',
#  'социально',
#  'значимый',
#  'вопрос',
#  'преподноситься',
#  'аудитория',
#  'отклик',
#  'можно',
#  'ожидать',
#  'публики',
#  'вторых',
#  'исследование',
#  'текст',
#  'социальный',
#  'медиа',
#  'блогов',
#  'социальный',
#  'сетей',
#  'форумов',
#  'пользовательский',
#  'контент',
#  'цель',
#  'выявление',
#  'общественный',
#  'мнение',
#  'части',
#  'представить',
#  'интернете',
#  'последний',
#  'компонент',
#  'являться',
#  'главный',
#  'целевой',
#  'область',
#  'знание',
#  'настоящий',
#  'проекта',
#  'очередь',
#  'проект',
#  'обращать',
#  'внимание',
#  'анализ',
#  'сми',
#  'сегодняшний',
#  'день',
#  'существовать',
#  'основный',
#  'подход',
#  'автоматический',
#  'определение',
#  'тональность',
#  'текстов',
#  'словарный',
#  'использовать',
#  'словарь',
#  'последний',
#  'применять',
#  'различный',
#  'метод',
#  'автоматический',
#  'классификация',
#  'основа',
#  'обучать',
#  'коллекций',
#  'удобный',
#  'коллекция',
#  'доступный',
#  'избыток',
#  'напр',
#  'отзыв',
#  'товар',
#  'общий',
#  'позитивный',
#  'негативный',
#  'оценка',
#  'товара',
#  'англоязычный',
#  'сфера',
#  'создать',
#  'большой',
#  'количество',
#  'текстовый',
#  'коллекция',
#  'особо',
#  'можно',
#  'выделить',
#  'университет',
#  'глазго',
#  'сконцентрировать',
#  'блог',
#  'разный',
#  'тематики',
#  'русский',
#  'сегменте',
#  'насколько',
#  'известно',
#  'свободный',
#  'доступ',
#  'находиться',
#  'коллекция',
#  'прямой',
#  'косвенный',
#  'речь',
#  'новостной',
#  'текстов',
#  'создать',
#  'ромип',
#  'непригодный',
#  'исследование',
#  'эмоциональный',
#  'составлять',
#  'текст',
#  'блогов',
#  'отсутствие',
#  'необходимый',
#  'количество',
#  'коллекция',
#  'текст',
#  'проставить',
#  'тональный',
#  'окраска',
#  'обратиться',
#  'словарный',
#  'подходу',
#  'английский',
#  'язык',
#  'словарный',
#  'подход',
#  'успешно',
#  'применяться',
#  'система',
#  'создать',
#  'фелвол',
#  'университет',
#  'вулверхемптон',
#  'великобритания',
#  'специально',
#  'предназначить',
#  'анализ',
#  'социальный',
#  'медиа',
#  'того',
#  'английский',
#  'сегмент',
#  'доступный',
#  'обширный',
#  'словари',
#  'русский',
#  'язык',
#  'известный',
#  'словарь',
#  'четверкин',
#  'н',
#  'лукашевич',
#  'представлять',
#  'список',
#  'оценочный',
#  'слов',
#  'извлечь',
#  'коллекция',
#  'отзыв',
#  'предметный',
#  'область',
#  'фильмы',
#  'книги',
#  'игры',
#  'телефоны',
#  'камеры',
#  'словарь',
#  'разработать',
#  'исследователь',
#  'соревнование',
#  'ромип',
#  'тональный',
#  'анализ',
#  'отзывов',
#  'видно',
#  'описания',
#  'создать',
#  'выявление',
#  'предпочтение',
#  'маркетинговый',
#  'исследованиях',
#  'анализ',
#  'общественный',
#  'мнение',
#  'текст',
#  'социально',
#  'политический',
#  'направленности',
#  'образом',
#  'цель',
#  'исследование',
#  'являться',
#  'разработка',
#  'тональный',
#  'словарь',
#  'краудсорсинговый',
#  'веб',
#  'ресурс',
#  'создание',
#  'инструмент',
#  'сентимент',
#  'анализа',
#  'тональный',
#  'словарь',
#  'список',
#  'слов',
#  'присвоить',
#  'вес',
#  'описывать',
#  'эмоциональный',
#  'окраску',
#  'словарь',
#  'использоваться',
#  'программный',
#  'обеспечении',
#  'находить',
#  'соответствующий',
#  'слово',
#  'текст',
#  'основа',
#  'усреднение',
#  'вес',
#  'определять',
#  'общий',
#  'тональность',
#  'текста',
#  'точность',
#  'качество',
#  'работа',
#  'словарь',
#  'проверяться',
#  'путём',
#  'сравнение',
#  'результат',
#  'результат',
#  'работа',
#  'людей',
#  'создавать',
#  'веб',
#  'ресурс',
#  'применимый',
#  'вид',
#  'тональный',
#  'разметки',
#  'словарь',
#  'проект',
#  'создаваться',
#  'настраивается',
#  'специально',
#  'анализ',
#  'пользовательский',
#  'интернет',
#  'контент',
#  'социально',
#  'политический',
#  'содержания',
#  'конечный',
#  'цель',
#  'использование',
#  'словарь',
#  'дальнейший',
#  'являться',
#  'изучение',
#  'общественный',
#  'мнение',
#  'интернет',
#  'аудитории',
#  'разработка',
#  'тональный',
#  'словарь',
#  'составление',
#  'тональный',
#  'словарь',
#  'язык',
#  'требовать',
#  'вычленение',
#  'эмоционально',
#  'окрасить',
#  'слово',
#  'слово',
#  'языка',
#  'полный',
#  'объём',
#  'невыполнимо',
#  'развитый',
#  'язык',
#  'насчитывать',
#  'сотня',
#  'тысяча',
#  'слов',
#  'возможно',
#  'альтернативный',
#  'стратегий',
#  'использование',
#  'уже',
#  'накопить',
#  'знание',
#  'язык',
#  'создание',
#  'собственных',
#  'опора',
#  'мнение',
#  'эксперт',
#  'сбор',
#  'представление',
#  'язык',
#  'простых',
#  'носителей',
#  'дать',
#  'работа',
#  'выбрать',
#  'сочетание',
#  'стратегий',
#  'этап',
#  'собираться',
#  'прототип',
#  'словаря',
#  'запасом',
#  'включаться',
#  'потенциально',
#  'окрасить',
#  'слова',
#  'этап',
#  'прототип',
#  'размечаться',
#  'добровольцами',
#  'человек',
#  'слово',
#  'прототип',
#  'словаря',
#  'потенциально',
#  'окрасить',
#  'слова',
#  'привязка',
#  'текст',
#  'социально',
#  'политический',
#  'направленности',
#  'этап',
#  'использовать',
#  'уже',
#  'иметься',
#  'сведение',
#  'тональный',
#  'окрасить',
#  'словах',
#  'сила',
#  'того',
#  'оценочный',
#  'значение',
#  'частый',
#  'выражаться',
#  'язык',
#  'помощь',
#  'признаковый',
#  'слово',
#  'прилагательное',
#  'наречий',
#  'начать',
#  'поиск',
#  'потенциально',
#  'окрасить',
#  'слово',
#  'частотный',
#  'словарь',
#  'прилагательных',
#  'создать',
#  'лаборатория',
#  'цифровой',
#  'общество',
#  'основа',
#  'обширный',
#  'коллекция',
#  'русскоязычный',
#  'текст',
#  'фэйсбук',
#  'рамка',
#  'сотрудничество',
#  'лаборатория',
#  'интернет',
#  'исследование',
#  'линис',
#  'ниу',
#  'вшэ',
#  'список',
#  'содержать',
#  'прилагательных',
#  'встретиться',
#  'коллекция',
#  'менее',
#  'получить',
#  'прилагательное',
#  'разметить',
#  'кодировщик',
#  'линиса',
#  'точка',
#  'зрение',
#  'наличие',
#  'эмоциональный',
#  'компонент',
#  'список',
#  'кодировщика',
#  'конец',
#  'получить',
#  'список',
#  'прилагательных',
#  'кодировщик',
#  'посчитать',
#  'отрицательно',
#  'положительный',
#  'окрасить',
#  'передавать',
#  'усиление',
#  'уменьшение',
#  'эмоции',
#  'затем',
#  'словарь',
#  'прилагательное',
#  'социальный',
#  'сеть',
#  'фэйсбук',
#  'дополнить',
#  'следующий',
#  'данными',
#  'наречий',
#  'получить',
#  'прилагательных',
#  'уже',
#  'содержаться',
#  'списке',
#  'добавление',
#  'наречие',
#  'сделать',
#  'автоматически',
#  'прилагательное',
#  'отрезаться',
#  'окончание',
#  'ий',
#  'ый',
#  'добавляться',
#  'окончание',
#  'наречие',
#  'е',
#  'затем',
#  'получить',
#  'слово',
#  'проверяться',
#  'помощь',
#  'морфоанализатор',
#  'слово',
#  'присутствовать',
#  'словаре',
#  'использовать',
#  'анализатор',
#  'т',
#  'е',
#  'реальный',
#  'наречием',
#  'добавляться',
#  'список',
#  'словарь',
#  'четверкин',
#  'н',
#  'лукашевич',
#  'словарь',
#  'находиться',
#  'свободный',
#  'доступ',
#  'адресу',
#  'междометие',
#  'взять',
#  'объяснительный',
#  'словарь',
#  'русский',
#  'язык',
#  'слово',
#  'добавить',
#  'словаря',
#  'составить',
#  'ю',
#  'павлов',
#  'основа',
#  'перевод',
#  'англоязычный',
#  'словаря',
#  'поставлять',
#  'программа',
#  'оценка',
#  'сила',
#  'положительный',
#  'отрицательный',
#  'настроений',
#  'ориентировать',
#  'работа',
#  'краткий',
#  'интернет',
#  'сообщениями',
#  'публиковать',
#  'социальный',
#  'сеть',
#  'отношение',
#  'сходный',
#  'текст',
#  'блогосферы',
#  'очередь',
#  'комментарий',
#  'постам',
#  'образом',
#  'предварительный',
#  'итоговый',
#  'словарь',
#  'потенциально',
#  'окрасить',
#  'тональный',
#  'слов',
#  'составить',
#  'различный',
#  'источник',
#  'состоять',
#  'лексический',
#  'единиц',
#  'повторяться',
#  'слова',
#  'тональный',
#  'словарь',
#  'ориентировать',
#  'текст',
#  'социальный',
#  'медиа',
#  'дать',
#  'блог',
#  'платформа',
#  'живой',
#  'журнал',
#  'этап',
#  'сформировать',
#  'коллекция',
#  'документов',
#  'посвятить',
#  'социально',
#  'политический',
#  'тематике',
#  'использовать',
#  'проект',
#  'целями',
#  'источник',
#  'специфичный',
#  'дать',
#  'предметный',
#  'область',
#  'тональный',
#  'слов',
#  'источник',
#  'контекст',
#  'слов',
#  'облегчать',
#  'разметка',
#  'особенно',
#  'случай',
#  'полисемии',
#  'источник',
#  'тестовый',
#  'коллекции',
#  'проверяться',
#  'качество',
#  'словарь',
#  'размечаться',
#  'год',
#  'вебресурсе',
#  'качество',
#  'источник',
#  'данные',
#  'использоваться',
#  'запись',
#  'блог',
#  'платформа',
#  'живой',
#  'журнал',
#  'линиса',
#  'разработать',
#  'программный',
#  'обеспечение',
#  'позволять',
#  'закачивать',
#  'пост',
#  'комментарий',
#  'живой',
#  'журнала',
#  'протяжение',
#  'год',
#  'март',
#  'март',
#  'лаборатория',
#  'вестись',
#  'постоянный',
#  'еженедельный',
#  'закачка',
#  'пост',
#  'комментарий',
#  'популярный',
#  'блогер',
#  'живой',
#  'журнал',
#  'рейтинг',
#  'социальный',
#  'капитал',
#  'предоставлять',
#  'жж',
#  'реляционный',
#  'база',
#  'дать',
#  'работа',
#  'использовать',
#  'пост',
#  'год',
#  'размер',
#  'порядок',
#  'млн',
#  'единиц',
#  'период',
#  'год',
#  'взять',
#  'того',
#  'компенсировать',
#  'наличие',
#  'узкий',
#  'событийно',
#  'зависимый',
#  'служить',
#  'источник',
#  'слишком',
#  'специализированный',
#  'слов',
#  'топовый',
#  'блогер',
#  'взяты',
#  'предыдущий',
#  'исследование',
#  'известно',
#  'отличаться',
#  'обычный',
#  'тематике',
#  'дать',
#  'блог',
#  'гораздо',
#  'менее',
#  'разредить',
#  'гораздо',
#  'менее',
#  'зашумлен',
#  'спамом',
#  'тематический',
#  'моделирование',
#  'вычленение',
#  'группа',
#  'текст',
#  'социально',
#  'политический',
#  'тематика',
#  'последующий',
#  'отбор',
#  'специфичный',
#  'тональный',
#  'слово',
#  'возможно',
#  'способами',
#  'заимствование',
#  'запись',
#  'создать',
#  'рубрик',
#  'тэгам',
#  'помощь',
#  'ручной',
#  'разметки',
#  'помощь',
#  'автоматический',
#  'выделение',
#  'релевантный',
#  'текст',
#  'например',
#  'помощь',
#  'кластерный',
#  'анализ',
#  'вероятностный',
#  'алгоритмов',
#  'тематический',
#  'моделирование',
#  'представление',
#  'создатель',
#  'рубрика',
#  'тэг',
#  'граница',
#  'социально',
#  'политический',
#  'известны',
#  'автоматический',
#  'метод',
#  'наиболее',
#  'подходить',
#  'самостоятельный',
#  'извлечение',
#  'релевантный',
#  'больший',
#  'коллекция',
#  'текстов',
#  'предпочесть',
#  'тематический',
#  'моделирование',
#  'кластерный',
#  'анализу',
#  'создавать',
#  'нечёткий',
#  'множество',
#  'текстов',
#  'можно',
#  'отсортировать',
#  'релевантности',
#  'тематический',
#  'моделирование',
#  'проводиться',
#  'помощь',
#  'программный',
#  'обеспечение',
#  'разработать',
#  'лаборатория',
#  'интернет',
#  'исследований',
#  'тематический',
#  'модель',
#  'заключаться',
#  'следующем',
#  'компьютерный',
#  'лингвистика',
#  'тема',
#  'пониматься',
#  'совокупность',
#  'слов',
#  'иметь',
#  'тенденция',
#  'встречаться',
#  'совместно',
#  'текстах',
#  'упрощённый',
#  'понимание',
#  'темы',
#  'результат',
#  'применение',
#  'группа',
#  'сходный',
#  'текст',
#  'многократно',
#  'проверяться',
#  'предмет',
#  'интерпретируемость',
#  'людьми',
#  'демонстрировать',
#  'хороший',
#  'качество',
#  'интерпретация',
#  'тема',
#  'позволять',
#  'сформулировать',
#  'лингвистический',
#  'модель',
#  'генерация',
#  'контент',
#  'документ',
#  'коллекции',
#  'основание',
#  'модель',
#  'разработать',
#  'алгоритм',
#  'вычисление',
#  'распределение',
#  'документ',
#  'слово',
#  'темам',
#  'момент',
#  'разработать',
#  'множество',
#  'различный',
#  'вариант',
#  'тематический',
#  'модель',
#  'базироваться',
#  'основный',
#  'вариантах',
#  'вариационный',
#  'модель',
#  'сэмплирование',
#  'гиббс',
#  'предполагается',
#  'существовать',
#  'конечный',
#  'множество',
#  'скрытый',
#  'коллекция',
#  'документ',
#  'порождаться',
#  'дискретный',
#  'распределение',
#  'документ',
#  'слово',
#  'тема',
#  'переменный',
#  'являться',
#  'наблюдать',
#  'переменный',
#  'коллекция',
#  'документов',
#  'переменный',
#  'скрытой',
#  'т',
#  'е',
#  'появление',
#  'пара',
#  'связать',
#  'неизвестный',
#  'тема',
#  'построить',
#  'тематический',
#  'модель',
#  'коллекция',
#  'означать',
#  'найти',
#  'множество',
#  'скрытый',
#  'определить',
#  'условный',
#  'распределение',
#  'тема',
#  'документ',
#  'образом',
#  'представлять',
#  'матрицу',
#  'набор',
#  'уникальный',
#  'слово',
#  'иметь',
#  'разный',
#  'вероятность',
#  'принадлежность',
#  'темам',
#  'представлять',
#  'матрица',
#  'набор',
#  'документ',
#  'иметь',
#  'разный',
#  'вероятность',
#  'темам',
#  'рамка',
#  'дать',
#  'работа',
#  'использоваться',
#  'процедура',
#  'сэмплирование',
#  'гиббс',
#  'нахождение',
#  'распределение',
#  'документ',
#  'слово',
#  'тема',
#  'задать',
#  'коллекция',
#  'документов',
#  'выбор',
#  'методика',
#  'обусловить',
#  'вычислительный',
#  'простотой',
#  'существовать',
#  'множество',
#  'различный',
#  'программный',
#  'средство',
#  'проведение',
#  'тематический',
#  'моделирование',
#  'показывать',
#  'анализ',
#  'средство',
#  'правило',
#  'отсутствовать',
#  'вычислительный',
#  'ядро',
#  'препроцессинг',
#  'интерфейс',
#  'др',
#  'справляться',
#  'больший',
#  'объемами',
#  'требовать',
#  'развёртывание',
#  'кластера',
#  'выбрать',
#  'программный',
#  'продукт',
#  'собственный',
#  'разработка',
#  'разработчик',
#  'н',
#  'кольцов',
#  'г',
#  'филипов',
#  'способный',
#  'работать',
#  'больший',
#  'данные',
#  'персональный',
#  'компьютер',
#  'иметь',
#  'необходимый',
#  'модули',
#  'модуль',
#  'препроцессина',
#  'модуль',
#  'тематический',
#  'моделирование',
#  'модуль',
#  'анализ',
#  'результатов',
#  'препроцессинг',
#  'данных',
#  'провести',
#  'препроцессинг',
#  'включить',
#  'следующий',
#  'процедуры',
#  'удаление',
#  'тэгов',
#  'лемматизация',
#  ...]

# %%
len(text_words)
# Out:
# 1621

# %%
frequency={}
for word in text_words:  # рассчитываем частоты слов
    count = frequency.get(word,0)  # создаём словарь СЛОВО и ЧАСТОТА
    frequency[word] = count + 1  # увеличиваем ЧАСТОТУ при считывании одинаковых лемм слова

frequency
# Out:
# {'лексический': 4,
#  'ресурс': 5,
#  'анализ': 14,
#  'тональность': 3,
#  'социально': 24,
#  'политический': 21,
#  'текст': 26,
#  'русский': 4,
#  'язык': 9,
#  'алексеева': 1,
#  'н': 5,
#  'кольцов': 3,
#  'ю': 2,
#  'национальный': 1,
#  'исследовательский': 1,
#  'университет': 3,
#  'высокий': 2,
#  'школа': 1,
#  'экономики': 1,
#  'санкт': 1,
#  'петербург': 1,
#  'введение': 1,
#  'тональный': 16,
#  'сентимент': 2,
#  'автоматизированный': 1,
#  'эмоциональный': 8,
#  'окрашенность': 2,
#  'плохо': 2,
#  'нравиться': 2,
#  'др': 2,
#  'можно': 6,
#  'отнести': 1,
#  'область': 4,
#  'компьютерный': 2,
#  'лингвистики': 1,
#  'задача': 2,
#  'применения': 1,
#  'основном': 1,
#  'лежать': 1,
#  'предел': 2,
#  'лингвистика': 2,
#  'разделить': 1,
#  'обширный': 3,
#  'области': 2,
#  'маркетинг': 1,
#  'очередь': 3,
#  'отзыв': 3,
#  'товар': 2,
#  'услуги': 1,
#  'социология': 1,
#  'политология': 1,
#  'последний': 4,
#  'включает': 1,
#  'первых': 1,
#  'сми': 2,
#  'выявление': 3,
#  'того': 4,
#  'значимый': 2,
#  'вопрос': 1,
#  'преподноситься': 1,
#  'аудитория': 1,
#  'отклик': 1,
#  'ожидать': 1,
#  'публики': 1,
#  'вторых': 1,
#  'исследование': 5,
#  'социальный': 9,
#  'медиа': 3,
#  'блогов': 2,
#  'сетей': 1,
#  'форумов': 1,
#  'пользовательский': 4,
#  'контент': 4,
#  'цель': 3,
#  'общественный': 5,
#  'мнение': 9,
#  'части': 1,
#  'представить': 1,
#  'интернете': 1,
#  'компонент': 2,
#  'являться': 6,
#  'главный': 1,
#  'целевой': 1,
#  'знание': 2,
#  'настоящий': 2,
#  'проекта': 1,
#  'проект': 4,
#  'обращать': 1,
#  'внимание': 1,
#  'сегодняшний': 1,
#  'день': 1,
#  'существовать': 3,
#  'основный': 2,
#  'подход': 2,
#  'автоматический': 6,
#  'определение': 3,
#  'текстов': 7,
#  'словарный': 3,
#  'использовать': 6,
#  'словарь': 25,
#  'применять': 1,
#  'различный': 4,
#  'метод': 3,
#  'классификация': 1,
#  'основа': 6,
#  'обучать': 1,
#  'коллекций': 1,
#  'удобный': 1,
#  'коллекция': 18,
#  'доступный': 2,
#  'избыток': 1,
#  'напр': 1,
#  'общий': 2,
#  'позитивный': 1,
#  'негативный': 1,
#  'оценка': 2,
#  'товара': 1,
#  'англоязычный': 2,
#  'сфера': 2,
#  'создать': 6,
#  'большой': 2,
#  'количество': 3,
#  'текстовый': 1,
#  'особо': 1,
#  'выделить': 3,
#  'глазго': 1,
#  'сконцентрировать': 1,
#  'блог': 5,
#  'разный': 5,
#  'тематики': 4,
#  'сегменте': 1,
#  'насколько': 1,
#  'известно': 2,
#  'свободный': 2,
#  'доступ': 2,
#  'находиться': 3,
#  'прямой': 1,
#  'косвенный': 1,
#  'речь': 1,
#  'новостной': 1,
#  'ромип': 2,
#  'непригодный': 1,
#  'составлять': 2,
#  'отсутствие': 1,
#  'необходимый': 2,
#  'проставить': 1,
#  'окраска': 1,
#  'обратиться': 1,
#  'подходу': 1,
#  'английский': 2,
#  'успешно': 1,
#  'применяться': 1,
#  'система': 1,
#  'фелвол': 1,
#  'вулверхемптон': 1,
#  'великобритания': 1,
#  'специально': 2,
#  'предназначить': 1,
#  'сегмент': 1,
#  'словари': 1,
#  'известный': 1,
#  'четверкин': 3,
#  'лукашевич': 3,
#  'представлять': 3,
#  'список': 18,
#  'оценочный': 3,
#  'слов': 16,
#  'извлечь': 1,
#  'предметный': 3,
#  'фильмы': 1,
#  'книги': 1,
#  'игры': 1,
#  'телефоны': 1,
#  'камеры': 1,
#  'разработать': 7,
#  'исследователь': 2,
#  'соревнование': 1,
#  'отзывов': 2,
#  'видно': 1,
#  'описания': 1,
#  'предпочтение': 1,
#  'маркетинговый': 1,
#  'исследованиях': 1,
#  'направленности': 6,
#  'образом': 6,
#  'разработка': 4,
#  'краудсорсинговый': 1,
#  'веб': 3,
#  'создание': 3,
#  'инструмент': 1,
#  'анализа': 1,
#  'присвоить': 1,
#  'вес': 2,
#  'описывать': 2,
#  'окраску': 1,
#  'использоваться': 4,
#  'программный': 5,
#  'обеспечении': 1,
#  'находить': 1,
#  'соответствующий': 1,
#  'слово': 42,
#  'усреднение': 1,
#  'определять': 2,
#  'текста': 1,
#  'точность': 1,
#  'качество': 4,
#  'работа': 7,
#  'проверяться': 4,
#  'путём': 1,
#  'сравнение': 1,
#  'результат': 6,
#  'людей': 1,
#  'создавать': 2,
#  'применимый': 1,
#  'вид': 2,
#  'разметки': 2,
#  'создаваться': 1,
#  'настраивается': 1,
#  'интернет': 8,
#  'содержания': 1,
#  'конечный': 3,
#  'использование': 2,
#  'дальнейший': 3,
#  'изучение': 2,
#  'аудитории': 1,
#  'составление': 1,
#  'требовать': 2,
#  'вычленение': 4,
#  'эмоционально': 1,
#  'окрасить': 11,
#  'языка': 1,
#  'полный': 1,
#  'объём': 1,
#  'невыполнимо': 1,
#  'развитый': 1,
#  'насчитывать': 1,
#  'сотня': 1,
#  'тысяча': 1,
#  'возможно': 2,
#  'альтернативный': 1,
#  'стратегий': 2,
#  'уже': 3,
#  'накопить': 1,
#  'собственных': 1,
#  'опора': 1,
#  'эксперт': 1,
#  'сбор': 1,
#  'представление': 3,
#  'простых': 1,
#  'носителей': 1,
#  'дать': 9,
#  'выбрать': 5,
#  'сочетание': 2,
#  'этап': 4,
#  'собираться': 1,
#  'прототип': 6,
#  'словаря': 8,
#  'запасом': 1,
#  'включаться': 1,
#  'потенциально': 8,
#  'слова': 9,
#  'размечаться': 2,
#  'добровольцами': 1,
#  'человек': 1,
#  'привязка': 1,
#  'иметься': 1,
#  'сведение': 1,
#  'словах': 1,
#  'сила': 2,
#  'значение': 2,
#  'частый': 2,
#  'выражаться': 1,
#  'помощь': 7,
#  'признаковый': 1,
#  'прилагательное': 4,
#  'наречий': 2,
#  'начать': 1,
#  'поиск': 1,
#  'частотный': 5,
#  'прилагательных': 4,
#  'лаборатория': 4,
#  'цифровой': 1,
#  'общество': 1,
#  'русскоязычный': 1,
#  'фэйсбук': 2,
#  'рамка': 2,
#  'сотрудничество': 1,
#  'линис': 1,
#  'ниу': 1,
#  'вшэ': 1,
#  'содержать': 4,
#  'встретиться': 3,
#  'менее': 4,
#  'получить': 8,
#  'разметить': 1,
#  'кодировщик': 3,
#  'линиса': 3,
#  'точка': 1,
#  'зрение': 1,
#  'наличие': 2,
#  'кодировщика': 2,
#  'конец': 1,
#  'посчитать': 1,
#  'отрицательно': 1,
#  'положительный': 2,
#  'передавать': 3,
#  'усиление': 2,
#  'уменьшение': 2,
#  'эмоции': 1,
#  'затем': 3,
#  'сеть': 3,
#  'дополнить': 1,
#  'следующий': 3,
#  'данными': 1,
#  'содержаться': 3,
#  'списке': 1,
#  'добавление': 1,
#  'наречие': 2,
#  'сделать': 2,
#  'автоматически': 1,
#  'отрезаться': 1,
#  'окончание': 2,
#  'ий': 1,
#  'ый': 1,
#  'добавляться': 3,
#  'е': 3,
#  'морфоанализатор': 1,
#  'присутствовать': 2,
#  'словаре': 1,
#  'анализатор': 1,
#  'т': 3,
#  'реальный': 1,
#  'наречием': 1,
#  'адресу': 1,
#  'междометие': 1,
#  'взять': 3,
#  'объяснительный': 1,
#  'добавить': 1,
#  'составить': 4,
#  'павлов': 1,
#  'перевод': 1,
#  'поставлять': 1,
#  'программа': 1,
#  'отрицательный': 1,
#  'настроений': 1,
#  'ориентировать': 3,
#  'краткий': 1,
#  'сообщениями': 1,
#  'публиковать': 1,
#  'отношение': 2,
#  'сходный': 2,
#  'блогосферы': 1,
#  'комментарий': 3,
#  'постам': 1,
#  'предварительный': 1,
#  'итоговый': 1,
#  'источник': 9,
#  'состоять': 1,
#  'единиц': 4,
#  'повторяться': 1,
#  'платформа': 2,
#  'живой': 4,
#  'журнал': 3,
#  'сформировать': 2,
#  'документов': 5,
#  'посвятить': 1,
#  'тематике': 2,
#  'целями': 1,
#  'специфичный': 4,
#  'контекст': 1,
#  'облегчать': 1,
#  'разметка': 3,
#  'особенно': 1,
#  'случай': 1,
#  'полисемии': 1,
#  'тестовый': 1,
#  'коллекции': 3,
#  'год': 4,
#  'вебресурсе': 1,
#  'данные': 2,
#  'запись': 2,
#  'обеспечение': 2,
#  'позволять': 2,
#  'закачивать': 1,
#  'пост': 3,
#  'журнала': 1,
#  'протяжение': 1,
#  'март': 2,
#  'вестись': 1,
#  'постоянный': 1,
#  'еженедельный': 1,
#  'закачка': 1,
#  'популярный': 1,
#  'блогер': 2,
#  'рейтинг': 1,
#  'капитал': 1,
#  'предоставлять': 1,
#  'жж': 1,
#  'реляционный': 1,
#  'база': 1,
#  'размер': 3,
#  'порядок': 1,
#  'млн': 1,
#  'период': 1,
#  'компенсировать': 1,
#  'узкий': 1,
#  'событийно': 1,
#  'зависимый': 1,
#  'служить': 1,
#  'слишком': 3,
#  'специализированный': 1,
#  'топовый': 1,
#  'взяты': 1,
#  'предыдущий': 2,
#  'отличаться': 1,
#  'обычный': 1,
#  'гораздо': 2,
#  'разредить': 1,
#  'зашумлен': 1,
#  'спамом': 1,
#  'тематический': 12,
#  'моделирование': 10,
#  'группа': 2,
#  'тематика': 3,
#  'последующий': 1,
#  'отбор': 2,
#  'способами': 1,
#  'заимствование': 1,
#  'рубрик': 1,
#  'тэгам': 1,
#  'ручной': 1,
#  'выделение': 1,
#  'релевантный': 3,
#  'например': 1,
#  'кластерный': 2,
#  'вероятностный': 10,
#  'алгоритмов': 1,
#  'создатель': 1,
#  'рубрика': 1,
#  'тэг': 1,
#  'граница': 1,
#  'известны': 1,
#  'наиболее': 9,
#  'подходить': 1,
#  'самостоятельный': 1,
#  'извлечение': 2,
#  'больший': 5,
#  'предпочесть': 1,
#  'анализу': 1,
#  'нечёткий': 1,
#  'множество': 5,
#  'отсортировать': 2,
#  'релевантности': 1,
#  'проводиться': 3,
#  'исследований': 1,
#  'модель': 7,
#  'заключаться': 1,
#  'следующем': 1,
#  'тема': 11,
#  'пониматься': 1,
#  'совокупность': 1,
#  'иметь': 5,
#  'тенденция': 1,
#  'встречаться': 5,
#  'совместно': 1,
#  'текстах': 2,
#  'упрощённый': 1,
#  'понимание': 1,
#  'темы': 2,
#  'применение': 1,
#  'многократно': 1,
#  'предмет': 1,
#  'интерпретируемость': 1,
#  'людьми': 1,
#  'демонстрировать': 1,
#  'хороший': 1,
#  'интерпретация': 1,
#  'сформулировать': 1,
#  'лингвистический': 2,
#  'генерация': 1,
#  'документ': 16,
#  'основание': 3,
#  'алгоритм': 3,
#  'вычисление': 1,
#  'распределение': 10,
#  'темам': 8,
#  'момент': 1,
#  'вариант': 1,
#  'базироваться': 1,
#  'вариантах': 1,
#  'вариационный': 1,
#  'сэмплирование': 3,
#  'гиббс': 3,
#  'предполагается': 1,
#  'скрытый': 2,
#  'порождаться': 1,
#  'дискретный': 1,
#  'переменный': 3,
#  'наблюдать': 1,
#  'скрытой': 1,
#  'появление': 1,
#  'пара': 1,
#  'связать': 1,
#  'неизвестный': 1,
#  'построить': 1,
#  'означать': 2,
#  'найти': 4,
#  'определить': 1,
#  'условный': 1,
#  'матрицу': 1,
#  'набор': 3,
#  'уникальный': 1,
#  'вероятность': 8,
#  'принадлежность': 4,
#  'матрица': 9,
#  'процедура': 1,
#  'нахождение': 1,
#  'задать': 1,
#  'выбор': 2,
#  'методика': 3,
#  'обусловить': 1,
#  'вычислительный': 2,
#  'простотой': 1,
#  'средство': 2,
#  'проведение': 1,
#  'показывать': 1,
#  'правило': 1,
#  'отсутствовать': 1,
#  'ядро': 1,
#  'препроцессинг': 3,
#  'интерфейс': 1,
#  'справляться': 1,
#  'объемами': 1,
#  'развёртывание': 1,
#  'кластера': 1,
#  'продукт': 1,
#  'собственный': 1,
#  'разработчик': 1,
#  'г': 1,
#  'филипов': 1,
#  'способный': 1,
#  'работать': 1,
#  'персональный': 1,
#  'компьютер': 1,
#  'модули': 1,
#  'модуль': 3,
#  'препроцессина': 1,
#  'результатов': 1,
#  'данных': 1,
#  'провести': 1,
#  'включить': 2,
#  'процедуры': 1,
#  'удаление': 4,
#  'тэгов': 1,
#  'лемматизация': 1,
#  'приведение': 1,
#  'начальный': 1,
#  'форме': 1,
#  'стопа': 1,
#  'несущий': 1,
#  'смысл': 1,
#  'влиять': 1,
#  'тематику': 1,
#  'постоянно': 1,
#  'корректироваться': 1,
#  'подсчёт': 1,
#  'частота': 3,
#  'лемм': 1,
#  'редкий': 1,
#  'дискриминировать': 1,
#  'силы': 1,
#  'конвертация': 1,
#  'векторный': 2,
#  'формат': 1,
#  'основать': 1,
#  'предполагать': 1,
#  'тексте': 1,
#  'входной': 1,
#  'параметр': 3,
#  'являются': 1,
#  'число': 6,
#  'дирихло': 1,
#  'итерация': 2,
#  'сэмплирования': 1,
#  'матрицы': 2,
#  'ячейка': 1,
#  'теме': 4,
#  'равный': 4,
#  'опыта': 1,
#  'показавшего': 1,
#  'маленький': 2,
#  'приводить': 1,
#  'излишний': 1,
#  'укрупнённый': 1,
#  'доля': 1,
#  'заимствовать': 1,
#  'подбираться': 1,
#  'экспериментально': 1,
#  'графика': 1,
#  'сходимость': 1,
#  'ход': 1,
#  'столбец': 1,
#  'отдельный': 1,
#  'тему': 1,
#  'элемент': 1,
#  'убыванию': 1,
#  'величина': 3,
#  'падать': 1,
#  'достаточно': 1,
#  'быстро': 1,
#  'передать': 1,
#  'кодировщикам': 1,
#  'определяли': 1,
#  'политическими': 1,
#  'кодирование': 1,
#  'отобрать': 6,
#  'считаться': 1,
#  'социальнополитической': 1,
#  'минимум': 1,
#  'согласованность': 1,
#  'расчёт': 1,
#  'довольно': 1,
#  'низкий': 1,
#  'показатель': 1,
#  'простой': 1,
#  'задач': 1,
#  'редко': 1,
#  'бывать': 1,
#  'согласие': 1,
#  'кодировщиков': 1,
#  'несмотря': 1,
#  'относиться': 2,
#  'выбирать': 1,
#  'документы': 1,
#  'средний': 1,
#  'порог': 1,
#  'массив': 1,
#  'миллион': 1,
#  'получиться': 1,
#  'формирование': 1,
#  'окончательный': 2,
#  'дополнение': 1,
#  'лингвист': 1,
#  'назвать': 1,
#  'темами': 2,
#  'связанный': 2,
#  'высказывание': 2,
#  'эмоций': 1,
#  'формироваться': 1,
#  'областей': 1,
#  'лексики': 1,
#  'лексика': 2,
#  'часто': 1,
#  'вместе': 1,
#  'объект': 1,
#  'направлена': 1,
#  'разным': 1,
#  'политическим': 1,
#  'оценку': 1,
#  'решить': 1,
#  'итог': 2,
#  'привести': 2,
#  'пример': 1,
#  'оформление': 1,
#  'списка': 1,
#  'социальнополитический': 3,
#  'нормализовать': 1,
#  'форму': 1,
#  'дублироваться': 1,
#  'единица': 2,
#  'немой': 1,
#  'остаться': 2,
#  'признать': 1,
#  'эмоция': 2,
#  'далее': 1,
#  'пересечь': 1,
#  'списками': 1,
#  'указать': 1,
#  'какого': 1,
#  'какий': 1,
#  'источника': 1,
#  'пришло': 1,
#  'списков': 1,
#  'информация': 1,
#  'том': 1,
#  'ещё': 2,
#  'списках': 2,
#  'встречается': 1,
#  'сразу': 1,
#  'источников': 1,
#  'исключение': 2,
#  'версия': 2,
#  'представлены': 1,
#  'просмотреть': 2,
#  'вручную': 1,
#  'исключить': 1,
#  'счесть': 1,
#  'нерелевантными': 1,
#  'основное': 1,
#  'войти': 2,
#  'аккумулятор': 1,
#  'диагональ': 1,
#  'панель': 1,
#  'этого': 1,
#  'часть': 3,
#  'оказаться': 2,
#  'исключили': 1,
#  'операция': 1,
#  'сумма': 1,
#  'дубликат': 1,
#  'удалены': 1,
#  'окончательно': 1,
#  'сопоставить': 1,
#  'выбираться': 1,
#  'максимальный': 1,
#  'финальный': 1,
#  'успешный': 1,
#  'необходимо': 1,
#  'понимать': 1,
#  'краудсорсинг': 1,
#  'время': 1,
#  'заключение': 1,
#  'статья': 1,
#  'описать': 1,
#  'промежуточный': 1,
#  'возможность': 1,
#  'заряженности': 1,
#  'контента': 1,
#  'позволить': 1,
#  'точнее': 1,
#  'активный': 1,
#  'население': 1,
#  'вопросам': 1,
#  'важность': 1,
#  'общественность': 1,
#  'подтверждается': 1,
#  'прочего': 1,
#  'роль': 1,
#  'прокатиться': 1,
#  'мир': 1,
#  'волна': 1,
#  'протест': 1,
#  'революция': 1,
#  'годов': 1}

# %%
freq = sorted(frequency.items(), key=lambda x:x[1], reverse = True) #создаём список, в котором пары СЛОВО и ЧАСТОТА упорядочены по убыванию
length = len(text_words)

print(length)
print(freq)
# Out:
# 1621
# [('слово', 42), ('текст', 26), ('словарь', 25), ('социально', 24), ('политический', 21), ('коллекция', 18), ('список', 18), ('тональный', 16), ('слов', 16), ('документ', 16), ('анализ', 14), ('тематический', 12), ('окрасить', 11), ('тема', 11), ('моделирование', 10), ('вероятностный', 10), ('распределение', 10), ('язык', 9), ('социальный', 9), ('мнение', 9), ('дать', 9), ('слова', 9), ('источник', 9), ('наиболее', 9), ('матрица', 9), ('эмоциональный', 8), ('интернет', 8), ('словаря', 8), ('потенциально', 8), ('получить', 8), ('темам', 8), ('вероятность', 8), ('текстов', 7), ('разработать', 7), ('работа', 7), ('помощь', 7), ('модель', 7), ('можно', 6), ('являться', 6), ('автоматический', 6), ('использовать', 6), ('основа', 6), ('создать', 6), ('направленности', 6), ('образом', 6), ('результат', 6), ('прототип', 6), ('число', 6), ('отобрать', 6), ('ресурс', 5), ('н', 5), ('исследование', 5), ('общественный', 5), ('блог', 5), ('разный', 5), ('программный', 5), ('выбрать', 5), ('частотный', 5), ('документов', 5), ('больший', 5), ('множество', 5), ('иметь', 5), ('встречаться', 5), ('лексический', 4), ('русский', 4), ('область', 4), ('последний', 4), ('того', 4), ('пользовательский', 4), ('контент', 4), ('проект', 4), ('различный', 4), ('тематики', 4), ('разработка', 4), ('использоваться', 4), ('качество', 4), ('проверяться', 4), ('вычленение', 4), ('этап', 4), ('прилагательное', 4), ('прилагательных', 4), ('лаборатория', 4), ('содержать', 4), ('менее', 4), ('составить', 4), ('единиц', 4), ('живой', 4), ('специфичный', 4), ('год', 4), ('найти', 4), ('принадлежность', 4), ('удаление', 4), ('теме', 4), ('равный', 4), ('тональность', 3), ('кольцов', 3), ('университет', 3), ('обширный', 3), ('очередь', 3), ('отзыв', 3), ('выявление', 3), ('медиа', 3), ('цель', 3), ('существовать', 3), ('определение', 3), ('словарный', 3), ('метод', 3), ('количество', 3), ('выделить', 3), ('находиться', 3), ('четверкин', 3), ('лукашевич', 3), ('представлять', 3), ('оценочный', 3), ('предметный', 3), ('веб', 3), ('создание', 3), ('конечный', 3), ('дальнейший', 3), ('уже', 3), ('представление', 3), ('встретиться', 3), ('кодировщик', 3), ('линиса', 3), ('передавать', 3), ('затем', 3), ('сеть', 3), ('следующий', 3), ('содержаться', 3), ('добавляться', 3), ('е', 3), ('т', 3), ('взять', 3), ('ориентировать', 3), ('комментарий', 3), ('журнал', 3), ('разметка', 3), ('коллекции', 3), ('пост', 3), ('размер', 3), ('слишком', 3), ('тематика', 3), ('релевантный', 3), ('проводиться', 3), ('основание', 3), ('алгоритм', 3), ('сэмплирование', 3), ('гиббс', 3), ('переменный', 3), ('набор', 3), ('методика', 3), ('препроцессинг', 3), ('модуль', 3), ('частота', 3), ('параметр', 3), ('величина', 3), ('социальнополитический', 3), ('часть', 3), ('ю', 2), ('высокий', 2), ('сентимент', 2), ('окрашенность', 2), ('плохо', 2), ('нравиться', 2), ('др', 2), ('компьютерный', 2), ('задача', 2), ('предел', 2), ('лингвистика', 2), ('области', 2), ('товар', 2), ('сми', 2), ('значимый', 2), ('блогов', 2), ('компонент', 2), ('знание', 2), ('настоящий', 2), ('основный', 2), ('подход', 2), ('доступный', 2), ('общий', 2), ('оценка', 2), ('англоязычный', 2), ('сфера', 2), ('большой', 2), ('известно', 2), ('свободный', 2), ('доступ', 2), ('ромип', 2), ('составлять', 2), ('необходимый', 2), ('английский', 2), ('специально', 2), ('исследователь', 2), ('отзывов', 2), ('вес', 2), ('описывать', 2), ('определять', 2), ('создавать', 2), ('вид', 2), ('разметки', 2), ('использование', 2), ('изучение', 2), ('требовать', 2), ('возможно', 2), ('стратегий', 2), ('сочетание', 2), ('размечаться', 2), ('сила', 2), ('значение', 2), ('частый', 2), ('наречий', 2), ('фэйсбук', 2), ('рамка', 2), ('наличие', 2), ('кодировщика', 2), ('положительный', 2), ('усиление', 2), ('уменьшение', 2), ('наречие', 2), ('сделать', 2), ('окончание', 2), ('присутствовать', 2), ('отношение', 2), ('сходный', 2), ('платформа', 2), ('сформировать', 2), ('тематике', 2), ('данные', 2), ('запись', 2), ('обеспечение', 2), ('позволять', 2), (' ...

# %%
n_list=[]
for words in freq:  # проверяем каждую пару СЛОВО и ЧАСТОТА в отсортированном тексте
    fr_lst = list(words) # превращаем пары в круглых скобках, созданные анонимной функцией LAMBDA, в список из двух элементов - СЛОВО и ЧАСТОТА
    n_list.append(fr_lst)

n_list
# Out:
# [['слово', 42],
#  ['текст', 26],
#  ['словарь', 25],
#  ['социально', 24],
#  ['политический', 21],
#  ['коллекция', 18],
#  ['список', 18],
#  ['тональный', 16],
#  ['слов', 16],
#  ['документ', 16],
#  ['анализ', 14],
#  ['тематический', 12],
#  ['окрасить', 11],
#  ['тема', 11],
#  ['моделирование', 10],
#  ['вероятностный', 10],
#  ['распределение', 10],
#  ['язык', 9],
#  ['социальный', 9],
#  ['мнение', 9],
#  ['дать', 9],
#  ['слова', 9],
#  ['источник', 9],
#  ['наиболее', 9],
#  ['матрица', 9],
#  ['эмоциональный', 8],
#  ['интернет', 8],
#  ['словаря', 8],
#  ['потенциально', 8],
#  ['получить', 8],
#  ['темам', 8],
#  ['вероятность', 8],
#  ['текстов', 7],
#  ['разработать', 7],
#  ['работа', 7],
#  ['помощь', 7],
#  ['модель', 7],
#  ['можно', 6],
#  ['являться', 6],
#  ['автоматический', 6],
#  ['использовать', 6],
#  ['основа', 6],
#  ['создать', 6],
#  ['направленности', 6],
#  ['образом', 6],
#  ['результат', 6],
#  ['прототип', 6],
#  ['число', 6],
#  ['отобрать', 6],
#  ['ресурс', 5],
#  ['н', 5],
#  ['исследование', 5],
#  ['общественный', 5],
#  ['блог', 5],
#  ['разный', 5],
#  ['программный', 5],
#  ['выбрать', 5],
#  ['частотный', 5],
#  ['документов', 5],
#  ['больший', 5],
#  ['множество', 5],
#  ['иметь', 5],
#  ['встречаться', 5],
#  ['лексический', 4],
#  ['русский', 4],
#  ['область', 4],
#  ['последний', 4],
#  ['того', 4],
#  ['пользовательский', 4],
#  ['контент', 4],
#  ['проект', 4],
#  ['различный', 4],
#  ['тематики', 4],
#  ['разработка', 4],
#  ['использоваться', 4],
#  ['качество', 4],
#  ['проверяться', 4],
#  ['вычленение', 4],
#  ['этап', 4],
#  ['прилагательное', 4],
#  ['прилагательных', 4],
#  ['лаборатория', 4],
#  ['содержать', 4],
#  ['менее', 4],
#  ['составить', 4],
#  ['единиц', 4],
#  ['живой', 4],
#  ['специфичный', 4],
#  ['год', 4],
#  ['найти', 4],
#  ['принадлежность', 4],
#  ['удаление', 4],
#  ['теме', 4],
#  ['равный', 4],
#  ['тональность', 3],
#  ['кольцов', 3],
#  ['университет', 3],
#  ['обширный', 3],
#  ['очередь', 3],
#  ['отзыв', 3],
#  ['выявление', 3],
#  ['медиа', 3],
#  ['цель', 3],
#  ['существовать', 3],
#  ['определение', 3],
#  ['словарный', 3],
#  ['метод', 3],
#  ['количество', 3],
#  ['выделить', 3],
#  ['находиться', 3],
#  ['четверкин', 3],
#  ['лукашевич', 3],
#  ['представлять', 3],
#  ['оценочный', 3],
#  ['предметный', 3],
#  ['веб', 3],
#  ['создание', 3],
#  ['конечный', 3],
#  ['дальнейший', 3],
#  ['уже', 3],
#  ['представление', 3],
#  ['встретиться', 3],
#  ['кодировщик', 3],
#  ['линиса', 3],
#  ['передавать', 3],
#  ['затем', 3],
#  ['сеть', 3],
#  ['следующий', 3],
#  ['содержаться', 3],
#  ['добавляться', 3],
#  ['е', 3],
#  ['т', 3],
#  ['взять', 3],
#  ['ориентировать', 3],
#  ['комментарий', 3],
#  ['журнал', 3],
#  ['разметка', 3],
#  ['коллекции', 3],
#  ['пост', 3],
#  ['размер', 3],
#  ['слишком', 3],
#  ['тематика', 3],
#  ['релевантный', 3],
#  ['проводиться', 3],
#  ['основание', 3],
#  ['алгоритм', 3],
#  ['сэмплирование', 3],
#  ['гиббс', 3],
#  ['переменный', 3],
#  ['набор', 3],
#  ['методика', 3],
#  ['препроцессинг', 3],
#  ['модуль', 3],
#  ['частота', 3],
#  ['параметр', 3],
#  ['величина', 3],
#  ['социальнополитический', 3],
#  ['часть', 3],
#  ['ю', 2],
#  ['высокий', 2],
#  ['сентимент', 2],
#  ['окрашенность', 2],
#  ['плохо', 2],
#  ['нравиться', 2],
#  ['др', 2],
#  ['компьютерный', 2],
#  ['задача', 2],
#  ['предел', 2],
#  ['лингвистика', 2],
#  ['области', 2],
#  ['товар', 2],
#  ['сми', 2],
#  ['значимый', 2],
#  ['блогов', 2],
#  ['компонент', 2],
#  ['знание', 2],
#  ['настоящий', 2],
#  ['основный', 2],
#  ['подход', 2],
#  ['доступный', 2],
#  ['общий', 2],
#  ['оценка', 2],
#  ['англоязычный', 2],
#  ['сфера', 2],
#  ['большой', 2],
#  ['известно', 2],
#  ['свободный', 2],
#  ['доступ', 2],
#  ['ромип', 2],
#  ['составлять', 2],
#  ['необходимый', 2],
#  ['английский', 2],
#  ['специально', 2],
#  ['исследователь', 2],
#  ['отзывов', 2],
#  ['вес', 2],
#  ['описывать', 2],
#  ['определять', 2],
#  ['создавать', 2],
#  ['вид', 2],
#  ['разметки', 2],
#  ['использование', 2],
#  ['изучение', 2],
#  ['требовать', 2],
#  ['возможно', 2],
#  ['стратегий', 2],
#  ['сочетание', 2],
#  ['размечаться', 2],
#  ['сила', 2],
#  ['значение', 2],
#  ['частый', 2],
#  ['наречий', 2],
#  ['фэйсбук', 2],
#  ['рамка', 2],
#  ['наличие', 2],
#  ['кодировщика', 2],
#  ['положительный', 2],
#  ['усиление', 2],
#  ['уменьшение', 2],
#  ['наречие', 2],
#  ['сделать', 2],
#  ['окончание', 2],
#  ['присутствовать', 2],
#  ['отношение', 2],
#  ['сходный', 2],
#  ['платформа', 2],
#  ['сформировать', 2],
#  ['тематике', 2],
#  ['данные', 2],
#  ['запись', 2],
#  ['обеспечение', 2],
#  ['позволять', 2],
#  ['март', 2],
#  ['блогер', 2],
#  ['предыдущий', 2],
#  ['гораздо', 2],
#  ['группа', 2],
#  ['отбор', 2],
#  ['кластерный', 2],
#  ['извлечение', 2],
#  ['отсортировать', 2],
#  ['текстах', 2],
#  ['темы', 2],
#  ['лингвистический', 2],
#  ['скрытый', 2],
#  ['означать', 2],
#  ['выбор', 2],
#  ['вычислительный', 2],
#  ['средство', 2],
#  ['включить', 2],
#  ['векторный', 2],
#  ['итерация', 2],
#  ['матрицы', 2],
#  ['маленький', 2],
#  ['относиться', 2],
#  ['окончательный', 2],
#  ['темами', 2],
#  ['связанный', 2],
#  ['высказывание', 2],
#  ['лексика', 2],
#  ['итог', 2],
#  ['привести', 2],
#  ['единица', 2],
#  ['остаться', 2],
#  ['эмоция', 2],
#  ['ещё', 2],
#  ['списках', 2],
#  ['исключение', 2],
#  ['версия', 2],
#  ['просмотреть', 2],
#  ['войти', 2],
#  ['оказаться', 2],
#  ['алексеева', 1],
#  ['национальный', 1],
#  ['исследовательский', 1],
#  ['школа', 1],
#  ['экономики', 1],
#  ['санкт', 1],
#  ['петербург', 1],
#  ['введение', 1],
#  ['автоматизированный', 1],
#  ['отнести', 1],
#  ['лингвистики', 1],
#  ['применения', 1],
#  ['основном', 1],
#  ['лежать', 1],
#  ['разделить', 1],
#  ['маркетинг', 1],
#  ['услуги', 1],
#  ['социология', 1],
#  ['политология', 1],
#  ['включает', 1],
#  ['первых', 1],
#  ['вопрос', 1],
#  ['преподноситься', 1],
#  ['аудитория', 1],
#  ['отклик', 1],
#  ['ожидать', 1],
#  ['публики', 1],
#  ['вторых', 1],
#  ['сетей', 1],
#  ['форумов', 1],
#  ['части', 1],
#  ['представить', 1],
#  ['интернете', 1],
#  ['главный', 1],
#  ['целевой', 1],
#  ['проекта', 1],
#  ['обращать', 1],
#  ['внимание', 1],
#  ['сегодняшний', 1],
#  ['день', 1],
#  ['применять', 1],
#  ['классификация', 1],
#  ['обучать', 1],
#  ['коллекций', 1],
#  ['удобный', 1],
#  ['избыток', 1],
#  ['напр', 1],
#  ['позитивный', 1],
#  ['негативный', 1],
#  ['товара', 1],
#  ['текстовый', 1],
#  ['особо', 1],
#  ['глазго', 1],
#  ['сконцентрировать', 1],
#  ['сегменте', 1],
#  ['насколько', 1],
#  ['прямой', 1],
#  ['косвенный', 1],
#  ['речь', 1],
#  ['новостной', 1],
#  ['непригодный', 1],
#  ['отсутствие', 1],
#  ['проставить', 1],
#  ['окраска', 1],
#  ['обратиться', 1],
#  ['подходу', 1],
#  ['успешно', 1],
#  ['применяться', 1],
#  ['система', 1],
#  ['фелвол', 1],
#  ['вулверхемптон', 1],
#  ['великобритания', 1],
#  ['предназначить', 1],
#  ['сегмент', 1],
#  ['словари', 1],
#  ['известный', 1],
#  ['извлечь', 1],
#  ['фильмы', 1],
#  ['книги', 1],
#  ['игры', 1],
#  ['телефоны', 1],
#  ['камеры', 1],
#  ['соревнование', 1],
#  ['видно', 1],
#  ['описания', 1],
#  ['предпочтение', 1],
#  ['маркетинговый', 1],
#  ['исследованиях', 1],
#  ['краудсорсинговый', 1],
#  ['инструмент', 1],
#  ['анализа', 1],
#  ['присвоить', 1],
#  ['окраску', 1],
#  ['обеспечении', 1],
#  ['находить', 1],
#  ['соответствующий', 1],
#  ['усреднение', 1],
#  ['текста', 1],
#  ['точность', 1],
#  ['путём', 1],
#  ['сравнение', 1],
#  ['людей', 1],
#  ['применимый', 1],
#  ['создаваться', 1],
#  ['настраивается', 1],
#  ['содержания', 1],
#  ['аудитории', 1],
#  ['составление', 1],
#  ['эмоционально', 1],
#  ['языка', 1],
#  ['полный', 1],
#  ['объём', 1],
#  ['невыполнимо', 1],
#  ['развитый', 1],
#  ['насчитывать', 1],
#  ['сотня', 1],
#  ['тысяча', 1],
#  ['альтернативный', 1],
#  ['накопить', 1],
#  ['собственных', 1],
#  ['опора', 1],
#  ['эксперт', 1],
#  ['сбор', 1],
#  ['простых', 1],
#  ['носителей', 1],
#  ['собираться', 1],
#  ['запасом', 1],
#  ['включаться', 1],
#  ['добровольцами', 1],
#  ['человек', 1],
#  ['привязка', 1],
#  ['иметься', 1],
#  ['сведение', 1],
#  ['словах', 1],
#  ['выражаться', 1],
#  ['признаковый', 1],
#  ['начать', 1],
#  ['поиск', 1],
#  ['цифровой', 1],
#  ['общество', 1],
#  ['русскоязычный', 1],
#  ['сотрудничество', 1],
#  ['линис', 1],
#  ['ниу', 1],
#  ['вшэ', 1],
#  ['разметить', 1],
#  ['точка', 1],
#  ['зрение', 1],
#  ['конец', 1],
#  ['посчитать', 1],
#  ['отрицательно', 1],
#  ['эмоции', 1],
#  ['дополнить', 1],
#  ['данными', 1],
#  ['списке', 1],
#  ['добавление', 1],
#  ['автоматически', 1],
#  ['отрезаться', 1],
#  ['ий', 1],
#  ['ый', 1],
#  ['морфоанализатор', 1],
#  ['словаре', 1],
#  ['анализатор', 1],
#  ['реальный', 1],
#  ['наречием', 1],
#  ['адресу', 1],
#  ['междометие', 1],
#  ['объяснительный', 1],
#  ['добавить', 1],
#  ['павлов', 1],
#  ['перевод', 1],
#  ['поставлять', 1],
#  ['программа', 1],
#  ['отрицательный', 1],
#  ['настроений', 1],
#  ['краткий', 1],
#  ['сообщениями', 1],
#  ['публиковать', 1],
#  ['блогосферы', 1],
#  ['постам', 1],
#  ['предварительный', 1],
#  ['итоговый', 1],
#  ['состоять', 1],
#  ['повторяться', 1],
#  ['посвятить', 1],
#  ['целями', 1],
#  ['контекст', 1],
#  ['облегчать', 1],
#  ['особенно', 1],
#  ['случай', 1],
#  ['полисемии', 1],
#  ['тестовый', 1],
#  ['вебресурсе', 1],
#  ['закачивать', 1],
#  ['журнала', 1],
#  ['протяжение', 1],
#  ['вестись', 1],
#  ['постоянный', 1],
#  ['еженедельный', 1],
#  ['закачка', 1],
#  ['популярный', 1],
#  ['рейтинг', 1],
#  ['капитал', 1],
#  ['предоставлять', 1],
#  ['жж', 1],
#  ['реляционный', 1],
#  ['база', 1],
#  ['порядок', 1],
#  ['млн', 1],
#  ['период', 1],
#  ['компенсировать', 1],
#  ['узкий', 1],
#  ['событийно', 1],
#  ['зависимый', 1],
#  ['служить', 1],
#  ['специализированный', 1],
#  ['топовый', 1],
#  ['взяты', 1],
#  ['отличаться', 1],
#  ['обычный', 1],
#  ['разредить', 1],
#  ['зашумлен', 1],
#  ['спамом', 1],
#  ['последующий', 1],
#  ['способами', 1],
#  ['заимствование', 1],
#  ['рубрик', 1],
#  ['тэгам', 1],
#  ['ручной', 1],
#  ['выделение', 1],
#  ['например', 1],
#  ['алгоритмов', 1],
#  ['создатель', 1],
#  ['рубрика', 1],
#  ['тэг', 1],
#  ['граница', 1],
#  ['известны', 1],
#  ['подходить', 1],
#  ['самостоятельный', 1],
#  ['предпочесть', 1],
#  ['анализу', 1],
#  ['нечёткий', 1],
#  ['релевантности', 1],
#  ['исследований', 1],
#  ['заключаться', 1],
#  ['следующем', 1],
#  ['пониматься', 1],
#  ['совокупность', 1],
#  ['тенденция', 1],
#  ['совместно', 1],
#  ['упрощённый', 1],
#  ['понимание', 1],
#  ['применение', 1],
#  ['многократно', 1],
#  ['предмет', 1],
#  ['интерпретируемость', 1],
#  ['людьми', 1],
#  ['демонстрировать', 1],
#  ['хороший', 1],
#  ['интерпретация', 1],
#  ['сформулировать', 1],
#  ['генерация', 1],
#  ['вычисление', 1],
#  ['момент', 1],
#  ['вариант', 1],
#  ['базироваться', 1],
#  ['вариантах', 1],
#  ['вариационный', 1],
#  ['предполагается', 1],
#  ['порождаться', 1],
#  ['дискретный', 1],
#  ['наблюдать', 1],
#  ['скрытой', 1],
#  ['появление', 1],
#  ['пара', 1],
#  ['связать', 1],
#  ['неизвестный', 1],
#  ['построить', 1],
#  ['определить', 1],
#  ['условный', 1],
#  ['матрицу', 1],
#  ['уникальный', 1],
#  ['процедура', 1],
#  ['нахождение', 1],
#  ['задать', 1],
#  ['обусловить', 1],
#  ['простотой', 1],
#  ['проведение', 1],
#  ['показывать', 1],
#  ['правило', 1],
#  ['отсутствовать', 1],
#  ['ядро', 1],
#  ['интерфейс', 1],
#  ['справляться', 1],
#  ['объемами', 1],
#  ['развёртывание', 1],
#  ['кластера', 1],
#  ['продукт', 1],
#  ['собственный', 1],
#  ['разработчик', 1],
#  ['г', 1],
#  ['филипов', 1],
#  ['способный', 1],
#  ['работать', 1],
#  ['персональный', 1],
#  ['компьютер', 1],
#  ['модули', 1],
#  ['препроцессина', 1],
#  ['результатов', 1],
#  ['данных', 1],
#  ['провести', 1],
#  ['процедуры', 1],
#  ['тэгов', 1],
#  ['лемматизация', 1],
#  ['приведение', 1],
#  ['начальный', 1],
#  ['форме', 1],
#  ['стопа', 1],
#  ['несущий', 1],
#  ['смысл', 1],
#  ['влиять', 1],
#  ['тематику', 1],
#  ['постоянно', 1],
#  ['корректироваться', 1],
#  ['подсчёт', 1],
#  ['лемм', 1],
#  ['редкий', 1],
#  ['дискриминировать', 1],
#  ['силы', 1],
#  ['конвертация', 1],
#  ['формат', 1],
#  ['основать', 1],
#  ['предполагать', 1],
#  ['тексте', 1],
#  ['входной', 1],
#  ['являются', 1],
#  ['дирихло', 1],
#  ['сэмплирования', 1],
#  ['ячейка', 1],
#  ['опыта', 1],
#  ['показавшего', 1],
#  ['приводить', 1],
#  ['излишний', 1],
#  ['укрупнённый', 1],
#  ['доля', 1],
#  ['заимствовать', 1],
#  ['подбираться', 1],
#  ['экспериментально', 1],
#  ['графика', 1],
#  ['сходимость', 1],
#  ['ход', 1],
#  ['столбец', 1],
#  ['отдельный', 1],
#  ['тему', 1],
#  ['элемент', 1],
#  ['убыванию', 1],
#  ['падать', 1],
#  ['достаточно', 1],
#  ['быстро', 1],
#  ['передать', 1],
#  ['кодировщикам', 1],
#  ['определяли', 1],
#  ['политическими', 1],
#  ['кодирование', 1],
#  ['считаться', 1],
#  ['социальнополитической', 1],
#  ['минимум', 1],
#  ['согласованность', 1],
#  ['расчёт', 1],
#  ['довольно', 1],
#  ['низкий', 1],
#  ['показатель', 1],
#  ['простой', 1],
#  ['задач', 1],
#  ['редко', 1],
#  ['бывать', 1],
#  ['согласие', 1],
#  ['кодировщиков', 1],
#  ['несмотря', 1],
#  ['выбирать', 1],
#  ['документы', 1],
#  ['средний', 1],
#  ['порог', 1],
#  ['массив', 1],
#  ['миллион', 1],
#  ['получиться', 1],
#  ['формирование', 1],
#  ['дополнение', 1],
#  ['лингвист', 1],
#  ['назвать', 1],
#  ['эмоций', 1],
#  ['формироваться', 1],
#  ['областей', 1],
#  ['лексики', 1],
#  ['часто', 1],
#  ['вместе', 1],
#  ['объект', 1],
#  ['направлена', 1],
#  ['разным', 1],
#  ['политическим', 1],
#  ['оценку', 1],
#  ['решить', 1],
#  ['пример', 1],
#  ['оформление', 1],
#  ['списка', 1],
#  ['нормализовать', 1],
#  ['форму', 1],
#  ['дублироваться', 1],
#  ['немой', 1],
#  ['признать', 1],
#  ['далее', 1],
#  ['пересечь', 1],
#  ['списками', 1],
#  ['указать', 1],
#  ['какого', 1],
#  ['какий', 1],
#  ['источника', 1],
#  ['пришло', 1],
#  ['списков', 1],
#  ['информация', 1],
#  ['том', 1],
#  ['встречается', 1],
#  ['сразу', 1],
#  ['источников', 1],
#  ['представлены', 1],
#  ['вручную', 1],
#  ['исключить', 1],
#  ['счесть', 1],
#  ['нерелевантными', 1],
#  ['основное', 1],
#  ['аккумулятор', 1],
#  ['диагональ', 1],
#  ['панель', 1],
#  ['этого', 1],
#  ['исключили', 1],
#  ['операция', 1],
#  ['сумма', 1],
#  ['дубликат', 1],
#  ['удалены', 1],
#  ['окончательно', 1],
#  ['сопоставить', 1],
#  ['выбираться', 1],
#  ['максимальный', 1],
#  ['финальный', 1],
#  ['успешный', 1],
#  ['необходимо', 1],
#  ['понимать', 1],
#  ['краудсорсинг', 1],
#  ['время', 1],
#  ['заключение', 1],
#  ['статья', 1],
#  ['описать', 1],
#  ['промежуточный', 1],
#  ['возможность', 1],
#  ['заряженности', 1],
#  ['контента', 1],
#  ['позволить', 1],
#  ['точнее', 1],
#  ['активный', 1],
#  ['население', 1],
#  ['вопросам', 1],
#  ['важность', 1],
#  ['общественность', 1],
#  ['подтверждается', 1],
#  ['прочего', 1],
#  ['роль', 1],
#  ['прокатиться', 1],
#  ['мир', 1],
#  ['волна', 1],
#  ['протест', 1],
#  ['революция', 1],
#  ['годов', 1]]

# %%
k = 1
for i in n_list:
    logfr = math.log(int(i[1]),10)
    logrank = math.log(k, 10)  # берём десятичные логарифмы для ранга и для частоты
    i.append(k)
    i.append(logfr)
    i.append(logrank)
    k+=1

# %%
n_list
# Out:
# [['слово', 42, 1, 1.6232492903979003, 0.0],
#  ['текст', 26, 2, 1.414973347970818, 0.30102999566398114],
#  ['словарь', 25, 3, 1.3979400086720375, 0.47712125471966244],
#  ['социально', 24, 4, 1.380211241711606, 0.6020599913279623],
#  ['политический', 21, 5, 1.322219294733919, 0.6989700043360187],
#  ['коллекция', 18, 6, 1.2552725051033058, 0.7781512503836435],
#  ['список', 18, 7, 1.2552725051033058, 0.8450980400142567],
#  ['тональный', 16, 8, 1.2041199826559246, 0.9030899869919434],
#  ['слов', 16, 9, 1.2041199826559246, 0.9542425094393249],
#  ['документ', 16, 10, 1.2041199826559246, 1.0],
#  ['анализ', 14, 11, 1.1461280356782377, 1.041392685158225],
#  ['тематический', 12, 12, 1.0791812460476247, 1.0791812460476247],
#  ['окрасить', 11, 13, 1.041392685158225, 1.1139433523068367],
#  ['тема', 11, 14, 1.041392685158225, 1.1461280356782377],
#  ['моделирование', 10, 15, 1.0, 1.1760912590556811],
#  ['вероятностный', 10, 16, 1.0, 1.2041199826559246],
#  ['распределение', 10, 17, 1.0, 1.2304489213782739],
#  ['язык', 9, 18, 0.9542425094393249, 1.2552725051033058],
#  ['социальный', 9, 19, 0.9542425094393249, 1.2787536009528289],
#  ['мнение', 9, 20, 0.9542425094393249, 1.301029995663981],
#  ['дать', 9, 21, 0.9542425094393249, 1.322219294733919],
#  ['слова', 9, 22, 0.9542425094393249, 1.3424226808222062],
#  ['источник', 9, 23, 0.9542425094393249, 1.3617278360175928],
#  ['наиболее', 9, 24, 0.9542425094393249, 1.380211241711606],
#  ['матрица', 9, 25, 0.9542425094393249, 1.3979400086720375],
#  ['эмоциональный', 8, 26, 0.9030899869919434, 1.414973347970818],
#  ['интернет', 8, 27, 0.9030899869919434, 1.4313637641589871],
#  ['словаря', 8, 28, 0.9030899869919434, 1.447158031342219],
#  ['потенциально', 8, 29, 0.9030899869919434, 1.462397997898956],
#  ['получить', 8, 30, 0.9030899869919434, 1.4771212547196624],
#  ['темам', 8, 31, 0.9030899869919434, 1.4913616938342726],
#  ['вероятность', 8, 32, 0.9030899869919434, 1.5051499783199058],
#  ['текстов', 7, 33, 0.8450980400142567, 1.5185139398778873],
#  ['разработать', 7, 34, 0.8450980400142567, 1.5314789170422551],
#  ['работа', 7, 35, 0.8450980400142567, 1.5440680443502754],
#  ['помощь', 7, 36, 0.8450980400142567, 1.556302500767287],
#  ['модель', 7, 37, 0.8450980400142567, 1.5682017240669948],
#  ['можно', 6, 38, 0.7781512503836435, 1.57978359661681],
#  ['являться', 6, 39, 0.7781512503836435, 1.591064607026499],
#  ['автоматический', 6, 40, 0.7781512503836435, 1.6020599913279623],
#  ['использовать', 6, 41, 0.7781512503836435, 1.6127838567197355],
#  ['основа', 6, 42, 0.7781512503836435, 1.6232492903979003],
#  ['создать', 6, 43, 0.7781512503836435, 1.6334684555795864],
#  ['направленности', 6, 44, 0.7781512503836435, 1.6434526764861872],
#  ['образом', 6, 45, 0.7781512503836435, 1.6532125137753435],
#  ['результат', 6, 46, 0.7781512503836435, 1.6627578316815739],
#  ['прототип', 6, 47, 0.7781512503836435, 1.6720978579357173],
#  ['число', 6, 48, 0.7781512503836435, 1.6812412373755872],
#  ['отобрать', 6, 49, 0.7781512503836435, 1.6901960800285134],
#  ['ресурс', 5, 50, 0.6989700043360187, 1.6989700043360185],
#  ['н', 5, 51, 0.6989700043360187, 1.7075701760979363],
#  ['исследование', 5, 52, 0.6989700043360187, 1.716003343634799],
#  ['общественный', 5, 53, 0.6989700043360187, 1.724275869600789],
#  ['блог', 5, 54, 0.6989700043360187, 1.7323937598229684],
#  ['разный', 5, 55, 0.6989700043360187, 1.7403626894942439],
#  ['программный', 5, 56, 0.6989700043360187, 1.7481880270062005],
#  ['выбрать', 5, 57, 0.6989700043360187, 1.7558748556724912],
#  ['частотный', 5, 58, 0.6989700043360187, 1.7634279935629371],
#  ['документов', 5, 59, 0.6989700043360187, 1.7708520116421442],
#  ['больший', 5, 60, 0.6989700043360187, 1.7781512503836434],
#  ['множество', 5, 61, 0.6989700043360187, 1.785329835010767],
#  ['иметь', 5, 62, 0.6989700043360187, 1.7923916894982537],
#  ['встречаться', 5, 63, 0.6989700043360187, 1.7993405494535815],
#  ['лексический', 4, 64, 0.6020599913279623, 1.8061799739838869],
#  ['русский', 4, 65, 0.6020599913279623, 1.8129133566428552],
#  ['область', 4, 66, 0.6020599913279623, 1.8195439355418683],
#  ['последний', 4, 67, 0.6020599913279623, 1.8260748027008262],
#  ['того', 4, 68, 0.6020599913279623, 1.8325089127062362],
#  ['пользовательский', 4, 69, 0.6020599913279623, 1.8388490907372552],
#  ['контент', 4, 70, 0.6020599913279623, 1.845098040014257],
#  ['проект', 4, 71, 0.6020599913279623, 1.851258348719075],
#  ['различный', 4, 72, 0.6020599913279623, 1.8573324964312683],
#  ['тематики', 4, 73, 0.6020599913279623, 1.8633228601204557],
#  ['разработка', 4, 74, 0.6020599913279623, 1.8692317197309762],
#  ['использоваться', 4, 75, 0.6020599913279623, 1.8750612633916997],
#  ['качество', 4, 76, 0.6020599913279623, 1.8808135922807911],
#  ['проверяться', 4, 77, 0.6020599913279623, 1.8864907251724818],
#  ['вычленение', 4, 78, 0.6020599913279623, 1.8920946026904801],
#  ['этап', 4, 79, 0.6020599913279623, 1.8976270912904412],
#  ['прилагательное', 4, 80, 0.6020599913279623, 1.9030899869919433],
#  ['прилагательных', 4, 81, 0.6020599913279623, 1.9084850188786497],
#  ['лаборатория', 4, 82, 0.6020599913279623, 1.9138138523837167],
#  ['содержать', 4, 83, 0.6020599913279623, 1.919078092376074],
#  ['менее', 4, 84, 0.6020599913279623, 1.9242792860618814],
#  ['составить', 4, 85, 0.6020599913279623, 1.9294189257142926],
#  ['единиц', 4, 86, 0.6020599913279623, 1.9344984512435675],
#  ['живой', 4, 87, 0.6020599913279623, 1.9395192526186182],
#  ['специфичный', 4, 88, 0.6020599913279623, 1.9444826721501687],
#  ['год', 4, 89, 0.6020599913279623, 1.9493900066449126],
#  ['найти', 4, 90, 0.6020599913279623, 1.9542425094393248],
#  ['принадлежность', 4, 91, 0.6020599913279623, 1.9590413923210932],
#  ['удаление', 4, 92, 0.6020599913279623, 1.9637878273455551],
#  ['теме', 4, 93, 0.6020599913279623, 1.968482948553935],
#  ['равный', 4, 94, 0.6020599913279623, 1.9731278535996983],
#  ['тональность', 3, 95, 0.47712125471966244, 1.9777236052888476],
#  ['кольцов', 3, 96, 0.47712125471966244, 1.9822712330395682],
#  ['университет', 3, 97, 0.47712125471966244, 1.9867717342662448],
#  ['обширный', 3, 98, 0.47712125471966244, 1.9912260756924949],
#  ['очередь', 3, 99, 0.47712125471966244, 1.9956351945975497],
#  ['отзыв', 3, 100, 0.47712125471966244, 2.0],
#  ['выявление', 3, 101, 0.47712125471966244, 2.0043213737826426],
#  ['медиа', 3, 102, 0.47712125471966244, 2.008600171761917],
#  ['цель', 3, 103, 0.47712125471966244, 2.012837224705172],
#  ['существовать', 3, 104, 0.47712125471966244, 2.0170333392987803],
#  ['определение', 3, 105, 0.47712125471966244, 2.021189299069938],
#  ['словарный', 3, 106, 0.47712125471966244, 2.02530586526477],
#  ['метод', 3, 107, 0.47712125471966244, 2.0293837776852093],
#  ['количество', 3, 108, 0.47712125471966244, 2.0334237554869494],
#  ['выделить', 3, 109, 0.47712125471966244, 2.0374264979406234],
#  ['находиться', 3, 110, 0.47712125471966244, 2.041392685158225],
#  ['четверкин', 3, 111, 0.47712125471966244, 2.045322978786657],
#  ['лукашевич', 3, 112, 0.47712125471966244, 2.049218022670181],
#  ['представлять', 3, 113, 0.47712125471966244, 2.0530784434834195],
#  ['оценочный', 3, 114, 0.47712125471966244, 2.0569048513364723],
#  ['предметный', 3, 115, 0.47712125471966244, 2.0606978403536114],
#  ['веб', 3, 116, 0.47712125471966244, 2.064457989226918],
#  ['создание', 3, 117, 0.47712125471966244, 2.0681858617461617],
#  ['конечный', 3, 118, 0.47712125471966244, 2.0718820073061255],
#  ['дальнейший', 3, 119, 0.47712125471966244, 2.0755469613925306],
#  ['уже', 3, 120, 0.47712125471966244, 2.0791812460476247],
#  ['представление', 3, 121, 0.47712125471966244, 2.08278537031645],
#  ['встретиться', 3, 122, 0.47712125471966244, 2.086359830674748],
#  ['кодировщик', 3, 123, 0.47712125471966244, 2.0899051114393976],
#  ['линиса', 3, 124, 0.47712125471966244, 2.093421685162235],
#  ['передавать', 3, 125, 0.47712125471966244, 2.0969100130080562],
#  ['затем', 3, 126, 0.47712125471966244, 2.1003705451175625],
#  ['сеть', 3, 127, 0.47712125471966244, 2.103803720955957],
#  ['следующий', 3, 128, 0.47712125471966244, 2.107209969647868],
#  ['содержаться', 3, 129, 0.47712125471966244, 2.110589710299249],
#  ['добавляться', 3, 130, 0.47712125471966244, 2.1139433523068365],
#  ['е', 3, 131, 0.47712125471966244, 2.117271295655764],
#  ['т', 3, 132, 0.47712125471966244, 2.1205739312058496],
#  ['взять', 3, 133, 0.47712125471966244, 2.123851640967086],
#  ['ориентировать', 3, 134, 0.47712125471966244, 2.1271047983648073],
#  ['комментарий', 3, 135, 0.47712125471966244, 2.130333768495006],
#  ['журнал', 3, 136, 0.47712125471966244, 2.1335389083702174],
#  ['разметка', 3, 137, 0.47712125471966244, 2.1367205671564067],
#  ['коллекции', 3, 138, 0.47712125471966244, 2.1398790864012365],
#  ['пост', 3, 139, 0.47712125471966244, 2.143014800254095],
#  ['размер', 3, 140, 0.47712125471966244, 2.1461280356782377],
#  ['слишком', 3, 141, 0.47712125471966244, 2.1492191126553797],
#  ['тематика', 3, 142, 0.47712125471966244, 2.1522883443830563],
#  ['релевантный', 3, 143, 0.47712125471966244, 2.1553360374650614],
#  ['проводиться', 3, 144, 0.47712125471966244, 2.1583624920952493],
#  ['основание', 3, 145, 0.47712125471966244, 2.1613680022349744],
#  ['алгоритм', 3, 146, 0.47712125471966244, 2.1643528557844367],
#  ['сэмплирование', 3, 147, 0.47712125471966244, 2.1673173347481756],
#  ['гиббс', 3, 148, 0.47712125471966244, 2.170261715394957],
#  ['переменный', 3, 149, 0.47712125471966244, 2.173186268412274],
#  ['набор', 3, 150, 0.47712125471966244, 2.176091259055681],
#  ['методика', 3, 151, 0.47712125471966244, 2.1789769472931693],
#  ['препроцессинг', 3, 152, 0.47712125471966244, 2.181843587944772],
#  ['модуль', 3, 153, 0.47712125471966244, 2.1846914308175984],
#  ['частота', 3, 154, 0.47712125471966244, 2.187520720836463],
#  ['параметр', 3, 155, 0.47712125471966244, 2.1903316981702914],
#  ['величина', 3, 156, 0.47712125471966244, 2.1931245983544616],
#  ['социальнополитический', 3, 157, 0.47712125471966244, 2.1958996524092336],
#  ['часть', 3, 158, 0.47712125471966244, 2.1986570869544226],
#  ['ю', 2, 159, 0.30102999566398114, 2.2013971243204513],
#  ['высокий', 2, 160, 0.30102999566398114, 2.2041199826559246],
#  ['сентимент', 2, 161, 0.30102999566398114, 2.2068258760318495],
#  ['окрашенность', 2, 162, 0.30102999566398114, 2.2095150145426303],
#  ['плохо', 2, 163, 0.30102999566398114, 2.2121876044039577],
#  ['нравиться', 2, 164, 0.30102999566398114, 2.214843848047698],
#  ['др', 2, 165, 0.30102999566398114, 2.217483944213906],
#  ['компьютерный', 2, 166, 0.30102999566398114, 2.220108088040055],
#  ['задача', 2, 167, 0.30102999566398114, 2.2227164711475833],
#  ['предел', 2, 168, 0.30102999566398114, 2.2253092817258624],
#  ['лингвистика', 2, 169, 0.30102999566398114, 2.2278867046136734],
#  ['области', 2, 170, 0.30102999566398114, 2.2304489213782737],
#  ['товар', 2, 171, 0.30102999566398114, 2.2329961103921536],
#  ['сми', 2, 172, 0.30102999566398114, 2.2355284469075487],
#  ['значимый', 2, 173, 0.30102999566398114, 2.2380461031287955],
#  ['блогов', 2, 174, 0.30102999566398114, 2.2405492482825995],
#  ['компонент', 2, 175, 0.30102999566398114, 2.2430380486862944],
#  ['знание', 2, 176, 0.30102999566398114, 2.2455126678141495],
#  ['настоящий', 2, 177, 0.30102999566398114, 2.2479732663618064],
#  ['основный', 2, 178, 0.30102999566398114, 2.2504200023088936],
#  ['подход', 2, 179, 0.30102999566398114, 2.252853030979893],
#  ['доступный', 2, 180, 0.30102999566398114, 2.255272505103306],
#  ['общий', 2, 181, 0.30102999566398114, 2.2576785748691846],
#  ['оценка', 2, 182, 0.30102999566398114, 2.2600713879850747],
#  ['англоязычный', 2, 183, 0.30102999566398114, 2.2624510897304293],
#  ['сфера', 2, 184, 0.30102999566398114, 2.2648178230095364],
#  ['большой', 2, 185, 0.30102999566398114, 2.2671717284030133],
#  ['известно', 2, 186, 0.30102999566398114, 2.2695129442179165],
#  ['свободный', 2, 187, 0.30102999566398114, 2.271841606536499],
#  ['доступ', 2, 188, 0.30102999566398114, 2.2741578492636796],
#  ['ромип', 2, 189, 0.30102999566398114, 2.276461804173244],
#  ['составлять', 2, 190, 0.30102999566398114, 2.278753600952829],
#  ['необходимый', 2, 191, 0.30102999566398114, 2.281033367247727],
#  ['английский', 2, 192, 0.30102999566398114, 2.2833012287035492],
#  ['специально', 2, 193, 0.30102999566398114, 2.2855573090077734],
#  ['исследователь', 2, 194, 0.30102999566398114, 2.287801729930226],
#  ['отзывов', 2, 195, 0.30102999566398114, 2.290034611362518],
#  ['вес', 2, 196, 0.30102999566398114, 2.2922560713564755],
#  ['описывать', 2, 197, 0.30102999566398114, 2.294466226161593],
#  ['определять', 2, 198, 0.30102999566398114, 2.296665190261531],
#  ['создавать', 2, 199, 0.30102999566398114, 2.2988530764097064],
#  ['вид', 2, 200, 0.30102999566398114, 2.301029995663981],
#  ['разметки', 2, 201, 0.30102999566398114, 2.3031960574204886],
#  ['использование', 2, 202, 0.30102999566398114, 2.305351369446624],
#  ['изучение', 2, 203, 0.30102999566398114, 2.3074960379132126],
#  ['требовать', 2, 204, 0.30102999566398114, 2.3096301674258983],
#  ['возможно', 2, 205, 0.30102999566398114, 2.311753861055754],
#  ['стратегий', 2, 206, 0.30102999566398114, 2.3138672203691533],
#  ['сочетание', 2, 207, 0.30102999566398114, 2.3159703454569174],
#  ['размечаться', 2, 208, 0.30102999566398114, 2.3180633349627615],
#  ['сила', 2, 209, 0.30102999566398114, 2.320146286111054],
#  ['значение', 2, 210, 0.30102999566398114, 2.322219294733919],
#  ['частый', 2, 211, 0.30102999566398114, 2.3242824552976926],
#  ['наречий', 2, 212, 0.30102999566398114, 2.326335860928751],
#  ['фэйсбук', 2, 213, 0.30102999566398114, 2.3283796034387376],
#  ['рамка', 2, 214, 0.30102999566398114, 2.3304137733491905],
#  ['наличие', 2, 215, 0.30102999566398114, 2.332438459915605],
#  ['кодировщика', 2, 216, 0.30102999566398114, 2.3344537511509307],
#  ['положительный', 2, 217, 0.30102999566398114, 2.3364597338485296],
#  ['усиление', 2, 218, 0.30102999566398114, 2.3384564936046046],
#  ['уменьшение', 2, 219, 0.30102999566398114, 2.340444114840118],
#  ['наречие', 2, 220, 0.30102999566398114, 2.342422680822206],
#  ['сделать', 2, 221, 0.30102999566398114, 2.34439227368511],
#  ['окончание', 2, 222, 0.30102999566398114, 2.3463529744506384],
#  ['присутствовать', 2, 223, 0.30102999566398114, 2.3483048630481607],
#  ['отношение', 2, 224, 0.30102999566398114, 2.3502480183341623],
#  ['сходный', 2, 225, 0.30102999566398114, 2.3521825181113623],
#  ['платформа', 2, 226, 0.30102999566398114, 2.3541084391474008],
#  ['сформировать', 2, 227, 0.30102999566398114, 2.3560258571931225],
#  ['тематике', 2, 228, 0.30102999566398114, 2.3579348470004535],
#  ['данные', 2, 229, 0.30102999566398114, 2.359835482339888],
#  ['запись', 2, 230, 0.30102999566398114, 2.3617278360175926],
#  ['обеспечение', 2, 231, 0.30102999566398114, 2.363611979892144],
#  ['позволять', 2, 232, 0.30102999566398114, 2.3654879848908994],
#  ['март', 2, 233, 0.30102999566398114, 2.3673559210260184],
#  ['блогер', 2, 234, 0.30102999566398114, 2.3692158574101425],
#  ['предыдущий', 2, 235, 0.30102999566398114, 2.371067862271736],
#  ['гораздо', 2, 236, 0.30102999566398114, 2.3729120029701067],
#  ['группа', 2, 237, 0.30102999566398114, 2.374748346010104],
#  ['отбор', 2, 238, 0.30102999566398114, 2.376576957056512],
#  ['кластерный', 2, 239, 0.30102999566398114, 2.3783979009481375],
#  ['извлечение', 2, 240, 0.30102999566398114, 2.380211241711606],
#  ['отсортировать', 2, 241, 0.30102999566398114, 2.382017042574868],
#  ['текстах', 2, 242, 0.30102999566398114, 2.383815365980431],
#  ['темы', 2, 243, 0.30102999566398114, 2.3856062735983117],
#  ['лингвистический', 2, 244, 0.30102999566398114, 2.387389826338729],
#  ['скрытый', 2, 245, 0.30102999566398114, 2.3891660843645326],
#  ['означать', 2, 246, 0.30102999566398114, 2.390935107103379],
#  ['выбор', 2, 247, 0.30102999566398114, 2.392696953259666],
#  ['вычислительный', 2, 248, 0.30102999566398114, 2.394451680826216],
#  ['средство', 2, 249, 0.30102999566398114, 2.396199347095736],
#  ['включить', 2, 250, 0.30102999566398114, 2.397940008672037],
#  ['векторный', 2, 251, 0.30102999566398114, 2.3996737214810375],
#  ['итерация', 2, 252, 0.30102999566398114, 2.4014005407815437],
#  ['матрицы', 2, 253, 0.30102999566398114, 2.4031205211758175],
#  ['маленький', 2, 254, 0.30102999566398114, 2.404833716619938],
#  ['относиться', 2, 255, 0.30102999566398114, 2.4065401804339546],
#  ['окончательный', 2, 256, 0.30102999566398114, 2.408239965311849],
#  ['темами', 2, 257, 0.30102999566398114, 2.4099331233312946],
#  ['связанный', 2, 258, 0.30102999566398114, 2.41161970596323],
#  ['высказывание', 2, 259, 0.30102999566398114, 2.4132997640812515],
#  ['лексика', 2, 260, 0.30102999566398114, 2.4149733479708178],
#  ['итог', 2, 261, 0.30102999566398114, 2.416640507338281],
#  ['привести', 2, 262, 0.30102999566398114, 2.4183012913197452],
#  ['единица', 2, 263, 0.30102999566398114, 2.4199557484897576],
#  ['остаться', 2, 264, 0.30102999566398114, 2.421603926869831],
#  ['эмоция', 2, 265, 0.30102999566398114, 2.4232458739368075],
#  ['ещё', 2, 266, 0.30102999566398114, 2.4248816366310666],
#  ['списках', 2, 267, 0.30102999566398114, 2.426511261364575],
#  ['исключение', 2, 268, 0.30102999566398114, 2.4281347940287885],
#  ['версия', 2, 269, 0.30102999566398114, 2.4297522800024076],
#  ['просмотреть', 2, 270, 0.30102999566398114, 2.4313637641589874],
#  ['войти', 2, 271, 0.30102999566398114, 2.4329692908744054],
#  ['оказаться', 2, 272, 0.30102999566398114, 2.4345689040341987],
#  ['алексеева', 1, 273, 0.0, 2.436162647040756],
#  ['национальный', 1, 274, 0.0, 2.437750562820388],
#  ['исследовательский', 1, 275, 0.0, 2.4393326938302624],
#  ['школа', 1, 276, 0.0, 2.4409090820652173],
#  ['экономики', 1, 277, 0.0, 2.442479769064448],
#  ['санкт', 1, 278, 0.0, 2.4440447959180758],
#  ['петербург', 1, 279, 0.0, 2.4456042032735974],
#  ['введение', 1, 280, 0.0, 2.447158031342219],
#  ['автоматизированный', 1, 281, 0.0, 2.4487063199050794],
#  ['отнести', 1, 282, 0.0, 2.450249108319361],
#  ['лингвистики', 1, 283, 0.0, 2.45178643552429],
#  ['применения', 1, 284, 0.0, 2.4533183400470375],
#  ['основном', 1, 285, 0.0, 2.45484486000851],
#  ['лежать', 1, 286, 0.0, 2.4563660331290427],
#  ['разделить', 1, 287, 0.0, 2.4578818967339924],
#  ['маркетинг', 1, 288, 0.0, 2.4593924877592306],
#  ['услуги', 1, 289, 0.0, 2.4608978427565478],
#  ['социология', 1, 290, 0.0, 2.4623979978989556],
#  ['политология', 1, 291, 0.0, 2.4638929889859074],
#  ['включает', 1, 292, 0.0, 2.465382851448418],
#  ['первых', 1, 293, 0.0, 2.4668676203541096],
#  ['вопрос', 1, 294, 0.0, 2.468347330412157],
#  ['преподноситься', 1, 295, 0.0, 2.469822015978163],
#  ['аудитория', 1, 296, 0.0, 2.4712917110589383],
#  ['отклик', 1, 297, 0.0, 2.4727564493172123],
#  ['ожидать', 1, 298, 0.0, 2.4742162640762553],
#  ['публики', 1, 299, 0.0, 2.4756711883244296],
#  ['вторых', 1, 300, 0.0, 2.477121254719662],
#  ['сетей', 1, 301, 0.0, 2.478566495593843],
#  ['форумов', 1, 302, 0.0, 2.4800069429571505],
#  ['части', 1, 303, 0.0, 2.481442628502305],
#  ['представить', 1, 304, 0.0, 2.4828735836087534],
#  ['интернете', 1, 305, 0.0, 2.484299839346786],
#  ['главный', 1, 306, 0.0, 2.4857214264815797],
#  ['целевой', 1, 307, 0.0, 2.487138375477186],
#  ['проекта', 1, 308, 0.0, 2.488550716500444],
#  ['обращать', 1, 309, 0.0, 2.4899584794248346],
#  ['внимание', 1, 310, 0.0, 2.4913616938342726],
#  ['сегодняшний', 1, 311, 0.0, 2.492760389026837],
#  ['день', 1, 312, 0.0, 2.4941545940184424],
#  ['применять', 1, 313, 0.0, 2.4955443375464483],
#  ['классификация', 1, 314, 0.0, 2.4969296480732144],
#  ['обучать', 1, 315, 0.0, 2.4983105537896004],
#  ['коллекций', 1, 316, 0.0, 2.4996870826184034],
#  ['удобный', 1, 317, 0.0, 2.501059262217751],
#  ['избыток', 1, 318, 0.0, 2.5024271199844326],
#  ['напр', 1, 319, 0.0, 2.503790683057181],
#  ['позитивный', 1, 320, 0.0, 2.505149978319906],
#  ['негативный', 1, 321, 0.0, 2.506505032404872],
#  ['товара', 1, 322, 0.0, 2.507855871695831],
#  ['текстовый', 1, 323, 0.0, 2.5092025223311025],
#  ['особо', 1, 324, 0.0, 2.5105450102066116],
#  ['глазго', 1, 325, 0.0, 2.511883360978874],
#  ['сконцентрировать', 1, 326, 0.0, 2.513217600067939],
#  ['сегменте', 1, 327, 0.0, 2.514547752660286],
#  ['насколько', 1, 328, 0.0, 2.515873843711679],
#  ['прямой', 1, 329, 0.0, 2.517195897949974],
#  ['косвенный', 1, 330, 0.0, 2.518513939877887],
#  ['речь', 1, 331, 0.0, 2.5198279937757184],
#  ['новостной', 1, 332, 0.0, 2.521138083704036],
#  ['непригодный', 1, 333, 0.0, 2.5224442335063197],
#  ['отсутствие', 1, 334, 0.0, 2.5237464668115646],
#  ['проставить', 1, 335, 0.0, 2.5250448070368448],
#  ['окраска', 1, 336, 0.0, 2.5263392773898437],
#  ['обратиться', 1, 337, 0.0, 2.5276299008713385],
#  ['подходу', 1, 338, 0.0, 2.5289167002776547],
#  ['успешно', 1, 339, 0.0, 2.5301996982030817],
#  ['применяться', 1, 340, 0.0, 2.531478917042255],
#  ['система', 1, 341, 0.0, 2.5327543789924976],
#  ['фелвол', 1, 342, 0.0, 2.5340261060561344],
#  ['вулверхемптон', 1, 343, 0.0, 2.53529412004277],
#  ['великобритания', 1, 344, 0.0, 2.53655844257153],
#  ['предназначить', 1, 345, 0.0, 2.537819095073274],
#  ['сегмент', 1, 346, 0.0, 2.5390760987927767],
#  ['словари', 1, 347, 0.0, 2.5403294747908736],
#  ['известный', 1, 348, 0.0, 2.5415792439465807],
#  ['извлечь', 1, 349, 0.0, 2.5428254269591797],
#  ['фильмы', 1, 350, 0.0, 2.5440680443502752],
#  ['книги', 1, 351, 0.0, 2.545307116465824],
#  ['игры', 1, 352, 0.0, 2.5465426634781307],
#  ['телефоны', 1, 353, 0.0, 2.5477747053878224],
#  ['камеры', 1, 354, 0.0, 2.5490032620257876],
#  ['соревнование', 1, 355, 0.0, 2.5502283530550938],
#  ['видно', 1, 356, 0.0, 2.551449997972875],
#  ['описания', 1, 357, 0.0, 2.5526682161121927],
#  ['предпочтение', 1, 358, 0.0, 2.553883026643874],
#  ['маркетинговый', 1, 359, 0.0, 2.555094448578319],
#  ['исследованиях', 1, 360, 0.0, 2.5563025007672873],
#  ['краудсорсинговый', 1, 361, 0.0, 2.5575072019056577],
#  ['инструмент', 1, 362, 0.0, 2.558708570533166],
#  ['анализа', 1, 363, 0.0, 2.559906625036112],
#  ['присвоить', 1, 364, 0.0, 2.5611013836490555],
#  ['окраску', 1, 365, 0.0, 2.5622928644564746],
#  ['обеспечении', 1, 366, 0.0, 2.56348108539441],
#  ['находить', 1, 367, 0.0, 2.5646660642520893],
#  ['соответствующий', 1, 368, 0.0, 2.5658478186735176],
#  ['усреднение', 1, 369, 0.0, 2.56702636615906],
#  ['текста', 1, 370, 0.0, 2.5682017240669945],
#  ['точность', 1, 371, 0.0, 2.5693739096150456],
#  ['путём', 1, 372, 0.0, 2.5705429398818973],
#  ['сравнение', 1, 373, 0.0, 2.5717088318086874],
#  ['людей', 1, 374, 0.0, 2.57287160220048],
#  ['применимый', 1, 375, 0.0, 2.5740312677277184],
#  ['создаваться', 1, 376, 0.0, 2.575187844927661],
#  ['настраивается', 1, 377, 0.0, 2.5763413502057926],
#  ['содержания', 1, 378, 0.0, 2.577491799837225],
#  ['аудитории', 1, 379, 0.0, 2.578639209968072],
#  ['составление', 1, 380, 0.0, 2.57978359661681],
#  ['эмоционально', 1, 381, 0.0, 2.580924975675619],
#  ['языка', 1, 382, 0.0, 2.5820633629117085],
#  ['полный', 1, 383, 0.0, 2.5831987739686224],
#  ['объём', 1, 384, 0.0, 2.5843312243675305],
#  ['невыполнимо', 1, 385, 0.0, 2.5854607295085006],
#  ['развитый', 1, 386, 0.0, 2.5865873046717547],
#  ['насчитывать', 1, 387, 0.0, 2.5877109650189114],
#  ['сотня', 1, 388, 0.0, 2.5888317255942073],
#  ['тысяча', 1, 389, 0.0, 2.5899496013257073],
#  ['альтернативный', 1, 390, 0.0, 2.591064607026499],
#  ['накопить', 1, 391, 0.0, 2.5921767573958667],
#  ['собственных', 1, 392, 0.0, 2.5932860670204567],
#  ['опора', 1, 393, 0.0, 2.5943925503754266],
#  ['эксперт', 1, 394, 0.0, 2.5954962218255737],
#  ['сбор', 1, 395, 0.0, 2.59659709562646],
#  ['простых', 1, 396, 0.0, 2.597695185925512],
#  ['носителей', 1, 397, 0.0, 2.598790506763115],
#  ['собираться', 1, 398, 0.0, 2.5998830720736876],
#  ['запасом', 1, 399, 0.0, 2.600972895686748],
#  ['включаться', 1, 400, 0.0, 2.602059991327962],
#  ['добровольцами', 1, 401, 0.0, 2.603144372620182],
#  ['человек', 1, 402, 0.0, 2.60422605308447],
#  ['привязка', 1, 403, 0.0, 2.605305046141109],
#  ['иметься', 1, 404, 0.0, 2.6063813651106047],
#  ['сведение', 1, 405, 0.0, 2.6074550232146683],
#  ['словах', 1, 406, 0.0, 2.608526033577194],
#  ['выражаться', 1, 407, 0.0, 2.6095944092252195],
#  ['признаковый', 1, 408, 0.0, 2.6106601630898796],
#  ['начать', 1, 409, 0.0, 2.611723308007342],
#  ['поиск', 1, 410, 0.0, 2.6127838567197355],
#  ['цифровой', 1, 411, 0.0, 2.613841821876069],
#  ['общество', 1, 412, 0.0, 2.6148972160331345],
#  ['русскоязычный', 1, 413, 0.0, 2.615950051656401],
#  ['сотрудничество', 1, 414, 0.0, 2.6170003411208986],
#  ['линис', 1, 415, 0.0, 2.6180480967120925],
#  ['ниу', 1, 416, 0.0, 2.6190933306267423],
#  ['вшэ', 1, 417, 0.0, 2.620136054973757],
#  ['разметить', 1, 418, 0.0, 2.621176281775035],
#  ['точка', 1, 419, 0.0, 2.622214022966295],
#  ['зрение', 1, 420, 0.0, 2.6232492903979003],
#  ['конец', 1, 421, 0.0, 2.624282095835668],
#  ['посчитать', 1, 422, 0.0, 2.625312450961674],
#  ['отрицательно', 1, 423, 0.0, 2.626340367375042],
#  ['эмоции', 1, 424, 0.0, 2.6273658565927325],
#  ['дополнить', 1, 425, 0.0, 2.6283889300503116],
#  ['данными', 1, 426, 0.0, 2.629409599102719],
#  ['списке', 1, 427, 0.0, 2.6304278750250236],
#  ['добавление', 1, 428, 0.0, 2.631443769013172],
#  ['автоматически', 1, 429, 0.0, 2.632457292184724],
#  ['отрезаться', 1, 430, 0.0, 2.633468455579586],
#  ['ий', 1, 431, 0.0, 2.634477270160731],
#  ['ый', 1, 432, 0.0, 2.635483746814912],
#  ['морфоанализатор', 1, 433, 0.0, 2.636487896353365],
#  ['словаре', 1, 434, 0.0, 2.6374897295125104],
#  ['анализатор', 1, 435, 0.0, 2.638489256954637],
#  ['реальный', 1, 436, 0.0, 2.639486489268586],
#  ['наречием', 1, 437, 0.0, 2.6404814369704215],
#  ['адресу', 1, 438, 0.0, 2.6414741105040993],
#  ['междометие', 1, 439, 0.0, 2.6424645202421213],
#  ['объяснительный', 1, 440, 0.0, 2.643452676486187],
#  ['добавить', 1, 441, 0.0, 2.644438589467838],
#  ['павлов', 1, 442, 0.0, 2.6454222693490914],
#  ['перевод', 1, 443, 0.0, 2.6464037262230695],
#  ['поставлять', 1, 444, 0.0, 2.6473829701146196],
#  ['программа', 1, 445, 0.0, 2.648360010980931],
#  ['отрицательный', 1, 446, 0.0, 2.649334858712142],
#  ['настроений', 1, 447, 0.0, 2.650307523131936],
#  ['краткий', 1, 448, 0.0, 2.6512780139981436],
#  ['сообщениями', 1, 449, 0.0, 2.6522463410033232],
#  ['публиковать', 1, 450, 0.0, 2.6532125137753435],
#  ['блогосферы', 1, 451, 0.0, 2.6541765418779604],
#  ['постам', 1, 452, 0.0, 2.655138434811382],
#  ['предварительный', 1, 453, 0.0, 2.656098202012832],
#  ['итоговый', 1, 454, 0.0, 2.6570558528571038],
#  ['состоять', 1, 455, 0.0, 2.658011396657112],
#  ['повторяться', 1, 456, 0.0, 2.658964842664435],
#  ['посвятить', 1, 457, 0.0, 2.65991620006985],
#  ['целями', 1, 458, 0.0, 2.660865478003869],
#  ['контекст', 1, 459, 0.0, 2.661812685537261],
#  ['облегчать', 1, 460, 0.0, 2.662757831681574],
#  ['особенно', 1, 461, 0.0, 2.663700925389648],
#  ['случай', 1, 462, 0.0, 2.6646419755561253],
#  ['полисемии', 1, 463, 0.0, 2.665580991017953],
#  ['тестовый', 1, 464, 0.0, 2.6665179805548807],
#  ['вебресурсе', 1, 465, 0.0, 2.6674529528899535],
#  ['закачивать', 1, 466, 0.0, 2.6683859166899997],
#  ['журнала', 1, 467, 0.0, 2.669316880566112],
#  ['протяжение', 1, 468, 0.0, 2.6702458530741238],
#  ['вестись', 1, 469, 0.0, 2.671172842715083],
#  ['постоянный', 1, 470, 0.0, 2.672097857935717],
#  ['еженедельный', 1, 471, 0.0, 2.6730209071288957],
#  ['закачка', 1, 472, 0.0, 2.6739419986340875],
#  ['популярный', 1, 473, 0.0, 2.674861140737811],
#  ['рейтинг', 1, 474, 0.0, 2.675778341674085],
#  ['капитал', 1, 475, 0.0, 2.6766936096248664],
#  ['предоставлять', 1, 476, 0.0, 2.677606952720493],
#  ['жж', 1, 477, 0.0, 2.678518379040114],
#  ['реляционный', 1, 478, 0.0, 2.6794278966121188],
#  ['база', 1, 479, 0.0, 2.6803355134145628],
#  ['порядок', 1, 480, 0.0, 2.681241237375587],
#  ['млн', 1, 481, 0.0, 2.6821450763738315],
#  ['период', 1, 482, 0.0, 2.683047038238849],
#  ['компенсировать', 1, 483, 0.0, 2.6839471307515117],
#  ['узкий', 1, 484, 0.0, 2.6848453616444123],
#  ['событийно', 1, 485, 0.0, 2.6857417386022635],
#  ['зависимый', 1, 486, 0.0, 2.686636269262293],
#  ['служить', 1, 487, 0.0, 2.687528961214634],
#  ['специализированный', 1, 488, 0.0, 2.6884198220027105],
#  ['топовый', 1, 489, 0.0, 2.6893088591236203],
#  ['взяты', 1, 490, 0.0, 2.6901960800285134],
#  ['отличаться', 1, 491, 0.0, 2.691081492122968],
#  ['обычный', 1, 492, 0.0, 2.69196510276736],
#  ['разредить', 1, 493, 0.0, 2.6928469192772297],
#  ['зашумлен', 1, 494, 0.0, 2.6937269489236466],
#  ['спамом', 1, 495, 0.0, 2.6946051989335684],
#  ['последующий', 1, 496, 0.0, 2.695481676490197],
#  ['способами', 1, 497, 0.0, 2.696356388733332],
#  ['заимствование', 1, 498, 0.0, 2.697229342759717],
#  ['рубрик', 1, 499, 0.0, 2.6981005456233897],
#  ['тэгам', 1, 500, 0.0, 2.6989700043360183],
#  ['ручной', 1, 501, 0.0, 2.6998377258672455],
#  ['выделение', 1, 502, 0.0, 2.700703717145019],
#  ['например', 1, 503, 0.0, 2.7015679850559273],
#  ['алгоритмов', 1, 504, 0.0, 2.702430536445525],
#  ['создатель', 1, 505, 0.0, 2.7032913781186614],
#  ['рубрика', 1, 506, 0.0, 2.704150516839799],
#  ['тэг', 1, 507, 0.0, 2.705007959333336],
#  ['граница', 1, 508, 0.0, 2.705863712283919],
#  ['известны', 1, 509, 0.0, 2.7067177823367583],
#  ['подходить', 1, 510, 0.0, 2.707570176097936],
#  ['самостоятельный', 1, 511, 0.0, 2.7084209001347124],
#  ['предпочесть', 1, 512, 0.0, 2.7092699609758304],
#  ['анализу', 1, 513, 0.0, 2.710117365111816],
#  ['нечёткий', 1, 514, 0.0, 2.7109631189952754],
#  ['релевантности', 1, 515, 0.0, 2.7118072290411908],
#  ['исследований', 1, 516, 0.0, 2.7126497016272113],
#  ['заключаться', 1, 517, 0.0, 2.7134905430939424],
#  ['следующем', 1, 518, 0.0, 2.7143297597452327],
#  ['пониматься', 1, 519, 0.0, 2.7151673578484576],
#  ['совокупность', 1, 520, 0.0, 2.716003343634799],
#  ['тенденция', 1, 521, 0.0, 2.716837723299524],
#  ['совместно', 1, 522, 0.0, 2.717670503002262],
#  ['упрощённый', 1, 523, 0.0, 2.718501688867274],
#  ['понимание', 1, 524, 0.0, 2.7193312869837265],
#  ['применение', 1, 525, 0.0, 2.7201593034059566],
#  ['многократно', 1, 526, 0.0, 2.720985744153739],
#  ['предмет', 1, 527, 0.0, 2.7218106152125463],
#  ['интерпретируемость', 1, 528, 0.0, 2.722633922533812],
#  ['людьми', 1, 529, 0.0, 2.7234556720351857],
#  ['демонстрировать', 1, 530, 0.0, 2.7242758696007887],
#  ['хороший', 1, 531, 0.0, 2.725094521081469],
#  ['интерпретация', 1, 532, 0.0, 2.725911632295048],
#  ['сформулировать', 1, 533, 0.0, 2.726727209026572],
#  ['генерация', 1, 534, 0.0, 2.727541257028556],
#  ['вычисление', 1, 535, 0.0, 2.728353782021228],
#  ['момент', 1, 536, 0.0, 2.7291647896927698],
#  ['вариант', 1, 537, 0.0, 2.7299742856995555],
#  ['базироваться', 1, 538, 0.0, 2.730782275666389],
#  ['вариантах', 1, 539, 0.0, 2.7315887651867388],
#  ['вариационный', 1, 540, 0.0, 2.7323937598229686],
#  ['предполагается', 1, 541, 0.0, 2.733197265106569],
#  ['порождаться', 1, 542, 0.0, 2.7339992865383866],
#  ['дискретный', 1, 543, 0.0, 2.7347998295888467],
#  ['наблюдать', 1, 544, 0.0, 2.7355988996981795],
#  ['скрытой', 1, 545, 0.0, 2.736396502276642],
#  ['появление', 1, 546, 0.0, 2.737192642704737],
#  ['пара', 1, 547, 0.0, 2.7379873263334304],
#  ['связать', 1, 548, 0.0, 2.738780558484369],
#  ['неизвестный', 1, 549, 0.0, 2.7395723444500915],
#  ['построить', 1, 550, 0.0, 2.740362689494243],
#  ['определить', 1, 551, 0.0, 2.741151598851785],
#  ['условный', 1, 552, 0.0, 2.7419390777291985],
#  ['матрицу', 1, 553, 0.0, 2.742725131304698],
#  ['уникальный', 1, 554, 0.0, 2.7435097647284294],
#  ['процедура', 1, 555, 0.0, 2.744292983122676],
#  ['нахождение', 1, 556, 0.0, 2.745074791582057],
#  ['задать', 1, 557, 0.0, 2.745855195173729],
#  ['обусловить', 1, 558, 0.0, 2.746634198937578],
#  ['простотой', 1, 559, 0.0, 2.747411807886423],
#  ['проведение', 1, 560, 0.0, 2.7481880270062002],
#  ['показывать', 1, 561, 0.0, 2.748962861256161],
#  ['правило', 1, 562, 0.0, 2.7497363155690606],
#  ['отсутствовать', 1, 563, 0.0, 2.7505083948513462],
#  ['ядро', 1, 564, 0.0, 2.751279103983342],
#  ['интерфейс', 1, 565, 0.0, 2.7520484478194382],
#  ['справляться', 1, 566, 0.0, 2.7528164311882715],
#  ['объемами', 1, 567, 0.0, 2.753583058892906],
#  ['развёртывание', 1, 568, 0.0, 2.754348335711019],
#  ['кластера', 1, 569, 0.0, 2.755112266395071],
#  ['продукт', 1, 570, 0.0, 2.7558748556724915],
#  ['собственный', 1, 571, 0.0, 2.7566361082458477],
#  ['разработчик', 1, 572, 0.0, 2.757396028793024],
#  ['г', 1, 573, 0.0, 2.75815462196739],
#  ['филипов', 1, 574, 0.0, 2.7589118923979736],
#  ['способный', 1, 575, 0.0, 2.75966784468963],
#  ['работать', 1, 576, 0.0, 2.760422483423212],
#  ['персональный', 1, 577, 0.0, 2.7611758131557314],
#  ['компьютер', 1, 578, 0.0, 2.761927838420529],
#  ['модули', 1, 579, 0.0, 2.762678563727436],
#  ['препроцессина', 1, 580, 0.0, 2.763427993562937],
#  ['результатов', 1, 581, 0.0, 2.76417613239033],
#  ['данных', 1, 582, 0.0, 2.7649229846498886],
#  ['провести', 1, 583, 0.0, 2.7656685547590136],
#  ['процедуры', 1, 584, 0.0, 2.766412847112399],
#  ['тэгов', 1, 585, 0.0, 2.7671558660821804],
#  ['лемматизация', 1, 586, 0.0, 2.7678976160180904],
#  ['приведение', 1, 587, 0.0, 2.7686381012476144],
#  ['начальный', 1, 588, 0.0, 2.769377326076138],
#  ['форме', 1, 589, 0.0, 2.7701152947871015],
#  ['стопа', 1, 590, 0.0, 2.770852011642144],
#  ['несущий', 1, 591, 0.0, 2.771587480881255],
#  ['смысл', 1, 592, 0.0, 2.7723217067229196],
#  ['влиять', 1, 593, 0.0, 2.7730546933642626],
#  ['тематику', 1, 594, 0.0, 2.7737864449811935],
#  ['постоянно', 1, 595, 0.0, 2.7745169657285493],
#  ['корректироваться', 1, 596, 0.0, 2.775246259740236],
#  ['подсчёт', 1, 597, 0.0, 2.775974331129369],
#  ['лемм', 1, 598, 0.0, 2.7767011839884104],
#  ['редкий', 1, 599, 0.0, 2.777426822389311],
#  ['дискриминировать', 1, 600, 0.0, 2.7781512503836434],
#  ['силы', 1, 601, 0.0, 2.778874472002739],
#  ['конвертация', 1, 602, 0.0, 2.7795964912578244],
#  ['формат', 1, 603, 0.0, 2.780317312140151],
#  ['основать', 1, 604, 0.0, 2.7810369386211318],
#  ['предполагать', 1, 605, 0.0, 2.7817553746524686],
#  ['тексте', 1, 606, 0.0, 2.782472624166286],
#  ['входной', 1, 607, 0.0, 2.7831886910752575],
#  ['являются', 1, 608, 0.0, 2.7839035792727347],
#  ['дирихло', 1, 609, 0.0, 2.784617292632875],
#  ['сэмплирования', 1, 610, 0.0, 2.7853298350107667],
#  ['ячейка', 1, 611, 0.0, 2.786041210242554],
#  ['опыта', 1, 612, 0.0, 2.786751422145561],
#  ['показавшего', 1, 613, 0.0, 2.787460474518415],
#  ['приводить', 1, 614, 0.0, 2.7881683711411673],
#  ['излишний', 1, 615, 0.0, 2.7888751157754164],
#  ['укрупнённый', 1, 616, 0.0, 2.789580712164425],
#  ['доля', 1, 617, 0.0, 2.7902851640332416],
#  ['заимствовать', 1, 618, 0.0, 2.7909884750888154],
#  ['подбираться', 1, 619, 0.0, 2.7916906490201177],
#  ['экспериментально', 1, 620, 0.0, 2.792391689498254],
#  ['графика', 1, 621, 0.0, 2.79309160017658],
#  ['сходимость', 1, 622, 0.0, 2.7937903846908183],
#  ['ход', 1, 623, 0.0, 2.7944880466591693],
#  ['столбец', 1, 624, 0.0, 2.7951845896824237],
#  ['отдельный', 1, 625, 0.0, 2.795880017344075],
#  ['тему', 1, 626, 0.0, 2.796574333210429],
#  ['элемент', 1, 627, 0.0, 2.7972675408307164],
#  ['убыванию', 1, 628, 0.0, 2.7979596437371956],
#  ['падать', 1, 629, 0.0, 2.7986506454452686],
#  ['достаточно', 1, 630, 0.0, 2.7993405494535817],
#  ['быстро', 1, 631, 0.0, 2.800029359244134],
#  ['передать', 1, 632, 0.0, 2.8007170782823847],
#  ['кодировщикам', 1, 633, 0.0, 2.8014037100173548],
#  ['определяли', 1, 634, 0.0, 2.8020892578817325],
#  ['политическими', 1, 635, 0.0, 2.8027737252919755],
#  ['кодирование', 1, 636, 0.0, 2.803457115648414],
#  ['считаться', 1, 637, 0.0, 2.80413943233535],
#  ['социальнополитической', 1, 638, 0.0, 2.804820678721162],
#  ['минимум', 1, 639, 0.0, 2.8055008581584],
#  ['согласованность', 1, 640, 0.0, 2.8061799739838866],
#  ['расчёт', 1, 641, 0.0, 2.8068580295188172],
#  ['довольно', 1, 642, 0.0, 2.807535028068853],
#  ['низкий', 1, 643, 0.0, 2.8082109729242215],
#  ['показатель', 1, 644, 0.0, 2.808885867359812],
#  ['простой', 1, 645, 0.0, 2.8095597146352675],
#  ['задач', 1, 646, 0.0, 2.810232517995084],
#  ['редко', 1, 647, 0.0, 2.8109042806687],
#  ['бывать', 1, 648, 0.0, 2.811575005870593],
#  ['согласие', 1, 649, 0.0, 2.812244696800369],
#  ['кодировщиков', 1, 650, 0.0, 2.8129133566428552],
#  ['несмотря', 1, 651, 0.0, 2.8135809885681917],
#  ['выбирать', 1, 652, 0.0, 2.81424759573192],
#  ['документы', 1, 653, 0.0, 2.814913181275074],
#  ['средний', 1, 654, 0.0, 2.815577748324267],
#  ['порог', 1, 655, 0.0, 2.8162412999917827],
#  ['массив', 1, 656, 0.0, 2.81690383937566],
#  ['миллион', 1, 657, 0.0, 2.81756536955978],
#  ['получиться', 1, 658, 0.0, 2.8182258936139553],
#  ['формирование', 1, 659, 0.0, 2.8188854145940097],
#  ['дополнение', 1, 660, 0.0, 2.8195439355418683],
#  ['лингвист', 1, 661, 0.0, 2.8202014594856397],
#  ['назвать', 1, 662, 0.0, 2.8208579894396997],
#  ['эмоций', 1, 663, 0.0, 2.8215135284047728],
#  ['формироваться', 1, 664, 0.0, 2.822168079368017],
#  ['областей', 1, 665, 0.0, 2.8228216453031045],
#  ['лексики', 1, 666, 0.0, 2.823474229170301],
#  ['часто', 1, 667, 0.0, 2.8241258339165487],
#  ['вместе', 1, 668, 0.0, 2.8247764624755454],
#  ['объект', 1, 669, 0.0, 2.825426117767823],
#  ['направлена', 1, 670, 0.0, 2.826074802700826],
#  ['разным', 1, 671, 0.0, 2.826722520168992],
#  ['политическим', 1, 672, 0.0, 2.827369273053825],
#  ['оценку', 1, 673, 0.0, 2.8280150642239765],
#  ['решить', 1, 674, 0.0, 2.8286598965353194],
#  ['пример', 1, 675, 0.0, 2.829303772831025],
#  ['оформление', 1, 676, 0.0, 2.829946695941636],
#  ['списка', 1, 677, 0.0, 2.8305886686851442],
#  ['нормализовать', 1, 678, 0.0, 2.831229693867063],
#  ['форму', 1, 679, 0.0, 2.8318697742805017],
#  ['дублироваться', 1, 680, 0.0, 2.8325089127062357],
#  ['немой', 1, 681, 0.0, 2.8331471119127847],
#  ['признать', 1, 682, 0.0, 2.833784374656479],
#  ['далее', 1, 683, 0.0, 2.8344207036815323],
#  ['пересечь', 1, 684, 0.0, 2.8350561017201157],
#  ['списками', 1, 685, 0.0, 2.8356905714924254],
#  ['указать', 1, 686, 0.0, 2.836324115706751],
#  ['какого', 1, 687, 0.0, 2.83695673705955],
#  ['какий', 1, 688, 0.0, 2.8375884382355108],
#  ['источника', 1, 689, 0.0, 2.8382192219076257],
#  ['пришло', 1, 690, 0.0, 2.8388490907372548],
#  ['списков', 1, 691, 0.0, 2.839478047374198],
#  ['информация', 1, 692, 0.0, 2.8401060944567575],
#  ['том', 1, 693, 0.0, 2.8407332346118066],
#  ['встречается', 1, 694, 0.0, 2.841359470454855],
#  ['сразу', 1, 695, 0.0, 2.8419848045901137],
#  ['источников', 1, 696, 0.0, 2.842609239610562],
#  ['представлены', 1, 697, 0.0, 2.843232778098009],
#  ['вручную', 1, 698, 0.0, 2.843855422623161],
#  ['исключить', 1, 699, 0.0, 2.844477175745681],
#  ['счесть', 1, 700, 0.0, 2.8450980400142565],
#  ['нерелевантными', 1, 701, 0.0, 2.8457180179666586],
#  ['основное', 1, 702, 0.0, 2.8463371121298047],
#  ['аккумулятор', 1, 703, 0.0, 2.846955325019824],
#  ['диагональ', 1, 704, 0.0, 2.847572659142112],
#  ['панель', 1, 705, 0.0, 2.8481891169913984],
#  ['этого', 1, 706, 0.0, 2.8488047010518036],
#  ['исключили', 1, 707, 0.0, 2.849419413796899],
#  ['операция', 1, 708, 0.0, 2.850033257689769],
#  ['сумма', 1, 709, 0.0, 2.850646235183066],
#  ['дубликат', 1, 710, 0.0, 2.851258348719075],
#  ['удалены', 1, 711, 0.0, 2.851869600729766],
#  ['окончательно', 1, 712, 0.0, 2.852479993636856],
#  ['сопоставить', 1, 713, 0.0, 2.8530895298518653],
#  ['выбираться', 1, 714, 0.0, 2.853698211776174],
#  ['максимальный', 1, 715, 0.0, 2.85430604180108],
#  ['финальный', 1, 716, 0.0, 2.8549130223078554],
#  ['успешный', 1, 717, 0.0, 2.8555191556677997],
#  ['необходимо', 1, 718, 0.0, 2.8561244442423],
#  ['понимать', 1, 719, 0.0, 2.8567288903828825],
#  ['краудсорсинг', 1, 720, 0.0, 2.857332496431268],
#  ['время', 1, 721, 0.0, 2.857935264719429],
#  ['заключение', 1, 722, 0.0, 2.8585371975696385],
#  ['статья', 1, 723, 0.0, 2.8591382972945305],
#  ['описать', 1, 724, 0.0, 2.8597385661971466],
#  ['промежуточный', 1, 725, 0.0, 2.8603380065709936],
#  ['возможность', 1, 726, 0.0, 2.8609366207000932],
#  ['заряженности', 1, 727, 0.0, 2.8615344108590377],
#  ['контента', 1, 728, 0.0, 2.8621313793130367],
#  ['позволить', 1, 729, 0.0, 2.8627275283179743],
#  ['точнее', 1, 730, 0.0, 2.8633228601204554],
#  ['активный', 1, 731, 0.0, 2.86391737695786],
#  ['население', 1, 732, 0.0, 2.8645110810583914],
#  ['вопросам', 1, 733, 0.0, 2.8651039746411278],
#  ['важность', 1, 734, 0.0, 2.86569605991607],
#  ['общественность', 1, 735, 0.0, 2.8662873390841948],
#  ['подтверждается', 1, 736, 0.0, 2.866877814337499],
#  ['прочего', 1, 737, 0.0, 2.867467487859051],
#  ['роль', 1, 738, 0.0, 2.8680563618230415],
#  ['прокатиться', 1, 739, 0.0, 2.8686444383948255],
#  ['мир', 1, 740, 0.0, 2.869231719730976],
#  ['волна', 1, 741, 0.0, 2.869818207979328],
#  ['протест', 1, 742, 0.0, 2.870403905279027],
#  ['революция', 1, 743, 0.0, 2.870988813760575],
#  ['годов', 1, 744, 0.0, 2.871572935545878]]

# %%
frame = pd.DataFrame(n_list, columns=['Words','Frequencies','Ranks', 'Logarithm of Frequencies', 'Logarithm of ranks']) # собираем фрейм
frame.to_csv('Frequency Dictionary.csv',encoding='utf-8', sep=';', index=False) #экспортируем в файл

# %%
bigrams = nltk.collocations.BigramAssocMeasures()
trigrams = nltk.collocations.TrigramAssocMeasures()

bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(text_words)
trigramFinder = nltk.collocations.TrigramCollocationFinder.from_words(text_words)

# bigrams
bigram_freq = bigramFinder.ngram_fd.items()
bigramFreqTable = pd.DataFrame(list(bigram_freq), columns=['bigram','freq']).sort_values(by='freq', ascending=False)
bigramFreqTable.to_csv('Bigrams.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# trigrams
trigram_freq = trigramFinder.ngram_fd.items()
trigramFreqTable = pd.DataFrame(list(trigram_freq), columns=['trigram','freq']).sort_values(by='freq', ascending=False)
trigramFreqTable.to_csv('Trigrams.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# %%
bigram_freq
# Out:
# dict_items([(('лексический', 'ресурс'), 1), (('ресурс', 'анализ'), 1), (('анализ', 'тональность'), 1), (('тональность', 'социально'), 1), (('социально', 'политический'), 21), (('политический', 'текст'), 1), (('текст', 'русский'), 1), (('русский', 'язык'), 3), (('язык', 'алексеева'), 1), (('алексеева', 'н'), 1), (('н', 'кольцов'), 2), (('кольцов', 'ю'), 1), (('ю', 'кольцов'), 1), (('кольцов', 'национальный'), 1), (('национальный', 'исследовательский'), 1), (('исследовательский', 'университет'), 1), (('университет', 'высокий'), 1), (('высокий', 'школа'), 1), (('школа', 'экономики'), 1), (('экономики', 'санкт'), 1), (('санкт', 'петербург'), 1), (('петербург', 'введение'), 1), (('введение', 'тональный'), 1), (('тональный', 'анализ'), 2), (('анализ', 'сентимент'), 1), (('сентимент', 'анализ'), 1), (('анализ', 'автоматизированный'), 1), (('автоматизированный', 'анализ'), 1), (('анализ', 'эмоциональный'), 1), (('эмоциональный', 'окрашенность'), 2), (('окрашенность', 'текст'), 1), (('текст', 'плохо'), 1), (('плохо', 'нравиться'), 1), (('нравиться', 'нравиться'), 1), (('нравиться', 'др'), 1), (('др', 'можно'), 1), (('можно', 'отнести'), 1), (('отнести', 'область'), 1), (('область', 'компьютерный'), 1), (('компьютерный', 'лингвистики'), 1), (('лингвистики', 'задача'), 1), (('задача', 'применения'), 1), (('применения', 'основном'), 1), (('основном', 'лежать'), 1), (('лежать', 'предел'), 1), (('предел', 'лингвистика'), 1), (('лингвистика', 'можно'), 1), (('можно', 'разделить'), 1), (('разделить', 'обширный'), 1), (('обширный', 'области'), 1), (('области', 'маркетинг'), 1), (('маркетинг', 'очередь'), 1), (('очередь', 'анализ'), 1), (('анализ', 'отзыв'), 1), (('отзыв', 'товар'), 2), (('товар', 'услуги'), 1), (('услуги', 'социология'), 1), (('социология', 'политология'), 1), (('политология', 'последний'), 1), (('последний', 'включает'), 1), (('включает', 'первых'), 1), (('первых', 'анализ'), 1), (('анализ', 'текст'), 1), (('текст', 'сми'), 1), (('сми', 'выявление'), 1), (('выявление', 'того'), 1), (('того', 'социально'), 1), (('социально', 'значимый'), 2), (('значимый', 'вопрос'), 1), (('вопрос', 'преподноситься'), 1), (('преподноситься', 'аудитория'), 1), (('аудитория', 'отклик'), 1), (('отклик', 'можно'), 1), (('можно', 'ожидать'), 1), (('ожидать', 'публики'), 1), (('публики', 'вторых'), 1), (('вторых', 'исследование'), 1), (('исследование', 'текст'), 1), (('текст', 'социальный'), 2), (('социальный', 'медиа'), 3), (('медиа', 'блогов'), 1), (('блогов', 'социальный'), 1), (('социальный', 'сетей'), 1), (('сетей', 'форумов'), 1), (('форумов', 'пользовательский'), 1), (('пользовательский', 'контент'), 2), (('контент', 'цель'), 1), (('цель', 'выявление'), 1), (('выявление', 'общественный'), 1), (('общественный', 'мнение'), 5), (('мнение', 'части'), 1), (('части', 'представить'), 1), (('представить', 'интернете'), 1), (('интернете', 'последний'), 1), (('последний', 'компонент'), 1), (('компонент', 'являться'), 1), (('являться', 'главный'), 1), (('главный', 'целевой'), 1), (('целевой', 'область'), 1), (('область', 'знание'), 1), (('знание', 'настоящий'), 1), (('настоящий', 'проекта'), 1), (('проекта', 'очередь'), 1), (('очередь', 'проект'), 1), (('проект', 'обращать'), 1), (('обращать', 'внимание'), 1), (('внимание', 'анализ'), 1), (('анализ', 'сми'), 1), (('сми', 'сегодняшний'), 1), (('сегодняшний', 'день'), 1), (('день', 'существовать'), 1), (('существовать', 'основный'), 1), (('основный', 'подход'), 1), (('подход', 'автоматический'), 1), (('автоматический', 'определение'), 2), (('определение', 'тональность'), 1), (('тональность', 'текстов'), 1), (('текстов', 'словарный'), 1), (('словарный', 'использовать'), 1), (('использовать', 'словарь'), 1), (('словарь', 'последний'), 1), (('последний', 'применять'), 1), (('применять', 'различный'), 1), (('различный', 'метод'), 1), (('метод', 'автоматический'), 1), (('автоматический', 'классификация'), 1), (('классификация', 'основа'), 1), (('основа', 'обучать'), 1), (('обучать', 'коллекций'), 1), (('коллекц ...

# %%
# t-test
bigramTtable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.student_t)), columns=['bigram','T-test']).sort_values(by='T-test', ascending=False)
trigramTtable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.student_t)), columns=['trigram','T-test']).sort_values(by='T-test', ascending=False)
bigramTtable = bigramTtable.head(20)
trigramTtable = trigramTtable.head(20) #вычленяем первые 20 лучших би- и триграмм
bigramTtable.to_csv('Bigrams-T-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл
trigramTtable.to_csv('Trigrams-T-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# chi-squared
bigramCHItable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.chi_sq)), columns=['bigram','Chi-squared']).sort_values(by='Chi-squared', ascending=False)
trigramCHItable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.chi_sq)), columns=['trigram','Chi-squared']).sort_values(by='Chi-squared', ascending=False)
bigramCHItable = bigramCHItable.head(20)
trigramCHItable = trigramCHItable.head(20) #вычленяем первые 20 лучших би- и триграмм
bigramCHItable.to_csv('Bigrams-CHI-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл
trigramCHItable.to_csv('Trigrams-CHI-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# log-likelihood
bigramlikelihoodtable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.likelihood_ratio)), columns=['bigram','Log-Likelihood']).sort_values(by='Log-Likelihood', ascending=False)
trigramlikelihoodtable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.likelihood_ratio)), columns=['trigram','Log-Likelihood']).sort_values(by='Log-Likelihood', ascending=False)
bigramlikelihoodtable = bigramlikelihoodtable.head(20)
trigramlikelihoodtable = trigramlikelihoodtable.head(20) #вычленяем первые 20 лучших би- и триграмм
bigramlikelihoodtable.to_csv('Bigrams-likelihood-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл
trigramlikelihoodtable.to_csv('Trigrams-likelihood-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# pmi
bigramPMItable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.pmi)), columns=['bigram','PMI']).sort_values(by='PMI', ascending=False)
trigramPMItable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.pmi)), columns=['trigram','PMI']).sort_values(by='PMI', ascending=False)
bigramPMItable = bigramPMItable.head(20)
trigramPMItable = trigramPMItable.head(20) #вычленяем первые 20 лучших би- и триграмм
bigramPMItable.to_csv('Bigrams-PMI-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл
trigramPMItable.to_csv('Trigrams-PMI-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# %%
#RAKE

# %%
# !pip install pymorphy3
# Out:
# Collecting pymorphy3
#   Downloading pymorphy3-2.0.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 2.8 MB/s eta 0:00:00
# Collecting dawg-python>=0.7.1 (from pymorphy3)
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting pymorphy3-dicts-ru (from pymorphy3)
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 71.9 MB/s eta 0:00:00
# Installing collected packages: pymorphy3-dicts-ru, dawg-python, pymorphy3
# Successfully installed dawg-python-0.7.2 pymorphy3-2.0.1 pymorphy3-dicts-ru-2.4.417150.4580142

# %%
import pymorphy3 as pm
import codecs
import string

# %%
m = pm.MorphAnalyzer()

# %%
words = []
words2 = ""

# %%
with open('Alexeeva_IMS_2015_rus_lem.txt', 'r', encoding='utf-8') as f: #прописываем путь к корпусу (папка или файл)
    text = f.read()
    words = text.split()
    for i in range(len(words) - 1):
        if m.parse(words[i])[0].tag.POS == "ADVB" or m.parse(words[i])[0].tag.POS == "VERB" or m.parse(words[i][:-1])[0].tag.POS == "VERB" or m.parse(words[i])[0].tag.POS == "PRTS"or m.parse(words[i])[0].tag.POS == "INFN"or m.parse(words[i])[0].tag.POS == "COMP" or m.parse(words[i])[0].tag.POS == "ADJS" or m.parse(words[i])[0].tag.POS == "GRND"or m.parse(words[i])[0].tag.POS == "CONJ":
            words2 += " | " + words[i] + " | "
        elif (m.parse(words[i])[0].tag.POS == "NOUN" and m.parse(words[i])[0].tag.case == ("gent" or "accs")):
            words2 += words[i] + " | "
        elif m.parse(words[i])[0].tag.POS == "NOUN" and m.parse(words[i + 1])[0].tag.POS == ("NOUN" or "ADJF") and m.parse(words[i])[0].tag.case != m.parse(words[i + 1])[0].tag.case and m.parse(words[i + 1])[0].tag.case != "gent":
            words2 += words[i] + " | "
        elif (m.parse(words[i])[0].tag.POS == "NOUN" and m.parse(words[i])[0].tag.case != ("nomn" or "accs") and m.parse(words[i + 1])[0].tag.POS == "NOUN" and m.parse(words[i + 1])[0].tag.case == ("nomn" or "accs")):
            words2 += words[i] + " | "
        elif (m.parse(words[i])[0].tag.POS == None and m.parse(words[i][:-1])[0].tag.POS == None and m.parse(words[i][1:])[0].tag.POS == None):
            words2 += " | " + words[i] + " | "
        elif (m.parse(words[i])[0].tag.POS == "NOUN" and m.parse(words[i - 1])[0].tag.POS == "ADJF" or m.parse(words[i - 1])[0].tag.POS == "PRTF") and m.parse(words[i])[0].tag.case == m.parse(words[i + 1])[0].tag.case:
            words2 += words[i] + " | "
        else:
            words2 += words[i] + " "

# %%
words2
# Out:
# ' | linis-crowd.org: | лексический ресурс для анализ | тональность социально-политический текст на русский язык с. в. алексеева, с. н. кольцов, о.  | ю. | кольцов национальный исследовательский университет | «высокий школа  | экономики»- | санкт-петербург  | 1. | введение тональный анализ (сентимент-анализ)  | или | автоматизированный анализ | эмоциональный окрашенность | текст  | (плохо |  | / | хорошо,  | нравиться |  | / | не  | нравиться |  | и |  | др.) | можно  | отнести | к область компьютерный лингвистики, однако, задача он применения, в основном,  | лежать | за предел собственно лингвистика  | [1]. | они можно  | разделить | на два обширный области: маркетинг (в первый очередь  | — |  | как | анализ отзыв на товар  | и | услуги)  | и | социология  | / | политология. последний  | включает, | во-первых, анализ текст  | сми | для выявление того,  | как | тот  | или | иной  | социально | значимый вопрос  | преподноситься | аудитория и, соответственно, какой отклик можно  | ожидать | на они от публики. во-вторых, это исследование текст социальный медиа: блогов, социальный сетей, форумов,  | а | также другой пользовательский контент с цель выявление общественный  | мнение | или,  | более | точно, он части,  | представить | в интернете. этот последний компонент  | являться | главный целевой область | знание настоящий проекта; в второй очередь | проект  | обращать | внимание на анализ сми. на сегодняшний день  | существовать | два основный подход к автоматический  | определение | тональность текстов:  | (1) | словарный  | и |  | (2) | не  | использовать | словарь. последний,  | применять | различный метод | автоматический классификация на основа  | обучать | коллекций, удобный тогда,  | когда | такой коллекция | доступный в избыток  | (напр., | отзыв на товар с общий позитивный  | / | негативный оценка  | товара). | в англоязычный сфера  | создать | большой количество | текстовый коллекция  | [1], | среди который  | особо | можно  | выделить |  | blog06 |  | (http://ir.dcs.gla.ac.uk/test_collections/blog06info.html) | университет глазго, который  | сконцентрировать | на блог разный тематики. в русский сегменте,  | насколько | мы известно, в свободный доступ  | находиться |  | только | коллекция прямой  | и | косвенный речь новостной текстов,  | создать | ромип  | (http://romip.ru/ru/collections/index.html), |  | но | она непригодный к исследование эмоциональный  | составлять | текст блогов. в  | отсутствие | необходимый количество | коллекция текст с  | проставить | тональный окраска | мы  | обратиться | к словарный подходу. для английский язык словарный подход  | успешно |  | применяться | в система  | sentistrength |  | (http://sentistrength.wlv.ac.uk/), |  | создать | м. фелвол в университет вулверхемптон  | (великобритания). | данный по  | специально |  | предназначить | для анализ социальный медиа. кроме того, в английский сегмент доступный обширный словари, такой  | как |  | opinionfinder |  | (http://mpqa.cs.pitt.edu/opinionfinder/) |  | и |  | sentiwordnet |  | (http://sentiwordnet.isti.cnr.it/). | для русский язык мы известный словарь и. четверкин  | и | н.  | лукашевич |  | [2] |  | (http://www.cir.ru/sentilexicon/productsentirus.txt), |  | представлять | себя список из  | 5000 | оценочный слов,  | извлечь | из коллекция отзыв в  | несколько | предметный область (фильмы, книги, игры, телефоны,  | камеры). | словарь  | быть |  | разработать |  | исследователь | для соревнование | ромип по тональный анализ отзывов.  | как |  | видно | из описания, он  | создать | прежде весь для выявление  | предпочтение | в маркетинговый исследованиях,  | а | не для анализ общественный  | мнение | в текст социально-политический направленности. такой образом, цель данный исследование  | являться | разработка тональный словарь  | и | краудсорсинговый веб-ресурс для создание | инструмент сентимент-анализа. тональный словарь  | – | это список слов, каждый из который  | присвоить |  | «вес», |  | описывать | он эмоциональный окраску. тако ...

# %%
with open('corpus_Alexeeva.txt', 'w', encoding='utf-8') as f2:
    f2.write(words2)

# %%
from __future__ import division
import operator
import nltk

# %%
punct = open("punct.txt", 'r', encoding='utf-8').read()

# %%
punct_list = nltk.word_tokenize(punct)

# %%
import nltk
nltk.download('punkt')
stop = open("stop.txt", 'r', encoding='utf-8').read()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
pronouns = open("pronouns.txt", 'r', encoding='utf-8').read()

# %%
preps = open("preps.txt", 'r', encoding='utf-8').read()

# %%
preps
# Out:
# 'а-ля\nбез\nбезо\nблагодаря\nблиз\nв\nвблизи\nввиду\nвглубь\nвдогон\nвдоль\nвзамен\nвключая\nвкруг\nвместо\nвне\nвнизу\nвнутри\nвнутрь\nво\nво имя\nвовнутрь\nвозле\nвокруг\nвопреки\nвослед\nвпереди\nвразрез\nвроде\nвслед\nвследствие\nдля\nдля-ради\nдо\nза\nзаместо\nиз\nиз-за\nиз-под\nизнутри\nизо\nк\nкасательно\nко\nкроме\nкругом\nмеж\nмежду\nмимо\nна\nнаверху\nнавроде\nнавстречу\nнад\nнадо\nназад\nнакануне\nнаперекор\nнаперерез\nнаподобие\nнапротив\nнасупротив\nнасчёт\nниже\nо\nоб\nобо\nобок\nоколо\nокрест\nокромя\nокруг\nопосля\nот\nотносительно\nото\nперед\nпередо\nпо\nпо-за\nпо-над\nпо-под\nповерх\nпод\nподле\nподо\nподобно\nпозади\nпозднее\nпомимо\nпоперёд\nпоперёк\nпорядка\nпосередине\nпосередь\nпосле\nпосреди\nпосредине\nпосредством\nпред\nпредо\nпрежде\nпри\nпро\nпротив\nпутём\nради\nс\nсверх\nсверху\nсвыше\nсзади\nсквозь\nскрозь\nснизу\nсо\nсогласно\nспустя\nсреди\nсредь\nсродни\nсупротив\nчерез\nчрез\n'

# %%
mystop = open("userstop.txt", 'r', encoding='utf-8').read()

# %%
#nltk.word_tokenize(preps.decode("utf8")) + nltk.word_tokenize(mystop.decode("utf8"))
nltk.word_tokenize(preps) + nltk.word_tokenize(mystop)
# Out:
# ['а-ля',
#  'без',
#  'безо',
#  'благодаря',
#  'близ',
#  'в',
#  'вблизи',
#  'ввиду',
#  'вглубь',
#  'вдогон',
#  'вдоль',
#  'взамен',
#  'включая',
#  'вкруг',
#  'вместо',
#  'вне',
#  'внизу',
#  'внутри',
#  'внутрь',
#  'во',
#  'во',
#  'имя',
#  'вовнутрь',
#  'возле',
#  'вокруг',
#  'вопреки',
#  'вослед',
#  'впереди',
#  'вразрез',
#  'вроде',
#  'вслед',
#  'вследствие',
#  'для',
#  'для-ради',
#  'до',
#  'за',
#  'заместо',
#  'из',
#  'из-за',
#  'из-под',
#  'изнутри',
#  'изо',
#  'к',
#  'касательно',
#  'ко',
#  'кроме',
#  'кругом',
#  'меж',
#  'между',
#  'мимо',
#  'на',
#  'наверху',
#  'навроде',
#  'навстречу',
#  'над',
#  'надо',
#  'назад',
#  'накануне',
#  'наперекор',
#  'наперерез',
#  'наподобие',
#  'напротив',
#  'насупротив',
#  'насчёт',
#  'ниже',
#  'о',
#  'об',
#  'обо',
#  'обок',
#  'около',
#  'окрест',
#  'окромя',
#  'округ',
#  'опосля',
#  'от',
#  'относительно',
#  'ото',
#  'перед',
#  'передо',
#  'по',
#  'по-за',
#  'по-над',
#  'по-под',
#  'поверх',
#  'под',
#  'подле',
#  'подо',
#  'подобно',
#  'позади',
#  'позднее',
#  'помимо',
#  'поперёд',
#  'поперёк',
#  'порядка',
#  'посередине',
#  'посередь',
#  'после',
#  'посреди',
#  'посредине',
#  'посредством',
#  'пред',
#  'предо',
#  'прежде',
#  'при',
#  'про',
#  'против',
#  'путём',
#  'ради',
#  'с',
#  'сверх',
#  'сверху',
#  'свыше',
#  'сзади',
#  'сквозь',
#  'скрозь',
#  'снизу',
#  'со',
#  'согласно',
#  'спустя',
#  'среди',
#  'средь',
#  'сродни',
#  'супротив',
#  'через',
#  'чрез',
#  '``',
#  '--',
#  '.-',
#  '...',
#  '``',
#  '»',
#  'благодаря',
#  'был',
#  'была',
#  'в',
#  'виде',
#  'в',
#  'случае',
#  'в',
#  'частности',
#  'виде',
#  'все',
#  'всей',
#  'всем',
#  'всеми',
#  'всякая',
#  'всякй',
#  'всё',
#  'главное',
#  'образ',
#  'главным',
#  'образом',
#  'года',
#  'году',
#  'два',
#  'два',
#  'две',
#  'двум',
#  'двум',
#  'двумя',
#  'двух',
#  'до',
#  'другие',
#  'другие',
#  'другим',
#  'другими',
#  'других',
#  'других',
#  'другого',
#  'другой',
#  'другому',
#  'ею',
#  'её',
#  'за',
#  'счет',
#  'какая-то',
#  'какие',
#  'какие-то',
#  'каким-нибудь',
#  'каким-то',
#  'какими',
#  'какими-то',
#  'каких-либо',
#  'каких-либо',
#  'каких-то',
#  'какое-то',
#  'какой-то',
#  'какому-то',
#  'качестве',
#  'кг',
#  'котором',
#  'мои',
#  'моими',
#  'моих',
#  'мой',
#  'мою',
#  'моя',
#  'нам',
#  'нами',
#  'например',
#  'нас',
#  'наши',
#  'наших',
#  'некоторые',
#  'некоторый',
#  'некоторых',
#  'нескольких',
#  'нем',
#  'нему',
#  'никакими',
#  'никаких',
#  'никакой',
#  'ними',
#  'них',
#  'один',
#  'одним',
#  'одного',
#  'одному',
#  'п/п',
#  'по',
#  'расчетам',
#  'по',
#  'словам',
#  'помощи',
#  'протяжении',
#  'расчетам',
#  'с',
#  'помощью',
#  'с',
#  'точки',
#  'зрения',
#  'сама',
#  'самая',
#  'самим',
#  'само',
#  'самое',
#  'самом',
#  'свое',
#  'своего',
#  'своей',
#  'своем',
#  'своемy',
#  'своему',
#  'своею',
#  'свои',
#  'своим',
#  'своими',
#  'своих',
#  'свой',
#  'своя',
#  'своё',
#  'своём',
#  'себя',
#  'сказал',
#  'следующим',
#  'собой',
#  'соответствующей',
#  'соответствующему',
#  'соответствующий',
#  'соответствующими',
#  'ста',
#  'стами',
#  'сто',
#  'таким',
#  'таким',
#  'образом',
#  'такими',
#  'такими',
#  'таких',
#  'такого',
#  'такой',
#  'таком',
#  'твоим',
#  'течение',
#  'тремя',
#  'трех',
#  'три',
#  'трёх',
#  'тысяч',
#  'тысяча',
#  'тысячами',
#  'уж',
#  'четыре',
#  'четырьмя',
#  'четырёх',
#  'эта',
#  'этим',
#  'этими',
#  'этих',
#  'это',
#  'этому',
#  '—',
#  '•',
#  '№']

# %%
stop_list = nltk.word_tokenize(stop) + nltk.word_tokenize(pronouns) + nltk.word_tokenize(preps) + nltk.word_tokenize(mystop)

# %%
def isPunct(word):
  return len(word) == 1 and (word in string.punctuation or word in punct_list)

# %%
def isNumeric(word):
  try:
    float(word) if '.' in word else int(word)
    return True
  except ValueError:
    return False

# %%
def isInitial(word):
  return len(word) == 2 and word[1] == "."

# %%
class RakeKeywordExtractor:

  def __init__(self):
    self.stopwords = set(nltk.corpus.stopwords.words())
    self.top_fraction = 1 # consider top third candidate keywords by score

  def _generate_candidate_keywords(self, sentences):
    phrase_list = []
    for sentence in sentences:
      words = map(lambda x: "|" if x in self.stopwords or x in stop_list or isNumeric(x) or isInitial(x) else x,
        nltk.word_tokenize(sentence.lower()))
      phrase = []
      for word in words:
        if word == "|" or isPunct(word):
          if len(phrase) > 0:
            phrase_list.append(phrase)
            phrase = []
        else:
          phrase.append(word)
    return phrase_list
## СТОП!!
  def _calculate_word_scores(self, phrase_list):
    word_freq = nltk.FreqDist()
    word_degree = nltk.FreqDist()
    for phrase in phrase_list:
      #degree = len(filter(lambda x: not isNumeric(x), phrase)) - 1
      degree = len(list(filter(lambda x: not isNumeric(x), phrase))) - 1
      for word in phrase:
        word_freq[word] += 1 ## word_fd.inc(word.lower()) with word_fd[word.lower()] += 1
        word_degree[word] += degree # other words
    for word in word_freq.keys():
      word_degree[word] = word_degree[word] + word_freq[word] # itself
    # word score = deg(w) / freq(w)
    word_scores = {}
    for word in word_freq.keys():
      word_scores[word] = word_degree[word] / word_freq[word]
    return word_scores

  def _calculate_phrase_scores(self, phrase_list, word_scores):
    phrase_scores = {}
    for phrase in phrase_list:
      phrase_score = 0
      for word in phrase:
        phrase_score += word_scores[word]
      phrase_scores[" ".join(phrase)] = phrase_score
    return phrase_scores

  def extract(self, text, incl_scores=False):
    sentences = nltk.sent_tokenize(text)
    phrase_list = self._generate_candidate_keywords(sentences)
    word_scores = self._calculate_word_scores(phrase_list)
    phrase_scores = self._calculate_phrase_scores(
      phrase_list, word_scores)
    #sorted_phrase_scores = sorted(phrase_scores.iteritems(),
    sorted_phrase_scores = sorted(phrase_scores.items(),
      key=operator.itemgetter(1), reverse=True)
    n_phrases = len(sorted_phrase_scores)
    if incl_scores:
      return sorted_phrase_scores[0:int(n_phrases/self.top_fraction)]
    else:
      return map(lambda x: x[0],
        sorted_phrase_scores[0:int(n_phrases/self.top_fraction)])

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
rake = RakeKeywordExtractor()

# %%
with open('Alexeeva_IMS_2015_rus_lem.txt', 'r', encoding='utf-8') as f:
    txt = f.read()

# %%
keywords = rake.extract(txt, incl_scores=True)

# %%
for eachkwrd in keywords:
    print(eachkwrd[0], eachkwrd[1])
# Out:
# интерпретация тема позволять сформулировать лингвистический модель генерация контент документ коллекции 64.7943722943723
# последний компонент являться главный целевой область знание настоящий проекта 60.5
# окончательно версия словарь потенциально окрасить лексический единица содержаться 38.00333333333334
# момент разработать множество различный вариант тематический модель 36.41904761904762
# качество источник данные использоваться запись блог-платформа живой журнал 36.208333333333336
# предварительный итоговый словарь потенциально окрасить тональный слов 34.62416666666667
# англоязычный сфера создать большой количество текстовый коллекция 33.83333333333333
# основание модель разработать алгоритм вычисление распределение документ 33.21904761904762
# набор уникальный слово иметь разный вероятность принадлежность 32.05833333333333
# лаборатория вестись постоянный еженедельный закачка пост 31.166666666666668
# настоящий время проводиться разметка эмоциональный окрашенность 30.958333333333336
# рамка дать работа использоваться процедура сэмплирование гиббс 30.376984126984127
# анализ пользовательский интернет-контент социально- политический содержания 30.23076923076923
# дальнейший являться изучение общественный мнение интернет-аудитории 29.855555555555554
# выбрать программный продукт собственный разработка topicminer 28.75
# позволить социальный исследователь определять общественный мнение 27.966666666666665
# английский язык словарный подход успешно применяться 27.944444444444443
# ячейка матрица находиться вероятность принадлежность слов/документ 26.84722222222222
# формирование окончательный список потенциально окрасить слов 26.794444444444444
# коллекция документ порождаться дискретный распределение p 26.26666666666667
# язык требовать вычленение эмоционально окрасить слово 25.194444444444443
# точка зрение наличие эмоциональный компонент 25.125
# основа обширный коллекция русскоязычный текст фэйсбук 25.089743589743588
# реляционный база ms sql server 25.0
# разработка тональный словарь составление тональный словарь 24.965000000000003
# важность изучение мнение интернет-общественность подтверждается 24.72222222222222
# определение общественный мнение необходимо понимать 23.68888888888889
# большой доля мало релевантный текстов 23.619047619047617
# социально значимый вопрос преподноситься аудитория 23.5
# английский сегмент доступный обширный словари 23.333333333333332
# кодировщик составлять 0.578. расчёт проводиться 23.333333333333332
# применять различный метод автоматический классификация 22.833333333333332
# начать поиск потенциально окрасить слово 22.75
# мнение эксперт vs. сбор представление 22.38888888888889
# развитый язык насчитывать несколько сотня 22.244444444444444
# столбец матрица означать отдельный тему 22.055555555555557
# набор документ иметь разный вероятность 21.725
# дальнейший разработать методика автоматический определение 21.642857142857146
# вес определять общий тональность текста 21.333333333333332
# исследование являться разработка тональный словарь 21.1075
# существовать множество различный программный средство 21.0
# текст социальный медиа дать блог-платформа 20.923076923076923
# автоматизированный анализ эмоциональный окрашенность текст 20.778846153846153
# основание список потенциально окрасить слово 20.52777777777778
# второй очередь проект обращать внимание 20.5
# помощь автоматический выделение релевантный текст 20.35164835164835
# предпочесть тематический моделирование кластерный анализу 20.233333333333334
# средний величина вероятность равный 0,03 20.125
# служить источник слишком специализированный слов 20.05833333333333
# тональный слово возможно несколько способами 19.9875
# отсутствие необходимый количество коллекция текст 19.589743589743588
# второй этап прототип размечаться добровольцами 19.583333333333336
# дать предметный область тональный слов 19.343055555555555
# исследование эмоциональный составлять текст блогов 19.298076923076923
# промежуточный результат создание тональный словаря 18.8125
# потенциально тональный окрасить слов 17.704166666666666
# лингвистический ресурс дать возможность 17.555555555555557
# первый этап собираться прототип словаря 17.308333333333334
# разный социально значимый вопросам 17.1
# вычленение группа текст социально-политический тематика 16.923076923076923
# кодировщик посчитать отрицательно/положительный окрасить 16.666666666666664
# помощь программный обеспечение topicminer 16.628571428571426
# компенсировать наличие узкий событийно-зависимый 16.5
# автоматический определение тональность текстов 16.452380952380953
# разработать программный обеспечение blogminer 16.34285714285714
# основа графика сходимость алгоритм 16.166666666666668
# включаться потенциально окрасить слова 16.13888888888889
# существовать конечный множество скрытый 16.133333333333333
# основа перевод англоязычный словаря 16.125
# наиболее вероятностный текст социально-политический направленности 16.006410256410255
# язык vs. создание собственных 15.944444444444445
# дать статья описать методика 15.88888888888889
# построить тематический модель коллекция 15.809523809523812
# создавать нечёткий множество текстов 15.585714285714285
# означать найти множество скрытый 15.55
# методика обусловить вычислительный простотой 15.333333333333332
# косвенный речь новостной текстов 15.285714285714285
# определить условный распределение p 15.266666666666666
# автоматический метод наиболее подходить 15.166666666666668
# исследование текст социальный медиа 15.117521367521368
# отношение интернет-активный часть население 15.0
# вид набор значение частота 14.999999999999998
# тема падать достаточно быстро 14.818181818181818
# возможно несколько альтернативный стратегий 14.8
# иметь тенденция встречаться совместно 14.6
# гораздо менее зашумлен спамом 14.5
# привести пример оформление списка 14.5
# создать лаборатория цифровой общество 14.166666666666666
# тема пониматься совокупность слов 14.084848484848486
# цель выявление общественный мнение 14.022222222222222
# программа оценка сила положительный 14.0
# высокий роль социальный сеть 13.944444444444445
# анализ тональность социально-политический текст 13.737179487179487
# число итерация подбираться экспериментально 13.666666666666666
# разный текст социально-политический тематики 13.523076923076923
# финальный коллекция документ войти 13.5
# отбор документ социально-политический направленности 13.416666666666666
# − 2.2. тональный словарь 13.250357142857142
# остаться часть частотный список 13.177777777777777
# позволять закачивать пост 13.166666666666666
# блог гораздо менее разредить 13.166666666666666
# окончательный версия словаря 13.125
# объяснительный словарь русский язык 12.864444444444445
# параметр описывать распределение дирихло 12.766666666666666
# пересечь частотный список слово 12.677777777777777
# кольцов национальный исследовательский университет 12.666666666666666
# w являться наблюдать переменный 12.428571428571429
# анализ общественный мнение 12.252991452991452
# тональный окрасить словах 12.1875
# потенциально окрасить слова 12.13888888888889
# несколько предметный область 12.133333333333333
# являться социально политическими 12.0
# больший часть слово встречаться 11.9
# максимальный вероятность принадлежность 11.625
# тематический модель заключаться 11.476190476190476
# различный источник состоять 11.125
# источник тестовый коллекции 11.125
# живой журнал '' 11.083333333333332
# векторный модель текст 11.065934065934066
# сэмплирование гиббс являются 11.0
# основание предыдущий опыта 11.0
# социальный сеть фэйсбук 10.944444444444445
# тематический моделирование проводиться 10.9
# вид тональный разметки 10.6875
# анализ социальный медиа 10.675213675213676
# помощь кластерный анализ 10.65934065934066
# область компьютерный лингвистики 10.5
# требовать развёртывание кластера 10.5
# тема формироваться алгоритм 10.484848484848484
# введение тональный анализ 10.41826923076923
# результат моделирование являться 10.4
# нахождение распределение документ 10.266666666666666
# проставить тональный окраска 10.1875
# предполагать представление текст 10.08974358974359
# блог разный тематики 10.016666666666666
# сегодняшний день существовать 10.0
# создание инструмент сентимент-анализа 10.0
# иметь дискриминировать силы 10.0
# наиболее вероятностный документ 10.0
# слишком редкий слов 9.933333333333334
# выбрать порог вероятность 9.925
# группа сходный текст 9.923076923076923
# тональный анализ отзывов 9.91826923076923
# затем получить слово проверяться 9.916666666666666
# получить тональный разметка 9.854166666666666
# самостоятельный извлечение релевантный 9.833333333333332
# матрица распределение документ 9.822222222222221
# демонстрировать хороший качество 9.75
# текст социально-политический направленности 9.673076923076923
# представление создатель рубрика 9.666666666666666
# социально-политический сфера слова 9.63888888888889
# передавать эмоциональный оценку 9.625
# наиболее вероятностный слов 9.600000000000001
# текст социальнополитический направленности 9.58974358974359
# конечный прототип словарь 9.586666666666666
# высокий школа экономики 9.5
# основа обучать коллекций 9.5
# негативный оценка товара 9.5
# 2.1. прототип словаря 9.458333333333334
# помощь морфоанализатор pymorphy2 9.428571428571429
# помощь ручной разметки 9.428571428571429
# помощь online calculator 9.428571428571429
# коллекция социальнополитический текст 9.423076923076923
# проверяться качество словарь 9.42
# больший коллекция текстов 9.419047619047618
# предыдущий исследование известно 9.25
# проведение тематический моделирование 9.233333333333334
# ход тематический моделирование 9.233333333333334
# создавать веб-ресурс применимый 9.166666666666666
# удаление слишком частый 9.166666666666666
# анализ текст сми 9.153846153846153
# полный объём невыполнимо 9.0
# предмет интерпретируемость людьми 9.0
# latent dirichlet allocation 9.0
# довольно низкий показатель 9.0
# мир волна протест 9.0
# революция 2011-2013 годов 9.0
# помощь признаковый слово 8.928571428571429
# модуль тематический моделирование 8.9
# модуль анализ результатов 8.897435897435898
# оценочный значение частый 8.833333333333334
# наиболее вероятностный слово 8.833333333333334
# тема считаться социальнополитической 8.818181818181818
# постоянно корректироваться список 8.777777777777779
# задать коллекция документов 8.733333333333334
# следующий список слов 8.711111111111112
# частотный список слово 8.677777777777777
# свободный доступ находиться 8.666666666666666
# дополнить следующий данными 8.666666666666666
# число итерация сэмплирования 8.666666666666666
# вероятность принадлежность 8.625
# упрощённый понимание темы 8.5
# − частотный список 8.32063492063492
# больший коллекция число 8.299999999999999
# прилагательное отрезаться окончание 8.25
# последующий отбор специфичный 8.25
# итог тематический моделирование 8.233333333333334
# подсчёт частота слово 8.166666666666666
# разработать исследователь 8.142857142857142
# живой журнал 8.083333333333332
# результат работа людей 8.071428571428571
# конечный цель использование 8.0
# передавать усиление/уменьшение эмоции 8.0
# сэмплирование гиббс 8.0
# удаление дублироваться слово 8.0
# операция сумма размер 8.0
# разработать веб-ресурс http 7.976190476190477
# содержать распределение слово 7.85
# затем словарь прилагательное 7.836666666666666
# частотный словарь прилагательных 7.82
# больший данные 7.8
# список оказаться равный 7.777777777777778
# посвятить социально-политический тематике 7.75
# сформировать коллекция документов 7.733333333333334
# словарь использоваться 7.67
# пользовательский контент 7.666666666666667
# лексика часто встречаться 7.6
# накопить знание 7.5
# провести препроцессинг включить 7.5
# слово коллекции 7.5
# передавать отобрать слово 7.333333333333333
# распределение документ 7.266666666666667
# излишний укрупнённый темам 7.25
# добавляться окончание наречие 7.166666666666667
# вариационный модель 7.142857142857143
# величина вероятность 7.125
# тональный словарь 7.1075
# заимствование запись 7.0
# дальнейший работа 6.904761904761905
# коллекция доступный 6.833333333333334
# использоваться согласие 6.75
# успешный разработка 6.75
# автоматический извлечение 6.666666666666667
# словарь находиться 6.586666666666666
# лексический ресурс 6.5
# рамка сотрудничество 6.5
# вычленение социально-политический 6.5
# прототип словаря 6.458333333333334
# социальный сеть 6.444444444444445
# обширный области 6.333333333333333
# параметр распределение 6.266666666666667
# тематический моделирование 6.233333333333333
# высказывание мнение 6.222222222222222
# программный обеспечении 6.2
# дать работа 6.1269841269841265
# распределение слово 6.1
# список слов 6.044444444444444
# основный подход 6.0
# основа отзывов 6.0
# русский язык 5.944444444444445
# первый этап 5.85
# слово коллекция 5.833333333333334
# выбрать равный 5.8
# живой журнала 5.75
# социально-политический тематика 5.75
# коллекция документов 5.733333333333333
# анализ сми 5.730769230769231
# словарь проверяться 5.67
# облегчать разметка 5.666666666666666
# массив документ 5.666666666666666
# метод краудсорсинг 5.666666666666666
# эмоциональный окраску 5.625
# эмоциональный заряженности 5.625
# первый очередь 5.6
# оценочный слов 5.6
# дать области 5.555555555555555
# последний включает 5.5
# общий позитивный 5.5
# основа усреднение 5.5
# лаборатория интернет-исследование 5.5
# отношение сходный 5.5
# лаборатория интернет-исследований 5.5
# необходимый модули 5.5
# последний основать 5.5
# социально-политический тематики 5.5
# вероятностный слово 5.5
# социальный сетей 5.444444444444445
# социальный капитал 5.444444444444445
# текст блогосферы 5.423076923076923
# конвертация текст 5.423076923076923
# текст вместе 5.423076923076923
# социальнополитический тематики 5.416666666666666
# коллекция прямой 5.333333333333334
# предметный областей 5.333333333333334
# кодировщик линиса 5.333333333333333
# несколько списках 5.3
# социально-политический темы 5.25
# задача вычленение 5.25
# показывать анализ 5.230769230769231
# источник контекст 5.125
# отобрать текстов 5.119047619047619
# − словарь 5.062857142857142
# словарный подходу 5.0
# коллекция отзыв 5.0
# свободный доступ 5.0
# лексический единиц 5.0
# использовать пост 5.0
# вероятностный алгоритмов 5.0
# вычислительный ядро 5.0
# равный 0,1 5.0
# маленький величина 5.0
# немой остаться 5.0
# пользовательский интернет-контента 5.0
# − список 4.920634920634921
# известный словарь 4.92
# анализ отзыв 4.897435897435898
# источник специфичный 4.875
# неизвестный тема 4.818181818181818
# больший объемами 4.8
# 1/3 список 4.777777777777778
# получить список 4.777777777777778
# ещё список 4.777777777777778
# исключение слов 4.766666666666667
# граница социально-политический 4.75
# многократно проверяться 4.75
# найти слово 4.75
# топ-слово социально-политический 4.75
# университет глазго 4.666666666666666
# создать ромип 4.666666666666666
# университет вулверхемптон 4.666666666666666
# краудсорсинговый веб-ресурс 4.666666666666666
# модуль препроцессина 4.666666666666666
# следующий процедуры 4.666666666666666
# входной параметр 4.666666666666666
# элемент матрица 4.555555555555555
# список содержать 4.527777777777778
# русский сегменте 4.5
# проект создаваться 4.5
# добавление наречие 4.5
# удаление html-тэгов 4.5
# удаление стопа-слово 4.5
# векторный формат 4.5
# результат кодирование 4.5
# лингвист проект 4.5
# решить включить 4.5
# единица 4.5
# миллион документов 4.4
# выявление предпочтение 4.333333333333334
# оценочный лексики 4.333333333333334
# количество 4.333333333333333
# выбрать сочетание 4.3
# использовать словарь 4.253333333333333
# получить прилагательное 4.25
# матрица φ 4.222222222222222
# матрица θ 4.222222222222222
# разработать 4.142857142857143
# просмотреть первый 4.1
# соревнование ромип 4.0
# маркетинговый исследованиях 4.0
# иметься сведение 4.0
# ниу вшэ 4.0
# слово присутствовать 4.0
# реальный наречием 4.0
# отрицательный настроений 4.0
# краткий интернет-сообщениями 4.0
# случай полисемии 4.0
# популярный блогер 4.0
# предоставлять жж 4.0
# размер порядок 4.0
# топовый блогер 4.0
# компьютерный лингвистика 4.0
# основный вариантах 4.0
# разработчик с.н 4.0
# способный работать 4.0
# персональный компьютер 4.0
# иметь 4.0
# препроцессинг данных 4.0
# начальный форме 4.0
# маленький приводить 4.0
# inter-rater agreement 4.0
# multiple raters 4.0
# простой задач 4.0
# редко бывать 4.0
# выбирать документы 4.0
# назвать темами 4.0
# нормализовать форму 4.0
# признать темами 4.0
# какого/какий источника/источник 4.0
# получить информация 4.0
# вручную исключить 4.0
# счесть нерелевантными 4.0
# социально-политический теме 4.0
# повторяться слова 3.888888888888889
# слово встретиться 3.833333333333333
# отобрать ещё 3.833333333333333
# качество 3.75
# выделить blog06 3.666666666666667
# ≡ φ 3.666666666666667
# ≡ θ 3.666666666666667
# документ 3.6666666666666665
# p 3.6666666666666665
# эмоциональный 3.625
# дать 3.5555555555555554
# последний 3.5
# специально предназначить 3.5
# сделать автоматически 3.5
# lda предполагается 3.5
# язык 3.4444444444444446
# текст 3.423076923076923
# коллекция 3.3333333333333335
# содержаться 3.3333333333333335
# система sentistrength 3.333333333333333
# отобрать текстах 3.333333333333333
# сразу взять 3.333333333333333
# текстов 3.2857142857142856
# слов 3.2666666666666666
# этап 3.25
# протяжение год 3.25
# выделить девять 3.166666666666667
# словаря 3.125
# источник 3.125
# блогов 3.0
# словарный 3.0
# вес 3.0
# размечаться 3.0
# средство 3.0
# словарь 2.92
# линиса составить 2.916666666666667
# тема 2.8181818181818183
# выбрать 2.8
# список 2.7777777777777777
# социально-политический 2.75
# создать 2.6666666666666665
# цель 2.6666666666666665
# частота 2.6666666666666665
# затем 2.6666666666666665
# блог 2.6666666666666665
# встречаться 2.6
# работа 2.5714285714285716
# матрица 2.5555555555555554
# описывать 2.5
# слово 2.5
# результат 2.5
# стратегий 2.5
# сила 2.5
# менее 2.5
# проект 2.5
# привести 2.5
# войти 2.5
# выявление 2.3333333333333335
# прилагательное 2.25
# найти 2.25
# число 2.1666666666666665
# − 2.142857142857143
# кольцов 2.0
# известно 2.0
# использование 2.0
# получить 2.0
# тематике 2.0
# переменный 2.0
# препроцессинг 2.0
# лексика 2.0
# сформировать 2.0
# оказаться 2.0
# итог 2.0
# размер 2.0
# усиление/уменьшение 2.0
# слова 1.8888888888888888
# отобрать 1.8333333333333333
# специфичный 1.75
# содержать 1.75
# отзыв 1.6666666666666667
# добавляться 1.6666666666666667
# линиса 1.6666666666666667
# φ 1.6666666666666667
# θ 1.6666666666666667
# выделить 1.6666666666666667
# задача 1.5
# лингвистика 1.5
# специально 1.5
# прилагательных 1.5
# единиц 1.5
# текстах 1.5
# lda 1.5
# девять 1.5
# присутствовать 1.5
# списках 1.5
# исключение 1.5
# сделать 1.5
# просмотреть 1.5
# сочетание 1.5
# w 1.4285714285714286
# использовать 1.3333333333333333
# встретиться 1.3333333333333333
# взять 1.3333333333333333
# sentistrength 1.3333333333333333
# составить 1.25
# год 1.25
# темам 1.25
# теме 1.25
# http 1.1666666666666667
# linis-crowd.org 1.0
# алексеева 1.0
# санкт-петербург 1.0
# сентимент-анализ 1.0
# плохо 1.0
# нравиться 1.0
# др 1.0
# отнести 1.0
# применения 1.0
# основном 1.0
# лежать 1.0
# предел 1.0
# разделить 1.0
# маркетинг 1.0
# товар 1.0
# услуги 1.0
# социология 1.0
# политология 1.0
# во-первых 1.0
# отклик 1.0
# ожидать 1.0
# публики 1.0
# во-вторых 1.0
# форумов 1.0
# части 1.0
# представить 1.0
# интернете 1.0
# удобный 1.0
# избыток 1.0
# напр. 1.0
# особо 1.0
# //ir.dcs.gla.ac.uk/test_collections/blog06info.html 1.0
# сконцентрировать 1.0
# насколько 1.0
# //romip.ru/ru/collections/index.html 1.0
# непригодный 1.0
# обратиться 1.0
# //sentistrength.wlv.ac.uk/ 1.0
# фелвол 1.0
# великобритания 1.0
# opinionfinder 1.0
# //mpqa.cs.pitt.edu/opinionfinder/ 1.0
# sentiwordnet 1.0
# //sentiwordnet.isti.cnr.it/ 1.0
# четверкин 1.0
# лукашевич 1.0
# //www.cir.ru/sentilexicon/productsentirus.txt 1.0
# представлять 1.0
# извлечь 1.0
# фильмы 1.0
# книги 1.0
# игры 1.0
# телефоны 1.0
# камеры 1.0
# видно 1.0
# описания 1.0
# присвоить 1.0
# находить 1.0
# точность 1.0
# сравнение 1.0
# настраивается 1.0
# языка 1.0
# опора 1.0
# простых 1.0
# носителей 1.0
# запасом 1.0
# человек 1.0
# привязка 1.0
# выражаться 1.0
# наречий 1.0
# //digsolab.ru 1.0
# линис 1.0
# разметить 1.0
# кодировщика 1.0
# конец 1.0
# списке 1.0
# -ий 1.0
# -ый 1.0
# -ой 1.0
# -о 1.0
# -е 1.0
# -и 1.0
# https 1.0
# //pymorphy2.readthedocs.org/en/latest/user/guide.html 1.0
# id2 1.0
# словаре 1.0
# анализатор 1.0
# т.е 1.0
# адресу 1.0
# междометие 1.0
# добавить 1.0
# павлов 1.0
# поставлять 1.0
# //sentistrength.wlv.ac.uk 1.0
# ориентировать 1.0
# публиковать 1.0
# myspace 1.0
# twitter 1.0
# комментарий 1.0
# постам 1.0
# целями 1.0
# особенно 1.0
# вебресурсе 1.0
# //linis.hse.ru/soft-linis 1.0
# март 1.0
# рейтинг 1.0
# млн 1.0
# период 1.0
# мочь 1.0
# взяты 1.0
# отличаться 1.0
# обычный 1.0
# рубрик 1.0
# тэгам 1.0
# тэг 1.0
# известны 1.0
# отсортировать 1.0
# релевантности 1.0
# следующем 1.0
# применение 1.0
# базироваться 1.0
# скрытой 1.0
# появление 1.0
# пара 1.0
# связать 1.0
# w| 1.0
# матрицу 1.0
# выбор 1.0
# правило 1.0
# отсутствовать 1.0
# интерфейс 1.0
# справляться 1.0
# в.г 1.0
# филипов 1.0
# лемматизация 1.0
# приведение 1.0
# несущий 1.0
# смысл 1.0
# влиять 1.0
# тематику 1.0
# лемм 1.0
# тексте 1.0
# α 1.0
# β 1.0
# матрицы 1.0
# показавшего 1.0
# заимствовать 1.0
# 0,5 1.0
# убыванию 1.0
# передать 1.0
# кодировщикам 1.0
# определяли 1.0
# минимум 1.0
# согласованность 1.0
# //mlnl.net/jg/software/ira/ 1.0
# кодировщиков 1.0
# несмотря 1.0
# относиться 1.0
# получиться 1.0
# дополнение 1.0
# связанный 1.0
# эмоций 1.0
# объект 1.0
# направлена 1.0
# разным 1.0
# политическим 1.0
# эмоция 1.0
# далее 1.0
# списками 1.0
# указать 1.0
# пришло 1.0
# т.о 1.0
# списков 1.0
# встречается 1.0
# источников 1.0
# представлены 1.0
# основное 1.0
# аккумулятор 1.0
# диагональ 1.0
# панель 1.0
# исключили 1.0
# дубликат 1.0
# удалены 1.0
# сопоставить 1.0
# выбираться 1.0
# хорошо/плохо 1.0
# //linis-crowd.org 1.0
# заключение 1.0
# точнее 1.0
# прочего 1.0
# прокатиться 1.0

# %%
keywords
# Out:
# [('интерпретация тема позволять сформулировать лингвистический модель генерация контент документ коллекции',
#   64.7943722943723),
#  ('последний компонент являться главный целевой область знание настоящий проекта',
#   60.5),
#  ('окончательно версия словарь потенциально окрасить лексический единица содержаться',
#   38.00333333333334),
#  ('момент разработать множество различный вариант тематический модель',
#   36.41904761904762),
#  ('качество источник данные использоваться запись блог-платформа живой журнал',
#   36.208333333333336),
#  ('предварительный итоговый словарь потенциально окрасить тональный слов',
#   34.62416666666667),
#  ('англоязычный сфера создать большой количество текстовый коллекция',
#   33.83333333333333),
#  ('основание модель разработать алгоритм вычисление распределение документ',
#   33.21904761904762),
#  ('набор уникальный слово иметь разный вероятность принадлежность',
#   32.05833333333333),
#  ('лаборатория вестись постоянный еженедельный закачка пост',
#   31.166666666666668),
#  ('настоящий время проводиться разметка эмоциональный окрашенность',
#   30.958333333333336),
#  ('рамка дать работа использоваться процедура сэмплирование гиббс',
#   30.376984126984127),
#  ('анализ пользовательский интернет-контент социально- политический содержания',
#   30.23076923076923),
#  ('дальнейший являться изучение общественный мнение интернет-аудитории',
#   29.855555555555554),
#  ('выбрать программный продукт собственный разработка topicminer', 28.75),
#  ('позволить социальный исследователь определять общественный мнение',
#   27.966666666666665),
#  ('английский язык словарный подход успешно применяться', 27.944444444444443),
#  ('ячейка матрица находиться вероятность принадлежность слов/документ',
#   26.84722222222222),
#  ('формирование окончательный список потенциально окрасить слов',
#   26.794444444444444),
#  ('коллекция документ порождаться дискретный распределение p',
#   26.26666666666667),
#  ('язык требовать вычленение эмоционально окрасить слово', 25.194444444444443),
#  ('точка зрение наличие эмоциональный компонент', 25.125),
#  ('основа обширный коллекция русскоязычный текст фэйсбук', 25.089743589743588),
#  ('реляционный база ms sql server', 25.0),
#  ('разработка тональный словарь составление тональный словарь',
#   24.965000000000003),
#  ('важность изучение мнение интернет-общественность подтверждается',
#   24.72222222222222),
#  ('определение общественный мнение необходимо понимать', 23.68888888888889),
#  ('большой доля мало релевантный текстов', 23.619047619047617),
#  ('социально значимый вопрос преподноситься аудитория', 23.5),
#  ('английский сегмент доступный обширный словари', 23.333333333333332),
#  ('кодировщик составлять 0.578. расчёт проводиться', 23.333333333333332),
#  ('применять различный метод автоматический классификация',
#   22.833333333333332),
#  ('начать поиск потенциально окрасить слово', 22.75),
#  ('мнение эксперт vs. сбор представление', 22.38888888888889),
#  ('развитый язык насчитывать несколько сотня', 22.244444444444444),
#  ('столбец матрица означать отдельный тему', 22.055555555555557),
#  ('набор документ иметь разный вероятность', 21.725),
#  ('дальнейший разработать методика автоматический определение',
#   21.642857142857146),
#  ('вес определять общий тональность текста', 21.333333333333332),
#  ('исследование являться разработка тональный словарь', 21.1075),
#  ('существовать множество различный программный средство', 21.0),
#  ('текст социальный медиа дать блог-платформа', 20.923076923076923),
#  ('автоматизированный анализ эмоциональный окрашенность текст',
#   20.778846153846153),
#  ('основание список потенциально окрасить слово', 20.52777777777778),
#  ('второй очередь проект обращать внимание', 20.5),
#  ('помощь автоматический выделение релевантный текст', 20.35164835164835),
#  ('предпочесть тематический моделирование кластерный анализу',
#   20.233333333333334),
#  ('средний величина вероятность равный 0,03', 20.125),
#  ('служить источник слишком специализированный слов', 20.05833333333333),
#  ('тональный слово возможно несколько способами', 19.9875),
#  ('отсутствие необходимый количество коллекция текст', 19.589743589743588),
#  ('второй этап прототип размечаться добровольцами', 19.583333333333336),
#  ('дать предметный область тональный слов', 19.343055555555555),
#  ('исследование эмоциональный составлять текст блогов', 19.298076923076923),
#  ('промежуточный результат создание тональный словаря', 18.8125),
#  ('потенциально тональный окрасить слов', 17.704166666666666),
#  ('лингвистический ресурс дать возможность', 17.555555555555557),
#  ('первый этап собираться прототип словаря', 17.308333333333334),
#  ('разный социально значимый вопросам', 17.1),
#  ('вычленение группа текст социально-политический тематика',
#   16.923076923076923),
#  ('кодировщик посчитать отрицательно/положительный окрасить',
#   16.666666666666664),
#  ('помощь программный обеспечение topicminer', 16.628571428571426),
#  ('компенсировать наличие узкий событийно-зависимый', 16.5),
#  ('автоматический определение тональность текстов', 16.452380952380953),
#  ('разработать программный обеспечение blogminer', 16.34285714285714),
#  ('основа графика сходимость алгоритм', 16.166666666666668),
#  ('включаться потенциально окрасить слова', 16.13888888888889),
#  ('существовать конечный множество скрытый', 16.133333333333333),
#  ('основа перевод англоязычный словаря', 16.125),
#  ('наиболее вероятностный текст социально-политический направленности',
#   16.006410256410255),
#  ('язык vs. создание собственных', 15.944444444444445),
#  ('дать статья описать методика', 15.88888888888889),
#  ('построить тематический модель коллекция', 15.809523809523812),
#  ('создавать нечёткий множество текстов', 15.585714285714285),
#  ('означать найти множество скрытый', 15.55),
#  ('методика обусловить вычислительный простотой', 15.333333333333332),
#  ('косвенный речь новостной текстов', 15.285714285714285),
#  ('определить условный распределение p', 15.266666666666666),
#  ('автоматический метод наиболее подходить', 15.166666666666668),
#  ('исследование текст социальный медиа', 15.117521367521368),
#  ('отношение интернет-активный часть население', 15.0),
#  ('вид набор значение частота', 14.999999999999998),
#  ('тема падать достаточно быстро', 14.818181818181818),
#  ('возможно несколько альтернативный стратегий', 14.8),
#  ('иметь тенденция встречаться совместно', 14.6),
#  ('гораздо менее зашумлен спамом', 14.5),
#  ('привести пример оформление списка', 14.5),
#  ('создать лаборатория цифровой общество', 14.166666666666666),
#  ('тема пониматься совокупность слов', 14.084848484848486),
#  ('цель выявление общественный мнение', 14.022222222222222),
#  ('программа оценка сила положительный', 14.0),
#  ('высокий роль социальный сеть', 13.944444444444445),
#  ('анализ тональность социально-политический текст', 13.737179487179487),
#  ('число итерация подбираться экспериментально', 13.666666666666666),
#  ('разный текст социально-политический тематики', 13.523076923076923),
#  ('финальный коллекция документ войти', 13.5),
#  ('отбор документ социально-политический направленности', 13.416666666666666),
#  ('− 2.2. тональный словарь', 13.250357142857142),
#  ('остаться часть частотный список', 13.177777777777777),
#  ('позволять закачивать пост', 13.166666666666666),
#  ('блог гораздо менее разредить', 13.166666666666666),
#  ('окончательный версия словаря', 13.125),
#  ('объяснительный словарь русский язык', 12.864444444444445),
#  ('параметр описывать распределение дирихло', 12.766666666666666),
#  ('пересечь частотный список слово', 12.677777777777777),
#  ('кольцов национальный исследовательский университет', 12.666666666666666),
#  ('w являться наблюдать переменный', 12.428571428571429),
#  ('анализ общественный мнение', 12.252991452991452),
#  ('тональный окрасить словах', 12.1875),
#  ('потенциально окрасить слова', 12.13888888888889),
#  ('несколько предметный область', 12.133333333333333),
#  ('являться социально политическими', 12.0),
#  ('больший часть слово встречаться', 11.9),
#  ('максимальный вероятность принадлежность', 11.625),
#  ('тематический модель заключаться', 11.476190476190476),
#  ('различный источник состоять', 11.125),
#  ('источник тестовый коллекции', 11.125),
#  ("живой журнал ''", 11.083333333333332),
#  ('векторный модель текст', 11.065934065934066),
#  ('сэмплирование гиббс являются', 11.0),
#  ('основание предыдущий опыта', 11.0),
#  ('социальный сеть фэйсбук', 10.944444444444445),
#  ('тематический моделирование проводиться', 10.9),
#  ('вид тональный разметки', 10.6875),
#  ('анализ социальный медиа', 10.675213675213676),
#  ('помощь кластерный анализ', 10.65934065934066),
#  ('область компьютерный лингвистики', 10.5),
#  ('требовать развёртывание кластера', 10.5),
#  ('тема формироваться алгоритм', 10.484848484848484),
#  ('введение тональный анализ', 10.41826923076923),
#  ('результат моделирование являться', 10.4),
#  ('нахождение распределение документ', 10.266666666666666),
#  ('проставить тональный окраска', 10.1875),
#  ('предполагать представление текст', 10.08974358974359),
#  ('блог разный тематики', 10.016666666666666),
#  ('сегодняшний день существовать', 10.0),
#  ('создание инструмент сентимент-анализа', 10.0),
#  ('иметь дискриминировать силы', 10.0),
#  ('наиболее вероятностный документ', 10.0),
#  ('слишком редкий слов', 9.933333333333334),
#  ('выбрать порог вероятность', 9.925),
#  ('группа сходный текст', 9.923076923076923),
#  ('тональный анализ отзывов', 9.91826923076923),
#  ('затем получить слово проверяться', 9.916666666666666),
#  ('получить тональный разметка', 9.854166666666666),
#  ('самостоятельный извлечение релевантный', 9.833333333333332),
#  ('матрица распределение документ', 9.822222222222221),
#  ('демонстрировать хороший качество', 9.75),
#  ('текст социально-политический направленности', 9.673076923076923),
#  ('представление создатель рубрика', 9.666666666666666),
#  ('социально-политический сфера слова', 9.63888888888889),
#  ('передавать эмоциональный оценку', 9.625),
#  ('наиболее вероятностный слов', 9.600000000000001),
#  ('текст социальнополитический направленности', 9.58974358974359),
#  ('конечный прототип словарь', 9.586666666666666),
#  ('высокий школа экономики', 9.5),
#  ('основа обучать коллекций', 9.5),
#  ('негативный оценка товара', 9.5),
#  ('2.1. прототип словаря', 9.458333333333334),
#  ('помощь морфоанализатор pymorphy2', 9.428571428571429),
#  ('помощь ручной разметки', 9.428571428571429),
#  ('помощь online calculator', 9.428571428571429),
#  ('коллекция социальнополитический текст', 9.423076923076923),
#  ('проверяться качество словарь', 9.42),
#  ('больший коллекция текстов', 9.419047619047618),
#  ('предыдущий исследование известно', 9.25),
#  ('проведение тематический моделирование', 9.233333333333334),
#  ('ход тематический моделирование', 9.233333333333334),
#  ('создавать веб-ресурс применимый', 9.166666666666666),
#  ('удаление слишком частый', 9.166666666666666),
#  ('анализ текст сми', 9.153846153846153),
#  ('полный объём невыполнимо', 9.0),
#  ('предмет интерпретируемость людьми', 9.0),
#  ('latent dirichlet allocation', 9.0),
#  ('довольно низкий показатель', 9.0),
#  ('мир волна протест', 9.0),
#  ('революция 2011-2013 годов', 9.0),
#  ('помощь признаковый слово', 8.928571428571429),
#  ('модуль тематический моделирование', 8.9),
#  ('модуль анализ результатов', 8.897435897435898),
#  ('оценочный значение частый', 8.833333333333334),
#  ('наиболее вероятностный слово', 8.833333333333334),
#  ('тема считаться социальнополитической', 8.818181818181818),
#  ('постоянно корректироваться список', 8.777777777777779),
#  ('задать коллекция документов', 8.733333333333334),
#  ('следующий список слов', 8.711111111111112),
#  ('частотный список слово', 8.677777777777777),
#  ('свободный доступ находиться', 8.666666666666666),
#  ('дополнить следующий данными', 8.666666666666666),
#  ('число итерация сэмплирования', 8.666666666666666),
#  ('вероятность принадлежность', 8.625),
#  ('упрощённый понимание темы', 8.5),
#  ('− частотный список', 8.32063492063492),
#  ('больший коллекция число', 8.299999999999999),
#  ('прилагательное отрезаться окончание', 8.25),
#  ('последующий отбор специфичный', 8.25),
#  ('итог тематический моделирование', 8.233333333333334),
#  ('подсчёт частота слово', 8.166666666666666),
#  ('разработать исследователь', 8.142857142857142),
#  ('живой журнал', 8.083333333333332),
#  ('результат работа людей', 8.071428571428571),
#  ('конечный цель использование', 8.0),
#  ('передавать усиление/уменьшение эмоции', 8.0),
#  ('сэмплирование гиббс', 8.0),
#  ('удаление дублироваться слово', 8.0),
#  ('операция сумма размер', 8.0),
#  ('разработать веб-ресурс http', 7.976190476190477),
#  ('содержать распределение слово', 7.85),
#  ('затем словарь прилагательное', 7.836666666666666),
#  ('частотный словарь прилагательных', 7.82),
#  ('больший данные', 7.8),
#  ('список оказаться равный', 7.777777777777778),
#  ('посвятить социально-политический тематике', 7.75),
#  ('сформировать коллекция документов', 7.733333333333334),
#  ('словарь использоваться', 7.67),
#  ('пользовательский контент', 7.666666666666667),
#  ('лексика часто встречаться', 7.6),
#  ('накопить знание', 7.5),
#  ('провести препроцессинг включить', 7.5),
#  ('слово коллекции', 7.5),
#  ('передавать отобрать слово', 7.333333333333333),
#  ('распределение документ', 7.266666666666667),
#  ('излишний укрупнённый темам', 7.25),
#  ('добавляться окончание наречие', 7.166666666666667),
#  ('вариационный модель', 7.142857142857143),
#  ('величина вероятность', 7.125),
#  ('тональный словарь', 7.1075),
#  ('заимствование запись', 7.0),
#  ('дальнейший работа', 6.904761904761905),
#  ('коллекция доступный', 6.833333333333334),
#  ('использоваться согласие', 6.75),
#  ('успешный разработка', 6.75),
#  ('автоматический извлечение', 6.666666666666667),
#  ('словарь находиться', 6.586666666666666),
#  ('лексический ресурс', 6.5),
#  ('рамка сотрудничество', 6.5),
#  ('вычленение социально-политический', 6.5),
#  ('прототип словаря', 6.458333333333334),
#  ('социальный сеть', 6.444444444444445),
#  ('обширный области', 6.333333333333333),
#  ('параметр распределение', 6.266666666666667),
#  ('тематический моделирование', 6.233333333333333),
#  ('высказывание мнение', 6.222222222222222),
#  ('программный обеспечении', 6.2),
#  ('дать работа', 6.1269841269841265),
#  ('распределение слово', 6.1),
#  ('список слов', 6.044444444444444),
#  ('основный подход', 6.0),
#  ('основа отзывов', 6.0),
#  ('русский язык', 5.944444444444445),
#  ('первый этап', 5.85),
#  ('слово коллекция', 5.833333333333334),
#  ('выбрать равный', 5.8),
#  ('живой журнала', 5.75),
#  ('социально-политический тематика', 5.75),
#  ('коллекция документов', 5.733333333333333),
#  ('анализ сми', 5.730769230769231),
#  ('словарь проверяться', 5.67),
#  ('облегчать разметка', 5.666666666666666),
#  ('массив документ', 5.666666666666666),
#  ('метод краудсорсинг', 5.666666666666666),
#  ('эмоциональный окраску', 5.625),
#  ('эмоциональный заряженности', 5.625),
#  ('первый очередь', 5.6),
#  ('оценочный слов', 5.6),
#  ('дать области', 5.555555555555555),
#  ('последний включает', 5.5),
#  ('общий позитивный', 5.5),
#  ('основа усреднение', 5.5),
#  ('лаборатория интернет-исследование', 5.5),
#  ('отношение сходный', 5.5),
#  ('лаборатория интернет-исследований', 5.5),
#  ('необходимый модули', 5.5),
#  ('последний основать', 5.5),
#  ('социально-политический тематики', 5.5),
#  ('вероятностный слово', 5.5),
#  ('социальный сетей', 5.444444444444445),
#  ('социальный капитал', 5.444444444444445),
#  ('текст блогосферы', 5.423076923076923),
#  ('конвертация текст', 5.423076923076923),
#  ('текст вместе', 5.423076923076923),
#  ('социальнополитический тематики', 5.416666666666666),
#  ('коллекция прямой', 5.333333333333334),
#  ('предметный областей', 5.333333333333334),
#  ('кодировщик линиса', 5.333333333333333),
#  ('несколько списках', 5.3),
#  ('социально-политический темы', 5.25),
#  ('задача вычленение', 5.25),
#  ('показывать анализ', 5.230769230769231),
#  ('источник контекст', 5.125),
#  ('отобрать текстов', 5.119047619047619),
#  ('− словарь', 5.062857142857142),
#  ('словарный подходу', 5.0),
#  ('коллекция отзыв', 5.0),
#  ('свободный доступ', 5.0),
#  ('лексический единиц', 5.0),
#  ('использовать пост', 5.0),
#  ('вероятностный алгоритмов', 5.0),
#  ('вычислительный ядро', 5.0),
#  ('равный 0,1', 5.0),
#  ('маленький величина', 5.0),
#  ('немой остаться', 5.0),
#  ('пользовательский интернет-контента', 5.0),
#  ('− список', 4.920634920634921),
#  ('известный словарь', 4.92),
#  ('анализ отзыв', 4.897435897435898),
#  ('источник специфичный', 4.875),
#  ('неизвестный тема', 4.818181818181818),
#  ('больший объемами', 4.8),
#  ('1/3 список', 4.777777777777778),
#  ('получить список', 4.777777777777778),
#  ('ещё список', 4.777777777777778),
#  ('исключение слов', 4.766666666666667),
#  ('граница социально-политический', 4.75),
#  ('многократно проверяться', 4.75),
#  ('найти слово', 4.75),
#  ('топ-слово социально-политический', 4.75),
#  ('университет глазго', 4.666666666666666),
#  ('создать ромип', 4.666666666666666),
#  ('университет вулверхемптон', 4.666666666666666),
#  ('краудсорсинговый веб-ресурс', 4.666666666666666),
#  ('модуль препроцессина', 4.666666666666666),
#  ('следующий процедуры', 4.666666666666666),
#  ('входной параметр', 4.666666666666666),
#  ('элемент матрица', 4.555555555555555),
#  ('список содержать', 4.527777777777778),
#  ('русский сегменте', 4.5),
#  ('проект создаваться', 4.5),
#  ('добавление наречие', 4.5),
#  ('удаление html-тэгов', 4.5),
#  ('удаление стопа-слово', 4.5),
#  ('векторный формат', 4.5),
#  ('результат кодирование', 4.5),
#  ('лингвист проект', 4.5),
#  ('решить включить', 4.5),
#  ('единица', 4.5),
#  ('миллион документов', 4.4),
#  ('выявление предпочтение', 4.333333333333334),
#  ('оценочный лексики', 4.333333333333334),
#  ('количество', 4.333333333333333),
#  ('выбрать сочетание', 4.3),
#  ('использовать словарь', 4.253333333333333),
#  ('получить прилагательное', 4.25),
#  ('матрица φ', 4.222222222222222),
#  ('матрица θ', 4.222222222222222),
#  ('разработать', 4.142857142857143),
#  ('просмотреть первый', 4.1),
#  ('соревнование ромип', 4.0),
#  ('маркетинговый исследованиях', 4.0),
#  ('иметься сведение', 4.0),
#  ('ниу вшэ', 4.0),
#  ('слово присутствовать', 4.0),
#  ('реальный наречием', 4.0),
#  ('отрицательный настроений', 4.0),
#  ('краткий интернет-сообщениями', 4.0),
#  ('случай полисемии', 4.0),
#  ('популярный блогер', 4.0),
#  ('предоставлять жж', 4.0),
#  ('размер порядок', 4.0),
#  ('топовый блогер', 4.0),
#  ('компьютерный лингвистика', 4.0),
#  ('основный вариантах', 4.0),
#  ('разработчик с.н', 4.0),
#  ('способный работать', 4.0),
#  ('персональный компьютер', 4.0),
#  ('иметь', 4.0),
#  ('препроцессинг данных', 4.0),
#  ('начальный форме', 4.0),
#  ('маленький приводить', 4.0),
#  ('inter-rater agreement', 4.0),
#  ('multiple raters', 4.0),
#  ('простой задач', 4.0),
#  ('редко бывать', 4.0),
#  ('выбирать документы', 4.0),
#  ('назвать темами', 4.0),
#  ('нормализовать форму', 4.0),
#  ('признать темами', 4.0),
#  ('какого/какий источника/источник', 4.0),
#  ('получить информация', 4.0),
#  ('вручную исключить', 4.0),
#  ('счесть нерелевантными', 4.0),
#  ('социально-политический теме', 4.0),
#  ('повторяться слова', 3.888888888888889),
#  ('слово встретиться', 3.833333333333333),
#  ('отобрать ещё', 3.833333333333333),
#  ('качество', 3.75),
#  ('выделить blog06', 3.666666666666667),
#  ('≡ φ', 3.666666666666667),
#  ('≡ θ', 3.666666666666667),
#  ('документ', 3.6666666666666665),
#  ('p', 3.6666666666666665),
#  ('эмоциональный', 3.625),
#  ('дать', 3.5555555555555554),
#  ('последний', 3.5),
#  ('специально предназначить', 3.5),
#  ('сделать автоматически', 3.5),
#  ('lda предполагается', 3.5),
#  ('язык', 3.4444444444444446),
#  ('текст', 3.423076923076923),
#  ('коллекция', 3.3333333333333335),
#  ('содержаться', 3.3333333333333335),
#  ('система sentistrength', 3.333333333333333),
#  ('отобрать текстах', 3.333333333333333),
#  ('сразу взять', 3.333333333333333),
#  ('текстов', 3.2857142857142856),
#  ('слов', 3.2666666666666666),
#  ('этап', 3.25),
#  ('протяжение год', 3.25),
#  ('выделить девять', 3.166666666666667),
#  ('словаря', 3.125),
#  ('источник', 3.125),
#  ('блогов', 3.0),
#  ('словарный', 3.0),
#  ('вес', 3.0),
#  ('размечаться', 3.0),
#  ('средство', 3.0),
#  ('словарь', 2.92),
#  ('линиса составить', 2.916666666666667),
#  ('тема', 2.8181818181818183),
#  ('выбрать', 2.8),
#  ('список', 2.7777777777777777),
#  ('социально-политический', 2.75),
#  ('создать', 2.6666666666666665),
#  ('цель', 2.6666666666666665),
#  ('частота', 2.6666666666666665),
#  ('затем', 2.6666666666666665),
#  ('блог', 2.6666666666666665),
#  ('встречаться', 2.6),
#  ('работа', 2.5714285714285716),
#  ('матрица', 2.5555555555555554),
#  ('описывать', 2.5),
#  ('слово', 2.5),
#  ('результат', 2.5),
#  ('стратегий', 2.5),
#  ('сила', 2.5),
#  ('менее', 2.5),
#  ('проект', 2.5),
#  ('привести', 2.5),
#  ('войти', 2.5),
#  ('выявление', 2.3333333333333335),
#  ('прилагательное', 2.25),
#  ('найти', 2.25),
#  ('число', 2.1666666666666665),
#  ('−', 2.142857142857143),
#  ('кольцов', 2.0),
#  ('известно', 2.0),
#  ('использование', 2.0),
#  ('получить', 2.0),
#  ('тематике', 2.0),
#  ('переменный', 2.0),
#  ('препроцессинг', 2.0),
#  ('лексика', 2.0),
#  ('сформировать', 2.0),
#  ('оказаться', 2.0),
#  ('итог', 2.0),
#  ('размер', 2.0),
#  ('усиление/уменьшение', 2.0),
#  ('слова', 1.8888888888888888),
#  ('отобрать', 1.8333333333333333),
#  ('специфичный', 1.75),
#  ('содержать', 1.75),
#  ('отзыв', 1.6666666666666667),
#  ('добавляться', 1.6666666666666667),
#  ('линиса', 1.6666666666666667),
#  ('φ', 1.6666666666666667),
#  ('θ', 1.6666666666666667),
#  ('выделить', 1.6666666666666667),
#  ('задача', 1.5),
#  ('лингвистика', 1.5),
#  ('специально', 1.5),
#  ('прилагательных', 1.5),
#  ('единиц', 1.5),
#  ('текстах', 1.5),
#  ('lda', 1.5),
#  ('девять', 1.5),
#  ('присутствовать', 1.5),
#  ('списках', 1.5),
#  ('исключение', 1.5),
#  ('сделать', 1.5),
#  ('просмотреть', 1.5),
#  ('сочетание', 1.5),
#  ('w', 1.4285714285714286),
#  ('использовать', 1.3333333333333333),
#  ('встретиться', 1.3333333333333333),
#  ('взять', 1.3333333333333333),
#  ('sentistrength', 1.3333333333333333),
#  ('составить', 1.25),
#  ('год', 1.25),
#  ('темам', 1.25),
#  ('теме', 1.25),
#  ('http', 1.1666666666666667),
#  ('linis-crowd.org', 1.0),
#  ('алексеева', 1.0),
#  ('санкт-петербург', 1.0),
#  ('сентимент-анализ', 1.0),
#  ('плохо', 1.0),
#  ('нравиться', 1.0),
#  ('др', 1.0),
#  ('отнести', 1.0),
#  ('применения', 1.0),
#  ('основном', 1.0),
#  ('лежать', 1.0),
#  ('предел', 1.0),
#  ('разделить', 1.0),
#  ('маркетинг', 1.0),
#  ('товар', 1.0),
#  ('услуги', 1.0),
#  ('социология', 1.0),
#  ('политология', 1.0),
#  ('во-первых', 1.0),
#  ('отклик', 1.0),
#  ('ожидать', 1.0),
#  ('публики', 1.0),
#  ('во-вторых', 1.0),
#  ('форумов', 1.0),
#  ('части', 1.0),
#  ('представить', 1.0),
#  ('интернете', 1.0),
#  ('удобный', 1.0),
#  ('избыток', 1.0),
#  ('напр.', 1.0),
#  ('особо', 1.0),
#  ('//ir.dcs.gla.ac.uk/test_collections/blog06info.html', 1.0),
#  ('сконцентрировать', 1.0),
#  ('насколько', 1.0),
#  ('//romip.ru/ru/collections/index.html', 1.0),
#  ('непригодный', 1.0),
#  ('обратиться', 1.0),
#  ('//sentistrength.wlv.ac.uk/', 1.0),
#  ('фелвол', 1.0),
#  ('великобритания', 1.0),
#  ('opinionfinder', 1.0),
#  ('//mpqa.cs.pitt.edu/opinionfinder/', 1.0),
#  ('sentiwordnet', 1.0),
#  ('//sentiwordnet.isti.cnr.it/', 1.0),
#  ('четверкин', 1.0),
#  ('лукашевич', 1.0),
#  ('//www.cir.ru/sentilexicon/productsentirus.txt', 1.0),
#  ('представлять', 1.0),
#  ('извлечь', 1.0),
#  ('фильмы', 1.0),
#  ('книги', 1.0),
#  ('игры', 1.0),
#  ('телефоны', 1.0),
#  ('камеры', 1.0),
#  ('видно', 1.0),
#  ('описания', 1.0),
#  ('присвоить', 1.0),
#  ('находить', 1.0),
#  ('точность', 1.0),
#  ('сравнение', 1.0),
#  ('настраивается', 1.0),
#  ('языка', 1.0),
#  ('опора', 1.0),
#  ('простых', 1.0),
#  ('носителей', 1.0),
#  ('запасом', 1.0),
#  ('человек', 1.0),
#  ('привязка', 1.0),
#  ('выражаться', 1.0),
#  ('наречий', 1.0),
#  ('//digsolab.ru', 1.0),
#  ('линис', 1.0),
#  ('разметить', 1.0),
#  ('кодировщика', 1.0),
#  ('конец', 1.0),
#  ('списке', 1.0),
#  ('-ий', 1.0),
#  ('-ый', 1.0),
#  ('-ой', 1.0),
#  ('-о', 1.0),
#  ('-е', 1.0),
#  ('-и', 1.0),
#  ('https', 1.0),
#  ('//pymorphy2.readthedocs.org/en/latest/user/guide.html', 1.0),
#  ('id2', 1.0),
#  ('словаре', 1.0),
#  ('анализатор', 1.0),
#  ('т.е', 1.0),
#  ('адресу', 1.0),
#  ('междометие', 1.0),
#  ('добавить', 1.0),
#  ('павлов', 1.0),
#  ('поставлять', 1.0),
#  ('//sentistrength.wlv.ac.uk', 1.0),
#  ('ориентировать', 1.0),
#  ('публиковать', 1.0),
#  ('myspace', 1.0),
#  ('twitter', 1.0),
#  ('комментарий', 1.0),
#  ('постам', 1.0),
#  ('целями', 1.0),
#  ('особенно', 1.0),
#  ('вебресурсе', 1.0),
#  ('//linis.hse.ru/soft-linis', 1.0),
#  ('март', 1.0),
#  ('рейтинг', 1.0),
#  ('млн', 1.0),
#  ('период', 1.0),
#  ('мочь', 1.0),
#  ('взяты', 1.0),
#  ('отличаться', 1.0),
#  ('обычный', 1.0),
#  ('рубрик', 1.0),
#  ('тэгам', 1.0),
#  ('тэг', 1.0),
#  ('известны', 1.0),
#  ('отсортировать', 1.0),
#  ('релевантности', 1.0),
#  ('следующем', 1.0),
#  ('применение', 1.0),
#  ('базироваться', 1.0),
#  ('скрытой', 1.0),
#  ('появление', 1.0),
#  ('пара', 1.0),
#  ('связать', 1.0),
#  ('w|', 1.0),
#  ('матрицу', 1.0),
#  ('выбор', 1.0),
#  ('правило', 1.0),
#  ('отсутствовать', 1.0),
#  ('интерфейс', 1.0),
#  ('справляться', 1.0),
#  ('в.г', 1.0),
#  ('филипов', 1.0),
#  ('лемматизация', 1.0),
#  ('приведение', 1.0),
#  ('несущий', 1.0),
#  ('смысл', 1.0),
#  ('влиять', 1.0),
#  ('тематику', 1.0),
#  ('лемм', 1.0),
#  ('тексте', 1.0),
#  ('α', 1.0),
#  ('β', 1.0),
#  ('матрицы', 1.0),
#  ('показавшего', 1.0),
#  ('заимствовать', 1.0),
#  ('0,5', 1.0),
#  ('убыванию', 1.0),
#  ('передать', 1.0),
#  ('кодировщикам', 1.0),
#  ('определяли', 1.0),
#  ('минимум', 1.0),
#  ('согласованность', 1.0),
#  ('//mlnl.net/jg/software/ira/', 1.0),
#  ('кодировщиков', 1.0),
#  ('несмотря', 1.0),
#  ('относиться', 1.0),
#  ('получиться', 1.0),
#  ('дополнение', 1.0),
#  ('связанный', 1.0),
#  ('эмоций', 1.0),
#  ('объект', 1.0),
#  ('направлена', 1.0),
#  ('разным', 1.0),
#  ('политическим', 1.0),
#  ('эмоция', 1.0),
#  ('далее', 1.0),
#  ('списками', 1.0),
#  ('указать', 1.0),
#  ('пришло', 1.0),
#  ('т.о', 1.0),
#  ('списков', 1.0),
#  ('встречается', 1.0),
#  ('источников', 1.0),
#  ('представлены', 1.0),
#  ('основное', 1.0),
#  ('аккумулятор', 1.0),
#  ('диагональ', 1.0),
#  ('панель', 1.0),
#  ('исключили', 1.0),
#  ('дубликат', 1.0),
#  ('удалены', 1.0),
#  ('сопоставить', 1.0),
#  ('выбираться', 1.0),
#  ('хорошо/плохо', 1.0),
#  ('//linis-crowd.org', 1.0),
#  ('заключение', 1.0),
#  ('точнее', 1.0),
#  ('прочего', 1.0),
#  ('прокатиться', 1.0)]

# %%
with open('rake_keywords.csv', 'w', encoding='utf-8') as f2:
    for eachkwrd in keywords:
        f2.write(str(eachkwrd[0])+";"+str(eachkwrd[1])+"\n")

# %%
#KeyBERT
# !pip install keybert
import keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.8.4.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sentence-transformers>=0.3.8 (from keybert)
#   Downloading sentence_transformers-2.6.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.2.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.25.2)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.10/dist-packages (from keybert) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (2.16.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (3.4.0)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.38.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (3.13.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (24.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 56.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 62.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 86.3 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.7 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.3 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.2 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.3 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.8 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.8 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.3.8->keybert) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.3.8->keybert) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers>=0.3.8->keybert) (0.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Building wheels for collected packages: keybert
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.8.4-py3-none-any.whl size=39200 sha256=e052ac5f1ec132c0ea57e3727fc3f8cc0667c0432e8d7e949d732cd0a9e01d42
#   Stored in directory: /root/.cache/pip/wheels/97/ef/4c/6588bd7072b0cc04225b40e639b991e49ebd4e21fb81f0acee
# Successfully built keybert
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence-transformers, keybert
# Successfully installed keybert-0.8.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 sentence-transformers-2.6.1

# %%
from keybert import KeyBERT

# %%
with open('Alexeeva_IMS_2015_rus_lem.txt', 'r', encoding='utf-8') as f:
    doc = f.read()

# %%
kw_model = KeyBERT()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
keywords = kw_model.extract_keywords(doc)

# %%
keywords
# Out:
# [('английский', 0.4845),
#  ('социальнополитический', 0.47),
#  ('исследовательский', 0.4568),
#  ('автоматический', 0.4491),
#  ('лингвистический', 0.448)]

# %%
keywords = kw_model.extract_keywords(doc, top_n=20)
keywords
# Out:
# [('английский', 0.4845),
#  ('социальнополитический', 0.47),
#  ('исследовательский', 0.4568),
#  ('автоматический', 0.4491),
#  ('лингвистический', 0.448),
#  ('политический', 0.4438),
#  ('высокий', 0.4427),
#  ('лексический', 0.4388),
#  ('исследований', 0.4253),
#  ('исключили', 0.4185),
#  ('полисемии', 0.415),
#  ('коллекций', 0.4143),
#  ('коллекции', 0.4143),
#  ('аудитории', 0.4114),
#  ('источников', 0.4056),
#  ('пользовательский', 0.4033),
#  ('русскоязычный', 0.402),
#  ('русский', 0.3995),
#  ('источник', 0.3995),
#  ('социальнополитической', 0.399)]

# %%
with open('KeyBERT_top_20.csv', 'w', encoding='utf-8') as f2:
    for eachkwrd in keywords:
        f2.write(str(eachkwrd[0])+";"+str(eachkwrd[1])+"\n")

# %%
keywords = kw_model.extract_keywords(doc, keyphrase_ngram_range=(1, 2), top_n=20)
keywords
# Out:
# [('высокий школа', 0.5297),
#  ('лингвистический ресурс', 0.5275),
#  ('национальный исследовательский', 0.5169),
#  ('лексический ресурс', 0.5118),
#  ('лексический единиц', 0.508),
#  ('лексический единица', 0.4985),
#  ('того английский', 0.4944),
#  ('автоматический классификация', 0.4928),
#  ('коллекция социальнополитический', 0.4925),
#  ('автоматический выделение', 0.4911),
#  ('автоматический определение', 0.491),
#  ('текст социальнополитический', 0.4904),
#  ('исследовательский университет', 0.4875),
#  ('английский', 0.4845),
#  ('автоматический извлечение', 0.4843),
#  ('английский язык', 0.4825),
#  ('тематический моделирование', 0.4823),
#  ('сочетание автоматический', 0.4805),
#  ('английский сегмент', 0.4795),
#  ('политический содержания', 0.4751)]

# %%
with open('KeyBERT_top_20_bigram.csv', 'w', encoding='utf-8') as f2:
    for eachkwrd in keywords:
        f2.write(str(eachkwrd[0])+";"+str(eachkwrd[1])+"\n")

# %%
keywords = kw_model.extract_keywords(doc, keyphrase_ngram_range=(1, 3), top_n=20)
keywords
# Out:
# [('университет высокий школа', 0.5853),
#  ('высокий школа экономики', 0.5725),
#  ('автоматический определение эмоциональный', 0.5605),
#  ('высокий школа', 0.5297),
#  ('лингвистический ресурс', 0.5275),
#  ('национальный исследовательский университет', 0.5254),
#  ('лексический единиц включая', 0.5244),
#  ('исследовательский университет высокий', 0.5237),
#  ('алгоритмов включая тематический', 0.5206),
#  ('кроме того английский', 0.5191),
#  ('вычленение социально политический', 0.5185),
#  ('национальный исследовательский', 0.5169),
#  ('политический направленности формирование', 0.5161),
#  ('тематический моделирование вычленение', 0.5151),
#  ('слово текст социальнополитический', 0.5151),
#  ('автоматический выделение релевантный', 0.5139),
#  ('английский язык словарный', 0.5134),
#  ('источник тестовый коллекции', 0.5132),
#  ('тематический моделирование кластерный', 0.513),
#  ('тематический моделирование поскольку', 0.5129)]

# %%
with open('KeyBERT_top_20_trigram.csv', 'w', encoding='utf-8') as f2:
    for eachkwrd in keywords:
        f2.write(str(eachkwrd[0])+";"+str(eachkwrd[1])+"\n")

# %%
#RuTermExtract

# %%
# !pip install rutermextract
# Out:
# Collecting rutermextract
#   Downloading rutermextract-0.3.tar.gz (8.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pymorphy2>=0.8 (from rutermextract)
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pymorphy2>=0.8->rutermextract) (0.7.2)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4 (from pymorphy2>=0.8->rutermextract)
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 72.8 MB/s eta 0:00:00
# Collecting docopt>=0.6 (from pymorphy2>=0.8->rutermextract)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: rutermextract, docopt
#   Building wheel for rutermextract (setup.py) ... done
#   Created wheel for rutermextract: filename=rutermextract-0.3-py3-none-any.whl size=9706 sha256=27dab186a18d9c01e0a6020a64c7d91fd18e0f8e3972d630a3d2a730df160b15
#   Stored in directory: /root/.cache/pip/wheels/44/00/bc/33a2ee393657898aed2be21b2598c4e2a7ababd404a2f979e1
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=b115fdb792a12c0b59e4b4f7fee5e278f381eccf4f095658c50860081115826e
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built rutermextract docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, pymorphy2, rutermextract
# Successfully installed docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844 rutermextract-0.3

# %%
from rutermextract import TermExtractor

# %%
term_extractor = TermExtractor()

# %%
with open('Alexeeva_IMS_2015_rus_lem.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
for term in term_extractor(text):
    print(term.normalized, term.count)
# Out:
# слово 25
# текст 15
# словарь 15
# список 10
# документ 10
# тематический моделирование 9
# темы 9
# матрица 9
# распределение 8
# коллекция 8
# анализ 8
# тональный словарь 6
# такая образ 6
# социально-политический тематика 6
# число 6
# тема 6
# помощь 6
# социально-политический направленность 5
# каждый тема 5
# слова 5
# результат 5
# работа 5
# основа 5
# источник 5
# t 5
# частотный список 4
# прототип словаря 4
# общественный мнение 4
# коллекция документов 4
# живая журнал 4
# вероятностный слово 4
# принадлежность 4
# прилагательное 4
# н 4
# мнение 4
# вычленение 4
# вероятность 4
# тематический модель 3
# такая словарь 3
# социальный сеть 3
# социальный медиа 3
# русский язык 3
# каждый слово 3
# весь слово 3
# четверкин 3
# частота 3
# удаление 3
# тексты 3
# сэмплирование 3
# списки 3
# создание 3
# сила 3
# размер 3
# представление 3
# пост 3
# отзыв 3
# основание 3
# набор 3
# множество 3
# методика 3
# лукашевич 3
# линиса 3
# лаборатория 3
# комментарий 3
# кольцов 3
# качество 3
# гиббс 3
# выявление 3
# блог 3
# алгоритм 3
# w 3
# d 3
# эмоциональный окрашенность 2
# три кодировщик 2
# тональный слова 2
# тональный разметка 2
# такая лексика 2
# словарный подход 2
# свободный доступ 2
# разный вероятность 2
# предметный область 2
# пользовательский интернет-контент 2
# первый этап 2
# первый очередь 2
# компьютерный лингвистика 2
# кластерный анализ 2
# два матрицы 2
# данный слово 2
# данный проект 2
# вероятностный документ 2
# автоматический определение 2
# язык 2
# эмоция 2
# эмоции 2
# часть 2
# цель 2
# фэйсбук 2
# усиление/уменьшение 2
# университет 2
# товар 2
# тематика 2
# сочетание 2
# сми 2
# ромип 2
# рамка 2
# разработка 2
# разметка 2
# проект 2
# применение 2
# препроцессинг 2
# предел 2
# параметр 2
# окончание 2
# область 2
# наречие 2
# наличие 2
# мочь 2
# модуль 2
# март 2
# итог 2
# исследование 2
# использование 2
# изучение 2
# знание 2
# запись 2
# задача 2
# др 2
# группа 2
# высказывание 2
# выбор 2
# вес 2
# блог-платформа 2
# sentistrength 2
# lda 2
# http://www.cir.ru/sentilexicon/productsentirus.txt 2
# http://sentistrength.wlv.ac.uk 2
# http://linis.hse.ru/soft-linis 2
# помощь online calculator for inter-rater agreement with multiple raters 1
# реляционный база ms sql server 1
# три следующий список слов 1
# некоторый неизвестный тема t 1
# 2000 самый популярный блогер 1
# 200 самый вероятностный слово 1
# частотный словарь прилагательных 1
# условный распределение p(w 1
# упрощённый понимание темы 1
# три разный текст 1
# тональный анализ отзывов 1
# социально-политический сфера слова 1
# собственный разработка topicminer 1
# различный программный средство 1
# программный обеспечение topicminer 1
# программный обеспечение blogminer 1
# предварительный итоговый словарь 1
# постоянный еженедельный закачка 1
# первый 3500 слово 1
# окончательный версия словаря 1
# общий тональность текста 1
# общественный мнение интернет-аудитории 1
# нечёткий множество текстов 1
# негативный оценка товара 1
# национальный исследовательский университет 1
# мало релевантный текстов 1
# любая развитый язык 1
# какая-либо социально-политический тема 1
# каждый тема t 1
# каждый документ d 1
# излишний укрупнённый темы 1
# другая пользовательский контент 1
# доступный обширный словари 1
# дискретный распределение p(d,w 1
# два основный подход 1
# два основный вариантах 1
# два обширный области 1
# данный лингвистический ресурс 1
# главный целевая область 1
# высокий школа экономики 1
# весь слово коллекции 1
# весь 70710 текстов 1
# больший коллекция текстов 1
# latent dirichlet allocation 1
# 9539 лексический единиц 1
# 70710 социальнополитический тематики 1
# 5000 оценочный слов 1
# 11869 лексический единиц 1
# 104 социально-политический темы 1
# 1.5 миллион документов 1
# язык vs 1
# эмоциональный оценка 1
# эмоциональный окраска 1
# эмоциональный компонент 1
# эмоциональный заряженность 1
# эксперт vs 1
# чей вероятность 1
# цифровая общество 1
# хороший качество 1
# финальный коллекция 1
# успешный разработка 1
# уникальный слово 1
# удаление html-тэгов 1
# тысяча слов 1
# три человек 1
# три целями 1
# три текст 1
# три кодировщикам 1
# три кодировщика 1
# топовый блогер 1
# тональный слово 1
# тональный окраска 1
# тональный анализ 1
# тональность текстов 1
# тестовый коллекция 1
# текстовый коллекция 1
# текст блогосферы 1
# текст блогов 1
# такая тема 1
# такая текст 1
# такая коллекция 1
# такая интерпретация 1
# сходный текст 1
# средний величина 1
# список слов 1
# специализированный слова 1
# социальный сети 1
# социальный капитал 1
# социальный исследователь 1
# социальнополитический текст 1
# социальнополитический направленность 1
# социально-политический текст 1
# соответствующий слово 1
# совокупность слов 1
# случай полисемии 1
# следующий процедура 1
# следующий данные 1
# система sentistrength 1
# сегодняшний день 1
# самостоятельный извлечение 1
# сам слово 1
# ручная разметка 1
# русскоязычный текст 1
# русский сегмент 1
# релевантный текст 1
# редкий слова 1
# реальный наречие 1
# разный тематика 1
# различный метод 1
# различный источник 1
# различный вариант 1
# развёртывание кластера 1
# работа людей 1
# простая задачи 1
# промежуточный результат 1
# программный продукт 1
# программный обеспечение 1
# признаковый слово 1
# препроцессинг данных 1
# предыдущий опыт 1
# предыдущий исследование 1
# предметный области 1
# последующий отбор 1
# последний компонент 1
# пользовательский контент 1
# полный объём 1
# политический содержание 1
# персональный компьютер 1
# переменный t 1
# переменный d 1
# оценочный лексика 1
# оценочный значение 1
# оформление списка 1
# отрицательный настроения 1
# отдельный тема 1
# остальная списки 1
# остальная источник 1
# основа отзывов 1
# окончательный список 1
# один источник 1
# один год 1
# объяснительный словарь 1
# обширный коллекция 1
# новостная тексты 1
# низкий показатель 1
# необходимый модули 1
# необходимый количество 1
# начальный форма 1
# настоящий проект 1
# настоящий время 1
# морфоанализатор pymorphy2 1
# модуль препроцессина 1
# многий отношение 1
# маркетинговый исследования 1
# маленький величина 1
# максимальный вероятность 1
# любая вид 1
# лингвистический модель 1
# лексический ресурс 1
# лексический единица 1
# лаборатория интернет-исследований 1
# краудсорсинговый веб-ресурс 1
# краткий интернет-сообщения 1
# косвенный речь 1
# конечный цель 1
# конечный прототип 1
# конечный множество 1
# количество раз 1
# какая-либо язык 1
# какая отклик 1
# каждый ячейка 1
# каждый столбец 1
# каждый пара 1
# каждый кодировщик 1
# итерация сэмплирования 1
# исключение слов 1
# интернет-активный часть 1
# инструмент сентимент-анализа 1
# известный словарь 1
# значимый вопросы 1
# значимый вопрос 1
# документ коллекции 1
# два матрица 1
# два кодировщиков 1
# два источников 1
# данный язык 1
# данный текст 1
# данный список 1
# данный момент 1
# данный исследование 1
# дальнейший работа 1
# вычислительный ядро 1
# вычислительный простота 1
# высокий роль 1
# входной параметр 1
# вторая этап 1
# вторая очередь 1
# весь список 1
# весь массив 1
# весь год 1
# вероятностный текст 1
# вероятностный слова 1
# вероятностный алгоритмы 1
# векторный формат 1
# векторный модель 1
# веб-ресурс http://linis-crowd.org 1
# вариационный модель 1
# больший часть 1
# больший объёмы 1
# больший коллекция 1
# большая количество 1
# большая доля 1
# англоязычный сфера 1
# англоязычный словарь 1
# английский язык 1
# английский сегмент 1
# анализ результатов 1
# альтернативный стратегии 1
# автоматический метод 1
# автоматический классификация 1
# автоматический извлечение 1
# автоматический выделение 1
# автоматизированный анализ 1
# inter-rater agreement 1
# 9539 единиц 1
# 8152 слова 1
# 752 слова 1
# 53 междометие 1
# 3293 прилагательных 1
# 28617 документ 1
# 2310 наречий 1
# 20800 единица 1
# 2015 год 1
# 14933 прилагательных 1
# 1213 слово 1
# 1000 раз 1
# 1.5 млн 1
# этап 1
# элемент 1
# ход 1
# форумы 1
# формирование 1
# форма 1
# фильмы 1
# филипы 1
# фелвол 1
# усреднение 1
# услуги 1
# убывание 1
# тэгам 1
# точность 1
# точка 1
# топ-слово 1
# тональность 1
# тенденция 1
# телефоны 1
# сходимость 1
# сумма 1
# стратегии 1
# стопа-слово 1
# статья 1
# средство 1
# сравнение 1
# способы 1
# спам 1
# социология 1
# сотрудничество 1
# сотня 1
# составление 1
# соревнование 1
# создатель 1
# согласованность 1
# согласие 1
# смысл 1
# слов/документ 1
# сентимент-анализ 1
# сведение 1
# сбор 1
# санкт-петербург 1
# рубрики 1
# рубрика 1
# релевантность 1
# рейтинг 1
# революция 1
# расчёт 1
# разработчик 1
# публика 1
# процедура 1
# протяжение 1
# прототип 1
# протест 1
# программа 1
# проведение 1
# пример 1
# прилагательные 1
# привязка 1
# приведение 1
# предпочтение 1
# предмет 1
# правило 1
# появление 1
# посты 1
# порядок 1
# порог 1
# политология 1
# поиск 1
# подсчёт 1
# период 1
# перевод 1
# панель 1
# павлов 1
# оценка 1
# отсутствие 1
# отношение 1
# отбор 1
# основное 1
# определение 1
# опора 1
# описание 1
# операция 1
# объект 1
# носители 1
# нахождение 1
# население 1
# наречия 1
# модель 1
# моделирование 1
# мир 1
# минимум 1
# метод 1
# маркетинг 1
# м 1
# люди 1
# линисы 1
# лингвистика 1
# лингвист 1
# леммы 1
# лемматизация 1
# краудсорсинг 1
# контент 1
# контекст 1
# конец 1
# конвертация 1
# коллекции 1
# кодировщик 1
# кодирование 1
# книга 1
# камера 1
# какого/какий 1
# итерация 1
# источника/источник 1
# исследователь 1
# исключение 1
# информация 1
# интерфейс 1
# интерпретируемость 1
# интернет-общественность 1
# интернет-исследование 1
# интернет 1
# ии 1
# избыток 1
# игра 1
# зрение 1
# значение 1
# зашумлен 1
# запас 1
# заключение 1
# заимствование 1
# жж 1
# единицы 1
# дубликат 1
# дополнение 1
# документы 1
# добровольцы 1
# добавление 1
# диагональ 1
# графика 1
# граница 1
# годы 1
# год 1
# глазго 1
# генерация 1
# вычисление 1
# вшэ 1
# вулверхемптон 1
# волна 1
# возможность 1
# внимание 1
# вид 1
# версия 1
# величина 1
# великобритания 1
# вебресурс 1
# веб-ресурс 1
# введение 1
# важность 1
# блоги 1
# аудитория 1
# анализатор 1
# алексеева 1
# аккумулятор 1
# адрес 1
# twitter 1
# sentiwordnet 1
# p(t 1
# opinionfinder 1
# myspace 1
# linis-crowd.org 1
# https://pymorphy2.readthedocs.org/en/latest/user/guide.html#id2 1
# https://mlnl.net/jg/software/ira 1
# http://sentiwordnet.isti.cnr.it 1
# http://romip.ru/ru/collections/index.html 1
# http://mpqa.cs.pitt.edu/opinionfinder 1
# http://ir.dcs.gla.ac.uk/test_collections/blog06info.html 1
# http://digsolab.ru 1
# blog06 1

# %%
with open('RuTermExtract_keywords.csv', 'w', encoding='utf-8') as f2:
    for term in term_extractor(text):
        f2.write(str(term.normalized)+";"+str(term.count)+"\n")

# %%
#SpaCy

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.1.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.7.11)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.3.5->spacy) (0.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.5.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.1.0/ru_core_news_sm-3.1.0.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.1.0/ru_core_news_sm-3.1.0.tar.gz
#   Using cached https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.1.0/ru_core_news_sm-3.1.0.tar.gz (15.9 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-sm==3.1.0) (3.1.7)
# Requirement already satisfied: pymorphy2>=0.9 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-sm==3.1.0) (0.9.1)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from pymorphy2>=0.9->ru-core-news-sm==3.1.0) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /usr/local/lib/python3.10/dist-packages (from pymorphy2>=0.9->ru-core-news-sm==3.1.0) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.10/dist-packages (from pymorphy2>=0.9->ru-core-news-sm==3.1.0) (0.6.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (3.0.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (0.7.11)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.0.10)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (0.4.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (4.66.2)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (1.25.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (1.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (24.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2024.2.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.1.5)

# %%
import spacy
from collections import Counter
from nltk.corpus import stopwords

# %%
# Для SpaCy (дополнительно взяли стоп-слова из nltk, с ними результаты улучшились)
spacy_model = spacy.load('ru_core_news_sm')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:696: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)

# %%
spacy_model.max_length = 2400000

# %%
nltk_stopwords = stopwords.words('russian')

# %%
spacy_stopwords = spacy_model.Defaults.stop_words

# %%
def extract_keywords_with_spacy(text):
    keywords = []
    doc = spacy_model(text.read())
    for token in doc:
        # Тексты уже очищены от знаков препинания и лемматизированы, тем не менее, остались некоторые символы,
        # которые нужно удалить
        if token.text not in spacy_stopwords and token.text not in nltk_stopwords and \
                token.text not in "`'«»...—-":
            if token.pos_ in ('ADJ', 'NOUN', 'VERB'):
                keywords.append(token.text)

    freq_word = Counter(keywords)
    max_freq = Counter(keywords).most_common(1)[0][1]
    for w in freq_word:
        freq_word[w] = round(freq_word[w] / max_freq, 3)

    freq_20 = freq_word.most_common(20)

    with open('spacykeywords.csv', 'w', encoding='utf-8') as f2:
        for term in freq_20:
            f2.write(str(term[0])+";"+str(term[1])+"\n")

    print(freq_20)

# %%
with open('Alexeeva_IMS_2015_rus_lem.txt', 'r', encoding='utf-8') as file:
    extract_keywords_with_spacy(file)
# Out:
# [('слово', 1.0), ('текст', 0.634), ('словарь', 0.61), ('политический', 0.512), ('социально', 0.488), ('коллекция', 0.439), ('список', 0.439), ('тональный', 0.39), ('слов', 0.39), ('документ', 0.39), ('анализ', 0.341), ('тематический', 0.293), ('данный', 0.268), ('окрасить', 0.268), ('моделирование', 0.244), ('вероятностный', 0.244), ('тема', 0.244), ('распределение', 0.244), ('язык', 0.22), ('социальный', 0.22)]

# %%
#Pullenti

# %%
# !pip install pullenti_wrapper
# Out:
# Collecting pullenti_wrapper
#   Downloading pullenti_wrapper-0.9.0-py3-none-any.whl (7.1 kB)
# Collecting pullenti==3.23 (from pullenti_wrapper)
#   Downloading pullenti-3.23-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 69.9 MB/s eta 0:00:00
# Collecting pullenti-client==0.6.0 (from pullenti_wrapper)
#   Downloading pullenti_client-0.6.0-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pullenti-client==0.6.0->pullenti_wrapper) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pullenti-client==0.6.0->pullenti_wrapper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pullenti-client==0.6.0->pullenti_wrapper) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pullenti-client==0.6.0->pullenti_wrapper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pullenti-client==0.6.0->pullenti_wrapper) (2024.2.2)
# Installing collected packages: pullenti, pullenti-client, pullenti_wrapper
# Successfully installed pullenti-3.23 pullenti-client-0.6.0 pullenti_wrapper-0.9.0

# %%
from pullenti_wrapper.processor import Processor, GEO, ORGANIZATION, PERSON, PHONE, ADDRESS
from collections import Counter

# %%
pullenti_processor = Processor([PERSON, ORGANIZATION, GEO, PHONE, ADDRESS])

# %%
def extract_keywords_with_pullenti(text):
    keywords = []
    for text in text.read().splitlines():
        try:
            result = pullenti_processor(text)
            for match in result.walk():
                for key, value in match.referent.slots:
                    if key not in ('ISRELATIVE', 'SEX', 'NUMBER', 'HIGHER', 'PROFILE',
                                   'ALPHA2', 'POINTER', 'FROM', 'REF', 'ATTRIBUTE'):
                        if 'LASTNAME' in str(match.referent.slots) and 'FIRSTNAME' in str(match.referent.slots):
                            try:
                                keywords.append(f'{match.referent.firstname} {match.referent.lastname}'.lower())
                            except AttributeError:
                                continue
                        keywords.append(str(value).lower())
        except ValueError:
            continue

    freq_word = Counter(keywords)

    freq_20 = freq_word.most_common(20)

    with open('pullenti_keywords.csv', 'w', encoding='utf-8') as f2:
        for term in freq_20:
            f2.write(str(term[0])+";"+str(term[1])+"\n")

    print(freq_20)

# %%
with open('Alexeeva_IMS_2015_rus_lem.txt', 'r', encoding='utf-8') as file:
    extract_keywords_with_pullenti(file)
# Out:
# [('университет', 1), ('национальный исследовательский университет', 1), ('санкт-петербург', 1), ('город', 1), ('живой журнал', 1), ('жж', 1), ('livejournal', 1), ('livejournal.ru', 1), ('livejournal ru', 1)]

# %% [markdown]
# YAKE

# %%
# !pip install git+https://github.com/LIAAD/yake
# Out:
# Collecting git+https://github.com/LIAAD/yake
#   Cloning https://github.com/LIAAD/yake to /tmp/pip-req-build-45y5wq5g
#   Running command git clone --filter=blob:none --quiet https://github.com/LIAAD/yake /tmp/pip-req-build-45y5wq5g
#   Resolved https://github.com/LIAAD/yake to commit 0fa58cceb465162b6bd0cab7ec967edeb907fbcc
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from yake==0.4.8) (0.9.0)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.10/dist-packages (from yake==0.4.8) (8.1.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from yake==0.4.8) (1.25.2)
# Collecting segtok (from yake==0.4.8)
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from yake==0.4.8) (3.2.1)
# Collecting jellyfish (from yake==0.4.8)
#   Downloading jellyfish-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from segtok->yake==0.4.8) (2023.12.25)
# Building wheels for collected packages: yake
#   Building wheel for yake (setup.py) ... done
#   Created wheel for yake: filename=yake-0.4.8-py2.py3-none-any.whl size=61995 sha256=52a700d409dd9894091b1e6fb0fe3a613c44785d43e58dc67bd3bc466f90ba02
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hcb6p1ud/wheels/10/9d/33/6a3358fd876c3d7c6c5c139d1496eb4b1618c7d0e15c375584
# Successfully built yake
# Installing collected packages: segtok, jellyfish, yake
# Successfully installed jellyfish-1.0.3 segtok-1.5.11 yake-0.4.8

# %%
import yake

# %%
kw_extractor = yake.KeywordExtractor()
with open('Alexeeva_IMS_2015_rus.txt', 'r', encoding='utf-8') as file:
    text = file.read()
keywords = [kw[0] for kw in kw_extractor.extract_keywords(text)]
for kw in keywords:
  print(kw)
# Out:
# слов
# для
# наиболее вероятностных слов
# словаря
# текстов
# документов
# вероятностных слов
# тем
# слова
# были
# окрашенных слов
# потенциально окрашенных слов
# как
# социально-политической
# наиболее вероятностных
# словарь
# Кольцова Национальный исследовательский
# коллекции
# которые
# всех слов

# %%
import os

# %%
#путь к папке с корпусом (лемматизированный корпус)
path = "corpus"
dirs = os.listdir(path)

# %%
i = 0
# словарь с именем файла и меткой класса (например, название рубрики или значение тональности)
dict_score = {}

# %%
for file in dirs:
    #есть нетекстовые файлы
    if (file[-4:] == '.txt'):
        with open(path + '/' + file, 'r', encoding='utf-8') as readfile:
            for line in readfile:
                list_words = line.split()
                # последним токеном в файле идёт оценка = для текстов отзывов
                dict_score[file] = list_words[len(list_words)-1]
                # формируем файл для анализа
                with open('reviews_for_work.txt', 'a', encoding='utf-8') as wfile:
                    # первым токеном в файле идёт номер файла, он не нужен
                    wfile.write(' '.join(list_words[1:len(list_words) - 1]) + '\n')
                    i += 1

# %%
print(f'files: {i}')
# Out:
# files: 46

# %%
print(f'dict_score: {len(dict_score)}')
# Out:
# dict_score: 3

# %%
dict_score
# Out:
# {'Kogan_IMS_2022.txt': 'студентов.',
#  'Kogan_IMS_2022_Abstract_rus.txt': 'интернет-ресурсов.',
#  'Kogan_IMS_2022_KW_rus.txt': 'квалификации'}

# %%
import re
import math
import pandas as pd
import nltk

# %%
with open('corpus/Kogan_IMS_2022.txt', 'r', encoding='utf-8') as file:
    f = file.read()

# %%
text_words_2 = re.findall(r'[а-яёА-ЯЁ]+', f)

text_words_1 = []
for i in text_words_2:
    k = i.lower()
    text_words_1.append(k)

text_words_2
# Out:
# ['Корпусная',
#  'лингводидактика',
#  'в',
#  'контексте',
#  'парадигмы',
#  'открытых',
#  'образовательных',
#  'ресурсов',
#  'М',
#  'С',
#  'Коган',
#  'Введение',
#  'Развитие',
#  'интернета',
#  'и',
#  'информационного',
#  'общества',
#  'привело',
#  'к',
#  'появлению',
#  'важного',
#  'тренда',
#  'на',
#  'открытое',
#  'образование',
#  'науку',
#  'информацию',
#  'Инициатором',
#  'этого',
#  'движения',
#  'считается',
#  'Майкл',
#  'Стерн',
#  'Харт',
#  'изобретатель',
#  'электронных',
#  'книг',
#  'и',
#  'основатель',
#  'проекта',
#  'Гутенберг',
#  'в',
#  'е',
#  'годы',
#  'прошлого',
#  'века',
#  'В',
#  'ХХ',
#  'веке',
#  'этот',
#  'тренд',
#  'задала',
#  'Будапештская',
#  'Инициатива',
#  'Открытый',
#  'Доступ',
#  'к',
#  'которой',
#  'с',
#  'тех',
#  'присоединились',
#  'тысячи',
#  'организаций',
#  'В',
#  'этом',
#  'документе',
#  'Открытый',
#  'доступ',
#  'определялся',
#  'как',
#  'открытые',
#  'для',
#  'всех',
#  'публикации',
#  'в',
#  'Интернете',
#  'которые',
#  'можно',
#  'читать',
#  'разгружать',
#  'копировать',
#  'распространять',
#  'распечатывать',
#  'находить',
#  'или',
#  'присоединять',
#  'к',
#  'полным',
#  'текстам',
#  'соответствующих',
#  'статей',
#  'использовать',
#  'для',
#  'составления',
#  'указателей',
#  'вводить',
#  'их',
#  'как',
#  'данные',
#  'в',
#  'программное',
#  'обеспечение',
#  'или',
#  'использовать',
#  'для',
#  'других',
#  'законных',
#  'целей',
#  'при',
#  'отсутствии',
#  'финансовых',
#  'правовых',
#  'и',
#  'технических',
#  'преград',
#  'при',
#  'соблюдении',
#  'целостности',
#  'работы',
#  'и',
#  'обязательной',
#  'ссылке',
#  'на',
#  'имя',
#  'автора',
#  'при',
#  'использовании',
#  'и',
#  'цитировании',
#  'В',
#  'последующие',
#  'годы',
#  'Будапештская',
#  'инициатива',
#  'получила',
#  'развитие',
#  'в',
#  'многочисленных',
#  'документах',
#  'ООН',
#  'и',
#  'ЮНЕСКО',
#  'например',
#  'в',
#  'рекомендациях',
#  'по',
#  'развитию',
#  'и',
#  'продвижению',
#  'открытого',
#  'доступа',
#  'рекомендациях',
#  'по',
#  'открытой',
#  'науке',
#  'по',
#  'работе',
#  'с',
#  'открытыми',
#  'образовательными',
#  'ресурсами',
#  'ООР',
#  'в',
#  'сфере',
#  'высшего',
#  'образования',
#  'об',
#  'открытых',
#  'образовательных',
#  'ресурсах',
#  'а',
#  'также',
#  'рекомендациях',
#  'по',
#  'развитию',
#  'практик',
#  'использования',
#  'ООР',
#  'и',
#  'т',
#  'д',
#  'Исследования',
#  'касающиеся',
#  'влияния',
#  'открытого',
#  'образования',
#  'на',
#  'изучение',
#  'и',
#  'преподавание',
#  'иностранных',
#  'языков',
#  'собраны',
#  'в',
#  'томе',
#  'находящемся',
#  'в',
#  'открытом',
#  'доступе',
#  'Открытые',
#  'образовательные',
#  'ресурсы',
#  'обладают',
#  'рядом',
#  'характеристик',
#  'важнейшими',
#  'из',
#  'которых',
#  'являются',
#  'бесплатный',
#  'доступ',
#  'право',
#  'на',
#  'использование',
#  'адаптацию',
#  'и',
#  'распространение',
#  'третьими',
#  'лицами',
#  'без',
#  'ограничений',
#  'или',
#  'с',
#  'незначительными',
#  'ограничениями',
#  'Некоторые',
#  'исследователи',
#  'дополняют',
#  'список',
#  'характеристик',
#  'понятия',
#  'открытость',
#  'до',
#  'пунктов',
#  'Обзор',
#  'исследований',
#  'принципов',
#  'и',
#  'характеристик',
#  'ООР',
#  'можно',
#  'найти',
#  'в',
#  'статье',
#  'Космас',
#  'с',
#  'коллегами',
#  'Одна',
#  'из',
#  'характеристик',
#  'открытой',
#  'науки',
#  'прозрачность',
#  'контроль',
#  'критический',
#  'анализ',
#  'и',
#  'воспроизводимость',
#  'результатов',
#  'в',
#  'целях',
#  'усиления',
#  'надежности',
#  'и',
#  'точности',
#  'научных',
#  'результатов',
#  'а',
#  'также',
#  'воздействия',
#  'науки',
#  'на',
#  'общество',
#  'с',
#  'Специалисты',
#  'в',
#  'области',
#  'прикладной',
#  'и',
#  'корпусной',
#  'лингвистики',
#  'говорят',
#  'о',
#  'кризисе',
#  'воспроизводимости',
#  'см',
#  'например',
#  'Анализируя',
#  'тенденции',
#  'развития',
#  'исследований',
#  'в',
#  'области',
#  'обучения',
#  'ИЯ',
#  'с',
#  'использованием',
#  'подходов',
#  'корпусной',
#  'лингвистики',
#  'за',
#  'последние',
#  'лет',
#  'на',
#  'материале',
#  'публикаций',
#  'в',
#  'авторитетных',
#  'рецензируемых',
#  'англоязычных',
#  'журналах',
#  'глав',
#  'монографий',
#  'и',
#  'материалах',
#  'авторитетных',
#  'конференций',
#  'А',
#  'Болтон',
#  'и',
#  'Н',
#  'Вяткина',
#  'обнаружили',
#  'полное',
#  'отсутствие',
#  'исследований',
#  'направленных',
#  'на',
#  'частичное',
#  'воспроизведение',
#  'повторение',
#  'классических',
#  'работ',
#  'в',
#  'новых',
#  'условиях',
#  'с',
#  'другими',
#  'категориями',
#  'обучающихся',
#  'Следует',
#  'заметить',
#  'что',
#  'авторы',
#  'в',
#  'соответствии',
#  'с',
#  'принципами',
#  'открытой',
#  'науки',
#  'разместили',
#  'информацию',
#  'о',
#  'всех',
#  'отобранных',
#  'для',
#  'анализа',
#  'публикациях',
#  'в',
#  'открытом',
#  'доступе',
#  'в',
#  'онлайн',
#  'репозитории',
#  'инструментов',
#  'и',
#  'материалов',
#  'для',
#  'исследований',
#  'в',
#  'области',
#  'иностранных',
#  'языков',
#  'Важность',
#  'концепции',
#  'ООР',
#  'для',
#  'более',
#  'широкого',
#  'использования',
#  'корпусной',
#  'лингводидактики',
#  'в',
#  'обучении',
#  'ИЯ',
#  'Несмотря',
#  'на',
#  'эффективность',
#  'использования',
#  'подходов',
#  'корпусной',
#  'лингвистики',
#  'в',
#  'обучении',
#  'ИЯ',
#  'как',
#  'показал',
#  'мета',
#  'анализ',
#  'проведенный',
#  'Болтоном',
#  'и',
#  'Коббом',
#  'и',
#  'давно',
#  'предсказанную',
#  'революцию',
#  'в',
#  'методах',
#  'обучения',
#  'ИЯ',
#  'благодаря',
#  'широкому',
#  'использованию',
#  'корпусов',
#  'этого',
#  'до',
#  'сих',
#  'пор',
#  'не',
#  'произошло',
#  'и',
#  'А',
#  'Чамбес',
#  'в',
#  'статье',
#  'г',
#  'обратила',
#  'внимание',
#  'на',
#  'необходимость',
#  'преодоления',
#  'разрыва',
#  'между',
#  'исследованиями',
#  'в',
#  'области',
#  'КЛ',
#  'и',
#  'методикой',
#  'преподавания',
#  'ИЯ',
#  'Разные',
#  'исследователи',
#  'называют',
#  'разные',
#  'причины',
#  'сложившейся',
#  'ситуации',
#  'Наша',
#  'попытка',
#  'проанализировать',
#  'их',
#  'привела',
#  'к',
#  'списку',
#  'из',
#  'причин',
#  'В',
#  'контексте',
#  'парадигмы',
#  'ООР',
#  'мы',
#  'остановимся',
#  'на',
#  'трех',
#  'проблемах',
#  'а',
#  'именно',
#  'недоступность',
#  'корпусов',
#  'описанных',
#  'в',
#  'статьях',
#  'недостаточная',
#  'подготовка',
#  'преподавателей',
#  'ИЯ',
#  'по',
#  'корпусной',
#  'лингводидактике',
#  'отсутствие',
#  'общедоступных',
#  'заданий',
#  'созданных',
#  'на',
#  'базе',
#  'находящихся',
#  'в',
#  'свободном',
#  'доступе',
#  'онлайн',
#  'корпусов',
#  'для',
#  'непосредственного',
#  'использования',
#  'в',
#  'учебном',
#  'процессе',
#  'Одним',
#  'из',
#  'препятствий',
#  'к',
#  'более',
#  'широкому',
#  'распространению',
#  'подходов',
#  'описанных',
#  'в',
#  'статьях',
#  'является',
#  'то',
#  'что',
#  'многие',
#  'исследования',
#  'выполнены',
#  'на',
#  'корпусах',
#  'составленных',
#  'специально',
#  'для',
#  'целей',
#  'исследования',
#  'и',
#  'потому',
#  'недоступных',
#  'для',
#  'научной',
#  'и',
#  'педагогической',
#  'общественности',
#  'В',
#  'свободном',
#  'доступе',
#  'находится',
#  'достаточно',
#  'большое',
#  'количество',
#  'больших',
#  'корпусов',
#  'в',
#  'первую',
#  'очередь',
#  'национальные',
#  'корпуса',
#  'НКРЯ',
#  'представительный',
#  'список',
#  'онлайн',
#  'корпусов',
#  'доступен',
#  'в',
#  'разделе',
#  'Другие',
#  'корпуса',
#  'сайта',
#  'НКРИ',
#  'с',
#  'указанием',
#  'режима',
#  'обращения',
#  'доступен',
#  'для',
#  'онлайн',
#  'поиска',
#  'требуется',
#  'регистрация',
#  'доступен',
#  'для',
#  'скачивания',
#  'Проблемой',
#  'однако',
#  'является',
#  'отсутствие',
#  'доступного',
#  'банка',
#  'упражнений',
#  'которые',
#  'преподаватель',
#  'мог',
#  'бы',
#  'использовать',
#  'при',
#  'изучении',
#  'той',
#  'или',
#  'иной',
#  'темы',
#  'Многочисленные',
#  'примеры',
#  'использования',
#  'корпусов',
#  'в',
#  'обучении',
#  'ИЯ',
#  'опубликованы',
#  'в',
#  'научных',
#  'статьях',
#  'и',
#  'материалах',
#  'конференций',
#  'но',
#  'доступ',
#  'к',
#  'ним',
#  'обычному',
#  'преподавателю',
#  'вуза',
#  'не',
#  'говоря',
#  'уже',
#  'об',
#  'учителях',
#  'средней',
#  'школы',
#  'затруднен',
#  'эти',
#  'публикации',
#  'нигде',
#  'не',
#  'каталогизированы',
#  'и',
#  'не',
#  'описаны',
#  'с',
#  'точки',
#  'зрения',
#  'имеющихся',
#  'в',
#  'них',
#  'корпусных',
#  'заданий',
#  'определенного',
#  'типа',
#  'В',
#  'качестве',
#  'примера',
#  'можно',
#  'сослаться',
#  'на',
#  'недавние',
#  'публикации',
#  'на',
#  'материале',
#  'Национального',
#  'корпуса',
#  'русского',
#  'языка',
#  'Изданные',
#  'немногочисленные',
#  'пособия',
#  'с',
#  'поисковыми',
#  'заданиями',
#  'как',
#  'правило',
#  'не',
#  'относятся',
#  'к',
#  'открытым',
#  'ресурсам',
#  'например',
#  'а',
#  'находящиеся',
#  'в',
#  'открытом',
#  'доступе',
#  'меняют',
#  'свой',
#  'адрес',
#  'Так',
#  'магистерская',
#  'диссертация',
#  'Е',
#  'М',
#  'Шоу',
#  'с',
#  'сайта',
#  'СОСА',
#  'где',
#  'она',
#  'находилась',
#  'вплоть',
#  'до',
#  'весны',
#  'г',
#  'переместилась',
#  'в',
#  'архив',
#  'университета',
#  'Бригама',
#  'Янга',
#  'Если',
#  'преподаватель',
#  'в',
#  'теме',
#  'то',
#  'он',
#  'вынужден',
#  'метаться',
#  'между',
#  'корпусом',
#  'и',
#  'разными',
#  'источниками',
#  'с',
#  'упражнениями',
#  'По',
#  'мнению',
#  'Н',
#  'Вяткиной',
#  'доступные',
#  'онлайн',
#  'корпуса',
#  'английского',
#  'языка',
#  'и',
#  'других',
#  'языков',
#  'не',
#  'содержат',
#  'как',
#  'инструкций',
#  'по',
#  'их',
#  'использованию',
#  'для',
#  'обучения',
#  'ИЯ',
#  'так',
#  'и',
#  'разработанных',
#  'заданий',
#  'системы',
#  'упражнений',
#  'привязанных',
#  'к',
#  'конкретному',
#  'корпусу',
#  'Проблемой',
#  'является',
#  'и',
#  'недостаточная',
#  'подготовка',
#  'преподавателей',
#  'ИЯ',
#  'в',
#  'области',
#  'корпусной',
#  'лингвистики',
#  'и',
#  'корпусной',
#  'лингводидактики',
#  'Проблема',
#  'серьезна',
#  'и',
#  'простых',
#  'путей',
#  'ее',
#  'решения',
#  'кажется',
#  'не',
#  'существует',
#  'В',
#  'нашем',
#  'исследовании',
#  'имевшем',
#  'целью',
#  'оценить',
#  'влияние',
#  'корпусной',
#  'лингвистики',
#  'на',
#  'систему',
#  'высшего',
#  'образования',
#  'в',
#  'России',
#  'мы',
#  'пришли',
#  'к',
#  'выводу',
#  'что',
#  'на',
#  'современном',
#  'этапе',
#  'в',
#  'соответствии',
#  'с',
#  'требованиями',
#  'ФГОС',
#  'все',
#  'студенты',
#  'филологических',
#  'специальностей',
#  'получают',
#  'базовые',
#  'знания',
#  'о',
#  'корпусной',
#  'лингвистике',
#  'некоторые',
#  'имеют',
#  'публикации',
#  'по',
#  'теме',
#  'использования',
#  'подходов',
#  'корпусной',
#  'лингвистики',
#  'в',
#  'обучении',
#  'ИЯ',
#  'зарегистрированные',
#  'наукометрических',
#  'базах',
#  'данных',
#  'разного',
#  'ранга',
#  'Однако',
#  'открытым',
#  'остается',
#  'вопрос',
#  'насколько',
#  'они',
#  'готовы',
#  'регулярно',
#  'использовать',
#  'эти',
#  'знания',
#  'в',
#  'практической',
#  'деятельности',
#  'после',
#  'окончания',
#  'обучения',
#  'А',
#  'Ленко',
#  'Шиманска',
#  'считает',
#  'что',
#  'элективного',
#  'односеместрового',
#  'специального',
#  'курса',
#  'по',
#  'использованию',
#  'корпусов',
#  'и',
#  'подходов',
#  'КЛ',
#  'в',
#  'обучении',
#  'ИЯ',
#  'недостаточно',
#  'для',
#  'того',
#  'чтобы',
#  'будущие',
#  'преподаватели',
#  'ИЯ',
#  'могли',
#  'успешно',
#  'интегрировать',
#  'подходы',
#  'КЛ',
#  'в',
#  'собственную',
#  'педагогическую',
#  'практику',
#  'Исследователь',
#  'предполагает',
#  'что',
#  'ситуация',
#  'улучшится',
#  'если',
#  'студенты',
#  'будут',
#  'изучать',
#  'возможности',
#  'корпусной',
#  'лингвистики',
#  'наряду',
#  'с',
#  'другими',
#  'подходами',
#  'в',
#  'курсе',
#  'методики',
#  'обучения',
#  'ИЯ',
#  'и',
#  'использовать',
#  'их',
#  'при',
#  'изучении',
#  'других',
#  'теоретических',
#  'и',
#  'практических',
#  'лингвистических',
#  'дисциплин',
#  'Для',
#  'мотивированных',
#  'будущих',
#  'и',
#  'действующих',
#  'преподавателей',
#  'ИЯ',
#  'желающих',
#  'освоить',
#  'основы',
#  'КЛ',
#  'и',
#  'способы',
#  'ее',
#  'применения',
#  'в',
#  'обучении',
#  'ИЯ',
#  'самостоятельно',
#  'доступны',
#  'разные',
#  'способы',
#  'которые',
#  'мы',
#  'рассмотрим',
#  'в',
#  'следующем',
#  'разделе',
#  'Обзор',
#  'открытых',
#  'образовательных',
#  'ресурсов',
#  'для',
#  'повышения',
#  'квалификации',
#  'по',
#  'КЛ',
#  'Есть',
#  'целый',
#  'ряд',
#  'образовательных',
#  'ресурсов',
#  'находящихся',
#  'в',
#  'свободном',
#  'открытом',
#  'доступе',
#  'которые',
#  'можно',
#  'использовать',
#  'для',
#  'самообразования',
#  'в',
#  'области',
#  'корпусной',
#  'лингвистики',
#  'Мы',
#  'рассмотрим',
#  'коллекции',
#  'МООК',
#  'курсы',
#  'и',
#  'записи',
#  'вебинаров',
#  'организованные',
#  'ведущими',
#  'центрами',
#  'по',
#  'корпусной',
#  'лингвистике',
#  'Начнем',
#  'с',
#  'обзора',
#  'видеоресурсов',
#  'по',
#  'корпусной',
#  'лингвистике',
#  'доступных',
#  'на',
#  'По',
#  'запросу',
#  'выдает',
#  'целый',
#  'ряд',
#  'ссылок',
#  'на',
#  'отдельные',
#  'ролики',
#  'и',
#  'на',
#  'целые',
#  'серии',
#  'в',
#  'которых',
#  'последовательно',
#  'объясняются',
#  'основы',
#  ...]

# %%
text_words_1
# Out:
# ['корпусная',
#  'лингводидактика',
#  'в',
#  'контексте',
#  'парадигмы',
#  'открытых',
#  'образовательных',
#  'ресурсов',
#  'м',
#  'с',
#  'коган',
#  'введение',
#  'развитие',
#  'интернета',
#  'и',
#  'информационного',
#  'общества',
#  'привело',
#  'к',
#  'появлению',
#  'важного',
#  'тренда',
#  'на',
#  'открытое',
#  'образование',
#  'науку',
#  'информацию',
#  'инициатором',
#  'этого',
#  'движения',
#  'считается',
#  'майкл',
#  'стерн',
#  'харт',
#  'изобретатель',
#  'электронных',
#  'книг',
#  'и',
#  'основатель',
#  'проекта',
#  'гутенберг',
#  'в',
#  'е',
#  'годы',
#  'прошлого',
#  'века',
#  'в',
#  'хх',
#  'веке',
#  'этот',
#  'тренд',
#  'задала',
#  'будапештская',
#  'инициатива',
#  'открытый',
#  'доступ',
#  'к',
#  'которой',
#  'с',
#  'тех',
#  'присоединились',
#  'тысячи',
#  'организаций',
#  'в',
#  'этом',
#  'документе',
#  'открытый',
#  'доступ',
#  'определялся',
#  'как',
#  'открытые',
#  'для',
#  'всех',
#  'публикации',
#  'в',
#  'интернете',
#  'которые',
#  'можно',
#  'читать',
#  'разгружать',
#  'копировать',
#  'распространять',
#  'распечатывать',
#  'находить',
#  'или',
#  'присоединять',
#  'к',
#  'полным',
#  'текстам',
#  'соответствующих',
#  'статей',
#  'использовать',
#  'для',
#  'составления',
#  'указателей',
#  'вводить',
#  'их',
#  'как',
#  'данные',
#  'в',
#  'программное',
#  'обеспечение',
#  'или',
#  'использовать',
#  'для',
#  'других',
#  'законных',
#  'целей',
#  'при',
#  'отсутствии',
#  'финансовых',
#  'правовых',
#  'и',
#  'технических',
#  'преград',
#  'при',
#  'соблюдении',
#  'целостности',
#  'работы',
#  'и',
#  'обязательной',
#  'ссылке',
#  'на',
#  'имя',
#  'автора',
#  'при',
#  'использовании',
#  'и',
#  'цитировании',
#  'в',
#  'последующие',
#  'годы',
#  'будапештская',
#  'инициатива',
#  'получила',
#  'развитие',
#  'в',
#  'многочисленных',
#  'документах',
#  'оон',
#  'и',
#  'юнеско',
#  'например',
#  'в',
#  'рекомендациях',
#  'по',
#  'развитию',
#  'и',
#  'продвижению',
#  'открытого',
#  'доступа',
#  'рекомендациях',
#  'по',
#  'открытой',
#  'науке',
#  'по',
#  'работе',
#  'с',
#  'открытыми',
#  'образовательными',
#  'ресурсами',
#  'оор',
#  'в',
#  'сфере',
#  'высшего',
#  'образования',
#  'об',
#  'открытых',
#  'образовательных',
#  'ресурсах',
#  'а',
#  'также',
#  'рекомендациях',
#  'по',
#  'развитию',
#  'практик',
#  'использования',
#  'оор',
#  'и',
#  'т',
#  'д',
#  'исследования',
#  'касающиеся',
#  'влияния',
#  'открытого',
#  'образования',
#  'на',
#  'изучение',
#  'и',
#  'преподавание',
#  'иностранных',
#  'языков',
#  'собраны',
#  'в',
#  'томе',
#  'находящемся',
#  'в',
#  'открытом',
#  'доступе',
#  'открытые',
#  'образовательные',
#  'ресурсы',
#  'обладают',
#  'рядом',
#  'характеристик',
#  'важнейшими',
#  'из',
#  'которых',
#  'являются',
#  'бесплатный',
#  'доступ',
#  'право',
#  'на',
#  'использование',
#  'адаптацию',
#  'и',
#  'распространение',
#  'третьими',
#  'лицами',
#  'без',
#  'ограничений',
#  'или',
#  'с',
#  'незначительными',
#  'ограничениями',
#  'некоторые',
#  'исследователи',
#  'дополняют',
#  'список',
#  'характеристик',
#  'понятия',
#  'открытость',
#  'до',
#  'пунктов',
#  'обзор',
#  'исследований',
#  'принципов',
#  'и',
#  'характеристик',
#  'оор',
#  'можно',
#  'найти',
#  'в',
#  'статье',
#  'космас',
#  'с',
#  'коллегами',
#  'одна',
#  'из',
#  'характеристик',
#  'открытой',
#  'науки',
#  'прозрачность',
#  'контроль',
#  'критический',
#  'анализ',
#  'и',
#  'воспроизводимость',
#  'результатов',
#  'в',
#  'целях',
#  'усиления',
#  'надежности',
#  'и',
#  'точности',
#  'научных',
#  'результатов',
#  'а',
#  'также',
#  'воздействия',
#  'науки',
#  'на',
#  'общество',
#  'с',
#  'специалисты',
#  'в',
#  'области',
#  'прикладной',
#  'и',
#  'корпусной',
#  'лингвистики',
#  'говорят',
#  'о',
#  'кризисе',
#  'воспроизводимости',
#  'см',
#  'например',
#  'анализируя',
#  'тенденции',
#  'развития',
#  'исследований',
#  'в',
#  'области',
#  'обучения',
#  'ия',
#  'с',
#  'использованием',
#  'подходов',
#  'корпусной',
#  'лингвистики',
#  'за',
#  'последние',
#  'лет',
#  'на',
#  'материале',
#  'публикаций',
#  'в',
#  'авторитетных',
#  'рецензируемых',
#  'англоязычных',
#  'журналах',
#  'глав',
#  'монографий',
#  'и',
#  'материалах',
#  'авторитетных',
#  'конференций',
#  'а',
#  'болтон',
#  'и',
#  'н',
#  'вяткина',
#  'обнаружили',
#  'полное',
#  'отсутствие',
#  'исследований',
#  'направленных',
#  'на',
#  'частичное',
#  'воспроизведение',
#  'повторение',
#  'классических',
#  'работ',
#  'в',
#  'новых',
#  'условиях',
#  'с',
#  'другими',
#  'категориями',
#  'обучающихся',
#  'следует',
#  'заметить',
#  'что',
#  'авторы',
#  'в',
#  'соответствии',
#  'с',
#  'принципами',
#  'открытой',
#  'науки',
#  'разместили',
#  'информацию',
#  'о',
#  'всех',
#  'отобранных',
#  'для',
#  'анализа',
#  'публикациях',
#  'в',
#  'открытом',
#  'доступе',
#  'в',
#  'онлайн',
#  'репозитории',
#  'инструментов',
#  'и',
#  'материалов',
#  'для',
#  'исследований',
#  'в',
#  'области',
#  'иностранных',
#  'языков',
#  'важность',
#  'концепции',
#  'оор',
#  'для',
#  'более',
#  'широкого',
#  'использования',
#  'корпусной',
#  'лингводидактики',
#  'в',
#  'обучении',
#  'ия',
#  'несмотря',
#  'на',
#  'эффективность',
#  'использования',
#  'подходов',
#  'корпусной',
#  'лингвистики',
#  'в',
#  'обучении',
#  'ия',
#  'как',
#  'показал',
#  'мета',
#  'анализ',
#  'проведенный',
#  'болтоном',
#  'и',
#  'коббом',
#  'и',
#  'давно',
#  'предсказанную',
#  'революцию',
#  'в',
#  'методах',
#  'обучения',
#  'ия',
#  'благодаря',
#  'широкому',
#  'использованию',
#  'корпусов',
#  'этого',
#  'до',
#  'сих',
#  'пор',
#  'не',
#  'произошло',
#  'и',
#  'а',
#  'чамбес',
#  'в',
#  'статье',
#  'г',
#  'обратила',
#  'внимание',
#  'на',
#  'необходимость',
#  'преодоления',
#  'разрыва',
#  'между',
#  'исследованиями',
#  'в',
#  'области',
#  'кл',
#  'и',
#  'методикой',
#  'преподавания',
#  'ия',
#  'разные',
#  'исследователи',
#  'называют',
#  'разные',
#  'причины',
#  'сложившейся',
#  'ситуации',
#  'наша',
#  'попытка',
#  'проанализировать',
#  'их',
#  'привела',
#  'к',
#  'списку',
#  'из',
#  'причин',
#  'в',
#  'контексте',
#  'парадигмы',
#  'оор',
#  'мы',
#  'остановимся',
#  'на',
#  'трех',
#  'проблемах',
#  'а',
#  'именно',
#  'недоступность',
#  'корпусов',
#  'описанных',
#  'в',
#  'статьях',
#  'недостаточная',
#  'подготовка',
#  'преподавателей',
#  'ия',
#  'по',
#  'корпусной',
#  'лингводидактике',
#  'отсутствие',
#  'общедоступных',
#  'заданий',
#  'созданных',
#  'на',
#  'базе',
#  'находящихся',
#  'в',
#  'свободном',
#  'доступе',
#  'онлайн',
#  'корпусов',
#  'для',
#  'непосредственного',
#  'использования',
#  'в',
#  'учебном',
#  'процессе',
#  'одним',
#  'из',
#  'препятствий',
#  'к',
#  'более',
#  'широкому',
#  'распространению',
#  'подходов',
#  'описанных',
#  'в',
#  'статьях',
#  'является',
#  'то',
#  'что',
#  'многие',
#  'исследования',
#  'выполнены',
#  'на',
#  'корпусах',
#  'составленных',
#  'специально',
#  'для',
#  'целей',
#  'исследования',
#  'и',
#  'потому',
#  'недоступных',
#  'для',
#  'научной',
#  'и',
#  'педагогической',
#  'общественности',
#  'в',
#  'свободном',
#  'доступе',
#  'находится',
#  'достаточно',
#  'большое',
#  'количество',
#  'больших',
#  'корпусов',
#  'в',
#  'первую',
#  'очередь',
#  'национальные',
#  'корпуса',
#  'нкря',
#  'представительный',
#  'список',
#  'онлайн',
#  'корпусов',
#  'доступен',
#  'в',
#  'разделе',
#  'другие',
#  'корпуса',
#  'сайта',
#  'нкри',
#  'с',
#  'указанием',
#  'режима',
#  'обращения',
#  'доступен',
#  'для',
#  'онлайн',
#  'поиска',
#  'требуется',
#  'регистрация',
#  'доступен',
#  'для',
#  'скачивания',
#  'проблемой',
#  'однако',
#  'является',
#  'отсутствие',
#  'доступного',
#  'банка',
#  'упражнений',
#  'которые',
#  'преподаватель',
#  'мог',
#  'бы',
#  'использовать',
#  'при',
#  'изучении',
#  'той',
#  'или',
#  'иной',
#  'темы',
#  'многочисленные',
#  'примеры',
#  'использования',
#  'корпусов',
#  'в',
#  'обучении',
#  'ия',
#  'опубликованы',
#  'в',
#  'научных',
#  'статьях',
#  'и',
#  'материалах',
#  'конференций',
#  'но',
#  'доступ',
#  'к',
#  'ним',
#  'обычному',
#  'преподавателю',
#  'вуза',
#  'не',
#  'говоря',
#  'уже',
#  'об',
#  'учителях',
#  'средней',
#  'школы',
#  'затруднен',
#  'эти',
#  'публикации',
#  'нигде',
#  'не',
#  'каталогизированы',
#  'и',
#  'не',
#  'описаны',
#  'с',
#  'точки',
#  'зрения',
#  'имеющихся',
#  'в',
#  'них',
#  'корпусных',
#  'заданий',
#  'определенного',
#  'типа',
#  'в',
#  'качестве',
#  'примера',
#  'можно',
#  'сослаться',
#  'на',
#  'недавние',
#  'публикации',
#  'на',
#  'материале',
#  'национального',
#  'корпуса',
#  'русского',
#  'языка',
#  'изданные',
#  'немногочисленные',
#  'пособия',
#  'с',
#  'поисковыми',
#  'заданиями',
#  'как',
#  'правило',
#  'не',
#  'относятся',
#  'к',
#  'открытым',
#  'ресурсам',
#  'например',
#  'а',
#  'находящиеся',
#  'в',
#  'открытом',
#  'доступе',
#  'меняют',
#  'свой',
#  'адрес',
#  'так',
#  'магистерская',
#  'диссертация',
#  'е',
#  'м',
#  'шоу',
#  'с',
#  'сайта',
#  'соса',
#  'где',
#  'она',
#  'находилась',
#  'вплоть',
#  'до',
#  'весны',
#  'г',
#  'переместилась',
#  'в',
#  'архив',
#  'университета',
#  'бригама',
#  'янга',
#  'если',
#  'преподаватель',
#  'в',
#  'теме',
#  'то',
#  'он',
#  'вынужден',
#  'метаться',
#  'между',
#  'корпусом',
#  'и',
#  'разными',
#  'источниками',
#  'с',
#  'упражнениями',
#  'по',
#  'мнению',
#  'н',
#  'вяткиной',
#  'доступные',
#  'онлайн',
#  'корпуса',
#  'английского',
#  'языка',
#  'и',
#  'других',
#  'языков',
#  'не',
#  'содержат',
#  'как',
#  'инструкций',
#  'по',
#  'их',
#  'использованию',
#  'для',
#  'обучения',
#  'ия',
#  'так',
#  'и',
#  'разработанных',
#  'заданий',
#  'системы',
#  'упражнений',
#  'привязанных',
#  'к',
#  'конкретному',
#  'корпусу',
#  'проблемой',
#  'является',
#  'и',
#  'недостаточная',
#  'подготовка',
#  'преподавателей',
#  'ия',
#  'в',
#  'области',
#  'корпусной',
#  'лингвистики',
#  'и',
#  'корпусной',
#  'лингводидактики',
#  'проблема',
#  'серьезна',
#  'и',
#  'простых',
#  'путей',
#  'ее',
#  'решения',
#  'кажется',
#  'не',
#  'существует',
#  'в',
#  'нашем',
#  'исследовании',
#  'имевшем',
#  'целью',
#  'оценить',
#  'влияние',
#  'корпусной',
#  'лингвистики',
#  'на',
#  'систему',
#  'высшего',
#  'образования',
#  'в',
#  'россии',
#  'мы',
#  'пришли',
#  'к',
#  'выводу',
#  'что',
#  'на',
#  'современном',
#  'этапе',
#  'в',
#  'соответствии',
#  'с',
#  'требованиями',
#  'фгос',
#  'все',
#  'студенты',
#  'филологических',
#  'специальностей',
#  'получают',
#  'базовые',
#  'знания',
#  'о',
#  'корпусной',
#  'лингвистике',
#  'некоторые',
#  'имеют',
#  'публикации',
#  'по',
#  'теме',
#  'использования',
#  'подходов',
#  'корпусной',
#  'лингвистики',
#  'в',
#  'обучении',
#  'ия',
#  'зарегистрированные',
#  'наукометрических',
#  'базах',
#  'данных',
#  'разного',
#  'ранга',
#  'однако',
#  'открытым',
#  'остается',
#  'вопрос',
#  'насколько',
#  'они',
#  'готовы',
#  'регулярно',
#  'использовать',
#  'эти',
#  'знания',
#  'в',
#  'практической',
#  'деятельности',
#  'после',
#  'окончания',
#  'обучения',
#  'а',
#  'ленко',
#  'шиманска',
#  'считает',
#  'что',
#  'элективного',
#  'односеместрового',
#  'специального',
#  'курса',
#  'по',
#  'использованию',
#  'корпусов',
#  'и',
#  'подходов',
#  'кл',
#  'в',
#  'обучении',
#  'ия',
#  'недостаточно',
#  'для',
#  'того',
#  'чтобы',
#  'будущие',
#  'преподаватели',
#  'ия',
#  'могли',
#  'успешно',
#  'интегрировать',
#  'подходы',
#  'кл',
#  'в',
#  'собственную',
#  'педагогическую',
#  'практику',
#  'исследователь',
#  'предполагает',
#  'что',
#  'ситуация',
#  'улучшится',
#  'если',
#  'студенты',
#  'будут',
#  'изучать',
#  'возможности',
#  'корпусной',
#  'лингвистики',
#  'наряду',
#  'с',
#  'другими',
#  'подходами',
#  'в',
#  'курсе',
#  'методики',
#  'обучения',
#  'ия',
#  'и',
#  'использовать',
#  'их',
#  'при',
#  'изучении',
#  'других',
#  'теоретических',
#  'и',
#  'практических',
#  'лингвистических',
#  'дисциплин',
#  'для',
#  'мотивированных',
#  'будущих',
#  'и',
#  'действующих',
#  'преподавателей',
#  'ия',
#  'желающих',
#  'освоить',
#  'основы',
#  'кл',
#  'и',
#  'способы',
#  'ее',
#  'применения',
#  'в',
#  'обучении',
#  'ия',
#  'самостоятельно',
#  'доступны',
#  'разные',
#  'способы',
#  'которые',
#  'мы',
#  'рассмотрим',
#  'в',
#  'следующем',
#  'разделе',
#  'обзор',
#  'открытых',
#  'образовательных',
#  'ресурсов',
#  'для',
#  'повышения',
#  'квалификации',
#  'по',
#  'кл',
#  'есть',
#  'целый',
#  'ряд',
#  'образовательных',
#  'ресурсов',
#  'находящихся',
#  'в',
#  'свободном',
#  'открытом',
#  'доступе',
#  'которые',
#  'можно',
#  'использовать',
#  'для',
#  'самообразования',
#  'в',
#  'области',
#  'корпусной',
#  'лингвистики',
#  'мы',
#  'рассмотрим',
#  'коллекции',
#  'моок',
#  'курсы',
#  'и',
#  'записи',
#  'вебинаров',
#  'организованные',
#  'ведущими',
#  'центрами',
#  'по',
#  'корпусной',
#  'лингвистике',
#  'начнем',
#  'с',
#  'обзора',
#  'видеоресурсов',
#  'по',
#  'корпусной',
#  'лингвистике',
#  'доступных',
#  'на',
#  'по',
#  'запросу',
#  'выдает',
#  'целый',
#  'ряд',
#  'ссылок',
#  'на',
#  'отдельные',
#  'ролики',
#  'и',
#  'на',
#  'целые',
#  'серии',
#  'в',
#  'которых',
#  'последовательно',
#  'объясняются',
#  'основы',
#  ...]

# %%
with open('swl.txt', 'r', encoding='utf8') as swl:
    swlist = []  # список стоп-слов из файла
    for i in swl:
        i = i.replace('\n','')
        swlist.append(i)
        # print(swlist)

len(swlist)
# Out:
# 936

# %%
text_words = []
for i in text_words_1:
    #i = morph.parse(i)[0].normal_form
    if i not in swlist:
        text_words.append(i)

text_words
# Out:
# ['корпусная',
#  'лингводидактика',
#  'контексте',
#  'парадигмы',
#  'открытых',
#  'образовательных',
#  'ресурсов',
#  'коган',
#  'введение',
#  'развитие',
#  'интернета',
#  'информационного',
#  'общества',
#  'привело',
#  'появлению',
#  'важного',
#  'тренда',
#  'открытое',
#  'образование',
#  'науку',
#  'информацию',
#  'инициатором',
#  'этого',
#  'движения',
#  'считается',
#  'майкл',
#  'стерн',
#  'харт',
#  'изобретатель',
#  'электронных',
#  'книг',
#  'основатель',
#  'проекта',
#  'гутенберг',
#  'е',
#  'годы',
#  'прошлого',
#  'века',
#  'хх',
#  'веке',
#  'тренд',
#  'задала',
#  'будапештская',
#  'инициатива',
#  'открытый',
#  'доступ',
#  'которой',
#  'тех',
#  'присоединились',
#  'тысячи',
#  'организаций',
#  'этом',
#  'документе',
#  'открытый',
#  'доступ',
#  'определялся',
#  'открытые',
#  'всех',
#  'публикации',
#  'интернете',
#  'которые',
#  'можно',
#  'читать',
#  'разгружать',
#  'копировать',
#  'распространять',
#  'распечатывать',
#  'находить',
#  'присоединять',
#  'полным',
#  'текстам',
#  'соответствующих',
#  'статей',
#  'использовать',
#  'составления',
#  'указателей',
#  'вводить',
#  'данные',
#  'программное',
#  'обеспечение',
#  'использовать',
#  'других',
#  'законных',
#  'целей',
#  'отсутствии',
#  'финансовых',
#  'правовых',
#  'технических',
#  'преград',
#  'соблюдении',
#  'целостности',
#  'работы',
#  'обязательной',
#  'ссылке',
#  'имя',
#  'автора',
#  'использовании',
#  'цитировании',
#  'последующие',
#  'годы',
#  'будапештская',
#  'инициатива',
#  'получила',
#  'развитие',
#  'многочисленных',
#  'документах',
#  'оон',
#  'юнеско',
#  'например',
#  'рекомендациях',
#  'развитию',
#  'продвижению',
#  'открытого',
#  'доступа',
#  'рекомендациях',
#  'открытой',
#  'науке',
#  'работе',
#  'открытыми',
#  'образовательными',
#  'ресурсами',
#  'оор',
#  'сфере',
#  'высшего',
#  'образования',
#  'открытых',
#  'образовательных',
#  'ресурсах',
#  'рекомендациях',
#  'развитию',
#  'практик',
#  'использования',
#  'оор',
#  'т',
#  'д',
#  'исследования',
#  'касающиеся',
#  'влияния',
#  'открытого',
#  'образования',
#  'изучение',
#  'преподавание',
#  'иностранных',
#  'языков',
#  'собраны',
#  'томе',
#  'находящемся',
#  'открытом',
#  'доступе',
#  'открытые',
#  'образовательные',
#  'ресурсы',
#  'обладают',
#  'рядом',
#  'характеристик',
#  'важнейшими',
#  'которых',
#  'являются',
#  'бесплатный',
#  'доступ',
#  'право',
#  'использование',
#  'адаптацию',
#  'распространение',
#  'третьими',
#  'лицами',
#  'ограничений',
#  'незначительными',
#  'ограничениями',
#  'исследователи',
#  'дополняют',
#  'список',
#  'характеристик',
#  'понятия',
#  'открытость',
#  'пунктов',
#  'обзор',
#  'исследований',
#  'принципов',
#  'характеристик',
#  'оор',
#  'можно',
#  'найти',
#  'статье',
#  'космас',
#  'коллегами',
#  'одна',
#  'характеристик',
#  'открытой',
#  'науки',
#  'прозрачность',
#  'контроль',
#  'критический',
#  'анализ',
#  'воспроизводимость',
#  'результатов',
#  'целях',
#  'усиления',
#  'надежности',
#  'точности',
#  'научных',
#  'результатов',
#  'воздействия',
#  'науки',
#  'общество',
#  'специалисты',
#  'области',
#  'прикладной',
#  'корпусной',
#  'лингвистики',
#  'говорят',
#  'кризисе',
#  'воспроизводимости',
#  'см',
#  'например',
#  'анализируя',
#  'тенденции',
#  'развития',
#  'исследований',
#  'области',
#  'обучения',
#  'ия',
#  'использованием',
#  'подходов',
#  'корпусной',
#  'лингвистики',
#  'последние',
#  'лет',
#  'материале',
#  'публикаций',
#  'авторитетных',
#  'рецензируемых',
#  'англоязычных',
#  'журналах',
#  'глав',
#  'монографий',
#  'материалах',
#  'авторитетных',
#  'конференций',
#  'болтон',
#  'н',
#  'вяткина',
#  'обнаружили',
#  'полное',
#  'отсутствие',
#  'исследований',
#  'направленных',
#  'частичное',
#  'воспроизведение',
#  'повторение',
#  'классических',
#  'работ',
#  'новых',
#  'условиях',
#  'другими',
#  'категориями',
#  'обучающихся',
#  'следует',
#  'заметить',
#  'авторы',
#  'соответствии',
#  'принципами',
#  'открытой',
#  'науки',
#  'разместили',
#  'информацию',
#  'всех',
#  'отобранных',
#  'анализа',
#  'публикациях',
#  'открытом',
#  'доступе',
#  'онлайн',
#  'репозитории',
#  'инструментов',
#  'материалов',
#  'исследований',
#  'области',
#  'иностранных',
#  'языков',
#  'важность',
#  'концепции',
#  'оор',
#  'широкого',
#  'использования',
#  'корпусной',
#  'лингводидактики',
#  'обучении',
#  'ия',
#  'несмотря',
#  'эффективность',
#  'использования',
#  'подходов',
#  'корпусной',
#  'лингвистики',
#  'обучении',
#  'ия',
#  'показал',
#  'мета',
#  'анализ',
#  'проведенный',
#  'болтоном',
#  'коббом',
#  'давно',
#  'предсказанную',
#  'революцию',
#  'методах',
#  'обучения',
#  'ия',
#  'широкому',
#  'использованию',
#  'корпусов',
#  'этого',
#  'сих',
#  'пор',
#  'произошло',
#  'чамбес',
#  'статье',
#  'г',
#  'обратила',
#  'внимание',
#  'необходимость',
#  'преодоления',
#  'разрыва',
#  'исследованиями',
#  'области',
#  'кл',
#  'методикой',
#  'преподавания',
#  'ия',
#  'разные',
#  'исследователи',
#  'называют',
#  'разные',
#  'причины',
#  'сложившейся',
#  'ситуации',
#  'наша',
#  'попытка',
#  'проанализировать',
#  'привела',
#  'списку',
#  'причин',
#  'контексте',
#  'парадигмы',
#  'оор',
#  'остановимся',
#  'трех',
#  'проблемах',
#  'недоступность',
#  'корпусов',
#  'описанных',
#  'статьях',
#  'недостаточная',
#  'подготовка',
#  'преподавателей',
#  'ия',
#  'корпусной',
#  'лингводидактике',
#  'отсутствие',
#  'общедоступных',
#  'заданий',
#  'созданных',
#  'базе',
#  'находящихся',
#  'свободном',
#  'доступе',
#  'онлайн',
#  'корпусов',
#  'непосредственного',
#  'использования',
#  'учебном',
#  'процессе',
#  'одним',
#  'препятствий',
#  'широкому',
#  'распространению',
#  'подходов',
#  'описанных',
#  'статьях',
#  'является',
#  'исследования',
#  'выполнены',
#  'корпусах',
#  'составленных',
#  'специально',
#  'целей',
#  'исследования',
#  'недоступных',
#  'научной',
#  'педагогической',
#  'общественности',
#  'свободном',
#  'доступе',
#  'находится',
#  'достаточно',
#  'большое',
#  'количество',
#  'больших',
#  'корпусов',
#  'первую',
#  'очередь',
#  'национальные',
#  'корпуса',
#  'нкря',
#  'представительный',
#  'список',
#  'онлайн',
#  'корпусов',
#  'доступен',
#  'разделе',
#  'корпуса',
#  'сайта',
#  'нкри',
#  'указанием',
#  'режима',
#  'обращения',
#  'доступен',
#  'онлайн',
#  'поиска',
#  'требуется',
#  'регистрация',
#  'доступен',
#  'скачивания',
#  'проблемой',
#  'является',
#  'отсутствие',
#  'доступного',
#  'банка',
#  'упражнений',
#  'которые',
#  'преподаватель',
#  'мог',
#  'использовать',
#  'изучении',
#  'темы',
#  'многочисленные',
#  'примеры',
#  'использования',
#  'корпусов',
#  'обучении',
#  'ия',
#  'опубликованы',
#  'научных',
#  'статьях',
#  'материалах',
#  'конференций',
#  'доступ',
#  'ним',
#  'обычному',
#  'преподавателю',
#  'вуза',
#  'говоря',
#  'уже',
#  'учителях',
#  'средней',
#  'школы',
#  'затруднен',
#  'эти',
#  'публикации',
#  'каталогизированы',
#  'описаны',
#  'точки',
#  'зрения',
#  'имеющихся',
#  'них',
#  'корпусных',
#  'заданий',
#  'определенного',
#  'качестве',
#  'примера',
#  'можно',
#  'сослаться',
#  'недавние',
#  'публикации',
#  'материале',
#  'национального',
#  'корпуса',
#  'русского',
#  'языка',
#  'изданные',
#  'немногочисленные',
#  'пособия',
#  'поисковыми',
#  'заданиями',
#  'правило',
#  'относятся',
#  'открытым',
#  'ресурсам',
#  'например',
#  'находящиеся',
#  'открытом',
#  'доступе',
#  'меняют',
#  'адрес',
#  'магистерская',
#  'диссертация',
#  'е',
#  'шоу',
#  'сайта',
#  'соса',
#  'находилась',
#  'вплоть',
#  'весны',
#  'г',
#  'переместилась',
#  'архив',
#  'университета',
#  'бригама',
#  'янга',
#  'преподаватель',
#  'теме',
#  'вынужден',
#  'метаться',
#  'корпусом',
#  'разными',
#  'источниками',
#  'упражнениями',
#  'мнению',
#  'н',
#  'вяткиной',
#  'доступные',
#  'онлайн',
#  'корпуса',
#  'английского',
#  'языка',
#  'других',
#  'языков',
#  'содержат',
#  'инструкций',
#  'использованию',
#  'обучения',
#  'ия',
#  'разработанных',
#  'заданий',
#  'системы',
#  'упражнений',
#  'привязанных',
#  'конкретному',
#  'корпусу',
#  'проблемой',
#  'является',
#  'недостаточная',
#  'подготовка',
#  'преподавателей',
#  'ия',
#  'области',
#  'корпусной',
#  'лингвистики',
#  'корпусной',
#  'лингводидактики',
#  'проблема',
#  'серьезна',
#  'простых',
#  'путей',
#  'решения',
#  'кажется',
#  'существует',
#  'нашем',
#  'исследовании',
#  'имевшем',
#  'целью',
#  'оценить',
#  'влияние',
#  'корпусной',
#  'лингвистики',
#  'систему',
#  'высшего',
#  'образования',
#  'россии',
#  'пришли',
#  'выводу',
#  'современном',
#  'этапе',
#  'соответствии',
#  'требованиями',
#  'фгос',
#  'студенты',
#  'филологических',
#  'специальностей',
#  'получают',
#  'базовые',
#  'знания',
#  'корпусной',
#  'лингвистике',
#  'имеют',
#  'публикации',
#  'теме',
#  'использования',
#  'подходов',
#  'корпусной',
#  'лингвистики',
#  'обучении',
#  'ия',
#  'зарегистрированные',
#  'наукометрических',
#  'базах',
#  'данных',
#  'разного',
#  'ранга',
#  'открытым',
#  'остается',
#  'вопрос',
#  'насколько',
#  'готовы',
#  'регулярно',
#  'использовать',
#  'эти',
#  'знания',
#  'практической',
#  'деятельности',
#  'окончания',
#  'обучения',
#  'ленко',
#  'шиманска',
#  'считает',
#  'элективного',
#  'односеместрового',
#  'специального',
#  'курса',
#  'использованию',
#  'корпусов',
#  'подходов',
#  'кл',
#  'обучении',
#  'ия',
#  'недостаточно',
#  'того',
#  'будущие',
#  'преподаватели',
#  'ия',
#  'могли',
#  'успешно',
#  'интегрировать',
#  'подходы',
#  'кл',
#  'собственную',
#  'педагогическую',
#  'практику',
#  'исследователь',
#  'предполагает',
#  'ситуация',
#  'улучшится',
#  'студенты',
#  'будут',
#  'изучать',
#  'возможности',
#  'корпусной',
#  'лингвистики',
#  'наряду',
#  'другими',
#  'подходами',
#  'курсе',
#  'методики',
#  'обучения',
#  'ия',
#  'использовать',
#  'изучении',
#  'других',
#  'теоретических',
#  'практических',
#  'лингвистических',
#  'дисциплин',
#  'мотивированных',
#  'будущих',
#  'действующих',
#  'преподавателей',
#  'ия',
#  'желающих',
#  'освоить',
#  'основы',
#  'кл',
#  'способы',
#  'применения',
#  'обучении',
#  'ия',
#  'самостоятельно',
#  'доступны',
#  'разные',
#  'способы',
#  'которые',
#  'рассмотрим',
#  'следующем',
#  'разделе',
#  'обзор',
#  'открытых',
#  'образовательных',
#  'ресурсов',
#  'повышения',
#  'квалификации',
#  'кл',
#  'есть',
#  'целый',
#  'ряд',
#  'образовательных',
#  'ресурсов',
#  'находящихся',
#  'свободном',
#  'открытом',
#  'доступе',
#  'которые',
#  'можно',
#  'использовать',
#  'самообразования',
#  'области',
#  'корпусной',
#  'лингвистики',
#  'рассмотрим',
#  'коллекции',
#  'моок',
#  'курсы',
#  'записи',
#  'вебинаров',
#  'организованные',
#  'ведущими',
#  'центрами',
#  'корпусной',
#  'лингвистике',
#  'начнем',
#  'обзора',
#  'видеоресурсов',
#  'корпусной',
#  'лингвистике',
#  'доступных',
#  'запросу',
#  'выдает',
#  'целый',
#  'ряд',
#  'ссылок',
#  'отдельные',
#  'ролики',
#  'целые',
#  'серии',
#  'которых',
#  'последовательно',
#  'объясняются',
#  'основы',
#  'этой',
#  'дисциплины',
#  'например',
#  'яссин',
#  'иабдунан',
#  'разместил',
#  'своем',
#  'канале',
#  'последние',
#  'года',
#  'уже',
#  'роликов',
#  'продолжительностью',
#  'мин',
#  'элен',
#  'фолл',
#  'выложила',
#  'роликов',
#  'наиболее',
#  'популярными',
#  'набравшими',
#  'год',
#  'просмотров',
#  'являются',
#  'ролики',
#  'освоению',
#  'созданию',
#  'собственного',
#  'специального',
#  'корпуса',
#  'корпусе',
#  'разработчики',
#  'крупных',
#  'корпусов',
#  'имеют',
#  'свои',
#  'каналы',
#  'разместил',
#  'ролика',
#  'продолжительность',
#  'обучающих',
#  'видео',
#  'колеблется',
#  'л',
#  'антони',
#  'своем',
#  'канале',
#  'разместил',
#  'видео',
#  'роликов',
#  'объясняющих',
#  'использовать',
#  'основные',
#  'функции',
#  'программы',
#  'версии',
#  'широкоизвестного',
#  'корпусного',
#  'менеджера',
#  'разработал',
#  'длительность',
#  'видео',
#  'колеблется',
#  'фолл',
#  'призывает',
#  'активно',
#  'создавать',
#  'небольшие',
#  'видео',
#  'делясь',
#  'них',
#  'собственным',
#  'опытом',
#  'применения',
#  'подходов',
#  'корпусной',
#  'лингвистики',
#  'обучении',
#  'ия',
#  'скрытыми',
#  'хитростями',
#  'работы',
#  'доступных',
#  'онлайн',
#  'корпусах',
#  'применения',
#  'корпусных',
#  'менеджеров',
#  'русскоязычном',
#  'сегменте',
#  'интернета',
#  'такие',
#  'материалы',
#  'практически',
#  'отсутствуют',
#  'массовые',
#  'открытые',
#  'онлайн',
#  'курсы',
#  'массовом',
#  'сознании',
#  'являются',
#  'примером',
#  'открытых',
#  'образовательных',
#  'ресурсов',
#  'специально',
#  'проведенный',
#  'анализ',
#  'сравнения',
#  'моок',
#  'курсов',
#  'оор',
#  'позволил',
#  'выявить',
#  'важные',
#  'отличия',
#  'этими',
#  'категориями',
#  'ресурсов',
#  'менее',
#  'доступность',
#  'делает',
#  'ценным',
#  'ресурсом',
#  'самообразования',
#  'наиболее',
#  'популярные',
#  'моок',
#  'курсы',
#  'корпусной',
#  'лингвистике',
#  'разработанный',
#  'ланкастерском',
#  'университете',
#  'т',
#  'макэнери',
#  'размещенный',
#  'платформе',
#  'моок',
#  'является',
#  'введением',
#  'кл',
#  'затрагивает',
#  'вопросы',
#  'обучения',
#  'ия',
#  'использованием',
#  'кл',
#  'знакомит',
#  'крупными',
#  'онлайн',
#  'корпусами',
#  'новым',
#  'корпусным',
#  'менеджером',
#  'разработанным',
#  'брезиной',
#  'введение',
#  'корпусную',
#  'лингвистику',
#  'курс',
#  'вшэ',
#  'представленный',
#  'левинзон',
#  'размещен',
#  'национальной',
#  'платформе',
#  'открытое',
#  'образование',
#  'курс',
#  'дает',
#  'представление',
#  'практическом',
#  'применении',
#  'достижений',
#  'современной',
#  'корпусной',
#  'лингвистики',
#  'учит',
#  'пользоваться',
#  'существующими',
#  'корпусами',
#  'русского',
#  'английского',
#  'языков',
#  'позволяет',
#  'освоить',
#  'базовые',
#  'методы',
#  'корпусного',
#  'преподавания',
#  'повседневной',
#  'работе',
#  'курс',
#  'относится',
#  'категории',
#  'маленький',
#  'частный',
#  'онлайн',
#  'курс',
#  'разработан',
#  'п',
#  'кроссвейтом',
#  'университете',
#  'квинсленда',
#  'размещен',
#  'платформе',
#  'целью',
#  'является',
#  'развитие',
#  'навыков',
#  'академического',
#  'письма',
#  'прямым',
#  'обращением',
#  'корпусу',
#  'задания',
#  'разработаны',
#  'основе',
#  'открытого',
#  'корпуса',
#  'коллекции',
#  'корпусов',
#  'апробация',
#  'курса',
#  'описана',
#  'статье',
#  'эту',
#  'группу',
#  'ресурсов',
#  'можно',
#  'включить',
#  'курс',
#  'разработанный',
#  'ленко',
#  'шиманска',
#  'студентов',
#  'варшавского',
#  'университета',
#  'находится',
#  'свободном',
#  'доступе',
#  'сайте',
#  'университета',
#  'целью',
#  'курса',
#  'является',
#  'знакомство',
#  'участников',
#  'базовыми',
#  'концепциями',
#  'корпус',
#  'анализ',
#  'корпуса',
#  'применение',
#  'корпусных',
#  'подходов',
#  'обучении',
#  'иностранным',
#  'родному',
#  'языку',
#  'развитие',
#  ...]

# %%
len(text_words)
# Out:
# 2412

# %%
frequency={}
for word in text_words:  # рассчитываем частоты слов
    count = frequency.get(word,0)  # создаём словарь СЛОВО и ЧАСТОТА
    frequency[word] = count + 1  # увеличиваем ЧАСТОТУ при считывании одинаковых лемм слова

frequency
# Out:
# {'корпусная': 2,
#  'лингводидактика': 1,
#  'контексте': 3,
#  'парадигмы': 2,
#  'открытых': 5,
#  'образовательных': 5,
#  'ресурсов': 6,
#  'коган': 1,
#  'введение': 4,
#  'развитие': 4,
#  'интернета': 3,
#  'информационного': 1,
#  'общества': 1,
#  'привело': 1,
#  'появлению': 1,
#  'важного': 1,
#  'тренда': 1,
#  'открытое': 3,
#  'образование': 3,
#  'науку': 2,
#  'информацию': 3,
#  'инициатором': 1,
#  'этого': 4,
#  'движения': 1,
#  'считается': 1,
#  'майкл': 1,
#  'стерн': 1,
#  'харт': 1,
#  'изобретатель': 1,
#  'электронных': 1,
#  'книг': 1,
#  'основатель': 1,
#  'проекта': 4,
#  'гутенберг': 1,
#  'е': 3,
#  'годы': 2,
#  'прошлого': 1,
#  'века': 1,
#  'хх': 1,
#  'веке': 1,
#  'тренд': 2,
#  'задала': 1,
#  'будапештская': 2,
#  'инициатива': 2,
#  'открытый': 2,
#  'доступ': 5,
#  'которой': 1,
#  'тех': 1,
#  'присоединились': 1,
#  'тысячи': 2,
#  'организаций': 1,
#  'этом': 1,
#  'документе': 1,
#  'определялся': 1,
#  'открытые': 3,
#  'всех': 2,
#  'публикации': 4,
#  'интернете': 1,
#  'которые': 7,
#  'можно': 8,
#  'читать': 1,
#  'разгружать': 1,
#  'копировать': 1,
#  'распространять': 1,
#  'распечатывать': 1,
#  'находить': 1,
#  'присоединять': 1,
#  'полным': 1,
#  'текстам': 1,
#  'соответствующих': 1,
#  'статей': 1,
#  'использовать': 9,
#  'составления': 2,
#  'указателей': 1,
#  'вводить': 1,
#  'данные': 1,
#  'программное': 1,
#  'обеспечение': 1,
#  'других': 6,
#  'законных': 1,
#  'целей': 3,
#  'отсутствии': 1,
#  'финансовых': 1,
#  'правовых': 1,
#  'технических': 1,
#  'преград': 1,
#  'соблюдении': 1,
#  'целостности': 1,
#  'работы': 6,
#  'обязательной': 1,
#  'ссылке': 1,
#  'имя': 1,
#  'автора': 2,
#  'использовании': 1,
#  'цитировании': 1,
#  'последующие': 1,
#  'получила': 1,
#  'многочисленных': 1,
#  'документах': 1,
#  'оон': 2,
#  'юнеско': 2,
#  'например': 10,
#  'рекомендациях': 3,
#  'развитию': 3,
#  'продвижению': 1,
#  'открытого': 3,
#  'доступа': 1,
#  'открытой': 3,
#  'науке': 1,
#  'работе': 4,
#  'открытыми': 2,
#  'образовательными': 2,
#  'ресурсами': 2,
#  'оор': 14,
#  'сфере': 1,
#  'высшего': 2,
#  'образования': 3,
#  'ресурсах': 2,
#  'практик': 1,
#  'использования': 8,
#  'т': 6,
#  'д': 6,
#  'исследования': 5,
#  'касающиеся': 1,
#  'влияния': 1,
#  'изучение': 2,
#  'преподавание': 1,
#  'иностранных': 3,
#  'языков': 7,
#  'собраны': 2,
#  'томе': 1,
#  'находящемся': 1,
#  'открытом': 5,
#  'доступе': 9,
#  'образовательные': 1,
#  'ресурсы': 2,
#  'обладают': 2,
#  'рядом': 1,
#  'характеристик': 5,
#  'важнейшими': 1,
#  'которых': 5,
#  'являются': 5,
#  'бесплатный': 1,
#  'право': 1,
#  'использование': 2,
#  'адаптацию': 1,
#  'распространение': 1,
#  'третьими': 1,
#  'лицами': 1,
#  'ограничений': 1,
#  'незначительными': 1,
#  'ограничениями': 1,
#  'исследователи': 3,
#  'дополняют': 2,
#  'список': 3,
#  'понятия': 1,
#  'открытость': 1,
#  'пунктов': 1,
#  'обзор': 3,
#  'исследований': 4,
#  'принципов': 1,
#  'найти': 1,
#  'статье': 4,
#  'космас': 1,
#  'коллегами': 1,
#  'одна': 1,
#  'науки': 3,
#  'прозрачность': 1,
#  'контроль': 1,
#  'критический': 1,
#  'анализ': 7,
#  'воспроизводимость': 1,
#  'результатов': 2,
#  'целях': 1,
#  'усиления': 1,
#  'надежности': 1,
#  'точности': 1,
#  'научных': 3,
#  'воздействия': 1,
#  'общество': 1,
#  'специалисты': 1,
#  'области': 8,
#  'прикладной': 2,
#  'корпусной': 29,
#  'лингвистики': 19,
#  'говорят': 1,
#  'кризисе': 1,
#  'воспроизводимости': 1,
#  'см': 1,
#  'анализируя': 1,
#  'тенденции': 1,
#  'развития': 4,
#  'обучения': 6,
#  'ия': 22,
#  'использованием': 8,
#  'подходов': 11,
#  'последние': 2,
#  'лет': 1,
#  'материале': 2,
#  'публикаций': 1,
#  'авторитетных': 2,
#  'рецензируемых': 1,
#  'англоязычных': 2,
#  'журналах': 1,
#  'глав': 1,
#  'монографий': 1,
#  'материалах': 4,
#  'конференций': 3,
#  'болтон': 2,
#  'н': 6,
#  'вяткина': 2,
#  'обнаружили': 1,
#  'полное': 1,
#  'отсутствие': 4,
#  'направленных': 1,
#  'частичное': 1,
#  'воспроизведение': 1,
#  'повторение': 1,
#  'классических': 1,
#  'работ': 1,
#  'новых': 5,
#  'условиях': 2,
#  'другими': 2,
#  'категориями': 2,
#  'обучающихся': 4,
#  'следует': 1,
#  'заметить': 1,
#  'авторы': 2,
#  'соответствии': 2,
#  'принципами': 1,
#  'разместили': 1,
#  'отобранных': 1,
#  'анализа': 1,
#  'публикациях': 1,
#  'онлайн': 13,
#  'репозитории': 1,
#  'инструментов': 2,
#  'материалов': 8,
#  'важность': 1,
#  'концепции': 1,
#  'широкого': 1,
#  'лингводидактики': 5,
#  'обучении': 9,
#  'несмотря': 1,
#  'эффективность': 1,
#  'показал': 3,
#  'мета': 1,
#  'проведенный': 3,
#  'болтоном': 1,
#  'коббом': 1,
#  'давно': 1,
#  'предсказанную': 1,
#  'революцию': 1,
#  'методах': 1,
#  'широкому': 4,
#  'использованию': 5,
#  'корпусов': 17,
#  'сих': 1,
#  'пор': 1,
#  'произошло': 1,
#  'чамбес': 1,
#  'г': 7,
#  'обратила': 1,
#  'внимание': 2,
#  'необходимость': 1,
#  'преодоления': 1,
#  'разрыва': 1,
#  'исследованиями': 1,
#  'кл': 8,
#  'методикой': 1,
#  'преподавания': 3,
#  'разные': 3,
#  'называют': 1,
#  'причины': 1,
#  'сложившейся': 1,
#  'ситуации': 1,
#  'наша': 1,
#  'попытка': 1,
#  'проанализировать': 1,
#  'привела': 1,
#  'списку': 1,
#  'причин': 1,
#  'остановимся': 1,
#  'трех': 1,
#  'проблемах': 1,
#  'недоступность': 1,
#  'описанных': 2,
#  'статьях': 5,
#  'недостаточная': 2,
#  'подготовка': 2,
#  'преподавателей': 8,
#  'лингводидактике': 1,
#  'общедоступных': 1,
#  'заданий': 10,
#  'созданных': 4,
#  'базе': 3,
#  'находящихся': 2,
#  'свободном': 5,
#  'непосредственного': 1,
#  'учебном': 1,
#  'процессе': 1,
#  'одним': 2,
#  'препятствий': 1,
#  'распространению': 1,
#  'является': 12,
#  'выполнены': 1,
#  'корпусах': 3,
#  'составленных': 1,
#  'специально': 2,
#  'недоступных': 1,
#  'научной': 1,
#  'педагогической': 3,
#  'общественности': 1,
#  'находится': 2,
#  'достаточно': 1,
#  'большое': 1,
#  'количество': 1,
#  'больших': 2,
#  'первую': 1,
#  'очередь': 1,
#  'национальные': 1,
#  'корпуса': 17,
#  'нкря': 7,
#  'представительный': 1,
#  'доступен': 4,
#  'разделе': 5,
#  'сайта': 3,
#  'нкри': 2,
#  'указанием': 1,
#  'режима': 2,
#  'обращения': 1,
#  'поиска': 2,
#  'требуется': 1,
#  'регистрация': 1,
#  'скачивания': 1,
#  'проблемой': 2,
#  'доступного': 1,
#  'банка': 1,
#  'упражнений': 2,
#  'преподаватель': 2,
#  'мог': 1,
#  'изучении': 2,
#  'темы': 3,
#  'многочисленные': 1,
#  'примеры': 5,
#  'опубликованы': 1,
#  'ним': 2,
#  'обычному': 1,
#  'преподавателю': 1,
#  'вуза': 1,
#  'говоря': 1,
#  'уже': 3,
#  'учителях': 1,
#  'средней': 4,
#  'школы': 5,
#  'затруднен': 1,
#  'эти': 5,
#  'каталогизированы': 1,
#  'описаны': 1,
#  'точки': 1,
#  'зрения': 1,
#  'имеющихся': 1,
#  'них': 2,
#  'корпусных': 7,
#  'определенного': 2,
#  'качестве': 3,
#  'примера': 1,
#  'сослаться': 1,
#  'недавние': 1,
#  'национального': 2,
#  'русского': 4,
#  'языка': 10,
#  'изданные': 1,
#  'немногочисленные': 1,
#  'пособия': 2,
#  'поисковыми': 1,
#  'заданиями': 4,
#  'правило': 2,
#  'относятся': 1,
#  'открытым': 2,
#  'ресурсам': 1,
#  'находящиеся': 2,
#  'меняют': 1,
#  'адрес': 1,
#  'магистерская': 1,
#  'диссертация': 1,
#  'шоу': 1,
#  'соса': 4,
#  'находилась': 1,
#  'вплоть': 1,
#  'весны': 1,
#  'переместилась': 1,
#  'архив': 1,
#  'университета': 7,
#  'бригама': 1,
#  'янга': 1,
#  'теме': 4,
#  'вынужден': 1,
#  'метаться': 1,
#  'корпусом': 4,
#  'разными': 1,
#  'источниками': 1,
#  'упражнениями': 1,
#  'мнению': 3,
#  'вяткиной': 4,
#  'доступные': 2,
#  'английского': 6,
#  'содержат': 1,
#  'инструкций': 1,
#  'разработанных': 3,
#  'системы': 1,
#  'привязанных': 1,
#  'конкретному': 2,
#  'корпусу': 6,
#  'проблема': 2,
#  'серьезна': 1,
#  'простых': 1,
#  'путей': 1,
#  'решения': 2,
#  'кажется': 1,
#  'существует': 1,
#  'нашем': 1,
#  'исследовании': 1,
#  'имевшем': 1,
#  'целью': 4,
#  'оценить': 1,
#  'влияние': 1,
#  'систему': 2,
#  'россии': 1,
#  'пришли': 1,
#  'выводу': 1,
#  'современном': 1,
#  'этапе': 1,
#  'требованиями': 1,
#  'фгос': 1,
#  'студенты': 2,
#  'филологических': 1,
#  'специальностей': 1,
#  'получают': 1,
#  'базовые': 2,
#  'знания': 2,
#  'лингвистике': 8,
#  'имеют': 2,
#  'зарегистрированные': 2,
#  'наукометрических': 1,
#  'базах': 1,
#  'данных': 2,
#  'разного': 1,
#  'ранга': 1,
#  'остается': 1,
#  'вопрос': 2,
#  'насколько': 1,
#  'готовы': 1,
#  'регулярно': 1,
#  'практической': 1,
#  'деятельности': 3,
#  'окончания': 1,
#  'ленко': 4,
#  'шиманска': 4,
#  'считает': 1,
#  'элективного': 1,
#  'односеместрового': 1,
#  'специального': 3,
#  'курса': 4,
#  'недостаточно': 1,
#  'того': 2,
#  'будущие': 1,
#  'преподаватели': 2,
#  'могли': 1,
#  'успешно': 1,
#  'интегрировать': 1,
#  'подходы': 2,
#  'собственную': 1,
#  'педагогическую': 2,
#  'практику': 2,
#  'исследователь': 1,
#  'предполагает': 1,
#  'ситуация': 1,
#  'улучшится': 1,
#  'будут': 1,
#  'изучать': 1,
#  'возможности': 1,
#  'наряду': 1,
#  'подходами': 2,
#  'курсе': 1,
#  'методики': 1,
#  'теоретических': 1,
#  'практических': 1,
#  'лингвистических': 1,
#  'дисциплин': 1,
#  'мотивированных': 1,
#  'будущих': 2,
#  'действующих': 1,
#  'желающих': 2,
#  'освоить': 2,
#  'основы': 2,
#  'способы': 3,
#  'применения': 4,
#  'самостоятельно': 2,
#  'доступны': 3,
#  'рассмотрим': 3,
#  'следующем': 1,
#  'повышения': 2,
#  'квалификации': 2,
#  'есть': 3,
#  'целый': 2,
#  'ряд': 3,
#  'самообразования': 4,
#  'коллекции': 3,
#  'моок': 4,
#  'курсы': 3,
#  'записи': 4,
#  'вебинаров': 6,
#  'организованные': 2,
#  'ведущими': 1,
#  'центрами': 1,
#  'начнем': 1,
#  'обзора': 1,
#  'видеоресурсов': 1,
#  'доступных': 3,
#  'запросу': 1,
#  'выдает': 1,
#  'ссылок': 1,
#  'отдельные': 2,
#  'ролики': 2,
#  'целые': 1,
#  'серии': 2,
#  'последовательно': 1,
#  'объясняются': 1,
#  'этой': 1,
#  'дисциплины': 1,
#  'яссин': 1,
#  'иабдунан': 1,
#  'разместил': 3,
#  'своем': 3,
#  'канале': 4,
#  'года': 1,
#  'роликов': 3,
#  'продолжительностью': 4,
#  'мин': 2,
#  'элен': 2,
#  'фолл': 3,
#  'выложила': 1,
#  'наиболее': 2,
#  'популярными': 1,
#  'набравшими': 1,
#  'год': 1,
#  'просмотров': 1,
#  'освоению': 1,
#  'созданию': 2,
#  'собственного': 2,
#  'корпусе': 2,
#  'разработчики': 1,
#  'крупных': 1,
#  'свои': 1,
#  'каналы': 1,
#  'ролика': 1,
#  'продолжительность': 1,
#  'обучающих': 1,
#  'видео': 13,
#  'колеблется': 2,
#  'л': 2,
#  'антони': 2,
#  'объясняющих': 1,
#  'основные': 2,
#  'функции': 4,
#  'программы': 3,
#  'версии': 3,
#  'широкоизвестного': 1,
#  'корпусного': 5,
#  'менеджера': 3,
#  'разработал': 1,
#  'длительность': 1,
#  'призывает': 1,
#  'активно': 1,
#  'создавать': 1,
#  'небольшие': 2,
#  'делясь': 1,
#  'собственным': 1,
#  'опытом': 1,
#  'скрытыми': 1,
#  'хитростями': 1,
#  'менеджеров': 1,
#  'русскоязычном': 2,
#  'сегменте': 2,
#  'такие': 1,
#  'материалы': 10,
#  'практически': 1,
#  'отсутствуют': 1,
#  'массовые': 1,
#  'массовом': 1,
#  'сознании': 1,
#  'примером': 3,
#  'сравнения': 1,
#  'курсов': 2,
#  'позволил': 1,
#  'выявить': 1,
#  'важные': 1,
#  'отличия': 1,
#  'этими': 1,
#  'менее': 1,
#  'доступность': 1,
#  'делает': 2,
#  'ценным': 1,
#  'ресурсом': 1,
#  'популярные': 1,
#  'разработанный': 2,
#  'ланкастерском': 2,
#  'университете': 4,
#  'макэнери': 2,
#  'размещенный': 1,
#  'платформе': 5,
#  'введением': 1,
#  'затрагивает': 1,
#  'вопросы': 1,
#  'знакомит': 1,
#  'крупными': 1,
#  'корпусами': 2,
#  'новым': 1,
#  'корпусным': 1,
#  'менеджером': 1,
#  'разработанным': 1,
#  'брезиной': 1,
#  'корпусную': 1,
#  'лингвистику': 1,
#  'курс': 5,
#  'вшэ': 2,
#  'представленный': 1,
#  'левинзон': 1,
#  'размещен': 2,
#  'национальной': 1,
#  'дает': 1,
#  'представление': 1,
#  'практическом': 1,
#  'применении': 1,
#  'достижений': 1,
#  'современной': 1,
#  'учит': 1,
#  'пользоваться': 1,
#  'существующими': 1,
#  'позволяет': 1,
#  'методы': 1,
#  'повседневной': 2,
#  'относится': 1,
#  'категории': 3,
#  'маленький': 1,
#  'частный': 1,
#  'разработан': 1,
#  'п': 4,
#  'кроссвейтом': 1,
#  'квинсленда': 3,
#  'навыков': 4,
#  'академического': 1,
#  'письма': 1,
#  'прямым': 1,
#  'обращением': 1,
#  'задания': 7,
#  'разработаны': 4,
#  'основе': 10,
#  'апробация': 2,
#  'описана': 2,
#  'эту': 3,
#  'группу': 1,
#  'включить': 1,
#  'студентов': 4,
#  'варшавского': 1,
#  'сайте': 6,
#  'знакомство': 1,
#  'участников': 1,
#  'базовыми': 2,
#  'концепциями': 1,
#  'корпус': 1,
#  'применение': 1,
#  'иностранным': 1,
#  'родному': 1,
#  'языку': 1,
#  'навыка': 1,
#  'создания': 2,
#  'учебных': 5,
#  'подхода': 1,
#  'важно': 3,
#  'изучаются': 3,
#  'общедоступные': 1,
#  'корпусные': 1,
#  'инструменты': 1,
#  'честь': 1,
#  'летия': 1,
#  'основания': 1,
#  'магистерской': 1,
#  'сан': 1,
#  'паолу': 1,
#  'бразилия': 1,
#  'руководители': 1,
#  'организовали': 1,
#  'серию': 1,
#  'пригласив': 1,
#  'участия': 1,
#  'всемирно': 1,
#  'известных': 3,
#  'ученых': 1,
#  'байбера': 1,
#  'скотта': 1,
#  'ю': 1,
#  'ромер': 1,
#  'дэвис': 1,
#  'р': 2,
#  'реппен': 1,
#  'др': 5,
#  'вебинары': 3,
#  'проходили': 2,
#  'еженедельно': 1,
#  'апреля': 1,
#  'сентябрь': 1,
#  'недели': 1,
#  'интенсива': 1,
#  'августе': 1,
#  'сентября': 1,
#  'течение': 2,
#  'проводилось': 1,
#  'мастер': 1,
#  'классов': 3,
#  'программных': 1,
#  'продуктов': 1,
#  'версий': 1,
#  'программ': 1,
#  'скотт': 1,
#  'представил': 1,
#  'последнюю': 1,
#  'версию': 1,
#  'которая': 4,
#  'момент': 1,
#  'была': 1,
#  'странице': 1,
#  'кафедры': 1,
#  'размещены': 2,
#  'презентации': 3,
#  'докладчиков': 2,
#  'осенью': 1,
#  'инициативу': 1,
#  'продолжили': 1,
#  'культур': 1,
#  'австралия': 1,
#  'октября': 1,
#  'апрель': 1,
#  'состоялся': 1,
#  'вебинар': 1,
#  'докладчиками': 1,
#  'были': 1,
#  'крупные': 1,
#  'разработки': 2,
#  'программного': 1,
#  'обеспечения': 1,
#  'франкенберг': 1,
#  'гарсия': 1,
#  'кроссвейт': 1,
#  'последний': 1,
#  'познакомил': 1,
#  'новой': 1,
#  'версией': 2,
#  'своего': 1,
#  'функционал': 1,
#  'которого': 1,
#  'существенно': 2,
#  'расширен': 1,
#  'сравнению': 1,
#  'кроссвейта': 1,
#  'ряде': 1,
#  'международных': 1,
#  'развернутое': 1,
#  'описание': 2,
#  'анонсы': 1,
#  'предстоящих': 1,
#  'событий': 2,
#  'публикуются': 1,
#  'социальных': 1,
#  'сетях': 1,
#  'таких': 2,
#  'группах': 2,
#  'фейсбуке': 1,
#  'посвящены': 1,
#  'лекции': 1,
#  'беседы': 2,
#  'плунгяна': 1,
#  'добровольского': 1,
#  'постнауке': 1,
#  'бузаджи': 1,
#  'захарова': 1,
#  'некоторых': 1,
#  'исследователей': 1,
#  'видеозаписи': 1,
#  'заседаний': 1,
#  'конференции': 2,
#  'лингвистика': 1,
#  'проходила': 1,
#  'дистанционном': 1,
#  'режиме': 1,
#  'кафедре': 2,
#  'математической': 1,
#  'спбгу': 1,
#  'обновленная': 1,
#  'мае': 1,
#  'версия': 1,
#  'содержит': 7,
#  'расширенный': 1,
#  'образовательный': 1,
#  'портал': 1,
#  'готовых': 1,
#  'предложение': 1,
#  'эффективности': 1,
#  'привязки': 2,
#  'планов': 6,
#  'уроков': 8,
#  'конкретным': 1,
#  'корпусам': 1,
#  'взгляд': 1,
#  'показаться': 1,
#  'неактуальна': 1,
#  'снабжены': 1,
#  'инструкциями': 2,
#  'пользователя': 2,
#  'внушительного': 1,
#  'объема': 1,
#  'инструкция': 3,
#  'никря': 1,
#  'стр': 2,
#  'дополнительными': 1,
#  'дополнительным': 1,
#  'инструментам': 2,
#  'просмотра': 1,
#  'указывает': 1,
#  'руководства': 1,
#  'далеки': 1,
#  'знакомых': 1,
#  'учителю': 1,
#  'инструкции': 2,
#  'должны': 2,
#  'базироваться': 1,
#  'педагогических': 1,
#  'принципах': 1,
#  'подразумевающих': 1,
#  'материала': 2,
#  'сопровождение': 1,
#  'вовлечение': 1,
#  'простого': 1,
#  'сложному': 1,
#  'большей': 1,
#  'поддержки': 2,
#  'стороны': 2,
#  'преподавателя': 2,
#  'заданиям': 1,
#  'выполняемым': 1,
#  'своих': 1,
#  'описывает': 1,
#  'обращений': 1,
#  'немецкого': 1,
#  'учащихся': 3,
#  'разным': 3,
#  'уровнем': 2,
#  'владения': 1,
#  'немецким': 1,
#  'языком': 1,
#  'начинающих': 1,
#  'продвинутых': 1,
#  'предполагающих': 1,
#  'разный': 1,
#  'формат': 2,
#  'индивидуальную': 1,
#  'работу': 2,
#  'парах': 1,
#  'малых': 1,
#  'преподавателем': 1,
#  'основным': 1,
#  'фокусом': 1,
#  'расширение': 2,
#  'словарного': 2,
#  'запаса': 2,
#  'могут': 2,
#  'включать': 1,
#  'освоение': 1,
#  'лексико': 1,
#  'грамматических': 1,
#  'слов': 5,
#  'помощью': 1,
#  'примеров': 3,
#  'верификация': 1,
#  'употребления': 2,
#  'словосочетаний': 1,
#  'учебниках': 2,
#  'примерами': 1,
#  'приведенные': 1,
#  'соответствуют': 1,
#  'базовый': 1,
#  'поиск': 1,
#  'временная': 1,
#  'ось': 1,
#  'визуализация': 1,
#  'коллокаций': 1,
#  'облако': 1,
#  'другим': 1,
#  'блестящим': 1,
#  'конкретного': 2,
#  'проект': 1,
#  'создаваемый': 1,
#  'руководством': 4,
#  'габласовой': 2,
#  'учебные': 6,
#  'привязаны': 1,
#  'большим': 1,
#  'выборкам': 1,
#  'устной': 1,
#  'речи': 4,
#  'х': 6,
#  'представляющих': 1,
#  'неформальные': 1,
#  'носителей': 2,
#  'британского': 1,
#  'варианта': 1,
#  'уроки': 3,
#  'готовящихся': 1,
#  'сдать': 1,
#  'итоговый': 1,
#  'экзамен': 1,
#  'курсу': 1,
#  'изучающих': 2,
#  'английский': 2,
#  'язык': 2,
#  'иностранный': 2,
#  'выборки': 1,
#  'представлены': 3,
#  'выпускников': 1,
#  'английских': 1,
#  'школ': 1,
#  'следующим': 1,
#  'рубрикам': 2,
#  'категориям': 2,
#  'рамках': 2,
#  'реальные': 1,
#  'явления': 2,
#  'современного': 1,
#  'отраженные': 1,
#  'английской': 1,
#  'грамматики': 2,
#  'изменение': 1,
#  'местоимения': 1,
#  'лица': 2,
#  'множественного': 3,
#  'числа': 3,
#  'выражения': 1,
#  'лице': 1,
#  'каждой': 2,
#  'включают': 1,
#  'раздаточные': 1,
#  'упражнения': 1,
#  'чтение': 1,
#  'абзаца': 1,
#  'иллюстрирующего': 1,
#  'конкордансных': 1,
#  'строк': 2,
#  'трансформация': 1,
#  'обсуждение': 1,
#  'предлагаемых': 1,
#  'обязательным': 1,
#  'изучаемого': 1,
#  'грамматического': 1,
#  'данном': 2,
#  'случае': 2,
#  'ед': 1,
#  'паролю': 1,
#  'файл': 1,
#  'ответами': 1,
#  'комментариями': 1,
#  'мультимедийный': 1,
#  'ресурс': 3,
#  'создан': 1,
#  'технологий': 1,
#  'млн': 1,
#  'аудиозаписей': 1,
#  'аудирования': 1,
#  'говорения': 1,
#  'каждую': 1,
#  'неделю': 1,
#  'добавляется': 1,
#  'контент': 1,
#  'отдельных': 1,
#  'указанным': 1,
#  'сложности': 2,
#  'мини': 5,
#  'категориях': 1,
#  'видеофрагмент': 1,
#  'длится': 1,
#  'минуты': 1,
#  'показ': 1,
#  'сопровождается': 1,
#  'субтитрами': 1,
#  'остановить': 1,
#  'любом': 1,
#  'месте': 1,
#  'прослушать': 2,
#  'незнакомое': 1,
#  'слово': 1,
#  ...}

# %%
freq = sorted(frequency.items(), key=lambda x:x[1], reverse = True) #создаём список, в котором пары СЛОВО и ЧАСТОТА упорядочены по убыванию
length = len(text_words)

print(length)
print(freq)
# Out:
# 2412
# [('корпусной', 29), ('ия', 22), ('лингвистики', 19), ('корпусов', 17), ('корпуса', 17), ('оор', 14), ('онлайн', 13), ('видео', 13), ('является', 12), ('подходов', 11), ('например', 10), ('заданий', 10), ('языка', 10), ('материалы', 10), ('основе', 10), ('урока', 10), ('использовать', 9), ('доступе', 9), ('обучении', 9), ('можно', 8), ('использования', 8), ('области', 8), ('использованием', 8), ('материалов', 8), ('кл', 8), ('преподавателей', 8), ('лингвистике', 8), ('уроков', 8), ('которые', 7), ('языков', 7), ('анализ', 7), ('г', 7), ('нкря', 7), ('корпусных', 7), ('университета', 7), ('задания', 7), ('содержит', 7), ('ресурсов', 6), ('других', 6), ('работы', 6), ('т', 6), ('д', 6), ('обучения', 6), ('н', 6), ('английского', 6), ('корпусу', 6), ('вебинаров', 6), ('сайте', 6), ('планов', 6), ('учебные', 6), ('х', 6), ('открытых', 5), ('образовательных', 5), ('доступ', 5), ('исследования', 5), ('открытом', 5), ('характеристик', 5), ('которых', 5), ('являются', 5), ('новых', 5), ('лингводидактики', 5), ('использованию', 5), ('статьях', 5), ('свободном', 5), ('разделе', 5), ('примеры', 5), ('школы', 5), ('эти', 5), ('корпусного', 5), ('платформе', 5), ('курс', 5), ('учебных', 5), ('др', 5), ('слов', 5), ('мини', 5), ('план', 5), ('й', 5), ('введение', 4), ('развитие', 4), ('этого', 4), ('проекта', 4), ('публикации', 4), ('работе', 4), ('исследований', 4), ('статье', 4), ('развития', 4), ('материалах', 4), ('отсутствие', 4), ('обучающихся', 4), ('широкому', 4), ('созданных', 4), ('доступен', 4), ('средней', 4), ('русского', 4), ('заданиями', 4), ('соса', 4), ('теме', 4), ('корпусом', 4), ('вяткиной', 4), ('целью', 4), ('ленко', 4), ('шиманска', 4), ('курса', 4), ('применения', 4), ('самообразования', 4), ('моок', 4), ('записи', 4), ('канале', 4), ('продолжительностью', 4), ('функции', 4), ('университете', 4), ('п', 4), ('навыков', 4), ('разработаны', 4), ('студентов', 4), ('которая', 4), ('руководством', 4), ('речи', 4), ('слова', 4), ('разных', 4), ('контексте', 3), ('интернета', 3), ('открытое', 3), ('образование', 3), ('информацию', 3), ('е', 3), ('открытые', 3), ('целей', 3), ('рекомендациях', 3), ('развитию', 3), ('открытого', 3), ('открытой', 3), ('образования', 3), ('иностранных', 3), ('исследователи', 3), ('список', 3), ('обзор', 3), ('науки', 3), ('научных', 3), ('конференций', 3), ('показал', 3), ('проведенный', 3), ('преподавания', 3), ('разные', 3), ('базе', 3), ('корпусах', 3), ('педагогической', 3), ('сайта', 3), ('темы', 3), ('уже', 3), ('качестве', 3), ('мнению', 3), ('разработанных', 3), ('деятельности', 3), ('специального', 3), ('способы', 3), ('доступны', 3), ('рассмотрим', 3), ('есть', 3), ('ряд', 3), ('коллекции', 3), ('курсы', 3), ('доступных', 3), ('разместил', 3), ('своем', 3), ('роликов', 3), ('фолл', 3), ('программы', 3), ('версии', 3), ('менеджера', 3), ('примером', 3), ('категории', 3), ('квинсленда', 3), ('эту', 3), ('важно', 3), ('изучаются', 3), ('известных', 3), ('вебинары', 3), ('классов', 3), ('презентации', 3), ('инструкция', 3), ('учащихся', 3), ('разным', 3), ('примеров', 3), ('уроки', 3), ('представлены', 3), ('множественного', 3), ('числа', 3), ('ресурс', 3), ('виде', 3), ('предложения', 3), ('видеосюжета', 3), ('вопроса', 3), ('своей', 3), ('практике', 3), ('корпусная', 2), ('парадигмы', 2), ('науку', 2), ('годы', 2), ('тренд', 2), ('будапештская', 2), ('инициатива', 2), ('открытый', 2), ('тысячи', 2), ('всех', 2), ('составления', 2), ('автора', 2), ('оон', 2), ('юнеско', 2), ('открытыми', 2), ('образовательными', 2), ('ресурсами', 2), ('высшего', 2), ('ресурсах', 2), ('изучение', 2), ('собраны', 2), ('ресурсы', 2), ('обладают', 2), ('использование', 2), ('дополняют', 2), ('результатов', 2), ('прикладной', 2), ('последние', 2), ('материале', 2), ('авторитетных', 2), ('англоязычных', 2), ('болтон', 2), ('вяткина', 2), ('условиях', 2), ('другими', 2), ('категориями', 2), ('авторы', 2), ('соответствии', 2), ('инструментов', 2), ('внимание', 2), ('описанных', 2), ('недостаточная', 2), ('подготов ...

# %%
n_list=[]
for words in freq:  # проверяем каждую пару СЛОВО и ЧАСТОТА в отсортированном тексте
    fr_lst = list(words) # превращаем пары в круглых скобках, созданные анонимной функцией LAMBDA, в список из двух элементов - СЛОВО и ЧАСТОТА
    n_list.append(fr_lst)

n_list
# Out:
# [['корпусной', 29],
#  ['ия', 22],
#  ['лингвистики', 19],
#  ['корпусов', 17],
#  ['корпуса', 17],
#  ['оор', 14],
#  ['онлайн', 13],
#  ['видео', 13],
#  ['является', 12],
#  ['подходов', 11],
#  ['например', 10],
#  ['заданий', 10],
#  ['языка', 10],
#  ['материалы', 10],
#  ['основе', 10],
#  ['урока', 10],
#  ['использовать', 9],
#  ['доступе', 9],
#  ['обучении', 9],
#  ['можно', 8],
#  ['использования', 8],
#  ['области', 8],
#  ['использованием', 8],
#  ['материалов', 8],
#  ['кл', 8],
#  ['преподавателей', 8],
#  ['лингвистике', 8],
#  ['уроков', 8],
#  ['которые', 7],
#  ['языков', 7],
#  ['анализ', 7],
#  ['г', 7],
#  ['нкря', 7],
#  ['корпусных', 7],
#  ['университета', 7],
#  ['задания', 7],
#  ['содержит', 7],
#  ['ресурсов', 6],
#  ['других', 6],
#  ['работы', 6],
#  ['т', 6],
#  ['д', 6],
#  ['обучения', 6],
#  ['н', 6],
#  ['английского', 6],
#  ['корпусу', 6],
#  ['вебинаров', 6],
#  ['сайте', 6],
#  ['планов', 6],
#  ['учебные', 6],
#  ['х', 6],
#  ['открытых', 5],
#  ['образовательных', 5],
#  ['доступ', 5],
#  ['исследования', 5],
#  ['открытом', 5],
#  ['характеристик', 5],
#  ['которых', 5],
#  ['являются', 5],
#  ['новых', 5],
#  ['лингводидактики', 5],
#  ['использованию', 5],
#  ['статьях', 5],
#  ['свободном', 5],
#  ['разделе', 5],
#  ['примеры', 5],
#  ['школы', 5],
#  ['эти', 5],
#  ['корпусного', 5],
#  ['платформе', 5],
#  ['курс', 5],
#  ['учебных', 5],
#  ['др', 5],
#  ['слов', 5],
#  ['мини', 5],
#  ['план', 5],
#  ['й', 5],
#  ['введение', 4],
#  ['развитие', 4],
#  ['этого', 4],
#  ['проекта', 4],
#  ['публикации', 4],
#  ['работе', 4],
#  ['исследований', 4],
#  ['статье', 4],
#  ['развития', 4],
#  ['материалах', 4],
#  ['отсутствие', 4],
#  ['обучающихся', 4],
#  ['широкому', 4],
#  ['созданных', 4],
#  ['доступен', 4],
#  ['средней', 4],
#  ['русского', 4],
#  ['заданиями', 4],
#  ['соса', 4],
#  ['теме', 4],
#  ['корпусом', 4],
#  ['вяткиной', 4],
#  ['целью', 4],
#  ['ленко', 4],
#  ['шиманска', 4],
#  ['курса', 4],
#  ['применения', 4],
#  ['самообразования', 4],
#  ['моок', 4],
#  ['записи', 4],
#  ['канале', 4],
#  ['продолжительностью', 4],
#  ['функции', 4],
#  ['университете', 4],
#  ['п', 4],
#  ['навыков', 4],
#  ['разработаны', 4],
#  ['студентов', 4],
#  ['которая', 4],
#  ['руководством', 4],
#  ['речи', 4],
#  ['слова', 4],
#  ['разных', 4],
#  ['контексте', 3],
#  ['интернета', 3],
#  ['открытое', 3],
#  ['образование', 3],
#  ['информацию', 3],
#  ['е', 3],
#  ['открытые', 3],
#  ['целей', 3],
#  ['рекомендациях', 3],
#  ['развитию', 3],
#  ['открытого', 3],
#  ['открытой', 3],
#  ['образования', 3],
#  ['иностранных', 3],
#  ['исследователи', 3],
#  ['список', 3],
#  ['обзор', 3],
#  ['науки', 3],
#  ['научных', 3],
#  ['конференций', 3],
#  ['показал', 3],
#  ['проведенный', 3],
#  ['преподавания', 3],
#  ['разные', 3],
#  ['базе', 3],
#  ['корпусах', 3],
#  ['педагогической', 3],
#  ['сайта', 3],
#  ['темы', 3],
#  ['уже', 3],
#  ['качестве', 3],
#  ['мнению', 3],
#  ['разработанных', 3],
#  ['деятельности', 3],
#  ['специального', 3],
#  ['способы', 3],
#  ['доступны', 3],
#  ['рассмотрим', 3],
#  ['есть', 3],
#  ['ряд', 3],
#  ['коллекции', 3],
#  ['курсы', 3],
#  ['доступных', 3],
#  ['разместил', 3],
#  ['своем', 3],
#  ['роликов', 3],
#  ['фолл', 3],
#  ['программы', 3],
#  ['версии', 3],
#  ['менеджера', 3],
#  ['примером', 3],
#  ['категории', 3],
#  ['квинсленда', 3],
#  ['эту', 3],
#  ['важно', 3],
#  ['изучаются', 3],
#  ['известных', 3],
#  ['вебинары', 3],
#  ['классов', 3],
#  ['презентации', 3],
#  ['инструкция', 3],
#  ['учащихся', 3],
#  ['разным', 3],
#  ['примеров', 3],
#  ['уроки', 3],
#  ['представлены', 3],
#  ['множественного', 3],
#  ['числа', 3],
#  ['ресурс', 3],
#  ['виде', 3],
#  ['предложения', 3],
#  ['видеосюжета', 3],
#  ['вопроса', 3],
#  ['своей', 3],
#  ['практике', 3],
#  ['корпусная', 2],
#  ['парадигмы', 2],
#  ['науку', 2],
#  ['годы', 2],
#  ['тренд', 2],
#  ['будапештская', 2],
#  ['инициатива', 2],
#  ['открытый', 2],
#  ['тысячи', 2],
#  ['всех', 2],
#  ['составления', 2],
#  ['автора', 2],
#  ['оон', 2],
#  ['юнеско', 2],
#  ['открытыми', 2],
#  ['образовательными', 2],
#  ['ресурсами', 2],
#  ['высшего', 2],
#  ['ресурсах', 2],
#  ['изучение', 2],
#  ['собраны', 2],
#  ['ресурсы', 2],
#  ['обладают', 2],
#  ['использование', 2],
#  ['дополняют', 2],
#  ['результатов', 2],
#  ['прикладной', 2],
#  ['последние', 2],
#  ['материале', 2],
#  ['авторитетных', 2],
#  ['англоязычных', 2],
#  ['болтон', 2],
#  ['вяткина', 2],
#  ['условиях', 2],
#  ['другими', 2],
#  ['категориями', 2],
#  ['авторы', 2],
#  ['соответствии', 2],
#  ['инструментов', 2],
#  ['внимание', 2],
#  ['описанных', 2],
#  ['недостаточная', 2],
#  ['подготовка', 2],
#  ['находящихся', 2],
#  ['одним', 2],
#  ['специально', 2],
#  ['находится', 2],
#  ['больших', 2],
#  ['нкри', 2],
#  ['режима', 2],
#  ['поиска', 2],
#  ['проблемой', 2],
#  ['упражнений', 2],
#  ['преподаватель', 2],
#  ['изучении', 2],
#  ['ним', 2],
#  ['них', 2],
#  ['определенного', 2],
#  ['национального', 2],
#  ['пособия', 2],
#  ['правило', 2],
#  ['открытым', 2],
#  ['находящиеся', 2],
#  ['доступные', 2],
#  ['конкретному', 2],
#  ['проблема', 2],
#  ['решения', 2],
#  ['систему', 2],
#  ['студенты', 2],
#  ['базовые', 2],
#  ['знания', 2],
#  ['имеют', 2],
#  ['зарегистрированные', 2],
#  ['данных', 2],
#  ['вопрос', 2],
#  ['того', 2],
#  ['преподаватели', 2],
#  ['подходы', 2],
#  ['педагогическую', 2],
#  ['практику', 2],
#  ['подходами', 2],
#  ['будущих', 2],
#  ['желающих', 2],
#  ['освоить', 2],
#  ['основы', 2],
#  ['самостоятельно', 2],
#  ['повышения', 2],
#  ['квалификации', 2],
#  ['целый', 2],
#  ['организованные', 2],
#  ['отдельные', 2],
#  ['ролики', 2],
#  ['серии', 2],
#  ['мин', 2],
#  ['элен', 2],
#  ['наиболее', 2],
#  ['созданию', 2],
#  ['собственного', 2],
#  ['корпусе', 2],
#  ['колеблется', 2],
#  ['л', 2],
#  ['антони', 2],
#  ['основные', 2],
#  ['небольшие', 2],
#  ['русскоязычном', 2],
#  ['сегменте', 2],
#  ['курсов', 2],
#  ['делает', 2],
#  ['разработанный', 2],
#  ['ланкастерском', 2],
#  ['макэнери', 2],
#  ['корпусами', 2],
#  ['вшэ', 2],
#  ['размещен', 2],
#  ['повседневной', 2],
#  ['апробация', 2],
#  ['описана', 2],
#  ['базовыми', 2],
#  ['создания', 2],
#  ['р', 2],
#  ['проходили', 2],
#  ['течение', 2],
#  ['размещены', 2],
#  ['докладчиков', 2],
#  ['разработки', 2],
#  ['версией', 2],
#  ['существенно', 2],
#  ['описание', 2],
#  ['событий', 2],
#  ['таких', 2],
#  ['группах', 2],
#  ['беседы', 2],
#  ['конференции', 2],
#  ['кафедре', 2],
#  ['привязки', 2],
#  ['инструкциями', 2],
#  ['пользователя', 2],
#  ['стр', 2],
#  ['инструментам', 2],
#  ['инструкции', 2],
#  ['должны', 2],
#  ['материала', 2],
#  ['поддержки', 2],
#  ['стороны', 2],
#  ['преподавателя', 2],
#  ['уровнем', 2],
#  ['формат', 2],
#  ['работу', 2],
#  ['расширение', 2],
#  ['словарного', 2],
#  ['запаса', 2],
#  ['могут', 2],
#  ['употребления', 2],
#  ['учебниках', 2],
#  ['конкретного', 2],
#  ['габласовой', 2],
#  ['носителей', 2],
#  ['изучающих', 2],
#  ['английский', 2],
#  ['язык', 2],
#  ['иностранный', 2],
#  ['рубрикам', 2],
#  ['категориям', 2],
#  ['рамках', 2],
#  ['явления', 2],
#  ['грамматики', 2],
#  ['лица', 2],
#  ['каждой', 2],
#  ['строк', 2],
#  ['данном', 2],
#  ['случае', 2],
#  ['сложности', 2],
#  ['прослушать', 2],
#  ['близких', 2],
#  ['автоматически', 2],
#  ['диктора', 2],
#  ['попытки', 2],
#  ['возможность', 2],
#  ['лексики', 2],
#  ['получить', 2],
#  ['последующей', 2],
#  ['задании', 2],
#  ['учащиеся', 2],
#  ['задание', 2],
#  ['формате', 2],
#  ['обучение', 2],
#  ['минут', 2],
#  ['письменных', 2],
#  ['студентами', 2],
#  ['методически', 2],
#  ['конкретной', 2],
#  ['старших', 2],
#  ['верные', 2],
#  ['школьников', 2],
#  ['требует', 2],
#  ['дальнейшего', 2],
#  ['идея', 2],
#  ['разработке', 2],
#  ['ма', 2],
#  ['определенной', 2],
#  ['думается', 2],
#  ['проектной', 2],
#  ['лингводидактика', 1],
#  ['коган', 1],
#  ['информационного', 1],
#  ['общества', 1],
#  ['привело', 1],
#  ['появлению', 1],
#  ['важного', 1],
#  ['тренда', 1],
#  ['инициатором', 1],
#  ['движения', 1],
#  ['считается', 1],
#  ['майкл', 1],
#  ['стерн', 1],
#  ['харт', 1],
#  ['изобретатель', 1],
#  ['электронных', 1],
#  ['книг', 1],
#  ['основатель', 1],
#  ['гутенберг', 1],
#  ['прошлого', 1],
#  ['века', 1],
#  ['хх', 1],
#  ['веке', 1],
#  ['задала', 1],
#  ['которой', 1],
#  ['тех', 1],
#  ['присоединились', 1],
#  ['организаций', 1],
#  ['этом', 1],
#  ['документе', 1],
#  ['определялся', 1],
#  ['интернете', 1],
#  ['читать', 1],
#  ['разгружать', 1],
#  ['копировать', 1],
#  ['распространять', 1],
#  ['распечатывать', 1],
#  ['находить', 1],
#  ['присоединять', 1],
#  ['полным', 1],
#  ['текстам', 1],
#  ['соответствующих', 1],
#  ['статей', 1],
#  ['указателей', 1],
#  ['вводить', 1],
#  ['данные', 1],
#  ['программное', 1],
#  ['обеспечение', 1],
#  ['законных', 1],
#  ['отсутствии', 1],
#  ['финансовых', 1],
#  ['правовых', 1],
#  ['технических', 1],
#  ['преград', 1],
#  ['соблюдении', 1],
#  ['целостности', 1],
#  ['обязательной', 1],
#  ['ссылке', 1],
#  ['имя', 1],
#  ['использовании', 1],
#  ['цитировании', 1],
#  ['последующие', 1],
#  ['получила', 1],
#  ['многочисленных', 1],
#  ['документах', 1],
#  ['продвижению', 1],
#  ['доступа', 1],
#  ['науке', 1],
#  ['сфере', 1],
#  ['практик', 1],
#  ['касающиеся', 1],
#  ['влияния', 1],
#  ['преподавание', 1],
#  ['томе', 1],
#  ['находящемся', 1],
#  ['образовательные', 1],
#  ['рядом', 1],
#  ['важнейшими', 1],
#  ['бесплатный', 1],
#  ['право', 1],
#  ['адаптацию', 1],
#  ['распространение', 1],
#  ['третьими', 1],
#  ['лицами', 1],
#  ['ограничений', 1],
#  ['незначительными', 1],
#  ['ограничениями', 1],
#  ['понятия', 1],
#  ['открытость', 1],
#  ['пунктов', 1],
#  ['принципов', 1],
#  ['найти', 1],
#  ['космас', 1],
#  ['коллегами', 1],
#  ['одна', 1],
#  ['прозрачность', 1],
#  ['контроль', 1],
#  ['критический', 1],
#  ['воспроизводимость', 1],
#  ['целях', 1],
#  ['усиления', 1],
#  ['надежности', 1],
#  ['точности', 1],
#  ['воздействия', 1],
#  ['общество', 1],
#  ['специалисты', 1],
#  ['говорят', 1],
#  ['кризисе', 1],
#  ['воспроизводимости', 1],
#  ['см', 1],
#  ['анализируя', 1],
#  ['тенденции', 1],
#  ['лет', 1],
#  ['публикаций', 1],
#  ['рецензируемых', 1],
#  ['журналах', 1],
#  ['глав', 1],
#  ['монографий', 1],
#  ['обнаружили', 1],
#  ['полное', 1],
#  ['направленных', 1],
#  ['частичное', 1],
#  ['воспроизведение', 1],
#  ['повторение', 1],
#  ['классических', 1],
#  ['работ', 1],
#  ['следует', 1],
#  ['заметить', 1],
#  ['принципами', 1],
#  ['разместили', 1],
#  ['отобранных', 1],
#  ['анализа', 1],
#  ['публикациях', 1],
#  ['репозитории', 1],
#  ['важность', 1],
#  ['концепции', 1],
#  ['широкого', 1],
#  ['несмотря', 1],
#  ['эффективность', 1],
#  ['мета', 1],
#  ['болтоном', 1],
#  ['коббом', 1],
#  ['давно', 1],
#  ['предсказанную', 1],
#  ['революцию', 1],
#  ['методах', 1],
#  ['сих', 1],
#  ['пор', 1],
#  ['произошло', 1],
#  ['чамбес', 1],
#  ['обратила', 1],
#  ['необходимость', 1],
#  ['преодоления', 1],
#  ['разрыва', 1],
#  ['исследованиями', 1],
#  ['методикой', 1],
#  ['называют', 1],
#  ['причины', 1],
#  ['сложившейся', 1],
#  ['ситуации', 1],
#  ['наша', 1],
#  ['попытка', 1],
#  ['проанализировать', 1],
#  ['привела', 1],
#  ['списку', 1],
#  ['причин', 1],
#  ['остановимся', 1],
#  ['трех', 1],
#  ['проблемах', 1],
#  ['недоступность', 1],
#  ['лингводидактике', 1],
#  ['общедоступных', 1],
#  ['непосредственного', 1],
#  ['учебном', 1],
#  ['процессе', 1],
#  ['препятствий', 1],
#  ['распространению', 1],
#  ['выполнены', 1],
#  ['составленных', 1],
#  ['недоступных', 1],
#  ['научной', 1],
#  ['общественности', 1],
#  ['достаточно', 1],
#  ['большое', 1],
#  ['количество', 1],
#  ['первую', 1],
#  ['очередь', 1],
#  ['национальные', 1],
#  ['представительный', 1],
#  ['указанием', 1],
#  ['обращения', 1],
#  ['требуется', 1],
#  ['регистрация', 1],
#  ['скачивания', 1],
#  ['доступного', 1],
#  ['банка', 1],
#  ['мог', 1],
#  ['многочисленные', 1],
#  ['опубликованы', 1],
#  ['обычному', 1],
#  ['преподавателю', 1],
#  ['вуза', 1],
#  ['говоря', 1],
#  ['учителях', 1],
#  ['затруднен', 1],
#  ['каталогизированы', 1],
#  ['описаны', 1],
#  ['точки', 1],
#  ['зрения', 1],
#  ['имеющихся', 1],
#  ['примера', 1],
#  ['сослаться', 1],
#  ['недавние', 1],
#  ['изданные', 1],
#  ['немногочисленные', 1],
#  ['поисковыми', 1],
#  ['относятся', 1],
#  ['ресурсам', 1],
#  ['меняют', 1],
#  ['адрес', 1],
#  ['магистерская', 1],
#  ['диссертация', 1],
#  ['шоу', 1],
#  ['находилась', 1],
#  ['вплоть', 1],
#  ['весны', 1],
#  ['переместилась', 1],
#  ['архив', 1],
#  ['бригама', 1],
#  ['янга', 1],
#  ['вынужден', 1],
#  ['метаться', 1],
#  ['разными', 1],
#  ['источниками', 1],
#  ['упражнениями', 1],
#  ['содержат', 1],
#  ['инструкций', 1],
#  ['системы', 1],
#  ['привязанных', 1],
#  ['серьезна', 1],
#  ['простых', 1],
#  ['путей', 1],
#  ['кажется', 1],
#  ['существует', 1],
#  ['нашем', 1],
#  ['исследовании', 1],
#  ['имевшем', 1],
#  ['оценить', 1],
#  ['влияние', 1],
#  ['россии', 1],
#  ['пришли', 1],
#  ['выводу', 1],
#  ['современном', 1],
#  ['этапе', 1],
#  ['требованиями', 1],
#  ['фгос', 1],
#  ['филологических', 1],
#  ['специальностей', 1],
#  ['получают', 1],
#  ['наукометрических', 1],
#  ['базах', 1],
#  ['разного', 1],
#  ['ранга', 1],
#  ['остается', 1],
#  ['насколько', 1],
#  ['готовы', 1],
#  ['регулярно', 1],
#  ['практической', 1],
#  ['окончания', 1],
#  ['считает', 1],
#  ['элективного', 1],
#  ['односеместрового', 1],
#  ['недостаточно', 1],
#  ['будущие', 1],
#  ['могли', 1],
#  ['успешно', 1],
#  ['интегрировать', 1],
#  ['собственную', 1],
#  ['исследователь', 1],
#  ['предполагает', 1],
#  ['ситуация', 1],
#  ['улучшится', 1],
#  ['будут', 1],
#  ['изучать', 1],
#  ['возможности', 1],
#  ['наряду', 1],
#  ['курсе', 1],
#  ['методики', 1],
#  ['теоретических', 1],
#  ['практических', 1],
#  ['лингвистических', 1],
#  ['дисциплин', 1],
#  ['мотивированных', 1],
#  ['действующих', 1],
#  ['следующем', 1],
#  ['ведущими', 1],
#  ['центрами', 1],
#  ['начнем', 1],
#  ['обзора', 1],
#  ['видеоресурсов', 1],
#  ['запросу', 1],
#  ['выдает', 1],
#  ['ссылок', 1],
#  ['целые', 1],
#  ['последовательно', 1],
#  ['объясняются', 1],
#  ['этой', 1],
#  ['дисциплины', 1],
#  ['яссин', 1],
#  ['иабдунан', 1],
#  ['года', 1],
#  ['выложила', 1],
#  ['популярными', 1],
#  ['набравшими', 1],
#  ['год', 1],
#  ['просмотров', 1],
#  ['освоению', 1],
#  ['разработчики', 1],
#  ['крупных', 1],
#  ['свои', 1],
#  ['каналы', 1],
#  ['ролика', 1],
#  ['продолжительность', 1],
#  ['обучающих', 1],
#  ['объясняющих', 1],
#  ['широкоизвестного', 1],
#  ['разработал', 1],
#  ['длительность', 1],
#  ['призывает', 1],
#  ['активно', 1],
#  ['создавать', 1],
#  ['делясь', 1],
#  ['собственным', 1],
#  ['опытом', 1],
#  ['скрытыми', 1],
#  ['хитростями', 1],
#  ['менеджеров', 1],
#  ['такие', 1],
#  ['практически', 1],
#  ['отсутствуют', 1],
#  ['массовые', 1],
#  ['массовом', 1],
#  ['сознании', 1],
#  ['сравнения', 1],
#  ['позволил', 1],
#  ['выявить', 1],
#  ['важные', 1],
#  ['отличия', 1],
#  ['этими', 1],
#  ['менее', 1],
#  ['доступность', 1],
#  ['ценным', 1],
#  ['ресурсом', 1],
#  ['популярные', 1],
#  ['размещенный', 1],
#  ['введением', 1],
#  ['затрагивает', 1],
#  ['вопросы', 1],
#  ['знакомит', 1],
#  ['крупными', 1],
#  ['новым', 1],
#  ['корпусным', 1],
#  ['менеджером', 1],
#  ['разработанным', 1],
#  ['брезиной', 1],
#  ['корпусную', 1],
#  ['лингвистику', 1],
#  ['представленный', 1],
#  ['левинзон', 1],
#  ['национальной', 1],
#  ['дает', 1],
#  ['представление', 1],
#  ['практическом', 1],
#  ['применении', 1],
#  ['достижений', 1],
#  ['современной', 1],
#  ['учит', 1],
#  ['пользоваться', 1],
#  ['существующими', 1],
#  ['позволяет', 1],
#  ['методы', 1],
#  ['относится', 1],
#  ['маленький', 1],
#  ['частный', 1],
#  ['разработан', 1],
#  ['кроссвейтом', 1],
#  ['академического', 1],
#  ['письма', 1],
#  ['прямым', 1],
#  ['обращением', 1],
#  ['группу', 1],
#  ['включить', 1],
#  ['варшавского', 1],
#  ['знакомство', 1],
#  ['участников', 1],
#  ['концепциями', 1],
#  ['корпус', 1],
#  ['применение', 1],
#  ['иностранным', 1],
#  ['родному', 1],
#  ['языку', 1],
#  ['навыка', 1],
#  ['подхода', 1],
#  ['общедоступные', 1],
#  ['корпусные', 1],
#  ['инструменты', 1],
#  ['честь', 1],
#  ['летия', 1],
#  ['основания', 1],
#  ['магистерской', 1],
#  ['сан', 1],
#  ['паолу', 1],
#  ['бразилия', 1],
#  ['руководители', 1],
#  ['организовали', 1],
#  ['серию', 1],
#  ['пригласив', 1],
#  ['участия', 1],
#  ['всемирно', 1],
#  ['ученых', 1],
#  ['байбера', 1],
#  ['скотта', 1],
#  ['ю', 1],
#  ['ромер', 1],
#  ['дэвис', 1],
#  ['реппен', 1],
#  ['еженедельно', 1],
#  ['апреля', 1],
#  ['сентябрь', 1],
#  ['недели', 1],
#  ['интенсива', 1],
#  ['августе', 1],
#  ['сентября', 1],
#  ['проводилось', 1],
#  ['мастер', 1],
#  ['программных', 1],
#  ['продуктов', 1],
#  ['версий', 1],
#  ['программ', 1],
#  ['скотт', 1],
#  ['представил', 1],
#  ['последнюю', 1],
#  ['версию', 1],
#  ['момент', 1],
#  ['была', 1],
#  ['странице', 1],
#  ['кафедры', 1],
#  ['осенью', 1],
#  ['инициативу', 1],
#  ['продолжили', 1],
#  ['культур', 1],
#  ['австралия', 1],
#  ['октября', 1],
#  ['апрель', 1],
#  ['состоялся', 1],
#  ['вебинар', 1],
#  ['докладчиками', 1],
#  ['были', 1],
#  ['крупные', 1],
#  ['программного', 1],
#  ['обеспечения', 1],
#  ['франкенберг', 1],
#  ['гарсия', 1],
#  ['кроссвейт', 1],
#  ['последний', 1],
#  ['познакомил', 1],
#  ['новой', 1],
#  ['своего', 1],
#  ['функционал', 1],
#  ['которого', 1],
#  ['расширен', 1],
#  ['сравнению', 1],
#  ['кроссвейта', 1],
#  ['ряде', 1],
#  ['международных', 1],
#  ['развернутое', 1],
#  ['анонсы', 1],
#  ['предстоящих', 1],
#  ['публикуются', 1],
#  ['социальных', 1],
#  ['сетях', 1],
#  ['фейсбуке', 1],
#  ['посвящены', 1],
#  ['лекции', 1],
#  ['плунгяна', 1],
#  ['добровольского', 1],
#  ['постнауке', 1],
#  ['бузаджи', 1],
#  ['захарова', 1],
#  ['некоторых', 1],
#  ['исследователей', 1],
#  ['видеозаписи', 1],
#  ['заседаний', 1],
#  ['лингвистика', 1],
#  ['проходила', 1],
#  ['дистанционном', 1],
#  ['режиме', 1],
#  ['математической', 1],
#  ['спбгу', 1],
#  ['обновленная', 1],
#  ['мае', 1],
#  ['версия', 1],
#  ['расширенный', 1],
#  ['образовательный', 1],
#  ['портал', 1],
#  ['готовых', 1],
#  ['предложение', 1],
#  ['эффективности', 1],
#  ['конкретным', 1],
#  ['корпусам', 1],
#  ['взгляд', 1],
#  ['показаться', 1],
#  ['неактуальна', 1],
#  ['снабжены', 1],
#  ['внушительного', 1],
#  ['объема', 1],
#  ['никря', 1],
#  ['дополнительными', 1],
#  ['дополнительным', 1],
#  ['просмотра', 1],
#  ['указывает', 1],
#  ['руководства', 1],
#  ['далеки', 1],
#  ['знакомых', 1],
#  ['учителю', 1],
#  ['базироваться', 1],
#  ['педагогических', 1],
#  ['принципах', 1],
#  ['подразумевающих', 1],
#  ['сопровождение', 1],
#  ['вовлечение', 1],
#  ['простого', 1],
#  ['сложному', 1],
#  ['большей', 1],
#  ['заданиям', 1],
#  ['выполняемым', 1],
#  ['своих', 1],
#  ['описывает', 1],
#  ['обращений', 1],
#  ['немецкого', 1],
#  ['владения', 1],
#  ['немецким', 1],
#  ['языком', 1],
#  ['начинающих', 1],
#  ['продвинутых', 1],
#  ['предполагающих', 1],
#  ['разный', 1],
#  ['индивидуальную', 1],
#  ['парах', 1],
#  ['малых', 1],
#  ['преподавателем', 1],
#  ['основным', 1],
#  ['фокусом', 1],
#  ['включать', 1],
#  ['освоение', 1],
#  ['лексико', 1],
#  ['грамматических', 1],
#  ['помощью', 1],
#  ['верификация', 1],
#  ['словосочетаний', 1],
#  ['примерами', 1],
#  ['приведенные', 1],
#  ['соответствуют', 1],
#  ['базовый', 1],
#  ['поиск', 1],
#  ['временная', 1],
#  ['ось', 1],
#  ['визуализация', 1],
#  ['коллокаций', 1],
#  ['облако', 1],
#  ['другим', 1],
#  ['блестящим', 1],
#  ['проект', 1],
#  ['создаваемый', 1],
#  ['привязаны', 1],
#  ['большим', 1],
#  ['выборкам', 1],
#  ['устной', 1],
#  ['представляющих', 1],
#  ['неформальные', 1],
#  ['британского', 1],
#  ['варианта', 1],
#  ['готовящихся', 1],
#  ['сдать', 1],
#  ['итоговый', 1],
#  ['экзамен', 1],
#  ['курсу', 1],
#  ['выборки', 1],
#  ['выпускников', 1],
#  ['английских', 1],
#  ['школ', 1],
#  ['следующим', 1],
#  ['реальные', 1],
#  ['современного', 1],
#  ['отраженные', 1],
#  ['английской', 1],
#  ['изменение', 1],
#  ['местоимения', 1],
#  ['выражения', 1],
#  ['лице', 1],
#  ['включают', 1],
#  ['раздаточные', 1],
#  ['упражнения', 1],
#  ...]

# %%
k = 1
for i in n_list:
    logfr = math.log(int(i[1]),10)
    logrank = math.log(k, 10)  # берём десятичные логарифмы для ранга и для частоты
    i.append(k)
    i.append(logfr)
    i.append(logrank)
    k+=1

# %%
n_list
# Out:
# [['корпусной', 29, 1, 1.462397997898956, 0.0],
#  ['ия', 22, 2, 1.3424226808222062, 0.30102999566398114],
#  ['лингвистики', 19, 3, 1.2787536009528289, 0.47712125471966244],
#  ['корпусов', 17, 4, 1.2304489213782739, 0.6020599913279623],
#  ['корпуса', 17, 5, 1.2304489213782739, 0.6989700043360187],
#  ['оор', 14, 6, 1.1461280356782377, 0.7781512503836435],
#  ['онлайн', 13, 7, 1.1139433523068367, 0.8450980400142567],
#  ['видео', 13, 8, 1.1139433523068367, 0.9030899869919434],
#  ['является', 12, 9, 1.0791812460476247, 0.9542425094393249],
#  ['подходов', 11, 10, 1.041392685158225, 1.0],
#  ['например', 10, 11, 1.0, 1.041392685158225],
#  ['заданий', 10, 12, 1.0, 1.0791812460476247],
#  ['языка', 10, 13, 1.0, 1.1139433523068367],
#  ['материалы', 10, 14, 1.0, 1.1461280356782377],
#  ['основе', 10, 15, 1.0, 1.1760912590556811],
#  ['урока', 10, 16, 1.0, 1.2041199826559246],
#  ['использовать', 9, 17, 0.9542425094393249, 1.2304489213782739],
#  ['доступе', 9, 18, 0.9542425094393249, 1.2552725051033058],
#  ['обучении', 9, 19, 0.9542425094393249, 1.2787536009528289],
#  ['можно', 8, 20, 0.9030899869919434, 1.301029995663981],
#  ['использования', 8, 21, 0.9030899869919434, 1.322219294733919],
#  ['области', 8, 22, 0.9030899869919434, 1.3424226808222062],
#  ['использованием', 8, 23, 0.9030899869919434, 1.3617278360175928],
#  ['материалов', 8, 24, 0.9030899869919434, 1.380211241711606],
#  ['кл', 8, 25, 0.9030899869919434, 1.3979400086720375],
#  ['преподавателей', 8, 26, 0.9030899869919434, 1.414973347970818],
#  ['лингвистике', 8, 27, 0.9030899869919434, 1.4313637641589871],
#  ['уроков', 8, 28, 0.9030899869919434, 1.447158031342219],
#  ['которые', 7, 29, 0.8450980400142567, 1.462397997898956],
#  ['языков', 7, 30, 0.8450980400142567, 1.4771212547196624],
#  ['анализ', 7, 31, 0.8450980400142567, 1.4913616938342726],
#  ['г', 7, 32, 0.8450980400142567, 1.5051499783199058],
#  ['нкря', 7, 33, 0.8450980400142567, 1.5185139398778873],
#  ['корпусных', 7, 34, 0.8450980400142567, 1.5314789170422551],
#  ['университета', 7, 35, 0.8450980400142567, 1.5440680443502754],
#  ['задания', 7, 36, 0.8450980400142567, 1.556302500767287],
#  ['содержит', 7, 37, 0.8450980400142567, 1.5682017240669948],
#  ['ресурсов', 6, 38, 0.7781512503836435, 1.57978359661681],
#  ['других', 6, 39, 0.7781512503836435, 1.591064607026499],
#  ['работы', 6, 40, 0.7781512503836435, 1.6020599913279623],
#  ['т', 6, 41, 0.7781512503836435, 1.6127838567197355],
#  ['д', 6, 42, 0.7781512503836435, 1.6232492903979003],
#  ['обучения', 6, 43, 0.7781512503836435, 1.6334684555795864],
#  ['н', 6, 44, 0.7781512503836435, 1.6434526764861872],
#  ['английского', 6, 45, 0.7781512503836435, 1.6532125137753435],
#  ['корпусу', 6, 46, 0.7781512503836435, 1.6627578316815739],
#  ['вебинаров', 6, 47, 0.7781512503836435, 1.6720978579357173],
#  ['сайте', 6, 48, 0.7781512503836435, 1.6812412373755872],
#  ['планов', 6, 49, 0.7781512503836435, 1.6901960800285134],
#  ['учебные', 6, 50, 0.7781512503836435, 1.6989700043360185],
#  ['х', 6, 51, 0.7781512503836435, 1.7075701760979363],
#  ['открытых', 5, 52, 0.6989700043360187, 1.716003343634799],
#  ['образовательных', 5, 53, 0.6989700043360187, 1.724275869600789],
#  ['доступ', 5, 54, 0.6989700043360187, 1.7323937598229684],
#  ['исследования', 5, 55, 0.6989700043360187, 1.7403626894942439],
#  ['открытом', 5, 56, 0.6989700043360187, 1.7481880270062005],
#  ['характеристик', 5, 57, 0.6989700043360187, 1.7558748556724912],
#  ['которых', 5, 58, 0.6989700043360187, 1.7634279935629371],
#  ['являются', 5, 59, 0.6989700043360187, 1.7708520116421442],
#  ['новых', 5, 60, 0.6989700043360187, 1.7781512503836434],
#  ['лингводидактики', 5, 61, 0.6989700043360187, 1.785329835010767],
#  ['использованию', 5, 62, 0.6989700043360187, 1.7923916894982537],
#  ['статьях', 5, 63, 0.6989700043360187, 1.7993405494535815],
#  ['свободном', 5, 64, 0.6989700043360187, 1.8061799739838869],
#  ['разделе', 5, 65, 0.6989700043360187, 1.8129133566428552],
#  ['примеры', 5, 66, 0.6989700043360187, 1.8195439355418683],
#  ['школы', 5, 67, 0.6989700043360187, 1.8260748027008262],
#  ['эти', 5, 68, 0.6989700043360187, 1.8325089127062362],
#  ['корпусного', 5, 69, 0.6989700043360187, 1.8388490907372552],
#  ['платформе', 5, 70, 0.6989700043360187, 1.845098040014257],
#  ['курс', 5, 71, 0.6989700043360187, 1.851258348719075],
#  ['учебных', 5, 72, 0.6989700043360187, 1.8573324964312683],
#  ['др', 5, 73, 0.6989700043360187, 1.8633228601204557],
#  ['слов', 5, 74, 0.6989700043360187, 1.8692317197309762],
#  ['мини', 5, 75, 0.6989700043360187, 1.8750612633916997],
#  ['план', 5, 76, 0.6989700043360187, 1.8808135922807911],
#  ['й', 5, 77, 0.6989700043360187, 1.8864907251724818],
#  ['введение', 4, 78, 0.6020599913279623, 1.8920946026904801],
#  ['развитие', 4, 79, 0.6020599913279623, 1.8976270912904412],
#  ['этого', 4, 80, 0.6020599913279623, 1.9030899869919433],
#  ['проекта', 4, 81, 0.6020599913279623, 1.9084850188786497],
#  ['публикации', 4, 82, 0.6020599913279623, 1.9138138523837167],
#  ['работе', 4, 83, 0.6020599913279623, 1.919078092376074],
#  ['исследований', 4, 84, 0.6020599913279623, 1.9242792860618814],
#  ['статье', 4, 85, 0.6020599913279623, 1.9294189257142926],
#  ['развития', 4, 86, 0.6020599913279623, 1.9344984512435675],
#  ['материалах', 4, 87, 0.6020599913279623, 1.9395192526186182],
#  ['отсутствие', 4, 88, 0.6020599913279623, 1.9444826721501687],
#  ['обучающихся', 4, 89, 0.6020599913279623, 1.9493900066449126],
#  ['широкому', 4, 90, 0.6020599913279623, 1.9542425094393248],
#  ['созданных', 4, 91, 0.6020599913279623, 1.9590413923210932],
#  ['доступен', 4, 92, 0.6020599913279623, 1.9637878273455551],
#  ['средней', 4, 93, 0.6020599913279623, 1.968482948553935],
#  ['русского', 4, 94, 0.6020599913279623, 1.9731278535996983],
#  ['заданиями', 4, 95, 0.6020599913279623, 1.9777236052888476],
#  ['соса', 4, 96, 0.6020599913279623, 1.9822712330395682],
#  ['теме', 4, 97, 0.6020599913279623, 1.9867717342662448],
#  ['корпусом', 4, 98, 0.6020599913279623, 1.9912260756924949],
#  ['вяткиной', 4, 99, 0.6020599913279623, 1.9956351945975497],
#  ['целью', 4, 100, 0.6020599913279623, 2.0],
#  ['ленко', 4, 101, 0.6020599913279623, 2.0043213737826426],
#  ['шиманска', 4, 102, 0.6020599913279623, 2.008600171761917],
#  ['курса', 4, 103, 0.6020599913279623, 2.012837224705172],
#  ['применения', 4, 104, 0.6020599913279623, 2.0170333392987803],
#  ['самообразования', 4, 105, 0.6020599913279623, 2.021189299069938],
#  ['моок', 4, 106, 0.6020599913279623, 2.02530586526477],
#  ['записи', 4, 107, 0.6020599913279623, 2.0293837776852093],
#  ['канале', 4, 108, 0.6020599913279623, 2.0334237554869494],
#  ['продолжительностью', 4, 109, 0.6020599913279623, 2.0374264979406234],
#  ['функции', 4, 110, 0.6020599913279623, 2.041392685158225],
#  ['университете', 4, 111, 0.6020599913279623, 2.045322978786657],
#  ['п', 4, 112, 0.6020599913279623, 2.049218022670181],
#  ['навыков', 4, 113, 0.6020599913279623, 2.0530784434834195],
#  ['разработаны', 4, 114, 0.6020599913279623, 2.0569048513364723],
#  ['студентов', 4, 115, 0.6020599913279623, 2.0606978403536114],
#  ['которая', 4, 116, 0.6020599913279623, 2.064457989226918],
#  ['руководством', 4, 117, 0.6020599913279623, 2.0681858617461617],
#  ['речи', 4, 118, 0.6020599913279623, 2.0718820073061255],
#  ['слова', 4, 119, 0.6020599913279623, 2.0755469613925306],
#  ['разных', 4, 120, 0.6020599913279623, 2.0791812460476247],
#  ['контексте', 3, 121, 0.47712125471966244, 2.08278537031645],
#  ['интернета', 3, 122, 0.47712125471966244, 2.086359830674748],
#  ['открытое', 3, 123, 0.47712125471966244, 2.0899051114393976],
#  ['образование', 3, 124, 0.47712125471966244, 2.093421685162235],
#  ['информацию', 3, 125, 0.47712125471966244, 2.0969100130080562],
#  ['е', 3, 126, 0.47712125471966244, 2.1003705451175625],
#  ['открытые', 3, 127, 0.47712125471966244, 2.103803720955957],
#  ['целей', 3, 128, 0.47712125471966244, 2.107209969647868],
#  ['рекомендациях', 3, 129, 0.47712125471966244, 2.110589710299249],
#  ['развитию', 3, 130, 0.47712125471966244, 2.1139433523068365],
#  ['открытого', 3, 131, 0.47712125471966244, 2.117271295655764],
#  ['открытой', 3, 132, 0.47712125471966244, 2.1205739312058496],
#  ['образования', 3, 133, 0.47712125471966244, 2.123851640967086],
#  ['иностранных', 3, 134, 0.47712125471966244, 2.1271047983648073],
#  ['исследователи', 3, 135, 0.47712125471966244, 2.130333768495006],
#  ['список', 3, 136, 0.47712125471966244, 2.1335389083702174],
#  ['обзор', 3, 137, 0.47712125471966244, 2.1367205671564067],
#  ['науки', 3, 138, 0.47712125471966244, 2.1398790864012365],
#  ['научных', 3, 139, 0.47712125471966244, 2.143014800254095],
#  ['конференций', 3, 140, 0.47712125471966244, 2.1461280356782377],
#  ['показал', 3, 141, 0.47712125471966244, 2.1492191126553797],
#  ['проведенный', 3, 142, 0.47712125471966244, 2.1522883443830563],
#  ['преподавания', 3, 143, 0.47712125471966244, 2.1553360374650614],
#  ['разные', 3, 144, 0.47712125471966244, 2.1583624920952493],
#  ['базе', 3, 145, 0.47712125471966244, 2.1613680022349744],
#  ['корпусах', 3, 146, 0.47712125471966244, 2.1643528557844367],
#  ['педагогической', 3, 147, 0.47712125471966244, 2.1673173347481756],
#  ['сайта', 3, 148, 0.47712125471966244, 2.170261715394957],
#  ['темы', 3, 149, 0.47712125471966244, 2.173186268412274],
#  ['уже', 3, 150, 0.47712125471966244, 2.176091259055681],
#  ['качестве', 3, 151, 0.47712125471966244, 2.1789769472931693],
#  ['мнению', 3, 152, 0.47712125471966244, 2.181843587944772],
#  ['разработанных', 3, 153, 0.47712125471966244, 2.1846914308175984],
#  ['деятельности', 3, 154, 0.47712125471966244, 2.187520720836463],
#  ['специального', 3, 155, 0.47712125471966244, 2.1903316981702914],
#  ['способы', 3, 156, 0.47712125471966244, 2.1931245983544616],
#  ['доступны', 3, 157, 0.47712125471966244, 2.1958996524092336],
#  ['рассмотрим', 3, 158, 0.47712125471966244, 2.1986570869544226],
#  ['есть', 3, 159, 0.47712125471966244, 2.2013971243204513],
#  ['ряд', 3, 160, 0.47712125471966244, 2.2041199826559246],
#  ['коллекции', 3, 161, 0.47712125471966244, 2.2068258760318495],
#  ['курсы', 3, 162, 0.47712125471966244, 2.2095150145426303],
#  ['доступных', 3, 163, 0.47712125471966244, 2.2121876044039577],
#  ['разместил', 3, 164, 0.47712125471966244, 2.214843848047698],
#  ['своем', 3, 165, 0.47712125471966244, 2.217483944213906],
#  ['роликов', 3, 166, 0.47712125471966244, 2.220108088040055],
#  ['фолл', 3, 167, 0.47712125471966244, 2.2227164711475833],
#  ['программы', 3, 168, 0.47712125471966244, 2.2253092817258624],
#  ['версии', 3, 169, 0.47712125471966244, 2.2278867046136734],
#  ['менеджера', 3, 170, 0.47712125471966244, 2.2304489213782737],
#  ['примером', 3, 171, 0.47712125471966244, 2.2329961103921536],
#  ['категории', 3, 172, 0.47712125471966244, 2.2355284469075487],
#  ['квинсленда', 3, 173, 0.47712125471966244, 2.2380461031287955],
#  ['эту', 3, 174, 0.47712125471966244, 2.2405492482825995],
#  ['важно', 3, 175, 0.47712125471966244, 2.2430380486862944],
#  ['изучаются', 3, 176, 0.47712125471966244, 2.2455126678141495],
#  ['известных', 3, 177, 0.47712125471966244, 2.2479732663618064],
#  ['вебинары', 3, 178, 0.47712125471966244, 2.2504200023088936],
#  ['классов', 3, 179, 0.47712125471966244, 2.252853030979893],
#  ['презентации', 3, 180, 0.47712125471966244, 2.255272505103306],
#  ['инструкция', 3, 181, 0.47712125471966244, 2.2576785748691846],
#  ['учащихся', 3, 182, 0.47712125471966244, 2.2600713879850747],
#  ['разным', 3, 183, 0.47712125471966244, 2.2624510897304293],
#  ['примеров', 3, 184, 0.47712125471966244, 2.2648178230095364],
#  ['уроки', 3, 185, 0.47712125471966244, 2.2671717284030133],
#  ['представлены', 3, 186, 0.47712125471966244, 2.2695129442179165],
#  ['множественного', 3, 187, 0.47712125471966244, 2.271841606536499],
#  ['числа', 3, 188, 0.47712125471966244, 2.2741578492636796],
#  ['ресурс', 3, 189, 0.47712125471966244, 2.276461804173244],
#  ['виде', 3, 190, 0.47712125471966244, 2.278753600952829],
#  ['предложения', 3, 191, 0.47712125471966244, 2.281033367247727],
#  ['видеосюжета', 3, 192, 0.47712125471966244, 2.2833012287035492],
#  ['вопроса', 3, 193, 0.47712125471966244, 2.2855573090077734],
#  ['своей', 3, 194, 0.47712125471966244, 2.287801729930226],
#  ['практике', 3, 195, 0.47712125471966244, 2.290034611362518],
#  ['корпусная', 2, 196, 0.30102999566398114, 2.2922560713564755],
#  ['парадигмы', 2, 197, 0.30102999566398114, 2.294466226161593],
#  ['науку', 2, 198, 0.30102999566398114, 2.296665190261531],
#  ['годы', 2, 199, 0.30102999566398114, 2.2988530764097064],
#  ['тренд', 2, 200, 0.30102999566398114, 2.301029995663981],
#  ['будапештская', 2, 201, 0.30102999566398114, 2.3031960574204886],
#  ['инициатива', 2, 202, 0.30102999566398114, 2.305351369446624],
#  ['открытый', 2, 203, 0.30102999566398114, 2.3074960379132126],
#  ['тысячи', 2, 204, 0.30102999566398114, 2.3096301674258983],
#  ['всех', 2, 205, 0.30102999566398114, 2.311753861055754],
#  ['составления', 2, 206, 0.30102999566398114, 2.3138672203691533],
#  ['автора', 2, 207, 0.30102999566398114, 2.3159703454569174],
#  ['оон', 2, 208, 0.30102999566398114, 2.3180633349627615],
#  ['юнеско', 2, 209, 0.30102999566398114, 2.320146286111054],
#  ['открытыми', 2, 210, 0.30102999566398114, 2.322219294733919],
#  ['образовательными', 2, 211, 0.30102999566398114, 2.3242824552976926],
#  ['ресурсами', 2, 212, 0.30102999566398114, 2.326335860928751],
#  ['высшего', 2, 213, 0.30102999566398114, 2.3283796034387376],
#  ['ресурсах', 2, 214, 0.30102999566398114, 2.3304137733491905],
#  ['изучение', 2, 215, 0.30102999566398114, 2.332438459915605],
#  ['собраны', 2, 216, 0.30102999566398114, 2.3344537511509307],
#  ['ресурсы', 2, 217, 0.30102999566398114, 2.3364597338485296],
#  ['обладают', 2, 218, 0.30102999566398114, 2.3384564936046046],
#  ['использование', 2, 219, 0.30102999566398114, 2.340444114840118],
#  ['дополняют', 2, 220, 0.30102999566398114, 2.342422680822206],
#  ['результатов', 2, 221, 0.30102999566398114, 2.34439227368511],
#  ['прикладной', 2, 222, 0.30102999566398114, 2.3463529744506384],
#  ['последние', 2, 223, 0.30102999566398114, 2.3483048630481607],
#  ['материале', 2, 224, 0.30102999566398114, 2.3502480183341623],
#  ['авторитетных', 2, 225, 0.30102999566398114, 2.3521825181113623],
#  ['англоязычных', 2, 226, 0.30102999566398114, 2.3541084391474008],
#  ['болтон', 2, 227, 0.30102999566398114, 2.3560258571931225],
#  ['вяткина', 2, 228, 0.30102999566398114, 2.3579348470004535],
#  ['условиях', 2, 229, 0.30102999566398114, 2.359835482339888],
#  ['другими', 2, 230, 0.30102999566398114, 2.3617278360175926],
#  ['категориями', 2, 231, 0.30102999566398114, 2.363611979892144],
#  ['авторы', 2, 232, 0.30102999566398114, 2.3654879848908994],
#  ['соответствии', 2, 233, 0.30102999566398114, 2.3673559210260184],
#  ['инструментов', 2, 234, 0.30102999566398114, 2.3692158574101425],
#  ['внимание', 2, 235, 0.30102999566398114, 2.371067862271736],
#  ['описанных', 2, 236, 0.30102999566398114, 2.3729120029701067],
#  ['недостаточная', 2, 237, 0.30102999566398114, 2.374748346010104],
#  ['подготовка', 2, 238, 0.30102999566398114, 2.376576957056512],
#  ['находящихся', 2, 239, 0.30102999566398114, 2.3783979009481375],
#  ['одним', 2, 240, 0.30102999566398114, 2.380211241711606],
#  ['специально', 2, 241, 0.30102999566398114, 2.382017042574868],
#  ['находится', 2, 242, 0.30102999566398114, 2.383815365980431],
#  ['больших', 2, 243, 0.30102999566398114, 2.3856062735983117],
#  ['нкри', 2, 244, 0.30102999566398114, 2.387389826338729],
#  ['режима', 2, 245, 0.30102999566398114, 2.3891660843645326],
#  ['поиска', 2, 246, 0.30102999566398114, 2.390935107103379],
#  ['проблемой', 2, 247, 0.30102999566398114, 2.392696953259666],
#  ['упражнений', 2, 248, 0.30102999566398114, 2.394451680826216],
#  ['преподаватель', 2, 249, 0.30102999566398114, 2.396199347095736],
#  ['изучении', 2, 250, 0.30102999566398114, 2.397940008672037],
#  ['ним', 2, 251, 0.30102999566398114, 2.3996737214810375],
#  ['них', 2, 252, 0.30102999566398114, 2.4014005407815437],
#  ['определенного', 2, 253, 0.30102999566398114, 2.4031205211758175],
#  ['национального', 2, 254, 0.30102999566398114, 2.404833716619938],
#  ['пособия', 2, 255, 0.30102999566398114, 2.4065401804339546],
#  ['правило', 2, 256, 0.30102999566398114, 2.408239965311849],
#  ['открытым', 2, 257, 0.30102999566398114, 2.4099331233312946],
#  ['находящиеся', 2, 258, 0.30102999566398114, 2.41161970596323],
#  ['доступные', 2, 259, 0.30102999566398114, 2.4132997640812515],
#  ['конкретному', 2, 260, 0.30102999566398114, 2.4149733479708178],
#  ['проблема', 2, 261, 0.30102999566398114, 2.416640507338281],
#  ['решения', 2, 262, 0.30102999566398114, 2.4183012913197452],
#  ['систему', 2, 263, 0.30102999566398114, 2.4199557484897576],
#  ['студенты', 2, 264, 0.30102999566398114, 2.421603926869831],
#  ['базовые', 2, 265, 0.30102999566398114, 2.4232458739368075],
#  ['знания', 2, 266, 0.30102999566398114, 2.4248816366310666],
#  ['имеют', 2, 267, 0.30102999566398114, 2.426511261364575],
#  ['зарегистрированные', 2, 268, 0.30102999566398114, 2.4281347940287885],
#  ['данных', 2, 269, 0.30102999566398114, 2.4297522800024076],
#  ['вопрос', 2, 270, 0.30102999566398114, 2.4313637641589874],
#  ['того', 2, 271, 0.30102999566398114, 2.4329692908744054],
#  ['преподаватели', 2, 272, 0.30102999566398114, 2.4345689040341987],
#  ['подходы', 2, 273, 0.30102999566398114, 2.436162647040756],
#  ['педагогическую', 2, 274, 0.30102999566398114, 2.437750562820388],
#  ['практику', 2, 275, 0.30102999566398114, 2.4393326938302624],
#  ['подходами', 2, 276, 0.30102999566398114, 2.4409090820652173],
#  ['будущих', 2, 277, 0.30102999566398114, 2.442479769064448],
#  ['желающих', 2, 278, 0.30102999566398114, 2.4440447959180758],
#  ['освоить', 2, 279, 0.30102999566398114, 2.4456042032735974],
#  ['основы', 2, 280, 0.30102999566398114, 2.447158031342219],
#  ['самостоятельно', 2, 281, 0.30102999566398114, 2.4487063199050794],
#  ['повышения', 2, 282, 0.30102999566398114, 2.450249108319361],
#  ['квалификации', 2, 283, 0.30102999566398114, 2.45178643552429],
#  ['целый', 2, 284, 0.30102999566398114, 2.4533183400470375],
#  ['организованные', 2, 285, 0.30102999566398114, 2.45484486000851],
#  ['отдельные', 2, 286, 0.30102999566398114, 2.4563660331290427],
#  ['ролики', 2, 287, 0.30102999566398114, 2.4578818967339924],
#  ['серии', 2, 288, 0.30102999566398114, 2.4593924877592306],
#  ['мин', 2, 289, 0.30102999566398114, 2.4608978427565478],
#  ['элен', 2, 290, 0.30102999566398114, 2.4623979978989556],
#  ['наиболее', 2, 291, 0.30102999566398114, 2.4638929889859074],
#  ['созданию', 2, 292, 0.30102999566398114, 2.465382851448418],
#  ['собственного', 2, 293, 0.30102999566398114, 2.4668676203541096],
#  ['корпусе', 2, 294, 0.30102999566398114, 2.468347330412157],
#  ['колеблется', 2, 295, 0.30102999566398114, 2.469822015978163],
#  ['л', 2, 296, 0.30102999566398114, 2.4712917110589383],
#  ['антони', 2, 297, 0.30102999566398114, 2.4727564493172123],
#  ['основные', 2, 298, 0.30102999566398114, 2.4742162640762553],
#  ['небольшие', 2, 299, 0.30102999566398114, 2.4756711883244296],
#  ['русскоязычном', 2, 300, 0.30102999566398114, 2.477121254719662],
#  ['сегменте', 2, 301, 0.30102999566398114, 2.478566495593843],
#  ['курсов', 2, 302, 0.30102999566398114, 2.4800069429571505],
#  ['делает', 2, 303, 0.30102999566398114, 2.481442628502305],
#  ['разработанный', 2, 304, 0.30102999566398114, 2.4828735836087534],
#  ['ланкастерском', 2, 305, 0.30102999566398114, 2.484299839346786],
#  ['макэнери', 2, 306, 0.30102999566398114, 2.4857214264815797],
#  ['корпусами', 2, 307, 0.30102999566398114, 2.487138375477186],
#  ['вшэ', 2, 308, 0.30102999566398114, 2.488550716500444],
#  ['размещен', 2, 309, 0.30102999566398114, 2.4899584794248346],
#  ['повседневной', 2, 310, 0.30102999566398114, 2.4913616938342726],
#  ['апробация', 2, 311, 0.30102999566398114, 2.492760389026837],
#  ['описана', 2, 312, 0.30102999566398114, 2.4941545940184424],
#  ['базовыми', 2, 313, 0.30102999566398114, 2.4955443375464483],
#  ['создания', 2, 314, 0.30102999566398114, 2.4969296480732144],
#  ['р', 2, 315, 0.30102999566398114, 2.4983105537896004],
#  ['проходили', 2, 316, 0.30102999566398114, 2.4996870826184034],
#  ['течение', 2, 317, 0.30102999566398114, 2.501059262217751],
#  ['размещены', 2, 318, 0.30102999566398114, 2.5024271199844326],
#  ['докладчиков', 2, 319, 0.30102999566398114, 2.503790683057181],
#  ['разработки', 2, 320, 0.30102999566398114, 2.505149978319906],
#  ['версией', 2, 321, 0.30102999566398114, 2.506505032404872],
#  ['существенно', 2, 322, 0.30102999566398114, 2.507855871695831],
#  ['описание', 2, 323, 0.30102999566398114, 2.5092025223311025],
#  ['событий', 2, 324, 0.30102999566398114, 2.5105450102066116],
#  ['таких', 2, 325, 0.30102999566398114, 2.511883360978874],
#  ['группах', 2, 326, 0.30102999566398114, 2.513217600067939],
#  ['беседы', 2, 327, 0.30102999566398114, 2.514547752660286],
#  ['конференции', 2, 328, 0.30102999566398114, 2.515873843711679],
#  ['кафедре', 2, 329, 0.30102999566398114, 2.517195897949974],
#  ['привязки', 2, 330, 0.30102999566398114, 2.518513939877887],
#  ['инструкциями', 2, 331, 0.30102999566398114, 2.5198279937757184],
#  ['пользователя', 2, 332, 0.30102999566398114, 2.521138083704036],
#  ['стр', 2, 333, 0.30102999566398114, 2.5224442335063197],
#  ['инструментам', 2, 334, 0.30102999566398114, 2.5237464668115646],
#  ['инструкции', 2, 335, 0.30102999566398114, 2.5250448070368448],
#  ['должны', 2, 336, 0.30102999566398114, 2.5263392773898437],
#  ['материала', 2, 337, 0.30102999566398114, 2.5276299008713385],
#  ['поддержки', 2, 338, 0.30102999566398114, 2.5289167002776547],
#  ['стороны', 2, 339, 0.30102999566398114, 2.5301996982030817],
#  ['преподавателя', 2, 340, 0.30102999566398114, 2.531478917042255],
#  ['уровнем', 2, 341, 0.30102999566398114, 2.5327543789924976],
#  ['формат', 2, 342, 0.30102999566398114, 2.5340261060561344],
#  ['работу', 2, 343, 0.30102999566398114, 2.53529412004277],
#  ['расширение', 2, 344, 0.30102999566398114, 2.53655844257153],
#  ['словарного', 2, 345, 0.30102999566398114, 2.537819095073274],
#  ['запаса', 2, 346, 0.30102999566398114, 2.5390760987927767],
#  ['могут', 2, 347, 0.30102999566398114, 2.5403294747908736],
#  ['употребления', 2, 348, 0.30102999566398114, 2.5415792439465807],
#  ['учебниках', 2, 349, 0.30102999566398114, 2.5428254269591797],
#  ['конкретного', 2, 350, 0.30102999566398114, 2.5440680443502752],
#  ['габласовой', 2, 351, 0.30102999566398114, 2.545307116465824],
#  ['носителей', 2, 352, 0.30102999566398114, 2.5465426634781307],
#  ['изучающих', 2, 353, 0.30102999566398114, 2.5477747053878224],
#  ['английский', 2, 354, 0.30102999566398114, 2.5490032620257876],
#  ['язык', 2, 355, 0.30102999566398114, 2.5502283530550938],
#  ['иностранный', 2, 356, 0.30102999566398114, 2.551449997972875],
#  ['рубрикам', 2, 357, 0.30102999566398114, 2.5526682161121927],
#  ['категориям', 2, 358, 0.30102999566398114, 2.553883026643874],
#  ['рамках', 2, 359, 0.30102999566398114, 2.555094448578319],
#  ['явления', 2, 360, 0.30102999566398114, 2.5563025007672873],
#  ['грамматики', 2, 361, 0.30102999566398114, 2.5575072019056577],
#  ['лица', 2, 362, 0.30102999566398114, 2.558708570533166],
#  ['каждой', 2, 363, 0.30102999566398114, 2.559906625036112],
#  ['строк', 2, 364, 0.30102999566398114, 2.5611013836490555],
#  ['данном', 2, 365, 0.30102999566398114, 2.5622928644564746],
#  ['случае', 2, 366, 0.30102999566398114, 2.56348108539441],
#  ['сложности', 2, 367, 0.30102999566398114, 2.5646660642520893],
#  ['прослушать', 2, 368, 0.30102999566398114, 2.5658478186735176],
#  ['близких', 2, 369, 0.30102999566398114, 2.56702636615906],
#  ['автоматически', 2, 370, 0.30102999566398114, 2.5682017240669945],
#  ['диктора', 2, 371, 0.30102999566398114, 2.5693739096150456],
#  ['попытки', 2, 372, 0.30102999566398114, 2.5705429398818973],
#  ['возможность', 2, 373, 0.30102999566398114, 2.5717088318086874],
#  ['лексики', 2, 374, 0.30102999566398114, 2.57287160220048],
#  ['получить', 2, 375, 0.30102999566398114, 2.5740312677277184],
#  ['последующей', 2, 376, 0.30102999566398114, 2.575187844927661],
#  ['задании', 2, 377, 0.30102999566398114, 2.5763413502057926],
#  ['учащиеся', 2, 378, 0.30102999566398114, 2.577491799837225],
#  ['задание', 2, 379, 0.30102999566398114, 2.578639209968072],
#  ['формате', 2, 380, 0.30102999566398114, 2.57978359661681],
#  ['обучение', 2, 381, 0.30102999566398114, 2.580924975675619],
#  ['минут', 2, 382, 0.30102999566398114, 2.5820633629117085],
#  ['письменных', 2, 383, 0.30102999566398114, 2.5831987739686224],
#  ['студентами', 2, 384, 0.30102999566398114, 2.5843312243675305],
#  ['методически', 2, 385, 0.30102999566398114, 2.5854607295085006],
#  ['конкретной', 2, 386, 0.30102999566398114, 2.5865873046717547],
#  ['старших', 2, 387, 0.30102999566398114, 2.5877109650189114],
#  ['верные', 2, 388, 0.30102999566398114, 2.5888317255942073],
#  ['школьников', 2, 389, 0.30102999566398114, 2.5899496013257073],
#  ['требует', 2, 390, 0.30102999566398114, 2.591064607026499],
#  ['дальнейшего', 2, 391, 0.30102999566398114, 2.5921767573958667],
#  ['идея', 2, 392, 0.30102999566398114, 2.5932860670204567],
#  ['разработке', 2, 393, 0.30102999566398114, 2.5943925503754266],
#  ['ма', 2, 394, 0.30102999566398114, 2.5954962218255737],
#  ['определенной', 2, 395, 0.30102999566398114, 2.59659709562646],
#  ['думается', 2, 396, 0.30102999566398114, 2.597695185925512],
#  ['проектной', 2, 397, 0.30102999566398114, 2.598790506763115],
#  ['лингводидактика', 1, 398, 0.0, 2.5998830720736876],
#  ['коган', 1, 399, 0.0, 2.600972895686748],
#  ['информационного', 1, 400, 0.0, 2.602059991327962],
#  ['общества', 1, 401, 0.0, 2.603144372620182],
#  ['привело', 1, 402, 0.0, 2.60422605308447],
#  ['появлению', 1, 403, 0.0, 2.605305046141109],
#  ['важного', 1, 404, 0.0, 2.6063813651106047],
#  ['тренда', 1, 405, 0.0, 2.6074550232146683],
#  ['инициатором', 1, 406, 0.0, 2.608526033577194],
#  ['движения', 1, 407, 0.0, 2.6095944092252195],
#  ['считается', 1, 408, 0.0, 2.6106601630898796],
#  ['майкл', 1, 409, 0.0, 2.611723308007342],
#  ['стерн', 1, 410, 0.0, 2.6127838567197355],
#  ['харт', 1, 411, 0.0, 2.613841821876069],
#  ['изобретатель', 1, 412, 0.0, 2.6148972160331345],
#  ['электронных', 1, 413, 0.0, 2.615950051656401],
#  ['книг', 1, 414, 0.0, 2.6170003411208986],
#  ['основатель', 1, 415, 0.0, 2.6180480967120925],
#  ['гутенберг', 1, 416, 0.0, 2.6190933306267423],
#  ['прошлого', 1, 417, 0.0, 2.620136054973757],
#  ['века', 1, 418, 0.0, 2.621176281775035],
#  ['хх', 1, 419, 0.0, 2.622214022966295],
#  ['веке', 1, 420, 0.0, 2.6232492903979003],
#  ['задала', 1, 421, 0.0, 2.624282095835668],
#  ['которой', 1, 422, 0.0, 2.625312450961674],
#  ['тех', 1, 423, 0.0, 2.626340367375042],
#  ['присоединились', 1, 424, 0.0, 2.6273658565927325],
#  ['организаций', 1, 425, 0.0, 2.6283889300503116],
#  ['этом', 1, 426, 0.0, 2.629409599102719],
#  ['документе', 1, 427, 0.0, 2.6304278750250236],
#  ['определялся', 1, 428, 0.0, 2.631443769013172],
#  ['интернете', 1, 429, 0.0, 2.632457292184724],
#  ['читать', 1, 430, 0.0, 2.633468455579586],
#  ['разгружать', 1, 431, 0.0, 2.634477270160731],
#  ['копировать', 1, 432, 0.0, 2.635483746814912],
#  ['распространять', 1, 433, 0.0, 2.636487896353365],
#  ['распечатывать', 1, 434, 0.0, 2.6374897295125104],
#  ['находить', 1, 435, 0.0, 2.638489256954637],
#  ['присоединять', 1, 436, 0.0, 2.639486489268586],
#  ['полным', 1, 437, 0.0, 2.6404814369704215],
#  ['текстам', 1, 438, 0.0, 2.6414741105040993],
#  ['соответствующих', 1, 439, 0.0, 2.6424645202421213],
#  ['статей', 1, 440, 0.0, 2.643452676486187],
#  ['указателей', 1, 441, 0.0, 2.644438589467838],
#  ['вводить', 1, 442, 0.0, 2.6454222693490914],
#  ['данные', 1, 443, 0.0, 2.6464037262230695],
#  ['программное', 1, 444, 0.0, 2.6473829701146196],
#  ['обеспечение', 1, 445, 0.0, 2.648360010980931],
#  ['законных', 1, 446, 0.0, 2.649334858712142],
#  ['отсутствии', 1, 447, 0.0, 2.650307523131936],
#  ['финансовых', 1, 448, 0.0, 2.6512780139981436],
#  ['правовых', 1, 449, 0.0, 2.6522463410033232],
#  ['технических', 1, 450, 0.0, 2.6532125137753435],
#  ['преград', 1, 451, 0.0, 2.6541765418779604],
#  ['соблюдении', 1, 452, 0.0, 2.655138434811382],
#  ['целостности', 1, 453, 0.0, 2.656098202012832],
#  ['обязательной', 1, 454, 0.0, 2.6570558528571038],
#  ['ссылке', 1, 455, 0.0, 2.658011396657112],
#  ['имя', 1, 456, 0.0, 2.658964842664435],
#  ['использовании', 1, 457, 0.0, 2.65991620006985],
#  ['цитировании', 1, 458, 0.0, 2.660865478003869],
#  ['последующие', 1, 459, 0.0, 2.661812685537261],
#  ['получила', 1, 460, 0.0, 2.662757831681574],
#  ['многочисленных', 1, 461, 0.0, 2.663700925389648],
#  ['документах', 1, 462, 0.0, 2.6646419755561253],
#  ['продвижению', 1, 463, 0.0, 2.665580991017953],
#  ['доступа', 1, 464, 0.0, 2.6665179805548807],
#  ['науке', 1, 465, 0.0, 2.6674529528899535],
#  ['сфере', 1, 466, 0.0, 2.6683859166899997],
#  ['практик', 1, 467, 0.0, 2.669316880566112],
#  ['касающиеся', 1, 468, 0.0, 2.6702458530741238],
#  ['влияния', 1, 469, 0.0, 2.671172842715083],
#  ['преподавание', 1, 470, 0.0, 2.672097857935717],
#  ['томе', 1, 471, 0.0, 2.6730209071288957],
#  ['находящемся', 1, 472, 0.0, 2.6739419986340875],
#  ['образовательные', 1, 473, 0.0, 2.674861140737811],
#  ['рядом', 1, 474, 0.0, 2.675778341674085],
#  ['важнейшими', 1, 475, 0.0, 2.6766936096248664],
#  ['бесплатный', 1, 476, 0.0, 2.677606952720493],
#  ['право', 1, 477, 0.0, 2.678518379040114],
#  ['адаптацию', 1, 478, 0.0, 2.6794278966121188],
#  ['распространение', 1, 479, 0.0, 2.6803355134145628],
#  ['третьими', 1, 480, 0.0, 2.681241237375587],
#  ['лицами', 1, 481, 0.0, 2.6821450763738315],
#  ['ограничений', 1, 482, 0.0, 2.683047038238849],
#  ['незначительными', 1, 483, 0.0, 2.6839471307515117],
#  ['ограничениями', 1, 484, 0.0, 2.6848453616444123],
#  ['понятия', 1, 485, 0.0, 2.6857417386022635],
#  ['открытость', 1, 486, 0.0, 2.686636269262293],
#  ['пунктов', 1, 487, 0.0, 2.687528961214634],
#  ['принципов', 1, 488, 0.0, 2.6884198220027105],
#  ['найти', 1, 489, 0.0, 2.6893088591236203],
#  ['космас', 1, 490, 0.0, 2.6901960800285134],
#  ['коллегами', 1, 491, 0.0, 2.691081492122968],
#  ['одна', 1, 492, 0.0, 2.69196510276736],
#  ['прозрачность', 1, 493, 0.0, 2.6928469192772297],
#  ['контроль', 1, 494, 0.0, 2.6937269489236466],
#  ['критический', 1, 495, 0.0, 2.6946051989335684],
#  ['воспроизводимость', 1, 496, 0.0, 2.695481676490197],
#  ['целях', 1, 497, 0.0, 2.696356388733332],
#  ['усиления', 1, 498, 0.0, 2.697229342759717],
#  ['надежности', 1, 499, 0.0, 2.6981005456233897],
#  ['точности', 1, 500, 0.0, 2.6989700043360183],
#  ['воздействия', 1, 501, 0.0, 2.6998377258672455],
#  ['общество', 1, 502, 0.0, 2.700703717145019],
#  ['специалисты', 1, 503, 0.0, 2.7015679850559273],
#  ['говорят', 1, 504, 0.0, 2.702430536445525],
#  ['кризисе', 1, 505, 0.0, 2.7032913781186614],
#  ['воспроизводимости', 1, 506, 0.0, 2.704150516839799],
#  ['см', 1, 507, 0.0, 2.705007959333336],
#  ['анализируя', 1, 508, 0.0, 2.705863712283919],
#  ['тенденции', 1, 509, 0.0, 2.7067177823367583],
#  ['лет', 1, 510, 0.0, 2.707570176097936],
#  ['публикаций', 1, 511, 0.0, 2.7084209001347124],
#  ['рецензируемых', 1, 512, 0.0, 2.7092699609758304],
#  ['журналах', 1, 513, 0.0, 2.710117365111816],
#  ['глав', 1, 514, 0.0, 2.7109631189952754],
#  ['монографий', 1, 515, 0.0, 2.7118072290411908],
#  ['обнаружили', 1, 516, 0.0, 2.7126497016272113],
#  ['полное', 1, 517, 0.0, 2.7134905430939424],
#  ['направленных', 1, 518, 0.0, 2.7143297597452327],
#  ['частичное', 1, 519, 0.0, 2.7151673578484576],
#  ['воспроизведение', 1, 520, 0.0, 2.716003343634799],
#  ['повторение', 1, 521, 0.0, 2.716837723299524],
#  ['классических', 1, 522, 0.0, 2.717670503002262],
#  ['работ', 1, 523, 0.0, 2.718501688867274],
#  ['следует', 1, 524, 0.0, 2.7193312869837265],
#  ['заметить', 1, 525, 0.0, 2.7201593034059566],
#  ['принципами', 1, 526, 0.0, 2.720985744153739],
#  ['разместили', 1, 527, 0.0, 2.7218106152125463],
#  ['отобранных', 1, 528, 0.0, 2.722633922533812],
#  ['анализа', 1, 529, 0.0, 2.7234556720351857],
#  ['публикациях', 1, 530, 0.0, 2.7242758696007887],
#  ['репозитории', 1, 531, 0.0, 2.725094521081469],
#  ['важность', 1, 532, 0.0, 2.725911632295048],
#  ['концепции', 1, 533, 0.0, 2.726727209026572],
#  ['широкого', 1, 534, 0.0, 2.727541257028556],
#  ['несмотря', 1, 535, 0.0, 2.728353782021228],
#  ['эффективность', 1, 536, 0.0, 2.7291647896927698],
#  ['мета', 1, 537, 0.0, 2.7299742856995555],
#  ['болтоном', 1, 538, 0.0, 2.730782275666389],
#  ['коббом', 1, 539, 0.0, 2.7315887651867388],
#  ['давно', 1, 540, 0.0, 2.7323937598229686],
#  ['предсказанную', 1, 541, 0.0, 2.733197265106569],
#  ['революцию', 1, 542, 0.0, 2.7339992865383866],
#  ['методах', 1, 543, 0.0, 2.7347998295888467],
#  ['сих', 1, 544, 0.0, 2.7355988996981795],
#  ['пор', 1, 545, 0.0, 2.736396502276642],
#  ['произошло', 1, 546, 0.0, 2.737192642704737],
#  ['чамбес', 1, 547, 0.0, 2.7379873263334304],
#  ['обратила', 1, 548, 0.0, 2.738780558484369],
#  ['необходимость', 1, 549, 0.0, 2.7395723444500915],
#  ['преодоления', 1, 550, 0.0, 2.740362689494243],
#  ['разрыва', 1, 551, 0.0, 2.741151598851785],
#  ['исследованиями', 1, 552, 0.0, 2.7419390777291985],
#  ['методикой', 1, 553, 0.0, 2.742725131304698],
#  ['называют', 1, 554, 0.0, 2.7435097647284294],
#  ['причины', 1, 555, 0.0, 2.744292983122676],
#  ['сложившейся', 1, 556, 0.0, 2.745074791582057],
#  ['ситуации', 1, 557, 0.0, 2.745855195173729],
#  ['наша', 1, 558, 0.0, 2.746634198937578],
#  ['попытка', 1, 559, 0.0, 2.747411807886423],
#  ['проанализировать', 1, 560, 0.0, 2.7481880270062002],
#  ['привела', 1, 561, 0.0, 2.748962861256161],
#  ['списку', 1, 562, 0.0, 2.7497363155690606],
#  ['причин', 1, 563, 0.0, 2.7505083948513462],
#  ['остановимся', 1, 564, 0.0, 2.751279103983342],
#  ['трех', 1, 565, 0.0, 2.7520484478194382],
#  ['проблемах', 1, 566, 0.0, 2.7528164311882715],
#  ['недоступность', 1, 567, 0.0, 2.753583058892906],
#  ['лингводидактике', 1, 568, 0.0, 2.754348335711019],
#  ['общедоступных', 1, 569, 0.0, 2.755112266395071],
#  ['непосредственного', 1, 570, 0.0, 2.7558748556724915],
#  ['учебном', 1, 571, 0.0, 2.7566361082458477],
#  ['процессе', 1, 572, 0.0, 2.757396028793024],
#  ['препятствий', 1, 573, 0.0, 2.75815462196739],
#  ['распространению', 1, 574, 0.0, 2.7589118923979736],
#  ['выполнены', 1, 575, 0.0, 2.75966784468963],
#  ['составленных', 1, 576, 0.0, 2.760422483423212],
#  ['недоступных', 1, 577, 0.0, 2.7611758131557314],
#  ['научной', 1, 578, 0.0, 2.761927838420529],
#  ['общественности', 1, 579, 0.0, 2.762678563727436],
#  ['достаточно', 1, 580, 0.0, 2.763427993562937],
#  ['большое', 1, 581, 0.0, 2.76417613239033],
#  ['количество', 1, 582, 0.0, 2.7649229846498886],
#  ['первую', 1, 583, 0.0, 2.7656685547590136],
#  ['очередь', 1, 584, 0.0, 2.766412847112399],
#  ['национальные', 1, 585, 0.0, 2.7671558660821804],
#  ['представительный', 1, 586, 0.0, 2.7678976160180904],
#  ['указанием', 1, 587, 0.0, 2.7686381012476144],
#  ['обращения', 1, 588, 0.0, 2.769377326076138],
#  ['требуется', 1, 589, 0.0, 2.7701152947871015],
#  ['регистрация', 1, 590, 0.0, 2.770852011642144],
#  ['скачивания', 1, 591, 0.0, 2.771587480881255],
#  ['доступного', 1, 592, 0.0, 2.7723217067229196],
#  ['банка', 1, 593, 0.0, 2.7730546933642626],
#  ['мог', 1, 594, 0.0, 2.7737864449811935],
#  ['многочисленные', 1, 595, 0.0, 2.7745169657285493],
#  ['опубликованы', 1, 596, 0.0, 2.775246259740236],
#  ['обычному', 1, 597, 0.0, 2.775974331129369],
#  ['преподавателю', 1, 598, 0.0, 2.7767011839884104],
#  ['вуза', 1, 599, 0.0, 2.777426822389311],
#  ['говоря', 1, 600, 0.0, 2.7781512503836434],
#  ['учителях', 1, 601, 0.0, 2.778874472002739],
#  ['затруднен', 1, 602, 0.0, 2.7795964912578244],
#  ['каталогизированы', 1, 603, 0.0, 2.780317312140151],
#  ['описаны', 1, 604, 0.0, 2.7810369386211318],
#  ['точки', 1, 605, 0.0, 2.7817553746524686],
#  ['зрения', 1, 606, 0.0, 2.782472624166286],
#  ['имеющихся', 1, 607, 0.0, 2.7831886910752575],
#  ['примера', 1, 608, 0.0, 2.7839035792727347],
#  ['сослаться', 1, 609, 0.0, 2.784617292632875],
#  ['недавние', 1, 610, 0.0, 2.7853298350107667],
#  ['изданные', 1, 611, 0.0, 2.786041210242554],
#  ['немногочисленные', 1, 612, 0.0, 2.786751422145561],
#  ['поисковыми', 1, 613, 0.0, 2.787460474518415],
#  ['относятся', 1, 614, 0.0, 2.7881683711411673],
#  ['ресурсам', 1, 615, 0.0, 2.7888751157754164],
#  ['меняют', 1, 616, 0.0, 2.789580712164425],
#  ['адрес', 1, 617, 0.0, 2.7902851640332416],
#  ['магистерская', 1, 618, 0.0, 2.7909884750888154],
#  ['диссертация', 1, 619, 0.0, 2.7916906490201177],
#  ['шоу', 1, 620, 0.0, 2.792391689498254],
#  ['находилась', 1, 621, 0.0, 2.79309160017658],
#  ['вплоть', 1, 622, 0.0, 2.7937903846908183],
#  ['весны', 1, 623, 0.0, 2.7944880466591693],
#  ['переместилась', 1, 624, 0.0, 2.7951845896824237],
#  ['архив', 1, 625, 0.0, 2.795880017344075],
#  ['бригама', 1, 626, 0.0, 2.796574333210429],
#  ['янга', 1, 627, 0.0, 2.7972675408307164],
#  ['вынужден', 1, 628, 0.0, 2.7979596437371956],
#  ['метаться', 1, 629, 0.0, 2.7986506454452686],
#  ['разными', 1, 630, 0.0, 2.7993405494535817],
#  ['источниками', 1, 631, 0.0, 2.800029359244134],
#  ['упражнениями', 1, 632, 0.0, 2.8007170782823847],
#  ['содержат', 1, 633, 0.0, 2.8014037100173548],
#  ['инструкций', 1, 634, 0.0, 2.8020892578817325],
#  ['системы', 1, 635, 0.0, 2.8027737252919755],
#  ['привязанных', 1, 636, 0.0, 2.803457115648414],
#  ['серьезна', 1, 637, 0.0, 2.80413943233535],
#  ['простых', 1, 638, 0.0, 2.804820678721162],
#  ['путей', 1, 639, 0.0, 2.8055008581584],
#  ['кажется', 1, 640, 0.0, 2.8061799739838866],
#  ['существует', 1, 641, 0.0, 2.8068580295188172],
#  ['нашем', 1, 642, 0.0, 2.807535028068853],
#  ['исследовании', 1, 643, 0.0, 2.8082109729242215],
#  ['имевшем', 1, 644, 0.0, 2.808885867359812],
#  ['оценить', 1, 645, 0.0, 2.8095597146352675],
#  ['влияние', 1, 646, 0.0, 2.810232517995084],
#  ['россии', 1, 647, 0.0, 2.8109042806687],
#  ['пришли', 1, 648, 0.0, 2.811575005870593],
#  ['выводу', 1, 649, 0.0, 2.812244696800369],
#  ['современном', 1, 650, 0.0, 2.8129133566428552],
#  ['этапе', 1, 651, 0.0, 2.8135809885681917],
#  ['требованиями', 1, 652, 0.0, 2.81424759573192],
#  ['фгос', 1, 653, 0.0, 2.814913181275074],
#  ['филологических', 1, 654, 0.0, 2.815577748324267],
#  ['специальностей', 1, 655, 0.0, 2.8162412999917827],
#  ['получают', 1, 656, 0.0, 2.81690383937566],
#  ['наукометрических', 1, 657, 0.0, 2.81756536955978],
#  ['базах', 1, 658, 0.0, 2.8182258936139553],
#  ['разного', 1, 659, 0.0, 2.8188854145940097],
#  ['ранга', 1, 660, 0.0, 2.8195439355418683],
#  ['остается', 1, 661, 0.0, 2.8202014594856397],
#  ['насколько', 1, 662, 0.0, 2.8208579894396997],
#  ['готовы', 1, 663, 0.0, 2.8215135284047728],
#  ['регулярно', 1, 664, 0.0, 2.822168079368017],
#  ['практической', 1, 665, 0.0, 2.8228216453031045],
#  ['окончания', 1, 666, 0.0, 2.823474229170301],
#  ['считает', 1, 667, 0.0, 2.8241258339165487],
#  ['элективного', 1, 668, 0.0, 2.8247764624755454],
#  ['односеместрового', 1, 669, 0.0, 2.825426117767823],
#  ['недостаточно', 1, 670, 0.0, 2.826074802700826],
#  ['будущие', 1, 671, 0.0, 2.826722520168992],
#  ['могли', 1, 672, 0.0, 2.827369273053825],
#  ['успешно', 1, 673, 0.0, 2.8280150642239765],
#  ['интегрировать', 1, 674, 0.0, 2.8286598965353194],
#  ['собственную', 1, 675, 0.0, 2.829303772831025],
#  ['исследователь', 1, 676, 0.0, 2.829946695941636],
#  ['предполагает', 1, 677, 0.0, 2.8305886686851442],
#  ['ситуация', 1, 678, 0.0, 2.831229693867063],
#  ['улучшится', 1, 679, 0.0, 2.8318697742805017],
#  ['будут', 1, 680, 0.0, 2.8325089127062357],
#  ['изучать', 1, 681, 0.0, 2.8331471119127847],
#  ['возможности', 1, 682, 0.0, 2.833784374656479],
#  ['наряду', 1, 683, 0.0, 2.8344207036815323],
#  ['курсе', 1, 684, 0.0, 2.8350561017201157],
#  ['методики', 1, 685, 0.0, 2.8356905714924254],
#  ['теоретических', 1, 686, 0.0, 2.836324115706751],
#  ['практических', 1, 687, 0.0, 2.83695673705955],
#  ['лингвистических', 1, 688, 0.0, 2.8375884382355108],
#  ['дисциплин', 1, 689, 0.0, 2.8382192219076257],
#  ['мотивированных', 1, 690, 0.0, 2.8388490907372548],
#  ['действующих', 1, 691, 0.0, 2.839478047374198],
#  ['следующем', 1, 692, 0.0, 2.8401060944567575],
#  ['ведущими', 1, 693, 0.0, 2.8407332346118066],
#  ['центрами', 1, 694, 0.0, 2.841359470454855],
#  ['начнем', 1, 695, 0.0, 2.8419848045901137],
#  ['обзора', 1, 696, 0.0, 2.842609239610562],
#  ['видеоресурсов', 1, 697, 0.0, 2.843232778098009],
#  ['запросу', 1, 698, 0.0, 2.843855422623161],
#  ['выдает', 1, 699, 0.0, 2.844477175745681],
#  ['ссылок', 1, 700, 0.0, 2.8450980400142565],
#  ['целые', 1, 701, 0.0, 2.8457180179666586],
#  ['последовательно', 1, 702, 0.0, 2.8463371121298047],
#  ['объясняются', 1, 703, 0.0, 2.846955325019824],
#  ['этой', 1, 704, 0.0, 2.847572659142112],
#  ['дисциплины', 1, 705, 0.0, 2.8481891169913984],
#  ['яссин', 1, 706, 0.0, 2.8488047010518036],
#  ['иабдунан', 1, 707, 0.0, 2.849419413796899],
#  ['года', 1, 708, 0.0, 2.850033257689769],
#  ['выложила', 1, 709, 0.0, 2.850646235183066],
#  ['популярными', 1, 710, 0.0, 2.851258348719075],
#  ['набравшими', 1, 711, 0.0, 2.851869600729766],
#  ['год', 1, 712, 0.0, 2.852479993636856],
#  ['просмотров', 1, 713, 0.0, 2.8530895298518653],
#  ['освоению', 1, 714, 0.0, 2.853698211776174],
#  ['разработчики', 1, 715, 0.0, 2.85430604180108],
#  ['крупных', 1, 716, 0.0, 2.8549130223078554],
#  ['свои', 1, 717, 0.0, 2.8555191556677997],
#  ['каналы', 1, 718, 0.0, 2.8561244442423],
#  ['ролика', 1, 719, 0.0, 2.8567288903828825],
#  ['продолжительность', 1, 720, 0.0, 2.857332496431268],
#  ['обучающих', 1, 721, 0.0, 2.857935264719429],
#  ['объясняющих', 1, 722, 0.0, 2.8585371975696385],
#  ['широкоизвестного', 1, 723, 0.0, 2.8591382972945305],
#  ['разработал', 1, 724, 0.0, 2.8597385661971466],
#  ['длительность', 1, 725, 0.0, 2.8603380065709936],
#  ['призывает', 1, 726, 0.0, 2.8609366207000932],
#  ['активно', 1, 727, 0.0, 2.8615344108590377],
#  ['создавать', 1, 728, 0.0, 2.8621313793130367],
#  ['делясь', 1, 729, 0.0, 2.8627275283179743],
#  ['собственным', 1, 730, 0.0, 2.8633228601204554],
#  ['опытом', 1, 731, 0.0, 2.86391737695786],
#  ['скрытыми', 1, 732, 0.0, 2.8645110810583914],
#  ['хитростями', 1, 733, 0.0, 2.8651039746411278],
#  ['менеджеров', 1, 734, 0.0, 2.86569605991607],
#  ['такие', 1, 735, 0.0, 2.8662873390841948],
#  ['практически', 1, 736, 0.0, 2.866877814337499],
#  ['отсутствуют', 1, 737, 0.0, 2.867467487859051],
#  ['массовые', 1, 738, 0.0, 2.8680563618230415],
#  ['массовом', 1, 739, 0.0, 2.8686444383948255],
#  ['сознании', 1, 740, 0.0, 2.869231719730976],
#  ['сравнения', 1, 741, 0.0, 2.869818207979328],
#  ['позволил', 1, 742, 0.0, 2.870403905279027],
#  ['выявить', 1, 743, 0.0, 2.870988813760575],
#  ['важные', 1, 744, 0.0, 2.871572935545878],
#  ['отличия', 1, 745, 0.0, 2.8721562727482928],
#  ['этими', 1, 746, 0.0, 2.872738827472668],
#  ['менее', 1, 747, 0.0, 2.8733206018153985],
#  ['доступность', 1, 748, 0.0, 2.873901597864461],
#  ['ценным', 1, 749, 0.0, 2.874481817699466],
#  ['ресурсом', 1, 750, 0.0, 2.8750612633916997],
#  ['популярные', 1, 751, 0.0, 2.875639937004168],
#  ['размещенный', 1, 752, 0.0, 2.876217840591642],
#  ['введением', 1, 753, 0.0, 2.8767949762007],
#  ['затрагивает', 1, 754, 0.0, 2.877371345869774],
#  ['вопросы', 1, 755, 0.0, 2.877946951629188],
#  ['знакомит', 1, 756, 0.0, 2.8785217955012063],
#  ['крупными', 1, 757, 0.0, 2.8790958795000723],
#  ['новым', 1, 758, 0.0, 2.8796692056320534],
#  ['корпусным', 1, 759, 0.0, 2.88024177589548],
#  ['менеджером', 1, 760, 0.0, 2.8808135922807914],
#  ['разработанным', 1, 761, 0.0, 2.8813846567705728],
#  ['брезиной', 1, 762, 0.0, 2.8819549713396],
#  ['корпусную', 1, 763, 0.0, 2.8825245379548803],
#  ['лингвистику', 1, 764, 0.0, 2.8830933585756897],
#  ['представленный', 1, 765, 0.0, 2.883661435153617],
#  ['левинзон', 1, 766, 0.0, 2.8842287696326037],
#  ['национальной', 1, 767, 0.0, 2.8847953639489807],
#  ['дает', 1, 768, 0.0, 2.8853612200315117],
#  ['представление', 1, 769, 0.0, 2.885926339801431],
#  ['практическом', 1, 770, 0.0, 2.8864907251724814],
#  ['применении', 1, 771, 0.0, 2.8870543780509568],
#  ['достижений', 1, 772, 0.0, 2.887617300335736],
#  ['современной', 1, 773, 0.0, 2.888179493918325],
#  ['учит', 1, 774, 0.0, 2.888740960682892],
#  ['пользоваться', 1, 775, 0.0, 2.88930170250631],
#  ['существующими', 1, 776, 0.0, 2.889861721258188],
#  ['позволяет', 1, 777, 0.0, 2.890421018800914],
#  ['методы', 1, 778, 0.0, 2.8909795969896885],
#  ['относится', 1, 779, 0.0, 2.8915374576725643],
#  ['маленький', 1, 780, 0.0, 2.8920946026904804],
#  ['частный', 1, 781, 0.0, 2.8926510338773],
#  ['разработан', 1, 782, 0.0, 2.893206753059848],
#  ['кроссвейтом', 1, 783, 0.0, 2.893761762057943],
#  ['академического', 1, 784, 0.0, 2.894316062684438],
#  ['письма', 1, 785, 0.0, 2.8948696567452523],
#  ['прямым', 1, 786, 0.0, 2.895422546039408],
#  ['обращением', 1, 787, 0.0, 2.8959747323590643],
#  ['группу', 1, 788, 0.0, 2.896526217489555],
#  ['включить', 1, 789, 0.0, 2.8970770032094197],
#  ['варшавского', 1, 790, 0.0, 2.8976270912904414],
#  ['знакомство', 1, 791, 0.0, 2.8981764834976764],
#  ['участников', 1, 792, 0.0, 2.8987251815894934],
#  ['концепциями', 1, 793, 0.0, 2.899273187317603],
#  ['корпус', 1, 794, 0.0, 2.899820502427096],
#  ['применение', 1, 795, 0.0, 2.90036712865647],
#  ['иностранным', 1, 796, 0.0, 2.900913067737669],
#  ['родному', 1, 797, 0.0, 2.9014583213961123],
#  ['языку', 1, 798, 0.0, 2.902002891350729],
#  ['навыка', 1, 799, 0.0, 2.902546779313991],
#  ['подхода', 1, 800, 0.0, 2.9030899869919433],
#  ['общедоступные', 1, 801, 0.0, 2.9036325160842376],
#  ['корпусные', 1, 802, 0.0, 2.9041743682841634],
#  ['инструменты', 1, 803, 0.0, 2.904715545278681],
#  ['честь', 1, 804, 0.0, 2.905256048748451],
#  ['летия', 1, 805, 0.0, 2.9057958803678683],
#  ['основания', 1, 806, 0.0, 2.9063350418050904],
#  ['магистерской', 1, 807, 0.0, 2.90687353472207],
#  ['сан', 1, 808, 0.0, 2.9074113607745855],
#  ['паолу', 1, 809, 0.0, 2.907948521612272],
#  ['бразилия', 1, 810, 0.0, 2.9084850188786495],
#  ['руководители', 1, 811, 0.0, 2.909020854211156],
#  ['организовали', 1, 812, 0.0, 2.909556029241175],
#  ['серию', 1, 813, 0.0, 2.9100905455940675],
#  ['пригласив', 1, 814, 0.0, 2.9106244048892007],
#  ['участия', 1, 815, 0.0, 2.9111576087399764],
#  ['всемирно', 1, 816, 0.0, 2.911690158753861],
#  ['ученых', 1, 817, 0.0, 2.9122220565324155],
#  ['байбера', 1, 818, 0.0, 2.9127533036713227],
#  ['скотта', 1, 819, 0.0, 2.913283901760418],
#  ['ю', 1, 820, 0.0, 2.9138138523837163],
#  ['ромер', 1, 821, 0.0, 2.9143431571194403],
#  ['дэвис', 1, 822, 0.0, 2.91487181754005],
#  ['реппен', 1, 823, 0.0, 2.9153998352122694],
#  ['еженедельно', 1, 824, 0.0, 2.9159272116971158],
#  ['апреля', 1, 825, 0.0, 2.9164539485499246],
#  ['сентябрь', 1, 826, 0.0, 2.916980047320382],
#  ['недели', 1, 827, 0.0, 2.917505509552546],
#  ['интенсива', 1, 828, 0.0, 2.91803033678488],
#  ['августе', 1, 829, 0.0, 2.9185545305502734],
#  ['сентября', 1, 830, 0.0, 2.9190780923760733],
#  ['проводилось', 1, 831, 0.0, 2.919601023784111],
#  ['мастер', 1, 832, 0.0, 2.9201233262907236],
#  ['программных', 1, 833, 0.0, 2.9206450014067875],
#  ['продуктов', 1, 834, 0.0, 2.9211660506377384],
#  ['версий', 1, 835, 0.0, 2.9216864754836016],
#  ['программ', 1, 836, 0.0, 2.9222062774390163],
#  ['скотт', 1, 837, 0.0, 2.9227254579932596],
#  ['представил', 1, 838, 0.0, 2.923244018630276],
#  ['последнюю', 1, 839, 0.0, 2.9237619608287],
#  ['версию', 1, 840, 0.0, 2.9242792860618816],
#  ['момент', 1, 841, 0.0, 2.924795995797912],
#  ['была', 1, 842, 0.0, 2.925312091499649],
#  ['странице', 1, 843, 0.0, 2.925827574624742],
#  ['кафедры', 1, 844, 0.0, 2.926342446625655],
#  ['осенью', 1, 845, 0.0, 2.926856708949692],
#  ['инициативу', 1, 846, 0.0, 2.927370363039023],
#  ['продолжили', 1, 847, 0.0, 2.9278834103307068],
#  ['культур', 1, 848, 0.0, 2.9283958522567137],
#  ['австралия', 1, 849, 0.0, 2.9289076902439524],
#  ['октября', 1, 850, 0.0, 2.929418925714293],
#  ['апрель', 1, 851, 0.0, 2.9299295600845876],
#  ['состоялся', 1, 852, 0.0, 2.9304395947666997],
#  ['вебинар', 1, 853, 0.0, 2.930949031167523],
#  ['докладчиками', 1, 854, 0.0, 2.931457870689005],
#  ['были', 1, 855, 0.0, 2.9319661147281724],
#  ['крупные', 1, 856, 0.0, 2.932473764677153],
#  ['программного', 1, 857, 0.0, 2.932980821923198],
#  ['обеспечения', 1, 858, 0.0, 2.9334872878487053],
#  ['франкенберг', 1, 859, 0.0, 2.933993163831242],
#  ['гарсия', 1, 860, 0.0, 2.9344984512435675],
#  ['кроссвейт', 1, 861, 0.0, 2.9350031514536545],
#  ['последний', 1, 862, 0.0, 2.9355072658247123],
#  ['познакомил', 1, 863, 0.0, 2.9360107957152093],
#  ['новой', 1, 864, 0.0, 2.9365137424788927],
#  ['своего', 1, 865, 0.0, 2.937016107464814],
#  ['функционал', 1, 866, 0.0, 2.9375178920173464],
#  ['которого', 1, 867, 0.0, 2.93801909747621],
#  ['расширен', 1, 868, 0.0, 2.9385197251764916],
#  ['сравнению', 1, 869, 0.0, 2.9390197764486663],
#  ['кроссвейта', 1, 870, 0.0, 2.9395192526186182],
#  ['ряде', 1, 871, 0.0, 2.940018155007663],
#  ['международных', 1, 872, 0.0, 2.940516484932567],
#  ['развернутое', 1, 873, 0.0, 2.9410142437055695],
#  ['анонсы', 1, 874, 0.0, 2.9415114326344027],
#  ['предстоящих', 1, 875, 0.0, 2.9420080530223127],
#  ['публикуются', 1, 876, 0.0, 2.9425041061680806],
#  ['социальных', 1, 877, 0.0, 2.9429995933660402],
#  ['сетях', 1, 878, 0.0, 2.9434945159061026],
#  ['фейсбуке', 1, 879, 0.0, 2.9439888750737717],
#  ['посвящены', 1, 880, 0.0, 2.9444826721501682],
#  ['лекции', 1, 881, 0.0, 2.9449759084120477],
#  ['плунгяна', 1, 882, 0.0, 2.9454685851318194],
#  ['добровольского', 1, 883, 0.0, 2.945960703577568],
#  ['постнауке', 1, 884, 0.0, 2.9464522650130727],
#  ['бузаджи', 1, 885, 0.0, 2.946943270697825],
#  ['захарова', 1, 886, 0.0, 2.9474337218870503],
#  ['некоторых', 1, 887, 0.0, 2.947923619831726],
#  ['исследователей', 1, 888, 0.0, 2.948412965778601],
#  ['видеозаписи', 1, 889, 0.0, 2.9489017609702133],
#  ['заседаний', 1, 890, 0.0, 2.9493900066449124],
#  ['лингвистика', 1, 891, 0.0, 2.9498777040368744],
#  ['проходила', 1, 892, 0.0, 2.9503648543761227],
#  ['дистанционном', 1, 893, 0.0, 2.950851458888546],
#  ['режиме', 1, 894, 0.0, 2.951337518795917],
#  ['математической', 1, 895, 0.0, 2.9518230353159116],
#  ['спбгу', 1, 896, 0.0, 2.952308009662125],
#  ['обновленная', 1, 897, 0.0, 2.9527924430440917],
#  ['мае', 1, 898, 0.0, 2.953276336667304],
#  ['версия', 1, 899, 0.0, 2.9537596917332283],
#  ['расширенный', 1, 900, 0.0, 2.9542425094393248],
#  ['образовательный', 1, 901, 0.0, 2.9547247909790624],
#  ['портал', 1, 902, 0.0, 2.9552065375419416],
#  ['готовых', 1, 903, 0.0, 2.9556877503135057],
#  ['предложение', 1, 904, 0.0, 2.956168430475363],
#  ['эффективности', 1, 905, 0.0, 2.956648579205203],
#  ['конкретным', 1, 906, 0.0, 2.957128197676813],
#  ['корпусам', 1, 907, 0.0, 2.9576072870600947],
#  ['взгляд', 1, 908, 0.0, 2.958085848521085],
#  ['показаться', 1, 909, 0.0, 2.958563883221967],
#  ['неактуальна', 1, 910, 0.0, 2.9590413923210934],
#  ['снабжены', 1, 911, 0.0, 2.959518376972998],
#  ['внушительного', 1, 912, 0.0, 2.9599948383284156],
#  ['объема', 1, 913, 0.0, 2.9604707775342987],
#  ['никря', 1, 914, 0.0, 2.9609461957338308],
#  ['дополнительными', 1, 915, 0.0, 2.961421094066448],
#  ['дополнительным', 1, 916, 0.0, 2.96189547366785],
#  ['просмотра', 1, 917, 0.0, 2.962369335670021],
#  ['указывает', 1, 918, 0.0, 2.9628426812012423],
#  ['руководства', 1, 919, 0.0, 2.963315511386111],
#  ['далеки', 1, 920, 0.0, 2.963787827345555],
#  ['знакомых', 1, 921, 0.0, 2.9642596301968487],
#  ['учителю', 1, 922, 0.0, 2.9647309210536292],
#  ['базироваться', 1, 923, 0.0, 2.9652017010259115],
#  ['педагогических', 1, 924, 0.0, 2.9656719712201065],
#  ['принципах', 1, 925, 0.0, 2.966141732739032],
#  ['подразумевающих', 1, 926, 0.0, 2.966610986681934],
#  ['сопровождение', 1, 927, 0.0, 2.9670797341444968],
#  ['вовлечение', 1, 928, 0.0, 2.967547976218862],
#  ['простого', 1, 929, 0.0, 2.9680157139936414],
#  ['сложному', 1, 930, 0.0, 2.968482948553935],
#  ['большей', 1, 931, 0.0, 2.9689496809813423],
#  ['заданиям', 1, 932, 0.0, 2.969415912353981],
#  ['выполняемым', 1, 933, 0.0, 2.9698816437464997],
#  ['своих', 1, 934, 0.0, 2.970346876230093],
#  ['описывает', 1, 935, 0.0, 2.9708116108725178],
#  ['обращений', 1, 936, 0.0, 2.9712758487381046],
#  ['немецкого', 1, 937, 0.0, 2.9717395908877777],
#  ['владения', 1, 938, 0.0, 2.972202838379064],
#  ['немецким', 1, 939, 0.0, 2.9726655922661105],
#  ['языком', 1, 940, 0.0, 2.9731278535996983],
#  ['начинающих', 1, 941, 0.0, 2.9735896234272565],
#  ['продвинутых', 1, 942, 0.0, 2.974050902792877],
#  ['предполагающих', 1, 943, 0.0, 2.974511692737328],
#  ['разный', 1, 944, 0.0, 2.9749719942980684],
#  ['индивидуальную', 1, 945, 0.0, 2.9754318085092626],
#  ['парах', 1, 946, 0.0, 2.9758911364017924],
#  ['малых', 1, 947, 0.0, 2.976349979003273],
#  ['преподавателем', 1, 948, 0.0, 2.9768083373380656],
#  ['основным', 1, 949, 0.0, 2.9772662124272924],
#  ['фокусом', 1, 950, 0.0, 2.9777236052888476],
#  ['включать', 1, 951, 0.0, 2.978180516937414],
#  ['освоение', 1, 952, 0.0, 2.978636948384474],
#  ['лексико', 1, 953, 0.0, 2.9790929006383258],
#  ['грамматических', 1, 954, 0.0, 2.979548374704095],
#  ['помощью', 1, 955, 0.0, 2.980003371583746],
#  ['верификация', 1, 956, 0.0, 2.9804578922760996],
#  ['словосочетаний', 1, 957, 0.0, 2.980911937776843],
#  ['примерами', 1, 958, 0.0, 2.981365509078544],
#  ['приведенные', 1, 959, 0.0, 2.9818186071706636],
#  ['соответствуют', 1, 960, 0.0, 2.982271233039568],
#  ['базовый', 1, 961, 0.0, 2.9827233876685453],
#  ['поиск', 1, 962, 0.0, 2.9831750720378127],
#  ['временная', 1, 963, 0.0, 2.9836262871245345],
#  ['ось', 1, 964, 0.0, 2.9840770339028304],
#  ['визуализация', 1, 965, 0.0, 2.984527313343792],
#  ['коллокаций', 1, 966, 0.0, 2.984977126415493],
#  ['облако', 1, 967, 0.0, 2.985426474083001],
#  ['другим', 1, 968, 0.0, 2.985875357308393],
#  ['блестящим', 1, 969, 0.0, 2.986323777050765],
#  ['проект', 1, 970, 0.0, 2.9867717342662448],
#  ['создаваемый', 1, 971, 0.0, 2.9872192299080047],
#  ['привязаны', 1, 972, 0.0, 2.987666264926274],
#  ['большим', 1, 973, 0.0, 2.9881128402683514],
#  ['выборкам', 1, 974, 0.0, 2.9885589568786153],
#  ['устной', 1, 975, 0.0, 2.9890046156985366],
#  ['представляющих', 1, 976, 0.0, 2.9894498176666913],
#  ['неформальные', 1, 977, 0.0, 2.9898945637187726],
#  ['британского', 1, 978, 0.0, 2.9903388547876015],
#  ['варианта', 1, 979, 0.0, 2.9907826918031377],
#  ['готовящихся', 1, 980, 0.0, 2.9912260756924947],
#  ['сдать', 1, 981, 0.0, 2.9916690073799486],
#  ['итоговый', 1, 982, 0.0, 2.9921114877869495],
#  ['экзамен', 1, 983, 0.0, 2.9925535178321354],
#  ['курсу', 1, 984, 0.0, 2.9929950984313414],
#  ['выборки', 1, 985, 0.0, 2.9934362304976116],
#  ['выпускников', 1, 986, 0.0, 2.993876914941211],
#  ['английских', 1, 987, 0.0, 2.9943171526696366],
#  ['школ', 1, 988, 0.0, 2.994756944587628],
#  ['следующим', 1, 989, 0.0, 2.9951962915971793],
#  ['реальные', 1, 990, 0.0, 2.9956351945975497],
#  ['современного', 1, 991, 0.0, 2.9960736544852753],
#  ['отраженные', 1, 992, 0.0, 2.996511672154178],
#  ['английской', 1, 993, 0.0, 2.996949248495381],
#  ['изменение', 1, 994, 0.0, 2.997386384397313],
#  ['местоимения', 1, 995, 0.0, 2.997823080745725],
#  ['выражения', 1, 996, 0.0, 2.9982593384236984],
#  ['лице', 1, 997, 0.0, 2.9986951583116555],
#  ['включают', 1, 998, 0.0, 2.999130541287371],
#  ['раздаточные', 1, 999, 0.0, 2.9995654882259823],
#  ['упражнения', 1, 1000, 0.0, 2.9999999999999996],
#  ...]

# %%
frame = pd.DataFrame(n_list, columns=['Words','Frequencies','Ranks', 'Logarithm of Frequencies', 'Logarithm of ranks']) # собираем фрейм
frame.to_csv('Frequency Dictionary.csv',encoding='utf-8', sep=';', index=False) #экспортируем в файл

# %%
bigrams = nltk.collocations.BigramAssocMeasures()
trigrams = nltk.collocations.TrigramAssocMeasures()

bigramFinder = nltk.collocations.BigramCollocationFinder.from_words(text_words)
trigramFinder = nltk.collocations.TrigramCollocationFinder.from_words(text_words)

# bigrams
bigram_freq = bigramFinder.ngram_fd.items()
bigramFreqTable = pd.DataFrame(list(bigram_freq), columns=['bigram','freq']).sort_values(by='freq', ascending=False)
bigramFreqTable.to_csv('Bigrams.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# trigrams
trigram_freq = trigramFinder.ngram_fd.items()
trigramFreqTable = pd.DataFrame(list(trigram_freq), columns=['trigram','freq']).sort_values(by='freq', ascending=False)
trigramFreqTable.to_csv('Trigrams.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# %%
bigram_freq
# Out:
# dict_items([(('корпусная', 'лингводидактика'), 1), (('лингводидактика', 'контексте'), 1), (('контексте', 'парадигмы'), 2), (('парадигмы', 'открытых'), 1), (('открытых', 'образовательных'), 4), (('образовательных', 'ресурсов'), 4), (('ресурсов', 'коган'), 1), (('коган', 'введение'), 1), (('введение', 'развитие'), 1), (('развитие', 'интернета'), 1), (('интернета', 'информационного'), 1), (('информационного', 'общества'), 1), (('общества', 'привело'), 1), (('привело', 'появлению'), 1), (('появлению', 'важного'), 1), (('важного', 'тренда'), 1), (('тренда', 'открытое'), 1), (('открытое', 'образование'), 3), (('образование', 'науку'), 2), (('науку', 'информацию'), 2), (('информацию', 'инициатором'), 1), (('инициатором', 'этого'), 1), (('этого', 'движения'), 1), (('движения', 'считается'), 1), (('считается', 'майкл'), 1), (('майкл', 'стерн'), 1), (('стерн', 'харт'), 1), (('харт', 'изобретатель'), 1), (('изобретатель', 'электронных'), 1), (('электронных', 'книг'), 1), (('книг', 'основатель'), 1), (('основатель', 'проекта'), 1), (('проекта', 'гутенберг'), 1), (('гутенберг', 'е'), 1), (('е', 'годы'), 1), (('годы', 'прошлого'), 1), (('прошлого', 'века'), 1), (('века', 'хх'), 1), (('хх', 'веке'), 1), (('веке', 'тренд'), 1), (('тренд', 'задала'), 1), (('задала', 'будапештская'), 1), (('будапештская', 'инициатива'), 2), (('инициатива', 'открытый'), 1), (('открытый', 'доступ'), 2), (('доступ', 'которой'), 1), (('которой', 'тех'), 1), (('тех', 'присоединились'), 1), (('присоединились', 'тысячи'), 1), (('тысячи', 'организаций'), 1), (('организаций', 'этом'), 1), (('этом', 'документе'), 1), (('документе', 'открытый'), 1), (('доступ', 'определялся'), 1), (('определялся', 'открытые'), 1), (('открытые', 'всех'), 1), (('всех', 'публикации'), 1), (('публикации', 'интернете'), 1), (('интернете', 'которые'), 1), (('которые', 'можно'), 3), (('можно', 'читать'), 1), (('читать', 'разгружать'), 1), (('разгружать', 'копировать'), 1), (('копировать', 'распространять'), 1), (('распространять', 'распечатывать'), 1), (('распечатывать', 'находить'), 1), (('находить', 'присоединять'), 1), (('присоединять', 'полным'), 1), (('полным', 'текстам'), 1), (('текстам', 'соответствующих'), 1), (('соответствующих', 'статей'), 1), (('статей', 'использовать'), 1), (('использовать', 'составления'), 1), (('составления', 'указателей'), 1), (('указателей', 'вводить'), 1), (('вводить', 'данные'), 1), (('данные', 'программное'), 1), (('программное', 'обеспечение'), 1), (('обеспечение', 'использовать'), 1), (('использовать', 'других'), 1), (('других', 'законных'), 1), (('законных', 'целей'), 1), (('целей', 'отсутствии'), 1), (('отсутствии', 'финансовых'), 1), (('финансовых', 'правовых'), 1), (('правовых', 'технических'), 1), (('технических', 'преград'), 1), (('преград', 'соблюдении'), 1), (('соблюдении', 'целостности'), 1), (('целостности', 'работы'), 1), (('работы', 'обязательной'), 1), (('обязательной', 'ссылке'), 1), (('ссылке', 'имя'), 1), (('имя', 'автора'), 1), (('автора', 'использовании'), 1), (('использовании', 'цитировании'), 1), (('цитировании', 'последующие'), 1), (('последующие', 'годы'), 1), (('годы', 'будапештская'), 1), (('инициатива', 'получила'), 1), (('получила', 'развитие'), 1), (('развитие', 'многочисленных'), 1), (('многочисленных', 'документах'), 1), (('документах', 'оон'), 1), (('оон', 'юнеско'), 2), (('юнеско', 'например'), 1), (('например', 'рекомендациях'), 1), (('рекомендациях', 'развитию'), 2), (('развитию', 'продвижению'), 1), (('продвижению', 'открытого'), 1), (('открытого', 'доступа'), 1), (('доступа', 'рекомендациях'), 1), (('рекомендациях', 'открытой'), 1), (('открытой', 'науке'), 1), (('науке', 'работе'), 1), (('работе', 'открытыми'), 1), (('открытыми', 'образовательными'), 2), (('образовательными', 'ресурсами'), 2), (('ресурсами', 'оор'), 1), (('оор', 'сфере'), 1), (('сфере', 'высшего'), 1), (('высшего', 'образования'), 2), (('образования', 'открытых'), 1), (('образовательных', 'ресурсах'), 1), (('ресурсах', 'рекомендациях'), 1), (('развитию', 'п ...

# %%
# t-test
bigramTtable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.student_t)), columns=['bigram','T-test']).sort_values(by='T-test', ascending=False)
trigramTtable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.student_t)), columns=['trigram','T-test']).sort_values(by='T-test', ascending=False)
bigramTtable = bigramTtable.head(20)
trigramTtable = trigramTtable.head(20) #вычленяем первые 20 лучших би- и триграмм
bigramTtable.to_csv('Bigrams-T-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл
trigramTtable.to_csv('Trigrams-T-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# chi-squared
bigramCHItable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.chi_sq)), columns=['bigram','Chi-squared']).sort_values(by='Chi-squared', ascending=False)
trigramCHItable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.chi_sq)), columns=['trigram','Chi-squared']).sort_values(by='Chi-squared', ascending=False)
bigramCHItable = bigramCHItable.head(20)
trigramCHItable = trigramCHItable.head(20) #вычленяем первые 20 лучших би- и триграмм
bigramCHItable.to_csv('Bigrams-CHI-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл
trigramCHItable.to_csv('Trigrams-CHI-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# log-likelihood
bigramlikelihoodtable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.likelihood_ratio)), columns=['bigram','Log-Likelihood']).sort_values(by='Log-Likelihood', ascending=False)
trigramlikelihoodtable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.likelihood_ratio)), columns=['trigram','Log-Likelihood']).sort_values(by='Log-Likelihood', ascending=False)
bigramlikelihoodtable = bigramlikelihoodtable.head(20)
trigramlikelihoodtable = trigramlikelihoodtable.head(20) #вычленяем первые 20 лучших би- и триграмм
bigramlikelihoodtable.to_csv('Bigrams-likelihood-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл
trigramlikelihoodtable.to_csv('Trigrams-likelihood-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# pmi
bigramPMItable = pd.DataFrame(list(bigramFinder.score_ngrams(bigrams.pmi)), columns=['bigram','PMI']).sort_values(by='PMI', ascending=False)
trigramPMItable = pd.DataFrame(list(trigramFinder.score_ngrams(trigrams.pmi)), columns=['trigram','PMI']).sort_values(by='PMI', ascending=False)
bigramPMItable = bigramPMItable.head(20)
trigramPMItable = trigramPMItable.head(20) #вычленяем первые 20 лучших би- и триграмм
bigramPMItable.to_csv('Bigrams-PMI-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл
trigramPMItable.to_csv('Trigrams-PMI-test-20.csv',encoding='utf8', sep=';', index=False) #экспортируем в файл

# %%
#RAKE

# %%
import pymorphy2 as pm
import codecs
import string

# %%
m = pm.MorphAnalyzer()

# %%
words = []
words2 = ""

# %%
with open('corpus/Kogan_IMS_2022.txt', 'r', encoding='utf-8') as f: #прописываем путь к корпусу (папка или файл)
    text = f.read()
    words = text.split()
    for i in range(len(words) - 1):
        if m.parse(words[i])[0].tag.POS == "ADVB" or m.parse(words[i])[0].tag.POS == "VERB" or m.parse(words[i][:-1])[0].tag.POS == "VERB" or m.parse(words[i])[0].tag.POS == "PRTS"or m.parse(words[i])[0].tag.POS == "INFN"or m.parse(words[i])[0].tag.POS == "COMP" or m.parse(words[i])[0].tag.POS == "ADJS" or m.parse(words[i])[0].tag.POS == "GRND"or m.parse(words[i])[0].tag.POS == "CONJ":
            words2 += " | " + words[i] + " | "
        elif (m.parse(words[i])[0].tag.POS == "NOUN" and m.parse(words[i])[0].tag.case == ("gent" or "accs")):
            words2 += words[i] + " | "
        elif m.parse(words[i])[0].tag.POS == "NOUN" and m.parse(words[i + 1])[0].tag.POS == ("NOUN" or "ADJF") and m.parse(words[i])[0].tag.case != m.parse(words[i + 1])[0].tag.case and m.parse(words[i + 1])[0].tag.case != "gent":
            words2 += words[i] + " | "
        elif (m.parse(words[i])[0].tag.POS == "NOUN" and m.parse(words[i])[0].tag.case != ("nomn" or "accs") and m.parse(words[i + 1])[0].tag.POS == "NOUN" and m.parse(words[i + 1])[0].tag.case == ("nomn" or "accs")):
            words2 += words[i] + " | "
        elif (m.parse(words[i])[0].tag.POS == None and m.parse(words[i][:-1])[0].tag.POS == None and m.parse(words[i][1:])[0].tag.POS == None):
            words2 += " | " + words[i] + " | "
        elif (m.parse(words[i])[0].tag.POS == "NOUN" and m.parse(words[i - 1])[0].tag.POS == "ADJF" or m.parse(words[i - 1])[0].tag.POS == "PRTF") and m.parse(words[i])[0].tag.case == m.parse(words[i + 1])[0].tag.case:
            words2 += words[i] + " | "
        else:
            words2 += words[i] + " "

# %%
words2
# Out:
# 'Корпусная лингводидактика в контексте парадигмы | открытых образовательных ресурсов |  | М.С. | Коган Введение | Развитие интернета |  | и | информационного общества |  | привело | к появлению важного тренда | на открытое образование, науку, информацию. Инициатором этого  | движения |  | считается | Майкл  | Стерн | Харт,  | изобретатель | электронных книг |  | и |  | основатель | проекта | «Гутенберг» в 60-е годы прошлого | века |  | [1]. | В  | ХХI | веке этот тренд  | задала | Будапештская Инициатива | «Открытый Доступ»  | , | к которой с тех  | присоединились | тысячи | организаций. В этом документе Открытый доступ  | определялся |  | как | «открытые для всех публикации | в Интернете, которые можно читать, разгружать, копировать, распространять, распечатывать,  | находить |  | или |  | присоединять | к полным текстам соответствующих статей,  | использовать | для  | составления | указателей,  | вводить | их  | как | данные в программное обеспечение  | или |  | использовать | для других законных целей | при  | отсутствии | финансовых, правовых  | и | технических преград»  | … | при соблюдении целостности | работы |  | и | обязательной ссылке на имя автора | при использовании  | и | цитировании. В последующие годы Будапештская инициатива  | получила | развитие в многочисленных документах ООН |  | и | ЮНЕСКО, например, в рекомендациях по развитию  | и |  | продвижению | открытого доступа |  | , | рекомендациях по открытой науке  | , | по работе с открытыми образовательными ресурсами (ООР) в сфере высшего образования |  | , | об открытых образовательных ресурсах  | , |  | а | также рекомендациях по развитию практик | использования | ООР  | и |  | т.д. | Исследования, касающиеся  | влияния | открытого образования | на изучение  | и | преподавание иностранных языков,  | собраны | в томе  | [2], | находящемся в открытом доступе. Открытые образовательные ресурсы  | обладают |  | рядом | характеристик, важнейшими из которых  | являются | бесплатный доступ, право на использование, адаптацию  | и |  | распространение | третьими лицами без ограничений |  | или | с незначительными ограничениями. Некоторые  | исследователи |  | дополняют | список  | характеристик | понятия | открытость до  | 12 | пунктов. Обзор исследований | принципов |  | и |  | характеристик | ООР можно  | найти | в статье | Космас с коллегами  | [3]. | Одна из  | характеристик | открытой науки: «прозрачность, контроль, критический анализ  | и | воспроизводимость результатов | …в целях усиления | надежности |  | и | точности | научных результатов,  | а | также  | воздействия | науки | на общество»  | [4, |  | с.12]. | Специалисты в области прикладной  | и | корпусной лингвистики |  | говорят | о кризисе воспроизводимости |  | (replication |  | crisis) |  | (см., | например,  | [5]). |  | Анализируя | тенденции развития | исследований | в области обучения | ИЯ с использованием подходов | корпусной лингвистики |  | (DDL) | за последние  | 30 | лет | на материале  | 480 | публикаций | в авторитетных рецензируемых англоязычных журналах, глав |  | монографий |  | и | материалах авторитетных конференций, А. Болтон  | и | Н. Вяткина |  | обнаружили | полное  | отсутствие | исследований, направленных на частичное воспроизведение/ повторение «классических» работ | в новых условиях с другими категориями обучающихся  | [6, |  | p. |  | 83.]. |  | Следует | заметить,  | что | авторы в  | соответствии | с принципами открытой науки |  | разместили | информацию о всех отобранных для анализа | публикациях в открытом доступе в  | онлайн | репозитории инструментов |  | и |  | материалов | для исследований | в области иностранных языков |  | IRIS |  | . |  | 1. | Важность концепции | ООР для  | более | широкого использования | корпусной лингводидактики | в обучении | ИЯ Несмотря на эффективность использования | подходов | корпусной лингвистики | в обучении | ИЯ  | как |  | показал | мета-анализ, проведенный Болтоном  | и | Коббом  | [7] |  | и |  | давно | предсказанную революцию в мет ...

# %%
with open('corpus_kogan.txt', 'w', encoding='utf-8') as f2:
    f2.write(words2)

# %%
from __future__ import division
import operator
import nltk

# %%
punct = open("stopwords/punct.txt", 'r', encoding='utf-8').read()

# %%
punct_list = nltk.word_tokenize(punct)

# %%
stop = open("stopwords/stop.txt", 'r', encoding='utf-8').read()

# %%
pronouns = open("stopwords/pronouns.txt", 'r', encoding='utf-8').read()

# %%
preps = open("stopwords/preps.txt", 'r', encoding='utf-8').read()

# %%
preps
# Out:
# 'а-ля\nбез\nбезо\nблагодаря\nблиз\nв\nвблизи\nввиду\nвглубь\nвдогон\nвдоль\nвзамен\nвключая\nвкруг\nвместо\nвне\nвнизу\nвнутри\nвнутрь\nво\nво имя\nвовнутрь\nвозле\nвокруг\nвопреки\nвослед\nвпереди\nвразрез\nвроде\nвслед\nвследствие\nдля\nдля-ради\nдо\nза\nзаместо\nиз\nиз-за\nиз-под\nизнутри\nизо\nк\nкасательно\nко\nкроме\nкругом\nмеж\nмежду\nмимо\nна\nнаверху\nнавроде\nнавстречу\nнад\nнадо\nназад\nнакануне\nнаперекор\nнаперерез\nнаподобие\nнапротив\nнасупротив\nнасчёт\nниже\nо\nоб\nобо\nобок\nоколо\nокрест\nокромя\nокруг\nопосля\nот\nотносительно\nото\nперед\nпередо\nпо\nпо-за\nпо-над\nпо-под\nповерх\nпод\nподле\nподо\nподобно\nпозади\nпозднее\nпомимо\nпоперёд\nпоперёк\nпорядка\nпосередине\nпосередь\nпосле\nпосреди\nпосредине\nпосредством\nпред\nпредо\nпрежде\nпри\nпро\nпротив\nпутём\nради\nс\nсверх\nсверху\nсвыше\nсзади\nсквозь\nскрозь\nснизу\nсо\nсогласно\nспустя\nсреди\nсредь\nсродни\nсупротив\nчерез\nчрез\n'

# %%
mystop = open("stopwords/userstop.txt", 'r', encoding='utf-8').read()

# %%
#nltk.word_tokenize(preps.decode("utf8")) + nltk.word_tokenize(mystop.decode("utf8"))
nltk.word_tokenize(preps) + nltk.word_tokenize(mystop)
# Out:
# ['а-ля',
#  'без',
#  'безо',
#  'благодаря',
#  'близ',
#  'в',
#  'вблизи',
#  'ввиду',
#  'вглубь',
#  'вдогон',
#  'вдоль',
#  'взамен',
#  'включая',
#  'вкруг',
#  'вместо',
#  'вне',
#  'внизу',
#  'внутри',
#  'внутрь',
#  'во',
#  'во',
#  'имя',
#  'вовнутрь',
#  'возле',
#  'вокруг',
#  'вопреки',
#  'вослед',
#  'впереди',
#  'вразрез',
#  'вроде',
#  'вслед',
#  'вследствие',
#  'для',
#  'для-ради',
#  'до',
#  'за',
#  'заместо',
#  'из',
#  'из-за',
#  'из-под',
#  'изнутри',
#  'изо',
#  'к',
#  'касательно',
#  'ко',
#  'кроме',
#  'кругом',
#  'меж',
#  'между',
#  'мимо',
#  'на',
#  'наверху',
#  'навроде',
#  'навстречу',
#  'над',
#  'надо',
#  'назад',
#  'накануне',
#  'наперекор',
#  'наперерез',
#  'наподобие',
#  'напротив',
#  'насупротив',
#  'насчёт',
#  'ниже',
#  'о',
#  'об',
#  'обо',
#  'обок',
#  'около',
#  'окрест',
#  'окромя',
#  'округ',
#  'опосля',
#  'от',
#  'относительно',
#  'ото',
#  'перед',
#  'передо',
#  'по',
#  'по-за',
#  'по-над',
#  'по-под',
#  'поверх',
#  'под',
#  'подле',
#  'подо',
#  'подобно',
#  'позади',
#  'позднее',
#  'помимо',
#  'поперёд',
#  'поперёк',
#  'порядка',
#  'посередине',
#  'посередь',
#  'после',
#  'посреди',
#  'посредине',
#  'посредством',
#  'пред',
#  'предо',
#  'прежде',
#  'при',
#  'про',
#  'против',
#  'путём',
#  'ради',
#  'с',
#  'сверх',
#  'сверху',
#  'свыше',
#  'сзади',
#  'сквозь',
#  'скрозь',
#  'снизу',
#  'со',
#  'согласно',
#  'спустя',
#  'среди',
#  'средь',
#  'сродни',
#  'супротив',
#  'через',
#  'чрез',
#  '``',
#  '--',
#  '.-',
#  '...',
#  '``',
#  '»',
#  'благодаря',
#  'был',
#  'была',
#  'в',
#  'виде',
#  'в',
#  'случае',
#  'в',
#  'частности',
#  'виде',
#  'все',
#  'всей',
#  'всем',
#  'всеми',
#  'всякая',
#  'всякй',
#  'всё',
#  'главное',
#  'образ',
#  'главным',
#  'образом',
#  'года',
#  'году',
#  'два',
#  'два',
#  'две',
#  'двум',
#  'двум',
#  'двумя',
#  'двух',
#  'до',
#  'другие',
#  'другие',
#  'другим',
#  'другими',
#  'других',
#  'других',
#  'другого',
#  'другой',
#  'другому',
#  'ею',
#  'её',
#  'за',
#  'счет',
#  'какая-то',
#  'какие',
#  'какие-то',
#  'каким-нибудь',
#  'каким-то',
#  'какими',
#  'какими-то',
#  'каких-либо',
#  'каких-либо',
#  'каких-то',
#  'какое-то',
#  'какой-то',
#  'какому-то',
#  'качестве',
#  'кг',
#  'котором',
#  'мои',
#  'моими',
#  'моих',
#  'мой',
#  'мою',
#  'моя',
#  'нам',
#  'нами',
#  'например',
#  'нас',
#  'наши',
#  'наших',
#  'некоторые',
#  'некоторый',
#  'некоторых',
#  'нескольких',
#  'нем',
#  'нему',
#  'никакими',
#  'никаких',
#  'никакой',
#  'ними',
#  'них',
#  'один',
#  'одним',
#  'одного',
#  'одному',
#  'п/п',
#  'по',
#  'расчетам',
#  'по',
#  'словам',
#  'помощи',
#  'протяжении',
#  'расчетам',
#  'с',
#  'помощью',
#  'с',
#  'точки',
#  'зрения',
#  'сама',
#  'самая',
#  'самим',
#  'само',
#  'самое',
#  'самом',
#  'свое',
#  'своего',
#  'своей',
#  'своем',
#  'своемy',
#  'своему',
#  'своею',
#  'свои',
#  'своим',
#  'своими',
#  'своих',
#  'свой',
#  'своя',
#  'своё',
#  'своём',
#  'себя',
#  'сказал',
#  'следующим',
#  'собой',
#  'соответствующей',
#  'соответствующему',
#  'соответствующий',
#  'соответствующими',
#  'ста',
#  'стами',
#  'сто',
#  'таким',
#  'таким',
#  'образом',
#  'такими',
#  'такими',
#  'таких',
#  'такого',
#  'такой',
#  'таком',
#  'твоим',
#  'течение',
#  'тремя',
#  'трех',
#  'три',
#  'трёх',
#  'тысяч',
#  'тысяча',
#  'тысячами',
#  'уж',
#  'четыре',
#  'четырьмя',
#  'четырёх',
#  'эта',
#  'этим',
#  'этими',
#  'этих',
#  'это',
#  'этому',
#  '—',
#  '•',
#  '№']

# %%
stop_list = nltk.word_tokenize(stop) + nltk.word_tokenize(pronouns) + nltk.word_tokenize(preps) + nltk.word_tokenize(mystop)

# %%
def isPunct(word):
  return len(word) == 1 and (word in string.punctuation or word in punct_list)

# %%
def isNumeric(word):
  try:
    float(word) if '.' in word else int(word)
    return True
  except ValueError:
    return False

# %%
def isInitial(word):
  return len(word) == 2 and word[1] == "."

# %%
class RakeKeywordExtractor:

  def __init__(self):
    self.stopwords = set(nltk.corpus.stopwords.words())
    self.top_fraction = 1 # consider top third candidate keywords by score

  def _generate_candidate_keywords(self, sentences):
    phrase_list = []
    for sentence in sentences:
      words = map(lambda x: "|" if x in self.stopwords or x in stop_list or isNumeric(x) or isInitial(x) else x,
        nltk.word_tokenize(sentence.lower()))
      phrase = []
      for word in words:
        if word == "|" or isPunct(word):
          if len(phrase) > 0:
            phrase_list.append(phrase)
            phrase = []
        else:
          phrase.append(word)
    return phrase_list
## СТОП!!
  def _calculate_word_scores(self, phrase_list):
    word_freq = nltk.FreqDist()
    word_degree = nltk.FreqDist()
    for phrase in phrase_list:
      #degree = len(filter(lambda x: not isNumeric(x), phrase)) - 1
      degree = len(list(filter(lambda x: not isNumeric(x), phrase))) - 1
      for word in phrase:
        word_freq[word] += 1 ## word_fd.inc(word.lower()) with word_fd[word.lower()] += 1
        word_degree[word] += degree # other words
    for word in word_freq.keys():
      word_degree[word] = word_degree[word] + word_freq[word] # itself
    # word score = deg(w) / freq(w)
    word_scores = {}
    for word in word_freq.keys():
      word_scores[word] = word_degree[word] / word_freq[word]
    return word_scores

  def _calculate_phrase_scores(self, phrase_list, word_scores):
    phrase_scores = {}
    for phrase in phrase_list:
      phrase_score = 0
      for word in phrase:
        phrase_score += word_scores[word]
      phrase_scores[" ".join(phrase)] = phrase_score
    return phrase_scores

  def extract(self, text, incl_scores=False):
    sentences = nltk.sent_tokenize(text)
    phrase_list = self._generate_candidate_keywords(sentences)
    word_scores = self._calculate_word_scores(phrase_list)
    phrase_scores = self._calculate_phrase_scores(
      phrase_list, word_scores)
    #sorted_phrase_scores = sorted(phrase_scores.iteritems(),
    sorted_phrase_scores = sorted(phrase_scores.items(),
      key=operator.itemgetter(1), reverse=True)
    n_phrases = len(sorted_phrase_scores)
    if incl_scores:
      return sorted_phrase_scores[0:int(n_phrases/self.top_fraction)]
    else:
      return map(lambda x: x[0],
        sorted_phrase_scores[0:int(n_phrases/self.top_fraction)])

# %%
rake = RakeKeywordExtractor()

# %%
with open('corpus/Kogan_IMS_2022.txt', 'r', encoding='utf-8') as f:
    txt = f.read()

# %%
keywords = rake.extract(txt, incl_scores=True)

# %%
for eachkwrd in keywords:
    print(eachkwrd[0], eachkwrd[1])
# Out:
# разделе teaching activities помещены примеры учебных материалов /детально разработанных планов уроков продолжительностью 80-120 мин 113.02857142857144
# другая возможность платной версии касается тестирования незнакомой лексики 59.66666666666667
# российские стандарты уделяют первостепенное внимание проектной деятельности студентов 54.083333333333336
# представляющих неформальные беседы носителей британского варианта английского языка 51.8
# сайте проекта языкового ресурсного центра канзасского университета https 51.77380952380952
# будущие преподаватели ия могли успешно интегрировать подходы кл 48.86363636363636
# рамках которых изучаются реальные явления современного английского языка 47.9
# имеющие подписки пользователи платформы соса часто сталкиваются 44.75
# разные исследователи называют разные причины сложившейся ситуации 44.66666666666667
# задания могут включать освоение новых лексико-грамматических характеристик слов 44.6
# свободном доступе находится достаточно большое количество больших корпусов 44.470588235294116
# русскоязычном сегменте интернета такие материалы практически отсутствуют 44.3
# каждая глава содержит подробную инструкцию поиска материалов 44.28571428571429
# скотт представил последнюю версию корпусного менеджера wordsmith 43.733333333333334
# 1-й просит кратко сформулировать основную идею видеосюжета 42.833333333333336
# студенты будут изучать возможности корпусной лингвистики наряду 42.363883847549914
# систему интегрирована передовая технология записи речи intellispeechsm 41.25
# русскоязычном сегменте интернета корпусной лингвистике посвящены лекции 40.758620689655174
# ряд вопросов /идей/высказанных предложений требует дальнейшего исследования 40.53333333333333
# план полноценного урока продолжительностью 80-120 минут 37.4
# рамках проектной деятельности заслуживает всяческого внимания 37.33333333333333
# массовом сознании являются примером открытых образовательных ресурсов 37.166666666666664
# каждого видео урока имеется интерактивный план урока 36.93846153846154
# мае 2022г версия нкря содержит существенно расширенный 36.85714285714286
# воспроизводимость результатов …в целях усиления надежности 34.5
# небольшие учебные видеоролики продолжительностью 5-7 минут 34.333333333333336
# студенты филологических специальностей получают базовые знания 34.0
# основным фокусом является расширение словарного запаса 34.0
# авторы анализируют используемые ими основные учебники 34.0
# использовать основные функции программы antconc версии 3.4.0 33.05555555555556
# формате ielts является расширение словарного запаса 32.5
# последующие годы будапештская инициатива получила развитие 32.25
# отсутствие примеров аутентичных разговорных речевых образцов 32.166666666666664
# зарегистрированные наукометрических базах данных разного ранга 32.0
# практическом применении достижений современной корпусной лингвистики 31.86388384754991
# большим выборкам устной речи bnc 1990-х 31.75
# открытые образовательные ресурсы обладают рядом характеристик 31.166666666666664
# позволяет освоить базовые методы корпусного преподавания 31.066666666666666
# исследователи дополняют список характеристик понятия открытость 31.0
# имевшем целью оценить влияние корпусной лингвистики 30.61388384754991
# образовательный портал национального корпуса русского языка 30.579411764705885
# фолл призывает активно создавать небольшие видео 30.53846153846154
# тематически близких видео выбранного уровня сложности 30.53846153846154
# целью является развитие навыков академического письма 29.75
# разделе сайта нкри studorium результаты проекта 28.883333333333333
# контексте парадигмы открытых образовательных ресурсов м.с 28.8
# бесплатной версии такая возможность представляется 28.166666666666668
# специально проведенный анализ сравнения моок курсов 27.25
# собственным опытом применения подходов корпусной лингвистики 26.61388384754991
# уменьшить употребление избыточно используемой лексики 26.5
# повседневную педагогическую практику преподавателей иностранных языков 26.208333333333332
# развитие навыка создания учебных материалов 25.978571428571428
# честь 50-летия основания магистерской программы 25.666666666666668
# движения считается майкл стерн харт 25.0
# основе конкретного корпуса является проект corpus 24.696078431372552
# обязательным использованием изучаемого грамматического явления 24.625
# учит пользоваться существующими корпусами русского 23.75
# руководители программы организовали серию вебинаров 23.666666666666668
# разным уровнем владения немецким языком 23.333333333333332
# снабжены инструкциями пользователя внушительного объема 23.0
# вопроса побуждают высказать собственное мнение 23.0
# оор позволил выявить важные отличия 22.857142857142858
# youtube выдает целый ряд ссылок 22.666666666666668
# целью курса является знакомство участников 22.5
# каждой теме включают раздаточные упражнения 22.0
# контент содержит тысячи отдельных видео 21.895604395604394
# которая автоматически сравнивает произнесенный фрагмент 21.75
# основе материалов открытых онлайн корпусов 21.732492997198882
# ресурсы являются открытыми образовательными ресурсами 21.7
# учащиеся должны составить собственные предложения 21.666666666666668
# материале национального корпуса русского языка 21.579411764705885
# выпускников английских школ задания представлены 21.333333333333332
# разработанные материалы представляли четкие инструкции 21.3
# вяткина обнаружили полное отсутствие исследований 21.25
# примером привязки планов уроков 20.8
# эффективность использования подходов корпусной лингвистики 20.73888384754991
# широкому внедрению методов корпусной лингводидактики 20.708620689655174
# доступные онлайн корпуса английского языка 20.662745098039217
# корпусу является мультимедийный ресурс englishcentral 20.0
# созданных оор недооценивается основной учебник 19.857142857142858
# знакомых учителю планов уроков 19.8
# представительный список онлайн корпусов доступен 19.47058823529412
# анализ учебных материалов/планов уроков 19.3
# теме использования подходов корпусной лингвистики 19.23888384754991
# соответствуют разным инструментам корпуса dwds 19.112745098039213
# принципами открытой науки разместили информацию 19.0
# целый ряд образовательных ресурсов 18.8
# коган введение развитие интернета 18.0
# эффективности привязки планов уроков/заданий 17.8
# требует дальнейшего исследования вопрос 17.7
# функционал которого существенно расширен 17.5
# обзор открытых образовательных ресурсов 17.3
# повседневной педагогической практике преподавателей ия 17.071969696969695
# 60-е годы прошлого века 17.0
# методически обоснованные планы уроков 17.0
# будущими преподавателями иностранного языка 16.8
# которых последовательно объясняются основы 16.6
# которых проводилось несколько мастер-классов 16.6
# многочисленные примеры использования корпусов 16.54558823529412
# тренд задала будапештская инициатива 16.5
# тех присоединились тысячи организаций 16.5
# блестящим примером создания оор 16.357142857142858
# использовать подходы корпусной лингвистики 16.086106069772132
# полным текстам соответствующих статей 16.0
# статье 2019г обратила внимание 16.0
# отсутствие доступного банка упражнений 16.0
# новым корпусным менеджером lancsbox. 16.0
# small private online course 16.0
# анонсы предстоящих событий публикуются 16.0
# готовящихся сдать итоговый экзамен 16.0
# видеофрагмент длится 1-2 минуты 16.0
# удалось избежать типичной ошибки 16.0
# сократив заложенное время ожидания 16.0
# использования разработанных материалов 15.970238095238097
# основе подходов корпусной лингвистики 15.86388384754991
# архив университета бригама янга 15.857142857142858
# элективного односеместрового специального курса 15.75
# описывает примеры заданий обращений 15.7
# руководства пользователя очень далеки 15.666666666666666
# основе информации видео урока 15.538461538461538
# первую очередь национальные корпуса 15.529411764705882
# созданию собственного специального корпуса 15.529411764705882
# основе параллельного англо-китайского корпуса 15.529411764705882
# прослушать незнакомое слово несколько 15.5
# которых являются бесплатный доступ 15.4
# 2-х страничный план мини-урока 15.4
# недостаточная подготовка преподавателей ия 15.238636363636363
# основе открытого корпуса bawe 15.196078431372548
# кафедре математической лингвистики спбгу 15.105263157894736
# продолжительность обучающих видео колеблется 15.038461538461538
# касающиеся влияния открытого образования 15.0
# авторитетных рецензируемых англоязычных журналах 15.0
# желающих освоить основы кл 15.0
# использованием подходов корпусной лингвистики 14.98888384754991
# обладают базовыми характеристиками оор 14.857142857142858
# широкого использования корпусной лингводидактики 14.833620689655174
# использования подходов корпусной лингводидактики 14.833620689655174
# массовые открытые онлайн курсы 14.833333333333334
# носителей английского языка 14.8
# широкому применению подходов кл 14.75
# участия всемирно известных ученых 14.666666666666666
# такому повороту событий учащихся 14.666666666666666
# основе доступных онлайн корпусов 14.637254901960786
# маленький частный онлайн курс 14.633333333333333
# курсе методики обучения ия 14.363636363636363
# затрагивает вопросы обучения ия 14.363636363636363
# обучение ия является платформа 14.363636363636363
# которые подбираются системой автоматически 14.357142857142858
# предполагающих разный формат работы 14.333333333333334
# контексте статьи важно отметить 14.333333333333332
# свободном доступе онлайн корпусов 14.303921568627452
# анализируя тенденции развития исследований 14.25
# области иностранных языков iris 14.208333333333332
# верификация примеров употребления слов/словосочетаний 14.166666666666666
# реализованной создателями english central 14.125
# наиболее популярные моок курсы 14.083333333333334
# корпусу немецкого языка dwds 14.05
# использованию новых программных продуктов 14.0
# прикладной лингвистике университета сан-паолу 13.857142857142858
# выводы проведенный анализ показал 13.833333333333334
# решения определенной педагогической задачи 13.666666666666666
# документе открытый доступ определялся 13.6
# исследовательской самостоятельной работы обучающихся 13.583333333333334
# коллекции корпусов sketch engine 13.47058823529412
# развитию практик использования оор 13.398809523809524
# разработке учебных материалов 13.228571428571428
# разработанных заданий/системы упражнений 13.166666666666668
# больших онлайн корпусов 12.803921568627452
# корпусного менеджера antconc 12.733333333333334
# обучении ия рассмотрим предложение 12.696969696969697
# способы выражения множественного числа 12.666666666666666
# канале youtube lael webinars 12.583333333333334
# лексем русского языка 12.55
# старших классов средней школы 12.5
# открытых образовательных ресурсах 12.3
# список которых приведен 12.266666666666666
# открытыми образовательными ресурсами 12.0
# собственную педагогическую практику 12.0
# проекта является размещенные 11.75
# широкоизвестного корпусного менеджера 11.733333333333334
# контексте парадигмы оор 11.69047619047619
# характеристик открытой науки 11.666666666666668
# разных учебных заведениях 11.55
# очень крупные исследователи 11.5
# указанным уровнем сложности 11.5
# мини-уроки легко могут 11.5
# основе корпусного подхода 11.4
# план урока занимает 11.4
# доступные онлайн корпуса 11.362745098039216
# систему высшего образования 11.333333333333334
# доступны разные способы 11.333333333333334
# ряду планов мини-уроков 11.3
# основе корпусных данных 11.214285714285715
# преподавателей должны базироваться 10.875
# предпочтительными являются предложения 10.866666666666667
# корпусной лингвистики говорят 10.86388384754991
# интегрированию корпусной лингвистики 10.86388384754991
# крупными онлайн корпусами 10.833333333333334
# формате множественного выбора 10.833333333333334
# teaching english language 10.833333333333332
# широкому распространению подходов 10.75
# моок является введением 10.75
# области корпусной лингвистики 10.73888384754991
# студентов варшавского университета 10.607142857142858
# просмотру видео урока 10.538461538461538
# учащиеся средних классов 10.5
# преподавание иностранных языков 10.333333333333332
# разным изучаемым темам 10.333333333333332
# коллекции англоязычных корпусов 10.303921568627452
# действующих преподавателей ия 10.238636363636363
# корпусной лингвистике доступных 10.091954022988507
# длительность видео колеблется 10.038461538461538
# методикой преподавания ия 10.03030303030303
# точности научных результатов 10.0
# отсутствие общедоступных заданий 10.0
# 24:21 мин 10.0
# спектрограммой речи диктора 10.0
# прослушать пропущенное слов 10.0
# составления конкретного задания 10.0
# основе определенного учебника 10.0
# использованием корпуса bnc 9.904411764705882
# подходами корпусной лингвистики 9.86388384754991
# содержит 3-4 вопроса 9.857142857142858
# апробация курса описана 9.75
# записи вебинаров доступны 9.75
# развития навыков аудирования 9.75
# развития письменных навыков 9.75
# идея вовлечения студентов 9.75
# применение корпусных подходов 9.714285714285715
# сайте университета квинсленда 9.69047619047619
# освоению sketch engine 9.666666666666668
# продвижению открытого доступа 9.666666666666666
# учебные материалы привязаны 9.633333333333333
# разработала учебные материалы 9.633333333333333
# разрабатывать учебные материалы 9.633333333333333
# содержатся учебные материалы 9.633333333333333
# широкому использованию корпусов 9.620588235294118
# обзор исследований принципов 9.583333333333334
# культур университета квинсленда 9.523809523809524
# странице кафедры lael 9.5
# теме international perspectives 9.5
# изменение функции местоимения 9.5
# анализ конкордансных строк 9.5
# активации функции sentence 9.5
# использование близких синонимов 9.5
# формат представления ближе 9.5
# разработчики крупных корпусов 9.470588235294118
# развитию письменных навыков 9.416666666666666
# повышения квалификации/самообразования преподавателей 9.375
# методах обучения ия 9.363636363636363
# сфере высшего образования 9.333333333333334
# онлайн репозитории инструментов 9.333333333333334
# sketch engine разместил 9.333333333333334
# сайте english central 9.291666666666666
# устному компоненту bnc 9.25
# определенной категорией обучающихся 9.25
# области обучения ия 9.238636363636363
# обзор готовых оор 9.190476190476192
# доступных онлайн корпусах 9.166666666666668
# очень ценным ресурсом 9.166666666666666
# выбрать отдельные предложения 9.166666666666666
# очень информативным блогом 9.166666666666666
# очень привлекательная идея 9.166666666666666
# очень трудоемкий процесс 9.166666666666666
# обучении ия несмотря 9.030303030303031
# обучении ия опубликованы 9.030303030303031
# обучении ия недостаточно 9.030303030303031
# информационного общества привело 9.0
# появлению важного тренда 9.0
# изобретатель электронных книг 9.0
# многочисленных документах оон 9.0
# распространение третьими лицами 9.0
# частичное воспроизведение/ повторение 9.0
# давно предсказанную революцию 9.0
# необходимость преодоления разрыва 9.0
# наша попытка проанализировать 9.0
# указанием режима обращения 9.0
# обычному преподавателю вуза 9.0
# учителях средней школы 9.0
# магистерская диссертация е.м 9.0
# открытым остается вопрос 9.0
# практических лингвистических дисциплин 9.0
# размещены презентации докладчиков 9.0
# презентации докладчиков размещены 9.0
# режима просмотра kwic 9.0
# курсу средней школы 9.0
# изучающих английский язык 9.0
# млн строк аудиозаписей 9.0
# каждую неделю добавляется 9.0
# показ сопровождается субтитрами 9.0
# пользователю предлагают посмотреть 9.0
# оценивая близость попытки 9.0
# неоднократно повторять попытки 9.0
# одной успешной практикой 9.0
# формату презентаций/научных докладов 9.0
# серьезных олимпиадных задач 9.0
# всемерно поддерживаемый оон 9.0
# самым необходимую гибкость 9.0
# самообразования преподавателей ия 8.905303030303031
# базе разных корпусов 8.887254901960784
# важность концепции оор 8.857142857142858
# создание качественных оор 8.857142857142858
# использованием корпусных технологий 8.839285714285715
# соблюдении целостности работы 8.833333333333334
# рассмотрим коллекции youtube 8.833333333333334
# скрытыми хитростями работы 8.833333333333334
# платформе представлены материалы 8.833333333333332
# курс дает представление 8.8
# курс improving writing 8.8
# подразумевающих введение материала 8.75
# введение материала преподавателем 8.75
# целью урока 8.75
# прохождении самых разных 8.75
# яссин иабдунан разместил 8.666666666666666
# роликов продолжительностью 8.666666666666666
# инициативу продолжили вебинары 8.666666666666666
# базе школы языков 8.666666666666666
# ряде международных конференций 8.666666666666666
# рубрикам current english 8.625
# обучении ия самостоятельно 8.530303030303031
# изданные немногочисленные пособия 8.5
# data-driven learning относится 8.5
# разработки программного обеспечения 8.5
# развернутое описание вебинаров 8.5
# лица множественного числа 8.5
# паролю доступен файл 8.5
# получить правильный ответ 8.5
# стороны предложили способ 8.5
# выполненный студентами вшэ 8.5
# применения корпусных менеджеров 8.464285714285715
# материалах авторитетных конференций 8.416666666666666
# план урока 8.4
# темы раскрываются /изучаются 8.333333333333334
# изучения конкретной темы 8.333333333333334
# открытом доступе меняют 8.25
# готовы регулярно использовать 8.222222222222221
# корпусных заданий определенного 8.214285714285715
# language teaching 8.208333333333332
# вебинары проходили еженедельно 8.166666666666666
# организованные ведущими центрами 8.0
# видеозаписи заседаний конференции 8.0
# конкретной категории учащихся 8.0
# рубрикам/категориям language change 7.875
# характеристик оор 7.857142857142858
# примеры заданий 7.7
# английского языков 7.5
# учебниках английской грамматики 7.5
# сайта нкри 7.333333333333334
# практической деятельности 7.333333333333333
# увидеть примеры 7.2
# новых видео 7.138461538461538
# кафедре лингвистики 7.105263157894737
# моок курсы 7.083333333333334
# преподавания ия 7.03030303030303
# анализ корпуса 7.029411764705882
# сайте университета 7.023809523809524
# подходов кл 7.0
# свободном доступе 7.0
# собраны презентации автора 7.0
# беседы в.а 7.0
# речи диктора 7.0
# корпусной лингводидактики 6.958620689655173
# которые преподаватель мог 6.857142857142858
# следующем разделе 6.8
# профессионально-ориентированного языка 6.8
# корпусной лингвистике 6.758620689655173
# основатель проекта 6.75
# записи вебинаров 6.75
# иностранный разработаны уроки 6.75
# учебные материалы 6.633333333333333
# использованием корпусов 6.595588235294118
# 2-х видео 6.538461538461538
# апрель 2022г 6.5
# version 3.4.0 6.5
# 1-й части 6.5
# обучения ия 6.363636363636363
# являются ролики 6.2
# категориями ресурсов 6.166666666666667
# группу ресурсов 6.166666666666667
# использованием кл 6.125
# сайта соса 6.083333333333334
# обучении ия 6.03030303030303
# проведенный болтоном 6.0
# составленных специально 6.0
# версией antconc 6.0
# средней школы 6.0
# плану урока 6.0
# далее дополняют 6.0
# области прикладной 5.875
# области кл 5.875
# непосредственного использования 5.875
# использованию корпусов 5.870588235294118
# никря содержит 5.857142857142858
# нкря содержит 5.857142857142858
# каждой категории 5.833333333333334
# корпусной лингводидактике 5.758620689655173
# педагогической общественности 5.666666666666666
# открытый доступ 5.6
# новых версий 5.6
# материалы разработаны 5.55
# общедоступные корпуса 5.529411764705882
# критический анализ 5.5
# проблемой является 5.5
# дополнительными инструкциями 5.5
# дополнительным инструментам 5.5
# вяткина указывает 5.5
# облако слов 5.5
# ресурс создавался 5.5
# недоступность корпусов 5.470588235294118
# материалов 5.428571428571429
# открытой науке 5.333333333333334
# воздействия науки 5.333333333333334
# выборки представлены 5.333333333333334
# понимание видеосюжета 5.333333333333334
# курс вшэ 5.3
# материалы созданы 5.3
# открытом доступе 5.25
# задания разработаны 5.25
# корпусных инструментов 5.214285714285714
# видео роликов 5.205128205128205
# исследования выполнены 5.2
# целей исследования 5.2
# вебинары проходили 5.166666666666666
# сайте bnclab 5.166666666666666
# новых условиях 5.1
# канале youtube 5.083333333333334
# окончания обучения 5.0
# свободном/открытом доступе 5.0
# фолл выложила 5.0
# наиболее популярными 5.0
# базовыми концепциями 5.0
# серии вебинаров 5.0
# современных языков 5.0
# обучение лексике 5.0
# последующего развития 5.0
# старших школьников 5.0
# желающих повысить 5.0
# методически целесообразнее 5.0
# разработки заданий 5.0
# материалах конференций 4.916666666666666
# канале разместил 4.916666666666666
# youtube каналы 4.833333333333334
# последующей работы 4.833333333333334
# разделе 4.8
# включить курс 4.8
# категориями обучающихся 4.75
# повседневной работе 4.75
# уроки разработаны 4.75
# категорию обучающихся 4.75
# разных корпусах 4.75
# корпусных пятиминуток 4.714285714285714
# corpus linguistics 4.666666666666666
# университете квинсленда 4.666666666666666
# обучении иностранным 4.666666666666666
# известных программ 4.666666666666666
# corpus technology 4.666666666666666
# известных исследователей 4.666666666666666
# собственной практике 4.666666666666666
# academic english 4.625
# travel english 4.625
# business english 4.625
# career english 4.625
# свободный доступ 4.6
# составления указателей 4.5
# открытым ресурсам 4.5
# конкретному корпусу 4.5
# повышения квалификации 4.5
# отдельные ролики 4.5
# находится 4.5
# изучаются 4.5
# выполняемым самостоятельно 4.5
# учебниках примерами 4.5
# лица ед 4.5
# получить подсказку 4.5
# английского 4.5
# приложении пособия 4.5
# описание изменений 4.5
# определенному корпусу 4.5
# рассмотренных ресурсах 4.5
# планах мини-уроков 4.5
# каких заданий 4.5
# разработка заданий 4.5
# преподаватели 4.5
# language learning 4.375
# показал мета-анализ 4.333333333333334
# категории spoc 4.333333333333334
# которая проходила 4.25
# платформе futurelearn 4.2
# национальной платформе 4.2
# платформе edex 4.2
# платформе bnclab 4.2
# базе находящихся 4.166666666666666
# eurocall corpus 4.166666666666666
# корпусная лингводидактика 4.0
# открытое образование 4.0
# ххi веке 4.0
# программное обеспечение 4.0
# законных целей 4.0
# отсутствии финансовых 4.0
# технических преград 4.0
# обязательной ссылке 4.0
# незначительными ограничениями 4.0
# статье космас 4.0
# кризисе воспроизводимости 4.0
# replication crisis 4.0
# глав монографий 4.0
# следует заметить 4.0
# анализа публикациях 4.0
# сих пор 4.0
# учебном процессе 4.0
# является 4.0
# требуется регистрация 4.0
# находилась вплоть 4.0
# весны 2020г. 4.0
# вынужден метаться 4.0
# разными источниками 4.0
# проблема серьезна 4.0
# простых путей 4.0
# нашем исследовании 4.0
# современном этапе 4.0
# требованиями фгос 4.0
# исследователь предполагает 4.0
# ситуация улучшится 4.0
# мотивированных будущих 4.0
# обзора видеоресурсов 4.0
# целые серии 4.0
# ланкастерском университете 4.0
# корпусную лингвистику 4.0
# представленный а.и 4.0
# прямым обращением 4.0
# родному языку 4.0
# корпусные инструменты 4.0
# сентябрь 2020г 4.0
# недели интенсива 4.0
# последний познакомил 4.0
# новой версией 4.0
# социальных сетях 4.0
# applied linguistics 4.0
# корпусная лингвистика 4.0
# дистанционном режиме 4.0
# конкретным корпусам 4.0
# первый взгляд 4.0
# проблема неактуальна 4.0
# педагогических принципах 4.0
# стороны преподавателя 4.0
# базовый поиск 4.0
# временная ось 4.0
# визуализация коллокаций 4.0
# a-level exam 4.0
# spoken communication 4.0
# communicative skills 4.0
# 2-м лице 4.0
# чтение абзаца 4.0
# обсуждение предлагаемых 4.0
# любом месте 4.0
# всплывающем окне 4.0
# затем вернуться 4.0
# пытаясь приблизить 4.0
# lesson plan 4.0
# 4-х заданий 4.0
# пользуясь контекстом 4.0
# последующей практики 4.0
# возможных ответов 4.0
# умолчанию деактивирована 4.0
# ответы даны 4.0
# corpus-aided platform 4.0
# университете гонконга 4.0
# qing angel 4.0
# младшие школьники 4.0
# фол вместе 4.0
# 3-х семестров 4.0
# начале студентам 4.0
# специальных целей 4.0
# конкретном корпусе 4.0
# выявленные трудности 4.0
# выполнении запроса 4.0
# должно способствовать 4.0
# некоторым аналогом 4.0
# своевольные смыслы 4.0
# 19-21 вв. 4.0
# бесплатным курсом 4.0
# младших школьников 4.0
# 13-15-летних подростков 4.0
# серией игр 4.0
# строгом смысле 4.0
# ценными инструментами 4.0
# профессиональный уровень 4.0
# каждому видеофрагменту 4.0
# десятки страниц 4.0
# доказательно критикуют 4.0
# крайней мере 4.0
# весьма эффективной 4.0
# конкретному учебнику 4.0
# увеличивая вероятность 4.0
# совершенно очевидно 4.0
# будущих педагогов 4.0
# language teachers 3.875
# содержит 3.857142857142857
# которые тренировались 3.857142857142857
# студентов 3.75
# материалах габласовой 3.75
# научных статьях 3.7
# открытые 3.6666666666666665
# примеров 3.6666666666666665
# видео 3.5384615384615383
# корпуса 3.5294117647058822
# авторы 3.5
# недавние публикации 3.5
# поисковыми заданиями 3.5
# теме 3.5
# знания 3.5
# ленко-шиманска считает 3.5
# корпусе coca 3.5
# доступность делает 3.5
# осенью 2021г 3.5
# большей поддержки 3.5
# индивидуальную работу 3.5
# малых группах 3.5
# иллюстрирующего правило 3.5
# функции 3.5
# video transcript 3.5
# слов 3.5
# зарегистрированные 3.5
# верные слова 3.5
# разнообразными заданиями 3.5
# материалах вяткиной 3.5
# видеосюжета 3.3333333333333335
# мнению разработчиков 3.333333333333333
# исследований 3.25
# bnc 3.25
# параллельным корпусом 3.25
# руководством н.р 3.25
# исследования 3.2
# лингводидактики 3.2
# сайте 3.1666666666666665
# материале 3.0
# языков 3.0
# имеют публикации 3.0
# кл 3.0
# ленко-шиманска corpora 3.0
# инструкции 3.0
# задания 3.0
# вопроса 3.0
# фолл 3.0
# оор 2.857142857142857
# youtube 2.8333333333333335
# работы 2.8333333333333335
# dwds 2.75
# применения 2.75
# введение 2.75
# соса 2.75
# развитию 2.6666666666666665
# способы 2.6666666666666665
# рассмотрим 2.6666666666666665
# учащихся 2.6666666666666665
# числа 2.6666666666666665
# практике 2.6666666666666665
# доступ 2.6
# доступен 2.5
# решения 2.5
# корпусу 2.5
# употребления 2.5
# тренд 2.5
# использованию 2.4
# информацию 2.3333333333333335
# темы 2.3333333333333335
# показал 2.3333333333333335
# канале 2.25
# которая 2.25
# использовать 2.2222222222222223
# автора 2.0
# собраны 2.0
# использование 2.0
# созданных 2.0
# корпусах 2.0
# нкря 2.0
# преподаватель 2.0
# подходами 2.0
# статье 2.0
# важно 2.0
# организованные 2.0
# иностранный 2.0
# грамматики 2.0
# конференции 2.0
# разработке 2.0
# language 1.875
# которые 1.8571428571428572
# самообразования 1.6666666666666667
# роликов 1.6666666666666667
# публикации 1.5
# coca 1.5
# проблемой 1.5
# правило 1.5
# находящихся 1.5
# имеют 1.5
# corpora 1.5
# ленко-шиманска 1.5
# eurocall 1.5
# группах 1.5
# 2021г 1.5
# работу 1.5
# габласовой 1.5
# преподавателя 1.5
# video 1.5
# слова 1.5
# делает 1.5
# 4-х 1.5
# заданиями 1.5
# поддержки 1.5
# условиях 1.5
# мнению 1.3333333333333333
# работе 1.25
# корпусом 1.25
# вяткиной 1.25
# руководством 1.25
# статьях 1.2
# науку 1.0
# инициатором 1.0
# гутенберг 1.0
# которой 1.0
# интернете 1.0
# читать 1.0
# разгружать 1.0
# копировать 1.0
# распространять 1.0
# распечатывать 1.0
# находить 1.0
# присоединять 1.0
# вводить 1.0
# данные 1.0
# правовых 1.0
# … 1.0
# использовании 1.0
# цитировании 1.0
# юнеско 1.0
# рекомендациях 1.0
# т.д 1.0
# изучение 1.0
# томе 1.0
# находящемся 1.0
# важнейшими 1.0
# право 1.0
# адаптацию 1.0
# ограничений 1.0
# пунктов 1.0
# найти 1.0
# коллегами 1.0
# одна 1.0
# прозрачность 1.0
# контроль 1.0
# общество 1.0
# с.12 1.0
# специалисты 1.0
# см. 1.0
# ddl 1.0
# последние 1.0
# лет 1.0
# публикаций 1.0
# болтон 1.0
# направленных 1.0
# классических 1.0
# работ 1.0
# p 1.0
# соответствии 1.0
# отобранных 1.0
# коббом 1.0
# произошло 1.0
# чамбес 1.0
# исследованиями 1.0
# привела 1.0
# списку 1.0
# причин 1.0
# остановимся 1.0
# проблемах 1.0
# описанных 1.0
# препятствий 1.0
# недоступных 1.0
# научной 1.0
# онлайн-поиска 1.0
# скачивания 1.0
# изучении 1.0
# говоря 1.0
# затруднен 1.0
# каталогизированы 1.0
# описаны 1.0
# имеющихся 1.0
# примера 1.0
# сослаться 1.0
# относятся 1.0
# находящиеся 1.0
# адрес 1.0
# шоу 1.0
# переместилась 1.0
# упражнениями 1.0
# содержат 1.0
# инструкций 1.0
# привязанных 1.0
# кажется 1.0
# существует 1.0
# россии 1.0
# пришли 1.0
# выводу 1.0
# насколько 1.0
# p.234 1.0
# теоретических 1.0
# начнем 1.0
# запросу 1.0
# дисциплины 1.0
# 6:57 1.0
# элен 1.0
# набравшими 1.0
# год 1.0
# просмотров 1.0
# ролика 1.0
# 0:29 1.0
# 5:25 1.0
# антони 1.0
# объясняющих 1.0
# разработал 1.0
# 4:15 1.0
# 14:38 1.0
# делясь 1.0
# менее 1.0
# method 1.0
# analysis 1.0
# interpretation 1.0
# разработанный 1.0
# макэнери 1.0
# размещенный 1.0
# знакомит 1.0
# разработанным 1.0
# брезиной 1.0
# левинзон 1.0
# размещен 1.0
# разработан 1.0
# кроссвейтом 1.0
# корпус 1.0
# бразилия 1.0
# пригласив 1.0
# байбера 1.0
# скотта 1.0
# ромер 1.0
# дэвис 1.0
# реппен 1.0
# др 1.0
# апреля 1.0
# августе 1.0
# сентября 1.0
# момент 1.0
# years 1.0
# австралия 1.0
# октября 1.0
# состоялся 1.0
# вебинар 1.0
# докладчиками 1.0
# франкенберг-гарсия 1.0
# кроссвейт 1.0
# сравнению 1.0
# кроссвейта 1.0
# talc 1.0
# фейсбуке 1.0
# linkedin 1.0
# плунгяна 1.0
# д.о 1.0
# добровольского 1.0
# постнауке 1.0
# бузаджи 1.0
# в.п 1.0
# захарова 1.0
# обновленная 1.0
# 364-365 1.0
# показаться 1.0
# т.к 1.0
# инструкция 1.0
# стр. 1.0
# стр 1.0
# сопровождение 1.0
# вовлечение 1.0
# идти 1.0
# простого 1.0
# сложному 1.0
# заданиям 1.0
# начинающих 1.0
# продвинутых 1.0
# парах 1.0
# приведенные 1.0
# schools 1.0
# создаваемый 1.0
# второй 1.0
# gender 1.0
# region 1.0
# age 1.0
# отраженные 1.0
# трансформация 1.0
# данном 1.0
# ответами 1.0
# комментариями 1.0
# создан 1.0
# говорения 1.0
# мини-курсов 1.0
# категориях 1.0
# expressions 1.0
# остановить 1.0
# процентах 1.0
# учащийся 1.0
# произношение 1.0
# месяц 1.0
# состоит 1.0
# пропусками 1.0
# 4-6 1.0
# заполнить 1.0
# памяти 1.0
# определения 1.0
# словаря 1.0
# впечатанного 1.0
# пробел 1.0
# кликнув 1.0
# пробелу 1.0
# задании 1.0
# словами 1.0
# приводятся 1.0
# задание 1.0
# предлагает 1.0
# обсуждения 1.0
# explain 1.0
# sentences 1.0
# cap 1.0
# созданная 1.0
# произношения 1.0
# категориям 1.0
# грамматике 1.0
# произношению 1.0
# подкатегории 1.0
# указывающие 1.0
# вузов 1.0
# дэвиса 1.0
# страницы 1.0
# студентами-магистрантами 1.0
# разместила 1.0
# поиску 1.0
# классе 1.0
# проблему 1.0
# решали 1.0
# ходу 1.0
# начальной 1.0
# 2-й 1.0
# 3-й 1.0
# 4-й 1.0
# идеи 1.0
# ограничения 1.0
# задержкой 1.0
# свидетельства 1.0
# факт 1.0
# демотивирующим 1.0
# неподготовленных 1.0
# сталкивались 1.0
# эффектом 1.0
# обойти 1.0
# направленного 1.0
# значении 1.0
# употреблении 1.0
# добрушиной 1.0
# м.а 1.0
# даниель 1.0
# 2012гг 1.0
# детский 1.0
# раздел 1.0
# путеводителем 1.0
# детей 1.0
# работать 1.0
# игровых 1.0
# помочь 1.0
# т.е 1.0
# описанными 1.0
# литературе 1.0
# понять 1.0
# привязке 1.0
# реализована 1.0
# //corpora.ku.edu 1.0
# случаях 1.0
# ма 1.0
# созданные 1.0
# эффективнее 1.0
# объемом 1.0
# думается 1.0
# ресурс/источник 1.0
# возможностей 1.0
# указания 1.0
# явно 1.0
# каком 1.0
# учебнике 1.0
# привести 1.0
# дополнения 1.0
# модели 1.0
# интегрированы 1.0
# обеспечивая 1.0
# знакомые 1.0
# начнут 1.0
# внедрения 1.0
# особенно 1.0

# %%
keywords
# Out:
# [('разделе teaching activities помещены примеры учебных материалов /детально разработанных планов уроков продолжительностью 80-120 мин',
#   113.02857142857144),
#  ('другая возможность платной версии касается тестирования незнакомой лексики',
#   59.66666666666667),
#  ('российские стандарты уделяют первостепенное внимание проектной деятельности студентов',
#   54.083333333333336),
#  ('представляющих неформальные беседы носителей британского варианта английского языка',
#   51.8),
#  ('сайте проекта языкового ресурсного центра канзасского университета https',
#   51.77380952380952),
#  ('будущие преподаватели ия могли успешно интегрировать подходы кл',
#   48.86363636363636),
#  ('рамках которых изучаются реальные явления современного английского языка',
#   47.9),
#  ('имеющие подписки пользователи платформы соса часто сталкиваются', 44.75),
#  ('разные исследователи называют разные причины сложившейся ситуации',
#   44.66666666666667),
#  ('задания могут включать освоение новых лексико-грамматических характеристик слов',
#   44.6),
#  ('свободном доступе находится достаточно большое количество больших корпусов',
#   44.470588235294116),
#  ('русскоязычном сегменте интернета такие материалы практически отсутствуют',
#   44.3),
#  ('каждая глава содержит подробную инструкцию поиска материалов',
#   44.28571428571429),
#  ('скотт представил последнюю версию корпусного менеджера wordsmith',
#   43.733333333333334),
#  ('1-й просит кратко сформулировать основную идею видеосюжета',
#   42.833333333333336),
#  ('студенты будут изучать возможности корпусной лингвистики наряду',
#   42.363883847549914),
#  ('систему интегрирована передовая технология записи речи intellispeechsm',
#   41.25),
#  ('русскоязычном сегменте интернета корпусной лингвистике посвящены лекции',
#   40.758620689655174),
#  ('ряд вопросов /идей/высказанных предложений требует дальнейшего исследования',
#   40.53333333333333),
#  ('план полноценного урока продолжительностью 80-120 минут', 37.4),
#  ('рамках проектной деятельности заслуживает всяческого внимания',
#   37.33333333333333),
#  ('массовом сознании являются примером открытых образовательных ресурсов',
#   37.166666666666664),
#  ('каждого видео урока имеется интерактивный план урока', 36.93846153846154),
#  ('мае 2022г версия нкря содержит существенно расширенный', 36.85714285714286),
#  ('воспроизводимость результатов …в целях усиления надежности', 34.5),
#  ('небольшие учебные видеоролики продолжительностью 5-7 минут',
#   34.333333333333336),
#  ('студенты филологических специальностей получают базовые знания', 34.0),
#  ('основным фокусом является расширение словарного запаса', 34.0),
#  ('авторы анализируют используемые ими основные учебники', 34.0),
#  ('использовать основные функции программы antconc версии 3.4.0',
#   33.05555555555556),
#  ('формате ielts является расширение словарного запаса', 32.5),
#  ('последующие годы будапештская инициатива получила развитие', 32.25),
#  ('отсутствие примеров аутентичных разговорных речевых образцов',
#   32.166666666666664),
#  ('зарегистрированные наукометрических базах данных разного ранга', 32.0),
#  ('практическом применении достижений современной корпусной лингвистики',
#   31.86388384754991),
#  ('большим выборкам устной речи bnc 1990-х', 31.75),
#  ('открытые образовательные ресурсы обладают рядом характеристик',
#   31.166666666666664),
#  ('позволяет освоить базовые методы корпусного преподавания',
#   31.066666666666666),
#  ('исследователи дополняют список характеристик понятия открытость', 31.0),
#  ('имевшем целью оценить влияние корпусной лингвистики', 30.61388384754991),
#  ('образовательный портал национального корпуса русского языка',
#   30.579411764705885),
#  ('фолл призывает активно создавать небольшие видео', 30.53846153846154),
#  ('тематически близких видео выбранного уровня сложности', 30.53846153846154),
#  ('целью является развитие навыков академического письма', 29.75),
#  ('разделе сайта нкри studorium результаты проекта', 28.883333333333333),
#  ('контексте парадигмы открытых образовательных ресурсов м.с', 28.8),
#  ('бесплатной версии такая возможность представляется', 28.166666666666668),
#  ('специально проведенный анализ сравнения моок курсов', 27.25),
#  ('собственным опытом применения подходов корпусной лингвистики',
#   26.61388384754991),
#  ('уменьшить употребление избыточно используемой лексики', 26.5),
#  ('повседневную педагогическую практику преподавателей иностранных языков',
#   26.208333333333332),
#  ('развитие навыка создания учебных материалов', 25.978571428571428),
#  ('честь 50-летия основания магистерской программы', 25.666666666666668),
#  ('движения считается майкл стерн харт', 25.0),
#  ('основе конкретного корпуса является проект corpus', 24.696078431372552),
#  ('обязательным использованием изучаемого грамматического явления', 24.625),
#  ('учит пользоваться существующими корпусами русского', 23.75),
#  ('руководители программы организовали серию вебинаров', 23.666666666666668),
#  ('разным уровнем владения немецким языком', 23.333333333333332),
#  ('снабжены инструкциями пользователя внушительного объема', 23.0),
#  ('вопроса побуждают высказать собственное мнение', 23.0),
#  ('оор позволил выявить важные отличия', 22.857142857142858),
#  ('youtube выдает целый ряд ссылок', 22.666666666666668),
#  ('целью курса является знакомство участников', 22.5),
#  ('каждой теме включают раздаточные упражнения', 22.0),
#  ('контент содержит тысячи отдельных видео', 21.895604395604394),
#  ('которая автоматически сравнивает произнесенный фрагмент', 21.75),
#  ('основе материалов открытых онлайн корпусов', 21.732492997198882),
#  ('ресурсы являются открытыми образовательными ресурсами', 21.7),
#  ('учащиеся должны составить собственные предложения', 21.666666666666668),
#  ('материале национального корпуса русского языка', 21.579411764705885),
#  ('выпускников английских школ задания представлены', 21.333333333333332),
#  ('разработанные материалы представляли четкие инструкции', 21.3),
#  ('вяткина обнаружили полное отсутствие исследований', 21.25),
#  ('примером привязки планов уроков', 20.8),
#  ('эффективность использования подходов корпусной лингвистики',
#   20.73888384754991),
#  ('широкому внедрению методов корпусной лингводидактики', 20.708620689655174),
#  ('доступные онлайн корпуса английского языка', 20.662745098039217),
#  ('корпусу является мультимедийный ресурс englishcentral', 20.0),
#  ('созданных оор недооценивается основной учебник', 19.857142857142858),
#  ('знакомых учителю планов уроков', 19.8),
#  ('представительный список онлайн корпусов доступен', 19.47058823529412),
#  ('анализ учебных материалов/планов уроков', 19.3),
#  ('теме использования подходов корпусной лингвистики', 19.23888384754991),
#  ('соответствуют разным инструментам корпуса dwds', 19.112745098039213),
#  ('принципами открытой науки разместили информацию', 19.0),
#  ('целый ряд образовательных ресурсов', 18.8),
#  ('коган введение развитие интернета', 18.0),
#  ('эффективности привязки планов уроков/заданий', 17.8),
#  ('требует дальнейшего исследования вопрос', 17.7),
#  ('функционал которого существенно расширен', 17.5),
#  ('обзор открытых образовательных ресурсов', 17.3),
#  ('повседневной педагогической практике преподавателей ия',
#   17.071969696969695),
#  ('60-е годы прошлого века', 17.0),
#  ('методически обоснованные планы уроков', 17.0),
#  ('будущими преподавателями иностранного языка', 16.8),
#  ('которых последовательно объясняются основы', 16.6),
#  ('которых проводилось несколько мастер-классов', 16.6),
#  ('многочисленные примеры использования корпусов', 16.54558823529412),
#  ('тренд задала будапештская инициатива', 16.5),
#  ('тех присоединились тысячи организаций', 16.5),
#  ('блестящим примером создания оор', 16.357142857142858),
#  ('использовать подходы корпусной лингвистики', 16.086106069772132),
#  ('полным текстам соответствующих статей', 16.0),
#  ('статье 2019г обратила внимание', 16.0),
#  ('отсутствие доступного банка упражнений', 16.0),
#  ('новым корпусным менеджером lancsbox.', 16.0),
#  ('small private online course', 16.0),
#  ('анонсы предстоящих событий публикуются', 16.0),
#  ('готовящихся сдать итоговый экзамен', 16.0),
#  ('видеофрагмент длится 1-2 минуты', 16.0),
#  ('удалось избежать типичной ошибки', 16.0),
#  ('сократив заложенное время ожидания', 16.0),
#  ('использования разработанных материалов', 15.970238095238097),
#  ('основе подходов корпусной лингвистики', 15.86388384754991),
#  ('архив университета бригама янга', 15.857142857142858),
#  ('элективного односеместрового специального курса', 15.75),
#  ('описывает примеры заданий обращений', 15.7),
#  ('руководства пользователя очень далеки', 15.666666666666666),
#  ('основе информации видео урока', 15.538461538461538),
#  ('первую очередь национальные корпуса', 15.529411764705882),
#  ('созданию собственного специального корпуса', 15.529411764705882),
#  ('основе параллельного англо-китайского корпуса', 15.529411764705882),
#  ('прослушать незнакомое слово несколько', 15.5),
#  ('которых являются бесплатный доступ', 15.4),
#  ('2-х страничный план мини-урока', 15.4),
#  ('недостаточная подготовка преподавателей ия', 15.238636363636363),
#  ('основе открытого корпуса bawe', 15.196078431372548),
#  ('кафедре математической лингвистики спбгу', 15.105263157894736),
#  ('продолжительность обучающих видео колеблется', 15.038461538461538),
#  ('касающиеся влияния открытого образования', 15.0),
#  ('авторитетных рецензируемых англоязычных журналах', 15.0),
#  ('желающих освоить основы кл', 15.0),
#  ('использованием подходов корпусной лингвистики', 14.98888384754991),
#  ('обладают базовыми характеристиками оор', 14.857142857142858),
#  ('широкого использования корпусной лингводидактики', 14.833620689655174),
#  ('использования подходов корпусной лингводидактики', 14.833620689655174),
#  ('массовые открытые онлайн курсы', 14.833333333333334),
#  ('носителей английского языка', 14.8),
#  ('широкому применению подходов кл', 14.75),
#  ('участия всемирно известных ученых', 14.666666666666666),
#  ('такому повороту событий учащихся', 14.666666666666666),
#  ('основе доступных онлайн корпусов', 14.637254901960786),
#  ('маленький частный онлайн курс', 14.633333333333333),
#  ('курсе методики обучения ия', 14.363636363636363),
#  ('затрагивает вопросы обучения ия', 14.363636363636363),
#  ('обучение ия является платформа', 14.363636363636363),
#  ('которые подбираются системой автоматически', 14.357142857142858),
#  ('предполагающих разный формат работы', 14.333333333333334),
#  ('контексте статьи важно отметить', 14.333333333333332),
#  ('свободном доступе онлайн корпусов', 14.303921568627452),
#  ('анализируя тенденции развития исследований', 14.25),
#  ('области иностранных языков iris', 14.208333333333332),
#  ('верификация примеров употребления слов/словосочетаний', 14.166666666666666),
#  ('реализованной создателями english central', 14.125),
#  ('наиболее популярные моок курсы', 14.083333333333334),
#  ('корпусу немецкого языка dwds', 14.05),
#  ('использованию новых программных продуктов', 14.0),
#  ('прикладной лингвистике университета сан-паолу', 13.857142857142858),
#  ('выводы проведенный анализ показал', 13.833333333333334),
#  ('решения определенной педагогической задачи', 13.666666666666666),
#  ('документе открытый доступ определялся', 13.6),
#  ('исследовательской самостоятельной работы обучающихся', 13.583333333333334),
#  ('коллекции корпусов sketch engine', 13.47058823529412),
#  ('развитию практик использования оор', 13.398809523809524),
#  ('разработке учебных материалов', 13.228571428571428),
#  ('разработанных заданий/системы упражнений', 13.166666666666668),
#  ('больших онлайн корпусов', 12.803921568627452),
#  ('корпусного менеджера antconc', 12.733333333333334),
#  ('обучении ия рассмотрим предложение', 12.696969696969697),
#  ('способы выражения множественного числа', 12.666666666666666),
#  ('канале youtube lael webinars', 12.583333333333334),
#  ('лексем русского языка', 12.55),
#  ('старших классов средней школы', 12.5),
#  ('открытых образовательных ресурсах', 12.3),
#  ('список которых приведен', 12.266666666666666),
#  ('открытыми образовательными ресурсами', 12.0),
#  ('собственную педагогическую практику', 12.0),
#  ('проекта является размещенные', 11.75),
#  ('широкоизвестного корпусного менеджера', 11.733333333333334),
#  ('контексте парадигмы оор', 11.69047619047619),
#  ('характеристик открытой науки', 11.666666666666668),
#  ('разных учебных заведениях', 11.55),
#  ('очень крупные исследователи', 11.5),
#  ('указанным уровнем сложности', 11.5),
#  ('мини-уроки легко могут', 11.5),
#  ('основе корпусного подхода', 11.4),
#  ('план урока занимает', 11.4),
#  ('доступные онлайн корпуса', 11.362745098039216),
#  ('систему высшего образования', 11.333333333333334),
#  ('доступны разные способы', 11.333333333333334),
#  ('ряду планов мини-уроков', 11.3),
#  ('основе корпусных данных', 11.214285714285715),
#  ('преподавателей должны базироваться', 10.875),
#  ('предпочтительными являются предложения', 10.866666666666667),
#  ('корпусной лингвистики говорят', 10.86388384754991),
#  ('интегрированию корпусной лингвистики', 10.86388384754991),
#  ('крупными онлайн корпусами', 10.833333333333334),
#  ('формате множественного выбора', 10.833333333333334),
#  ('teaching english language', 10.833333333333332),
#  ('широкому распространению подходов', 10.75),
#  ('моок является введением', 10.75),
#  ('области корпусной лингвистики', 10.73888384754991),
#  ('студентов варшавского университета', 10.607142857142858),
#  ('просмотру видео урока', 10.538461538461538),
#  ('учащиеся средних классов', 10.5),
#  ('преподавание иностранных языков', 10.333333333333332),
#  ('разным изучаемым темам', 10.333333333333332),
#  ('коллекции англоязычных корпусов', 10.303921568627452),
#  ('действующих преподавателей ия', 10.238636363636363),
#  ('корпусной лингвистике доступных', 10.091954022988507),
#  ('длительность видео колеблется', 10.038461538461538),
#  ('методикой преподавания ия', 10.03030303030303),
#  ('точности научных результатов', 10.0),
#  ('отсутствие общедоступных заданий', 10.0),
#  ('24:21 мин', 10.0),
#  ('спектрограммой речи диктора', 10.0),
#  ('прослушать пропущенное слов', 10.0),
#  ('составления конкретного задания', 10.0),
#  ('основе определенного учебника', 10.0),
#  ('использованием корпуса bnc', 9.904411764705882),
#  ('подходами корпусной лингвистики', 9.86388384754991),
#  ('содержит 3-4 вопроса', 9.857142857142858),
#  ('апробация курса описана', 9.75),
#  ('записи вебинаров доступны', 9.75),
#  ('развития навыков аудирования', 9.75),
#  ('развития письменных навыков', 9.75),
#  ('идея вовлечения студентов', 9.75),
#  ('применение корпусных подходов', 9.714285714285715),
#  ('сайте университета квинсленда', 9.69047619047619),
#  ('освоению sketch engine', 9.666666666666668),
#  ('продвижению открытого доступа', 9.666666666666666),
#  ('учебные материалы привязаны', 9.633333333333333),
#  ('разработала учебные материалы', 9.633333333333333),
#  ('разрабатывать учебные материалы', 9.633333333333333),
#  ('содержатся учебные материалы', 9.633333333333333),
#  ('широкому использованию корпусов', 9.620588235294118),
#  ('обзор исследований принципов', 9.583333333333334),
#  ('культур университета квинсленда', 9.523809523809524),
#  ('странице кафедры lael', 9.5),
#  ('теме international perspectives', 9.5),
#  ('изменение функции местоимения', 9.5),
#  ('анализ конкордансных строк', 9.5),
#  ('активации функции sentence', 9.5),
#  ('использование близких синонимов', 9.5),
#  ('формат представления ближе', 9.5),
#  ('разработчики крупных корпусов', 9.470588235294118),
#  ('развитию письменных навыков', 9.416666666666666),
#  ('повышения квалификации/самообразования преподавателей', 9.375),
#  ('методах обучения ия', 9.363636363636363),
#  ('сфере высшего образования', 9.333333333333334),
#  ('онлайн репозитории инструментов', 9.333333333333334),
#  ('sketch engine разместил', 9.333333333333334),
#  ('сайте english central', 9.291666666666666),
#  ('устному компоненту bnc', 9.25),
#  ('определенной категорией обучающихся', 9.25),
#  ('области обучения ия', 9.238636363636363),
#  ('обзор готовых оор', 9.190476190476192),
#  ('доступных онлайн корпусах', 9.166666666666668),
#  ('очень ценным ресурсом', 9.166666666666666),
#  ('выбрать отдельные предложения', 9.166666666666666),
#  ('очень информативным блогом', 9.166666666666666),
#  ('очень привлекательная идея', 9.166666666666666),
#  ('очень трудоемкий процесс', 9.166666666666666),
#  ('обучении ия несмотря', 9.030303030303031),
#  ('обучении ия опубликованы', 9.030303030303031),
#  ('обучении ия недостаточно', 9.030303030303031),
#  ('информационного общества привело', 9.0),
#  ('появлению важного тренда', 9.0),
#  ('изобретатель электронных книг', 9.0),
#  ('многочисленных документах оон', 9.0),
#  ('распространение третьими лицами', 9.0),
#  ('частичное воспроизведение/ повторение', 9.0),
#  ('давно предсказанную революцию', 9.0),
#  ('необходимость преодоления разрыва', 9.0),
#  ('наша попытка проанализировать', 9.0),
#  ('указанием режима обращения', 9.0),
#  ('обычному преподавателю вуза', 9.0),
#  ('учителях средней школы', 9.0),
#  ('магистерская диссертация е.м', 9.0),
#  ('открытым остается вопрос', 9.0),
#  ('практических лингвистических дисциплин', 9.0),
#  ('размещены презентации докладчиков', 9.0),
#  ('презентации докладчиков размещены', 9.0),
#  ('режима просмотра kwic', 9.0),
#  ('курсу средней школы', 9.0),
#  ('изучающих английский язык', 9.0),
#  ('млн строк аудиозаписей', 9.0),
#  ('каждую неделю добавляется', 9.0),
#  ('показ сопровождается субтитрами', 9.0),
#  ('пользователю предлагают посмотреть', 9.0),
#  ('оценивая близость попытки', 9.0),
#  ('неоднократно повторять попытки', 9.0),
#  ('одной успешной практикой', 9.0),
#  ('формату презентаций/научных докладов', 9.0),
#  ('серьезных олимпиадных задач', 9.0),
#  ('всемерно поддерживаемый оон', 9.0),
#  ('самым необходимую гибкость', 9.0),
#  ('самообразования преподавателей ия', 8.905303030303031),
#  ('базе разных корпусов', 8.887254901960784),
#  ('важность концепции оор', 8.857142857142858),
#  ('создание качественных оор', 8.857142857142858),
#  ('использованием корпусных технологий', 8.839285714285715),
#  ('соблюдении целостности работы', 8.833333333333334),
#  ('рассмотрим коллекции youtube', 8.833333333333334),
#  ('скрытыми хитростями работы', 8.833333333333334),
#  ('платформе представлены материалы', 8.833333333333332),
#  ('курс дает представление', 8.8),
#  ('курс improving writing', 8.8),
#  ('подразумевающих введение материала', 8.75),
#  ('введение материала преподавателем', 8.75),
#  ('целью урока', 8.75),
#  ('прохождении самых разных', 8.75),
#  ('яссин иабдунан разместил', 8.666666666666666),
#  ('роликов продолжительностью', 8.666666666666666),
#  ('инициативу продолжили вебинары', 8.666666666666666),
#  ('базе школы языков', 8.666666666666666),
#  ('ряде международных конференций', 8.666666666666666),
#  ('рубрикам current english', 8.625),
#  ('обучении ия самостоятельно', 8.530303030303031),
#  ('изданные немногочисленные пособия', 8.5),
#  ('data-driven learning относится', 8.5),
#  ('разработки программного обеспечения', 8.5),
#  ('развернутое описание вебинаров', 8.5),
#  ('лица множественного числа', 8.5),
#  ('паролю доступен файл', 8.5),
#  ('получить правильный ответ', 8.5),
#  ('стороны предложили способ', 8.5),
#  ('выполненный студентами вшэ', 8.5),
#  ('применения корпусных менеджеров', 8.464285714285715),
#  ('материалах авторитетных конференций', 8.416666666666666),
#  ('план урока', 8.4),
#  ('темы раскрываются /изучаются', 8.333333333333334),
#  ('изучения конкретной темы', 8.333333333333334),
#  ('открытом доступе меняют', 8.25),
#  ('готовы регулярно использовать', 8.222222222222221),
#  ('корпусных заданий определенного', 8.214285714285715),
#  ('language teaching', 8.208333333333332),
#  ('вебинары проходили еженедельно', 8.166666666666666),
#  ('организованные ведущими центрами', 8.0),
#  ('видеозаписи заседаний конференции', 8.0),
#  ('конкретной категории учащихся', 8.0),
#  ('рубрикам/категориям language change', 7.875),
#  ('характеристик оор', 7.857142857142858),
#  ('примеры заданий', 7.7),
#  ('английского языков', 7.5),
#  ('учебниках английской грамматики', 7.5),
#  ('сайта нкри', 7.333333333333334),
#  ('практической деятельности', 7.333333333333333),
#  ('увидеть примеры', 7.2),
#  ('новых видео', 7.138461538461538),
#  ('кафедре лингвистики', 7.105263157894737),
#  ('моок курсы', 7.083333333333334),
#  ('преподавания ия', 7.03030303030303),
#  ('анализ корпуса', 7.029411764705882),
#  ('сайте университета', 7.023809523809524),
#  ('подходов кл', 7.0),
#  ('свободном доступе', 7.0),
#  ('собраны презентации автора', 7.0),
#  ('беседы в.а', 7.0),
#  ('речи диктора', 7.0),
#  ('корпусной лингводидактики', 6.958620689655173),
#  ('которые преподаватель мог', 6.857142857142858),
#  ('следующем разделе', 6.8),
#  ('профессионально-ориентированного языка', 6.8),
#  ('корпусной лингвистике', 6.758620689655173),
#  ('основатель проекта', 6.75),
#  ('записи вебинаров', 6.75),
#  ('иностранный разработаны уроки', 6.75),
#  ('учебные материалы', 6.633333333333333),
#  ('использованием корпусов', 6.595588235294118),
#  ('2-х видео', 6.538461538461538),
#  ('апрель 2022г', 6.5),
#  ('version 3.4.0', 6.5),
#  ('1-й части', 6.5),
#  ('обучения ия', 6.363636363636363),
#  ('являются ролики', 6.2),
#  ('категориями ресурсов', 6.166666666666667),
#  ('группу ресурсов', 6.166666666666667),
#  ('использованием кл', 6.125),
#  ('сайта соса', 6.083333333333334),
#  ('обучении ия', 6.03030303030303),
#  ('проведенный болтоном', 6.0),
#  ('составленных специально', 6.0),
#  ('версией antconc', 6.0),
#  ('средней школы', 6.0),
#  ('плану урока', 6.0),
#  ('далее дополняют', 6.0),
#  ('области прикладной', 5.875),
#  ('области кл', 5.875),
#  ('непосредственного использования', 5.875),
#  ('использованию корпусов', 5.870588235294118),
#  ('никря содержит', 5.857142857142858),
#  ('нкря содержит', 5.857142857142858),
#  ('каждой категории', 5.833333333333334),
#  ('корпусной лингводидактике', 5.758620689655173),
#  ('педагогической общественности', 5.666666666666666),
#  ('открытый доступ', 5.6),
#  ('новых версий', 5.6),
#  ('материалы разработаны', 5.55),
#  ('общедоступные корпуса', 5.529411764705882),
#  ('критический анализ', 5.5),
#  ('проблемой является', 5.5),
#  ('дополнительными инструкциями', 5.5),
#  ('дополнительным инструментам', 5.5),
#  ('вяткина указывает', 5.5),
#  ('облако слов', 5.5),
#  ('ресурс создавался', 5.5),
#  ('недоступность корпусов', 5.470588235294118),
#  ('материалов', 5.428571428571429),
#  ('открытой науке', 5.333333333333334),
#  ('воздействия науки', 5.333333333333334),
#  ('выборки представлены', 5.333333333333334),
#  ('понимание видеосюжета', 5.333333333333334),
#  ('курс вшэ', 5.3),
#  ('материалы созданы', 5.3),
#  ('открытом доступе', 5.25),
#  ('задания разработаны', 5.25),
#  ('корпусных инструментов', 5.214285714285714),
#  ('видео роликов', 5.205128205128205),
#  ('исследования выполнены', 5.2),
#  ('целей исследования', 5.2),
#  ('вебинары проходили', 5.166666666666666),
#  ('сайте bnclab', 5.166666666666666),
#  ('новых условиях', 5.1),
#  ('канале youtube', 5.083333333333334),
#  ('окончания обучения', 5.0),
#  ('свободном/открытом доступе', 5.0),
#  ('фолл выложила', 5.0),
#  ('наиболее популярными', 5.0),
#  ('базовыми концепциями', 5.0),
#  ('серии вебинаров', 5.0),
#  ('современных языков', 5.0),
#  ('обучение лексике', 5.0),
#  ('последующего развития', 5.0),
#  ('старших школьников', 5.0),
#  ('желающих повысить', 5.0),
#  ('методически целесообразнее', 5.0),
#  ('разработки заданий', 5.0),
#  ('материалах конференций', 4.916666666666666),
#  ('канале разместил', 4.916666666666666),
#  ('youtube каналы', 4.833333333333334),
#  ('последующей работы', 4.833333333333334),
#  ('разделе', 4.8),
#  ('включить курс', 4.8),
#  ('категориями обучающихся', 4.75),
#  ('повседневной работе', 4.75),
#  ('уроки разработаны', 4.75),
#  ('категорию обучающихся', 4.75),
#  ('разных корпусах', 4.75),
#  ('корпусных пятиминуток', 4.714285714285714),
#  ('corpus linguistics', 4.666666666666666),
#  ('университете квинсленда', 4.666666666666666),
#  ('обучении иностранным', 4.666666666666666),
#  ('известных программ', 4.666666666666666),
#  ('corpus technology', 4.666666666666666),
#  ('известных исследователей', 4.666666666666666),
#  ('собственной практике', 4.666666666666666),
#  ('academic english', 4.625),
#  ('travel english', 4.625),
#  ('business english', 4.625),
#  ('career english', 4.625),
#  ('свободный доступ', 4.6),
#  ('составления указателей', 4.5),
#  ('открытым ресурсам', 4.5),
#  ('конкретному корпусу', 4.5),
#  ('повышения квалификации', 4.5),
#  ('отдельные ролики', 4.5),
#  ('находится', 4.5),
#  ('изучаются', 4.5),
#  ('выполняемым самостоятельно', 4.5),
#  ('учебниках примерами', 4.5),
#  ('лица ед', 4.5),
#  ('получить подсказку', 4.5),
#  ('английского', 4.5),
#  ('приложении пособия', 4.5),
#  ('описание изменений', 4.5),
#  ('определенному корпусу', 4.5),
#  ('рассмотренных ресурсах', 4.5),
#  ('планах мини-уроков', 4.5),
#  ('каких заданий', 4.5),
#  ('разработка заданий', 4.5),
#  ('преподаватели', 4.5),
#  ('language learning', 4.375),
#  ('показал мета-анализ', 4.333333333333334),
#  ('категории spoc', 4.333333333333334),
#  ('которая проходила', 4.25),
#  ('платформе futurelearn', 4.2),
#  ('национальной платформе', 4.2),
#  ('платформе edex', 4.2),
#  ('платформе bnclab', 4.2),
#  ('базе находящихся', 4.166666666666666),
#  ('eurocall corpus', 4.166666666666666),
#  ('корпусная лингводидактика', 4.0),
#  ('открытое образование', 4.0),
#  ('ххi веке', 4.0),
#  ('программное обеспечение', 4.0),
#  ('законных целей', 4.0),
#  ('отсутствии финансовых', 4.0),
#  ('технических преград', 4.0),
#  ('обязательной ссылке', 4.0),
#  ('незначительными ограничениями', 4.0),
#  ('статье космас', 4.0),
#  ('кризисе воспроизводимости', 4.0),
#  ('replication crisis', 4.0),
#  ('глав монографий', 4.0),
#  ('следует заметить', 4.0),
#  ('анализа публикациях', 4.0),
#  ('сих пор', 4.0),
#  ('учебном процессе', 4.0),
#  ('является', 4.0),
#  ('требуется регистрация', 4.0),
#  ('находилась вплоть', 4.0),
#  ('весны 2020г.', 4.0),
#  ('вынужден метаться', 4.0),
#  ('разными источниками', 4.0),
#  ('проблема серьезна', 4.0),
#  ('простых путей', 4.0),
#  ('нашем исследовании', 4.0),
#  ('современном этапе', 4.0),
#  ('требованиями фгос', 4.0),
#  ('исследователь предполагает', 4.0),
#  ('ситуация улучшится', 4.0),
#  ('мотивированных будущих', 4.0),
#  ('обзора видеоресурсов', 4.0),
#  ('целые серии', 4.0),
#  ('ланкастерском университете', 4.0),
#  ('корпусную лингвистику', 4.0),
#  ('представленный а.и', 4.0),
#  ('прямым обращением', 4.0),
#  ('родному языку', 4.0),
#  ('корпусные инструменты', 4.0),
#  ('сентябрь 2020г', 4.0),
#  ('недели интенсива', 4.0),
#  ('последний познакомил', 4.0),
#  ('новой версией', 4.0),
#  ('социальных сетях', 4.0),
#  ('applied linguistics', 4.0),
#  ('корпусная лингвистика', 4.0),
#  ('дистанционном режиме', 4.0),
#  ('конкретным корпусам', 4.0),
#  ('первый взгляд', 4.0),
#  ('проблема неактуальна', 4.0),
#  ('педагогических принципах', 4.0),
#  ('стороны преподавателя', 4.0),
#  ('базовый поиск', 4.0),
#  ('временная ось', 4.0),
#  ('визуализация коллокаций', 4.0),
#  ('a-level exam', 4.0),
#  ('spoken communication', 4.0),
#  ('communicative skills', 4.0),
#  ('2-м лице', 4.0),
#  ('чтение абзаца', 4.0),
#  ('обсуждение предлагаемых', 4.0),
#  ('любом месте', 4.0),
#  ('всплывающем окне', 4.0),
#  ('затем вернуться', 4.0),
#  ('пытаясь приблизить', 4.0),
#  ('lesson plan', 4.0),
#  ('4-х заданий', 4.0),
#  ('пользуясь контекстом', 4.0),
#  ('последующей практики', 4.0),
#  ('возможных ответов', 4.0),
#  ('умолчанию деактивирована', 4.0),
#  ('ответы даны', 4.0),
#  ('corpus-aided platform', 4.0),
#  ('университете гонконга', 4.0),
#  ('qing angel', 4.0),
#  ('младшие школьники', 4.0),
#  ('фол вместе', 4.0),
#  ('3-х семестров', 4.0),
#  ('начале студентам', 4.0),
#  ('специальных целей', 4.0),
#  ('конкретном корпусе', 4.0),
#  ('выявленные трудности', 4.0),
#  ('выполнении запроса', 4.0),
#  ('должно способствовать', 4.0),
#  ('некоторым аналогом', 4.0),
#  ('своевольные смыслы', 4.0),
#  ('19-21 вв.', 4.0),
#  ('бесплатным курсом', 4.0),
#  ('младших школьников', 4.0),
#  ('13-15-летних подростков', 4.0),
#  ('серией игр', 4.0),
#  ('строгом смысле', 4.0),
#  ('ценными инструментами', 4.0),
#  ('профессиональный уровень', 4.0),
#  ('каждому видеофрагменту', 4.0),
#  ('десятки страниц', 4.0),
#  ('доказательно критикуют', 4.0),
#  ('крайней мере', 4.0),
#  ('весьма эффективной', 4.0),
#  ('конкретному учебнику', 4.0),
#  ('увеличивая вероятность', 4.0),
#  ('совершенно очевидно', 4.0),
#  ('будущих педагогов', 4.0),
#  ('language teachers', 3.875),
#  ('содержит', 3.857142857142857),
#  ('которые тренировались', 3.857142857142857),
#  ('студентов', 3.75),
#  ('материалах габласовой', 3.75),
#  ('научных статьях', 3.7),
#  ('открытые', 3.6666666666666665),
#  ('примеров', 3.6666666666666665),
#  ('видео', 3.5384615384615383),
#  ('корпуса', 3.5294117647058822),
#  ('авторы', 3.5),
#  ('недавние публикации', 3.5),
#  ('поисковыми заданиями', 3.5),
#  ('теме', 3.5),
#  ('знания', 3.5),
#  ('ленко-шиманска считает', 3.5),
#  ('корпусе coca', 3.5),
#  ('доступность делает', 3.5),
#  ('осенью 2021г', 3.5),
#  ('большей поддержки', 3.5),
#  ('индивидуальную работу', 3.5),
#  ('малых группах', 3.5),
#  ('иллюстрирующего правило', 3.5),
#  ('функции', 3.5),
#  ('video transcript', 3.5),
#  ('слов', 3.5),
#  ('зарегистрированные', 3.5),
#  ('верные слова', 3.5),
#  ('разнообразными заданиями', 3.5),
#  ('материалах вяткиной', 3.5),
#  ('видеосюжета', 3.3333333333333335),
#  ('мнению разработчиков', 3.333333333333333),
#  ('исследований', 3.25),
#  ('bnc', 3.25),
#  ('параллельным корпусом', 3.25),
#  ('руководством н.р', 3.25),
#  ('исследования', 3.2),
#  ('лингводидактики', 3.2),
#  ('сайте', 3.1666666666666665),
#  ('материале', 3.0),
#  ('языков', 3.0),
#  ('имеют публикации', 3.0),
#  ('кл', 3.0),
#  ('ленко-шиманска corpora', 3.0),
#  ('инструкции', 3.0),
#  ('задания', 3.0),
#  ('вопроса', 3.0),
#  ('фолл', 3.0),
#  ('оор', 2.857142857142857),
#  ('youtube', 2.8333333333333335),
#  ('работы', 2.8333333333333335),
#  ('dwds', 2.75),
#  ('применения', 2.75),
#  ('введение', 2.75),
#  ('соса', 2.75),
#  ('развитию', 2.6666666666666665),
#  ('способы', 2.6666666666666665),
#  ('рассмотрим', 2.6666666666666665),
#  ('учащихся', 2.6666666666666665),
#  ('числа', 2.6666666666666665),
#  ('практике', 2.6666666666666665),
#  ('доступ', 2.6),
#  ('доступен', 2.5),
#  ('решения', 2.5),
#  ('корпусу', 2.5),
#  ('употребления', 2.5),
#  ('тренд', 2.5),
#  ('использованию', 2.4),
#  ('информацию', 2.3333333333333335),
#  ('темы', 2.3333333333333335),
#  ('показал', 2.3333333333333335),
#  ('канале', 2.25),
#  ('которая', 2.25),
#  ('использовать', 2.2222222222222223),
#  ('автора', 2.0),
#  ('собраны', 2.0),
#  ('использование', 2.0),
#  ('созданных', 2.0),
#  ('корпусах', 2.0),
#  ('нкря', 2.0),
#  ('преподаватель', 2.0),
#  ('подходами', 2.0),
#  ('статье', 2.0),
#  ('важно', 2.0),
#  ('организованные', 2.0),
#  ('иностранный', 2.0),
#  ('грамматики', 2.0),
#  ('конференции', 2.0),
#  ('разработке', 2.0),
#  ('language', 1.875),
#  ('которые', 1.8571428571428572),
#  ('самообразования', 1.6666666666666667),
#  ('роликов', 1.6666666666666667),
#  ('публикации', 1.5),
#  ('coca', 1.5),
#  ('проблемой', 1.5),
#  ('правило', 1.5),
#  ('находящихся', 1.5),
#  ('имеют', 1.5),
#  ('corpora', 1.5),
#  ('ленко-шиманска', 1.5),
#  ('eurocall', 1.5),
#  ('группах', 1.5),
#  ('2021г', 1.5),
#  ('работу', 1.5),
#  ('габласовой', 1.5),
#  ('преподавателя', 1.5),
#  ('video', 1.5),
#  ('слова', 1.5),
#  ('делает', 1.5),
#  ('4-х', 1.5),
#  ('заданиями', 1.5),
#  ('поддержки', 1.5),
#  ('условиях', 1.5),
#  ('мнению', 1.3333333333333333),
#  ('работе', 1.25),
#  ('корпусом', 1.25),
#  ('вяткиной', 1.25),
#  ('руководством', 1.25),
#  ('статьях', 1.2),
#  ('науку', 1.0),
#  ('инициатором', 1.0),
#  ('гутенберг', 1.0),
#  ('которой', 1.0),
#  ('интернете', 1.0),
#  ('читать', 1.0),
#  ('разгружать', 1.0),
#  ('копировать', 1.0),
#  ('распространять', 1.0),
#  ('распечатывать', 1.0),
#  ('находить', 1.0),
#  ('присоединять', 1.0),
#  ('вводить', 1.0),
#  ('данные', 1.0),
#  ('правовых', 1.0),
#  ('…', 1.0),
#  ('использовании', 1.0),
#  ('цитировании', 1.0),
#  ('юнеско', 1.0),
#  ('рекомендациях', 1.0),
#  ('т.д', 1.0),
#  ('изучение', 1.0),
#  ('томе', 1.0),
#  ('находящемся', 1.0),
#  ('важнейшими', 1.0),
#  ('право', 1.0),
#  ('адаптацию', 1.0),
#  ('ограничений', 1.0),
#  ('пунктов', 1.0),
#  ('найти', 1.0),
#  ('коллегами', 1.0),
#  ('одна', 1.0),
#  ('прозрачность', 1.0),
#  ('контроль', 1.0),
#  ('общество', 1.0),
#  ('с.12', 1.0),
#  ('специалисты', 1.0),
#  ('см.', 1.0),
#  ('ddl', 1.0),
#  ('последние', 1.0),
#  ('лет', 1.0),
#  ('публикаций', 1.0),
#  ('болтон', 1.0),
#  ('направленных', 1.0),
#  ('классических', 1.0),
#  ('работ', 1.0),
#  ('p', 1.0),
#  ('соответствии', 1.0),
#  ('отобранных', 1.0),
#  ('коббом', 1.0),
#  ('произошло', 1.0),
#  ('чамбес', 1.0),
#  ('исследованиями', 1.0),
#  ('привела', 1.0),
#  ('списку', 1.0),
#  ('причин', 1.0),
#  ('остановимся', 1.0),
#  ('проблемах', 1.0),
#  ('описанных', 1.0),
#  ('препятствий', 1.0),
#  ('недоступных', 1.0),
#  ('научной', 1.0),
#  ('онлайн-поиска', 1.0),
#  ('скачивания', 1.0),
#  ('изучении', 1.0),
#  ('говоря', 1.0),
#  ('затруднен', 1.0),
#  ('каталогизированы', 1.0),
#  ('описаны', 1.0),
#  ('имеющихся', 1.0),
#  ('примера', 1.0),
#  ('сослаться', 1.0),
#  ('относятся', 1.0),
#  ('находящиеся', 1.0),
#  ('адрес', 1.0),
#  ('шоу', 1.0),
#  ('переместилась', 1.0),
#  ('упражнениями', 1.0),
#  ('содержат', 1.0),
#  ('инструкций', 1.0),
#  ('привязанных', 1.0),
#  ('кажется', 1.0),
#  ('существует', 1.0),
#  ('россии', 1.0),
#  ('пришли', 1.0),
#  ('выводу', 1.0),
#  ('насколько', 1.0),
#  ('p.234', 1.0),
#  ('теоретических', 1.0),
#  ('начнем', 1.0),
#  ('запросу', 1.0),
#  ('дисциплины', 1.0),
#  ('6:57', 1.0),
#  ('элен', 1.0),
#  ('набравшими', 1.0),
#  ('год', 1.0),
#  ('просмотров', 1.0),
#  ('ролика', 1.0),
#  ('0:29', 1.0),
#  ('5:25', 1.0),
#  ('антони', 1.0),
#  ('объясняющих', 1.0),
#  ('разработал', 1.0),
#  ('4:15', 1.0),
#  ('14:38', 1.0),
#  ('делясь', 1.0),
#  ('менее', 1.0),
#  ('method', 1.0),
#  ('analysis', 1.0),
#  ('interpretation', 1.0),
#  ('разработанный', 1.0),
#  ('макэнери', 1.0),
#  ('размещенный', 1.0),
#  ('знакомит', 1.0),
#  ('разработанным', 1.0),
#  ('брезиной', 1.0),
#  ('левинзон', 1.0),
#  ('размещен', 1.0),
#  ('разработан', 1.0),
#  ('кроссвейтом', 1.0),
#  ('корпус', 1.0),
#  ('бразилия', 1.0),
#  ('пригласив', 1.0),
#  ('байбера', 1.0),
#  ('скотта', 1.0),
#  ('ромер', 1.0),
#  ('дэвис', 1.0),
#  ('реппен', 1.0),
#  ('др', 1.0),
#  ('апреля', 1.0),
#  ('августе', 1.0),
#  ('сентября', 1.0),
#  ('момент', 1.0),
#  ('years', 1.0),
#  ('австралия', 1.0),
#  ('октября', 1.0),
#  ('состоялся', 1.0),
#  ('вебинар', 1.0),
#  ('докладчиками', 1.0),
#  ('франкенберг-гарсия', 1.0),
#  ('кроссвейт', 1.0),
#  ('сравнению', 1.0),
#  ('кроссвейта', 1.0),
#  ('talc', 1.0),
#  ('фейсбуке', 1.0),
#  ('linkedin', 1.0),
#  ('плунгяна', 1.0),
#  ('д.о', 1.0),
#  ('добровольского', 1.0),
#  ('постнауке', 1.0),
#  ('бузаджи', 1.0),
#  ('в.п', 1.0),
#  ('захарова', 1.0),
#  ('обновленная', 1.0),
#  ('364-365', 1.0),
#  ('показаться', 1.0),
#  ('т.к', 1.0),
#  ('инструкция', 1.0),
#  ('стр.', 1.0),
#  ('стр', 1.0),
#  ('сопровождение', 1.0),
#  ('вовлечение', 1.0),
#  ('идти', 1.0),
#  ('простого', 1.0),
#  ('сложному', 1.0),
#  ('заданиям', 1.0),
#  ('начинающих', 1.0),
#  ('продвинутых', 1.0),
#  ('парах', 1.0),
#  ('приведенные', 1.0),
#  ('schools', 1.0),
#  ('создаваемый', 1.0),
#  ('второй', 1.0),
#  ('gender', 1.0),
#  ('region', 1.0),
#  ('age', 1.0),
#  ('отраженные', 1.0),
#  ('трансформация', 1.0),
#  ('данном', 1.0),
#  ('ответами', 1.0),
#  ('комментариями', 1.0),
#  ('создан', 1.0),
#  ('говорения', 1.0),
#  ('мини-курсов', 1.0),
#  ('категориях', 1.0),
#  ('expressions', 1.0),
#  ('остановить', 1.0),
#  ('процентах', 1.0),
#  ('учащийся', 1.0),
#  ('произношение', 1.0),
#  ('месяц', 1.0),
#  ('состоит', 1.0),
#  ('пропусками', 1.0),
#  ('4-6', 1.0),
#  ('заполнить', 1.0),
#  ('памяти', 1.0),
#  ('определения', 1.0),
#  ('словаря', 1.0),
#  ('впечатанного', 1.0),
#  ('пробел', 1.0),
#  ('кликнув', 1.0),
#  ('пробелу', 1.0),
#  ('задании', 1.0),
#  ('словами', 1.0),
#  ('приводятся', 1.0),
#  ('задание', 1.0),
#  ('предлагает', 1.0),
#  ('обсуждения', 1.0),
#  ('explain', 1.0),
#  ('sentences', 1.0),
#  ('cap', 1.0),
#  ('созданная', 1.0),
#  ('произношения', 1.0),
#  ('категориям', 1.0),
#  ('грамматике', 1.0),
#  ('произношению', 1.0),
#  ('подкатегории', 1.0),
#  ('указывающие', 1.0),
#  ('вузов', 1.0),
#  ('дэвиса', 1.0),
#  ('страницы', 1.0),
#  ('студентами-магистрантами', 1.0),
#  ('разместила', 1.0),
#  ('поиску', 1.0),
#  ('классе', 1.0),
#  ('проблему', 1.0),
#  ('решали', 1.0),
#  ('ходу', 1.0),
#  ('начальной', 1.0),
#  ('2-й', 1.0),
#  ('3-й', 1.0),
#  ('4-й', 1.0),
#  ('идеи', 1.0),
#  ('ограничения', 1.0),
#  ('задержкой', 1.0),
#  ('свидетельства', 1.0),
#  ('факт', 1.0),
#  ('демотивирующим', 1.0),
#  ('неподготовленных', 1.0),
#  ('сталкивались', 1.0),
#  ('эффектом', 1.0),
#  ('обойти', 1.0),
#  ('направленного', 1.0),
#  ('значении', 1.0),
#  ('употреблении', 1.0),
#  ('добрушиной', 1.0),
#  ('м.а', 1.0),
#  ('даниель', 1.0),
#  ('2012гг', 1.0),
#  ('детский', 1.0),
#  ('раздел', 1.0),
#  ('путеводителем', 1.0),
#  ('детей', 1.0),
#  ('работать', 1.0),
#  ('игровых', 1.0),
#  ('помочь', 1.0),
#  ('т.е', 1.0),
#  ('описанными', 1.0),
#  ('литературе', 1.0),
#  ('понять', 1.0),
#  ('привязке', 1.0),
#  ('реализована', 1.0),
#  ('//corpora.ku.edu', 1.0),
#  ('случаях', 1.0),
#  ('ма', 1.0),
#  ('созданные', 1.0),
#  ('эффективнее', 1.0),
#  ('объемом', 1.0),
#  ('думается', 1.0),
#  ('ресурс/источник', 1.0),
#  ('возможностей', 1.0),
#  ('указания', 1.0),
#  ('явно', 1.0),
#  ('каком', 1.0),
#  ('учебнике', 1.0),
#  ('привести', 1.0),
#  ('дополнения', 1.0),
#  ('модели', 1.0),
#  ('интегрированы', 1.0),
#  ('обеспечивая', 1.0),
#  ('знакомые', 1.0),
#  ('начнут', 1.0),
#  ('внедрения', 1.0),
#  ('особенно', 1.0)]

# %%
with open('rake_keywords.csv', 'w', encoding='utf-8') as f2:
    for eachkwrd in keywords:
        f2.write(str(eachkwrd[0])+";"+str(eachkwrd[1])+"\n")

# %%
#KeyBERT
import keybert
# Out:
# WARNING:tensorflow:From C:\Users\Андрей\AppData\Roaming\Python\Python310\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from keybert import KeyBERT

# %%
with open('corpus/Kogan_IMS_2022.txt', 'r', encoding='utf-8') as f:
    doc = f.read()

# %%
kw_model = KeyBERT()

# %%
keywords = kw_model.extract_keywords(
    docs=doc,
    stop_words=stop_list,
    top_n=20,
    highlight=True
    )
# Out:
# C:\Users\Андрей\AppData\Roaming\Python\Python310\site-packages\sklearn\feature_extraction\text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ак', 'бляха', 'богу', 'бу', 'буль', 'вашему', 'вообще', 'всякому', 'го', 'ей', 'елки', 'иному', 'какая', 'каким', 'каких', 'какое', 'какому', 'кей', 'кис', 'кэй', 'мое', 'моему', 'муха', 'нашему', 'нить', 'палки', 'паф', 'пиф', 'твоему', 'тик', 'тра', 'тс', 'ту', 'чегой', 'черт', 'чик', 'чтой', 'яй'] not in stop_words.
#   warnings.warn(
# Корпусная лингводидактика контексте парадигмы открытых образовательных ресурсов Коган Введение Развитие интернета
# информационного общества привело появлению важного тренда на открытое образование науку информацию Инициатором
# этого движения считается Майкл Стерн Харт изобретатель электронных книг основатель проекта Гутенберг 60 годы
# прошлого века ХХI веке этот тренд задала Будапештская Инициатива Открытый Доступ которой тех присоединились тысячи
# организаций этом документе Открытый доступ определялся как открытые для всех публикации Интернете которые можно
# читать разгружать копировать распространять распечатывать находить или присоединять полным текстам соответствующих
# статей использовать для составления указателей вводить их как данные программное обеспечение или использовать для
# других законных целей при отсутствии финансовых правовых технических преград при соблюдении целостности работы
# обязательной ссылке на имя автора при использовании цитировании последующие годы Будапештская инициатива получила
# развитие многочисленных документах ООН ЮНЕСКО например рекомендациях по развитию продвижению открытого доступа
# рекомендациях по открытой науке по работе открытыми образовательными ресурсами ООР сфере высшего образования об
# открытых образовательных ресурсах также рекомендациях по развитию практик использования ООР Исследования касающиеся
# влияния открытого образования на изучение преподавание иностранных языков собраны томе находящемся открытом доступе
# Открытые образовательные ресурсы обладают рядом характеристик важнейшими из которых являются бесплатный доступ
# право на использование адаптацию распространение третьими лицами без ограничений или незначительными ограничениями
# Некоторые исследователи дополняют список характеристик понятия открытость до 12 пунктов Обзор исследований
# принципов характеристик ООР можно найти статье Космас коллегами Одна из характеристик открытой науки прозрачность
# контроль критический анализ воспроизводимость результатов целях усиления надежности точности научных результатов
# также воздействия науки на общество 12 Специалисты области прикладной корпусной лингвистики говорят кризисе
# воспроизводимости replication crisis см например Анализируя тенденции развития исследований области обучения ИЯ
# использованием подходов корпусной лингвистики DDL за последние 30 лет на материале 480 публикаций авторитетных
# рецензируемых англоязычных журналах глав монографий материалах авторитетных конференций Болтон Вяткина обнаружили
# полное отсутствие исследований направленных на частичное воспроизведение повторение классических работ новых
# условиях другими категориями обучающихся 83 Следует заметить что авторы соответствии принципами открытой науки
# разместили информацию всех отобранных для анализа публикациях открытом доступе онлайн репозитории инструментов
# материалов для исследований области иностранных языков IRIS Важность концепции ООР для более широкого использования
# корпусной лингводидактики обучении ИЯ Несмотря на эффективность использования подходов корпусной лингвистики
# обучении ИЯ как показал мета анализ проведенный Болтоном Коббом давно предсказанную революцию методах обучения ИЯ
# благодаря широкому использованию корпусов этого до сих пор не произошло Чамбес статье 2019г обратила внимание на
# необходимость преодоления разрыва между исследованиями области КЛ методикой преподавания ИЯ Разные исследователи
# называют разные причины сложившейся ситуации Наша попытка проанализировать их привела списку из причин 10 контексте
# парадигмы ООР мы остановимся на трех проблемах именно недоступность корпусов описанных статьях недостаточная
# подготовка преподавателей ИЯ по корпусной лингводидактике отсутствие общедоступных заданий созданных на базе
# находящихся свободном доступе онлайн корпусов для непосредственного использования учебном процессе Одним из
# препятствий более широкому распространению подходов описанных статьях является то что многие исследования выполнены
# на корпусах составленных специально для целей исследования потому недоступных для научной педагогической
# общественности свободном доступе находится достаточно большое количество больших корпусов первую очередь
# национальные корпуса НКРЯ BNC COCA DWDS представительный список онлайн корпусов доступен разделе Другие корпуса
# сайта НКРИ указанием режима обращения доступен для онлайн поиска требуется регистрация доступен для скачивания
# Проблемой однако является отсутствие доступного банка упражнений которые преподаватель мог бы использовать при
# изучении той или иной темы Многочисленные примеры использования корпусов обучении ИЯ опубликованы научных статьях
# материалах конференций но доступ ним обычному преподавателю вуза не говоря уже об учителях средней школы затруднен
# эти публикации нигде не каталогизированы не описаны точки зрения имеющихся них корпусных заданий определенного типа
# качестве примера можно сослаться на недавние публикации на материале Национального корпуса русского языка 11 12 13
# Изданные немногочисленные пособия поисковыми заданиями как правило не относятся открытым ресурсам например 14 15 16
# находящиеся открытом доступе меняют свой адрес Так магистерская диссертация Шоу сайта СОСА где она находилась
# вплоть до весны 2020г переместилась архив университета Бригама Янга Если преподаватель теме то он вынужден метаться
# между корпусом разными источниками упражнениями По мнению Вяткиной доступные онлайн корпуса английского языка
# других языков не содержат как инструкций по их использованию для обучения ИЯ так разработанных заданий системы
# упражнений привязанных конкретному корпусу 17 364 Проблемой является недостаточная подготовка преподавателей ИЯ
# области корпусной лингвистики корпусной лингводидактики Проблема серьезна простых путей ее решения кажется не
# существует нашем исследовании имевшем целью оценить влияние корпусной лингвистики на систему высшего образования
# России мы пришли выводу что на современном этапе соответствии требованиями ФГОС все студенты филологических
# специальностей получают базовые знания корпусной лингвистике некоторые имеют публикации по теме использования
# подходов корпусной лингвистики обучении ИЯ зарегистрированные наукометрических базах данных разного ранга 18 Однако
# открытым остается вопрос насколько они готовы регулярно использовать эти знания практической деятельности после
# окончания обучения Ленко Шиманска считает что элективного односеместрового специального курса по использованию
# корпусов подходов КЛ обучении ИЯ недостаточно для того чтобы будущие преподаватели ИЯ могли успешно интегрировать
# подходы КЛ собственную педагогическую практику 19 234 Исследователь предполагает что ситуация улучшится если
# студенты будут изучать возможности корпусной лингвистики наряду другими подходами курсе методики обучения ИЯ
# использовать их при изучении других теоретических практических лингвистических дисциплин Для мотивированных будущих
# действующих преподавателей ИЯ желающих освоить основы КЛ способы ее применения обучении ИЯ самостоятельно доступны
# разные способы которые мы рассмотрим следующем разделе Обзор открытых образовательных ресурсов для повышения
# квалификации по КЛ Есть целый ряд образовательных ресурсов находящихся свободном открытом доступе которые можно
# использовать для самообразования области корпусной лингвистики Мы рассмотрим коллекции YouTube МООК курсы записи
# вебинаров организованные ведущими центрами по корпусной лингвистике Начнем обзора видеоресурсов по корпусной
# лингвистике доступных на YouTube По запросу Corpus linguistics YouTube выдает целый ряд ссылок на отдельные ролики
# на целые серии которых последовательно объясняются основы этой дисциплины Например Яссин Иабдунан разместил своем
# канале за последние года уже 11 роликов продолжительностью от 57 до 24 21 мин каждый Элен Ле Фолл выложила 10
# роликов Наиболее популярными набравшими за год более 1000 просмотров являются ролики по освоению Sketch Engine по
# созданию собственного специального корпуса корпусе COCA Разработчики крупных корпусов также имеют свои YouTube
# каналы Так Sketch Engine разместил 24 ролика Продолжительность обучающих видео колеблется от 29 до 25 Антони своем
# канале разместил 11 видео роликов объясняющих как использовать основные функции программы AntConc Версии
# широкоизвестного корпусного менеджера который он разработал Длительность видео колеблется от 15 до 14 38 Ле Фолл
# призывает активно создавать небольшие видео делясь них собственным опытом применения подходов корпусной лингвистики
# обучении ИЯ скрытыми хитростями работы доступных онлайн корпусах или применения корпусных менеджеров русскоязычном
# сегменте интернета такие материалы практически отсутствуют Массовые открытые онлайн курсы массовом сознании
# являются примером открытых образовательных ресурсов хотя специально проведенный анализ сравнения МООК курсов ООР
# позволил выявить важные отличия между этими категориями ресурсов 20 Тем не менее их доступность делает их очень
# ценным ресурсом для самообразования Наиболее популярные МООК курсы по корпусной лингвистике это Corpus Linguistics
# Method Analysis Interpretation разработанный Ланкастерском университете МакЭнери размещенный на платформе
# FutureLearn Этот МООК является введением КЛ затрагивает вопросы обучения ИЯ использованием КЛ знакомит крупными
# онлайн корпусами новым корпусным менеджером LancsBox разработанным Брезиной Введение корпусную лингвистику курс ВШЭ
# представленный Левинзон Он размещен на Национальной платформе Открытое образование Курс дает представление
# практическом применении достижений современной корпусной лингвистики учит пользоваться существующими корпусами
# русского английского языков позволяет освоить базовые методы корпусного преподавания повседневной работе Курс
# Improving writing through corpora Data driven learning относится категории SPOC small private online course
# маленький частный онлайн курс Разработан Кроссвейтом университете Квинсленда размещен на платформе EdEx Его целью
# является развитие навыков академического письма прямым обращением корпусу Задания разработаны на основе открытого
# корпуса BAWE из коллекции корпусов Sketch Engine Апробация курса описана статье 21 эту же группу ресурсов можно
# включить курс разработанный Ленко Шиманска Corpora in Language Teaching для студентов варшавского университета
# который находится свободном доступе на сайте университета Целью курса является знакомство участников базовыми
# концепциями корпус анализ корпуса применение корпусных подходов обучении иностранным родному языку развитие навыка
# создания учебных материалов на основе корпусного подхода Важно что изучаются только общедоступные корпуса корпусные
# инструменты находящиеся открытом доступе Апробация курса описана Ленко Шиманска статьях 19 22 Серии вебинаров честь
# 50 летия основания магистерской программы по прикладной лингвистике университета Сан Паолу Бразилия руководители
# программы организовали серию вебинаров по корпусной лингвистике пригласив для участия всемирно известных ученых
# Байбера Скотта МакЭнери Ромер Дэвис Реппен др Вебинары проходили еженедельно апреля по сентябрь 2020г включая
# недели интенсива августе сентября течение которых проводилось несколько мастер классов по использованию новых
# программных продуктов или новых версий уже известных программ Например Скотт представил последнюю версию корпусного
# менеджера WordSmith которая на тот момент была свободном доступе Записи вебинаров доступны на канале YouTube LAEL
# Webinars на странице кафедры LAEL 50 years где также размещены презентации докладчиков Осенью 2021г эту инициативу
# продолжили вебинары организованные на базе Школы языков культур университета Квинсленда Австралия по теме
# International Perspectives on Corpus Technology for Language Learning Вебинары проходили октября 2021 по апрель
# 2022г Всего состоялся 21 вебинар Докладчиками также были очень крупные исследователи области корпусной лингвистики
# разработки программного обеспечения Франкенберг Гарсия Ленко Шиманска Болтон Кроссвейт Антони Последний познакомил
# новой версией своего корпусного менеджера Antconc функционал которого существенно расширен по сравнению версией
# AntConc Version Записи вебинаров доступны на канале YouTube Кроссвейта где также собраны презентации автора на ряде
# международных конференций по корпусной лингвистике Например TaLC 2020 EuroCALL 2021 др Развернутое описание
# вебинаров презентации докладчиков размещены на сайте университета Квинсленда Анонсы предстоящих событий публикуются
# социальных сетях таких группах как The Eurocall Corpus SIG на фейсбуке Applied Linguistics LinkedIn русскоязычном
# сегменте интернета корпусной лингвистике посвящены лекции беседы Плунгяна Добровольского Постнауке Бузаджи Захарова
# некоторых других известных исследователей также видеозаписи заседаний конференции Корпусная лингвистика которая
# проходила дистанционном режиме на кафедре Математической лингвистики СПбГУ 2021г Обновленная мае 2022г версия НКРЯ
# содержит существенно расширенный Образовательный портал Национального корпуса русского языка Обзор готовых ООР для
# использования подходов корпусной лингводидактики обучении ИЯ Рассмотрим предложение Вяткиной об эффективности
# привязки планов уроков заданий по работе корпусом конкретным корпусам 17 364 365 На первый взгляд может показаться
# что для больших онлайн корпусов таких как НКРЯ или СОСА проблема неактуальна они снабжены инструкциями пользователя
# внушительного объема инструкция по НИКРЯ содержит 87 стр инструкция по СОСА 27 стр дополнительными инструкциями по
# созданию собственного специального корпуса дополнительным инструментам для режима просмотра KWIC Вяткина указывает
# на то что эти руководства пользователя очень далеки от знакомых учителю планов уроков использованием корпусов 23 По
# ее мнению инструкции для преподавателей должны базироваться на педагогических принципах подразумевающих введение
# материала сопровождение вовлечение идти от простого сложному от большей поддержки со стороны преподавателя заданиям
# выполняемым самостоятельно своих статьях она описывает примеры заданий обращений корпусу немецкого языка DWDS для
# учащихся разным уровнем владения немецким языком от начинающих до продвинутых предполагающих разный формат работы
# индивидуальную работу работу парах малых группах введение материала преподавателем Основным фокусом является
# расширение словарного запаса задания могут включать освоение новых лексико грамматических характеристик слов
# помощью примеров из корпуса верификация примеров употребления слов словосочетаний учебниках примерами из корпуса
# Примеры заданий приведенные статье соответствуют разным инструментам корпуса DWDS базовый поиск временная ось
# визуализация коллокаций через облако слов др 23 Другим блестящим примером создания ООР для преподавания ИЯ на
# основе конкретного корпуса является проект CORPUS FOR SCHOOLS Teaching English Language with Corpus Linguistics
# создаваемый Ланкастерском университете под руководством Габласовой Учебные материалы привязаны большим выборкам
# устной речи BNC 1990 2014 представляющих неформальные беседы носителей британского варианта английского языка Уроки
# разработаны как для носителей английского языка готовящихся сдать итоговый экзамен по курсу средней школы level
# exam так для изучающих английский язык как второй или иностранный Выборки представлены на платформе BNClab Для
# выпускников английских школ задания представлены по следующим рубрикам категориям Language Change Language and
# Gender Language and Region Language and Age Spoken Communication Для изучающих английский язык как второй или
# иностранный разработаны уроки по рубрикам Current English Use Spoken Communication Communicative Skills рамках
# которых изучаются реальные явления современного английского языка не отраженные учебниках английской грамматики
# например изменение функции местоимения лица множественного числа they или способы выражения множественного числа во
# лице Учебные материалы по каждой теме включают раздаточные упражнения задания чтение абзаца иллюстрирующего правило
# анализ конкордансных строк трансформация обсуждение предлагаемых тем обязательным использованием изучаемого
# грамматического явления данном случае they функции лица ед числа По паролю доступен файл ответами комментариями для
# преподавателя Еще одним примером привязки планов уроков корпусу является мультимедийный ресурс EnglishCentral Он
# создан использованием корпусных технологий содержит более 14000 видео 250 млн строк аудиозаписей для развития
# навыков аудирования говорения каждую неделю добавляется по 50 новых видео Контент содержит тысячи отдельных видео
# указанным уровнем сложности более 100 мини курсов категориях Academic English Travel English Business English
# Career English Useful Expressions др Каждый видеофрагмент длится минуты Показ сопровождается субтитрами Видео можно
# остановить любом месте чтобы прослушать незнакомое слово несколько раз увидеть примеры его употребления всплывающем
# окне затем вернуться просмотру видео урока Пользователю предлагают посмотреть тематически близких видео выбранного
# уровня сложности которые подбираются системой автоматически систему интегрирована передовая технология записи речи
# IntelliSpeechSM которая автоматически сравнивает произнесенный фрагмент спектрограммой речи диктора оценивая
# близость попытки процентах Учащийся может неоднократно повторять попытки пытаясь приблизить свое произношение речи
# диктора бесплатной версии такая возможность представляется только для видео месяц Другая возможность платной версии
# касается тестирования незнакомой лексики контексте статьи важно отметить что для каждого видео урока имеется
# интерактивный План урока Lesson Plan Он состоит из заданий Video transcript пропусками нескольких слов которые
# можно заполнить по памяти пользуясь контекстом получить подсказку виде определения из словаря впечатанного пробел
# или прослушать пропущенное слов кликнув по пробелу получить правильный ответ выбрать отдельные предложения для
# последующей практики задании учащиеся должны составить собственные предложения со словами которые тренировались
# задании Предпочтительными являются предложения из видеосюжета Именно они приводятся качестве возможных ответов при
# активации функции Sentence которая по умолчанию деактивирована Задание содержит вопроса на понимание видеосюжета
# формате множественного выбора Ответы даны ниже Задание предлагает вопроса для обсуждения просит кратко
# сформулировать основную идею видеосюжета Please explain what this video is about in few sentences других вопроса
# побуждают высказать собственное мнение на основе информации видео урока Еще одной успешной практикой по
# интегрированию корпусной лингвистики обучение ИЯ является платформа The Corpus Aided Platform for Language Teachers
# CAP созданная на кафедре лингвистики современных языков университете Гонконга под руководством Ma Qing Angel На
# платформе представлены материалы для повышения квалификации самообразования преподавателей области корпусной
# лингвистики лингводидактики небольшие учебные видеоролики продолжительностью минут для грамматики произношения
# развития письменных навыков работе параллельным корпусом др разделе Teaching Activities помещены примеры учебных
# материалов детально разработанных планов уроков продолжительностью 80 120 мин по категориям обучение лексике
# грамматике произношению задания на основе параллельного англо китайского корпуса каждой категории есть подкатегории
# указывающие на категорию обучающихся младшие школьники учащиеся средних классов или вузов Например целью урока по
# развитию письменных навыков формате IELTS является расширение словарного запаса использование близких синонимов
# чтобы уменьшить употребление избыточно используемой лексики данном случае слова people использованием корпуса BNC
# коллекции англоязычных корпусов Дэвиса План урока занимает 22 страницы Элен Ле Фол вместе со своими студентами
# магистрантами будущими преподавателями иностранного языка разработала учебные материалы задания на основе
# материалов открытых онлайн корпусов по разным изучаемым темам разместила их на своем сайте как ООР Ресурс
# создавался течение семестров Важно что начале студентам не удалось избежать типичной ошибки разработанные материалы
# представляли четкие инструкции по поиску разных корпусах не методически обоснованные планы уроков по использованию
# корпусов классе Эту проблему они решали по ходу своей работы Материалы разработаны для конкретной категории
# учащихся части для начальной средней школы во для старших классов средней школы для использования разработанных
# материалов для английского для специальных целей профессионально ориентированного языка Каждая глава содержит
# подробную инструкцию поиска материалов конкретном корпусе для составления конкретного задания план урока идеи для
# последующего развития применения выявленные трудности ограничения 24 Например зарегистрированные но не имеющие
# подписки пользователи платформы СОСА часто сталкиваются задержкой выполнении запроса Есть свидетельства что этот
# факт может быть демотивирующим для последующей работы корпусом неподготовленных такому повороту событий учащихся 25
# Мы также сталкивались этим эффектом со своей стороны предложили способ его обойти сократив заложенное время
# ожидания 26 Все материалы созданы на основе доступных онлайн корпусов корпусных инструментов список которых
# приведен приложении пособия По мнению разработчиков это должно способствовать более широкому применению подходов КЛ
# повседневной педагогической практике преподавателей ИЯ Некоторым аналогом этого проекта является размещенные
# разделе сайта НКРИ Studorium результаты проекта Своевольные смыслы направленного на изучение описание изменений
# значении употреблении 30 лексем русского языка на протяжении 19 21 вв выполненный студентами ВШЭ под руководством
# Добрушиной Даниель 2010 2012гг Однако формат представления ближе формату презентаций научных докладов на
# конференции не плану урока НКРЯ содержит детский раздел Верные слова путеводителем по корпусу Инструкция по НКРЯ
# для детей бесплатным курсом Как работать НКРЯ разнообразными заданиями от игровых для младших школьников до
# серьезных олимпиадных задач для 13 15 летних подростков серией игр для старших школьников студентов очень
# информативным блогом Выводы Проведенный анализ показал что тренд на открытое образование науку информацию всемерно
# поддерживаемый ООН ЮНЕСКО может помочь более широкому внедрению методов корпусной лингводидактики повседневную
# педагогическую практику преподавателей иностранных языков Не все доступные онлайн корпуса другие ресурсы являются
# открытыми образовательными ресурсами строгом смысле этого слова обладают базовыми характеристиками ООР описанными
# литературе но свободный доступ ним делает их ценными инструментами для самообразования преподавателей ИЯ желающих
# повысить свой профессиональный уровень понять как можно использовать подходы корпусной лингвистики своей практике
# также как разрабатывать учебные материалы на основе корпусных данных Анализ учебных материалов планов уроков
# созданных как ООР показал что ряд вопросов идей высказанных предложений требует дальнейшего исследования Так очень
# привлекательная идея Вяткиной разработке учебных материалов привязке определенному корпусу реализована из
# рассмотренных ресурсах материалах Вяткиной для DWDS на сайте проекта языкового ресурсного центра канзасского
# университета https corpora ku edu материалах Габласовой по устному компоненту BNC на сайте BNClab планах мини
# уроков каждому видеофрагменту на сайте English Central разделе Верные слова НКРЯ двух других случаях ООР созданных
# под руководством Ле Фолл Ма содержатся учебные материалы созданные на базе разных корпусов для решения определенной
# педагогической задачи определенной категорией обучающихся Требует дальнейшего исследования вопрос том что
# эффективнее методически целесообразнее страничный план мини урока заданиями или план полноценного урока
# продолжительностью 80 120 минут как Ма объемом десятки страниц Думается что созданных ООР недооценивается основной
# учебник как ресурс источник для разработки заданий на основе подходов корпусной лингвистики Авторы анализируют
# используемые ими основные учебники доказательно критикуют их например за отсутствие примеров аутентичных
# разговорных речевых образцов возможностей для исследовательской самостоятельной работы обучающихся 24 далее
# дополняют их заданиями без указания по крайней мере явно на то каком виде посредством каких заданий эти темы
# раскрываются изучаются учебнике Думается что разработка заданий использованием подходов корпусной лингвистики для
# изучения конкретной темы на основе определенного учебника также может быть весьма эффективной привести ряду планов
# мини уроков качестве дополнения конкретному учебнику по модели реализованной создателями English Central Эти мини
# уроки легко могут быть интегрированы виде корпусных пятиминуток при прохождении самых разных тем обеспечивая тем
# самым необходимую гибкость увеличивая вероятность того что преподаватели не знакомые подходами корпусной
# лингвистики начнут их использовать собственной практике Наконец совершенно очевидно что создание качественных ООР
# использованием корпусов очень трудоемкий процесс Идея вовлечения студентов будущих педагогов их разработке рамках
# проектной деятельности заслуживает всяческого внимания поддержки внедрения разных учебных заведениях особенно
# условиях когда Российские стандарты уделяют первостепенное внимание проектной деятельности студентов

# %%
with open('KeyBERT_top_20.csv', 'w', encoding='utf-8') as f2:
    for eachkwrd in keywords:
        f2.write(str(eachkwrd[0])+";"+str(eachkwrd[1])+"\n")

# %%
keywords = kw_model.extract_keywords(
    docs=doc,
    stop_words=stop_list,
    keyphrase_ngram_range=(1, 2),
    top_n=20,
    highlight=True
    )
# Out:
# C:\Users\Андрей\AppData\Roaming\Python\Python310\site-packages\sklearn\feature_extraction\text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ак', 'бляха', 'богу', 'бу', 'буль', 'вашему', 'вообще', 'всякому', 'го', 'ей', 'елки', 'иному', 'какая', 'каким', 'каких', 'какое', 'какому', 'кей', 'кис', 'кэй', 'мое', 'моему', 'муха', 'нашему', 'нить', 'палки', 'паф', 'пиф', 'твоему', 'тик', 'тра', 'тс', 'ту', 'чегой', 'черт', 'чик', 'чтой', 'яй'] not in stop_words.
#   warnings.warn(
# Корпусная лингводидактика контексте парадигмы открытых образовательных ресурсов Коган Введение Развитие интернета
# информационного общества появлению важного тренда на открытое образование науку информацию Инициатором этого
# движения считается Майкл Стерн Харт изобретатель электронных книг основатель проекта Гутенберг 60 годы прошлого
# века ХХI веке этот тренд задала Будапештская Инициатива Открытый Доступ которой тех присоединились тысячи
# организаций этом документе Открытый доступ определялся как открытые для всех публикации Интернете которые можно
# читать разгружать копировать распространять распечатывать находить или присоединять полным текстам соответствующих
# статей использовать для составления указателей вводить их как данные программное обеспечение или использовать для
# других законных целей при отсутствии финансовых правовых технических преград при соблюдении целостности работы
# обязательной ссылке на имя автора при использовании цитировании последующие годы Будапештская инициатива получила
# развитие многочисленных документах ООН ЮНЕСКО например рекомендациях по развитию продвижению открытого доступа
# рекомендациях по открытой науке по работе открытыми образовательными ресурсами ООР сфере высшего образования об
# открытых образовательных ресурсах также рекомендациях по развитию практик использования ООР Исследования касающиеся
# влияния открытого образования на изучение преподавание иностранных языков собраны томе находящемся открытом доступе
# Открытые образовательные ресурсы обладают рядом характеристик важнейшими из которых являются бесплатный доступ
# право на использование адаптацию распространение третьими лицами без ограничений или незначительными ограничениями
# Некоторые исследователи дополняют список характеристик понятия открытость до 12 пунктов Обзор исследований
# принципов характеристик ООР можно найти статье Космас коллегами Одна из характеристик открытой науки прозрачность
# контроль критический анализ воспроизводимость результатов целях усиления надежности точности научных результатов
# также воздействия науки на общество 12 Специалисты области прикладной корпусной лингвистики говорят кризисе
# воспроизводимости replication crisis см например Анализируя тенденции развития исследований области обучения ИЯ
# использованием подходов корпусной лингвистики DDL за последние 30 лет на материале 480 публикаций авторитетных
# рецензируемых англоязычных журналах глав монографий материалах авторитетных конференций Болтон Вяткина обнаружили
# полное отсутствие исследований направленных на частичное воспроизведение повторение работ новых условиях другими
# категориями обучающихся 83 Следует заметить что авторы соответствии принципами открытой науки разместили информацию
# всех отобранных для анализа публикациях открытом доступе онлайн репозитории инструментов для исследований области
# иностранных языков IRIS Важность концепции ООР для более широкого использования корпусной лингводидактики обучении
# ИЯ Несмотря на эффективность использования подходов корпусной лингвистики обучении ИЯ как показал мета анализ
# проведенный Болтоном Коббом давно предсказанную революцию методах обучения ИЯ благодаря широкому использованию
# корпусов этого до сих пор не произошло Чамбес статье 2019г обратила внимание на необходимость преодоления между
# исследованиями области КЛ методикой преподавания ИЯ Разные исследователи называют разные причины сложившейся
# ситуации Наша попытка проанализировать их привела списку из причин 10 контексте парадигмы ООР мы остановимся на
# трех проблемах именно недоступность корпусов описанных статьях недостаточная подготовка преподавателей ИЯ по
# корпусной лингводидактике отсутствие общедоступных заданий созданных на базе находящихся свободном доступе онлайн
# корпусов для непосредственного использования учебном процессе Одним из препятствий более широкому распространению
# подходов описанных статьях является то что многие исследования выполнены на корпусах составленных специально для
# целей исследования потому недоступных для научной педагогической общественности доступе находится достаточно
# большое количество больших корпусов первую очередь национальные корпуса НКРЯ BNC COCA DWDS представительный список
# онлайн корпусов доступен разделе Другие корпуса сайта НКРИ указанием режима обращения доступен для онлайн поиска
# требуется регистрация доступен для скачивания Проблемой однако является отсутствие доступного банка упражнений
# которые преподаватель мог бы использовать при изучении той или иной темы Многочисленные примеры использования
# корпусов обучении ИЯ опубликованы научных статьях материалах конференций но доступ ним обычному преподавателю вуза
# не говоря уже об учителях средней школы затруднен эти публикации нигде не каталогизированы не описаны точки зрения
# имеющихся них корпусных заданий определенного типа качестве примера можно сослаться на недавние публикации на
# материале Национального корпуса русского языка 11 12 13 Изданные немногочисленные пособия заданиями как правило не
# относятся открытым ресурсам например 14 15 16 находящиеся открытом доступе меняют свой адрес Так магистерская
# диссертация Шоу сайта СОСА где она находилась вплоть до весны 2020г переместилась архив университета Бригама Янга
# Если преподаватель теме то он вынужден метаться между корпусом разными источниками упражнениями По мнению Вяткиной
# доступные онлайн корпуса английского языка других языков не содержат как инструкций по их использованию для
# обучения ИЯ так разработанных заданий системы упражнений привязанных конкретному корпусу 17 364 Проблемой является
# недостаточная подготовка преподавателей ИЯ области корпусной лингвистики корпусной лингводидактики Проблема
# серьезна простых путей ее решения кажется не существует нашем исследовании имевшем целью оценить влияние корпусной
# лингвистики на систему высшего образования России мы пришли выводу что на современном этапе соответствии
# требованиями ФГОС все студенты филологических специальностей получают базовые знания корпусной лингвистике
# некоторые имеют публикации по теме использования подходов корпусной лингвистики обучении ИЯ зарегистрированные
# наукометрических данных разного ранга 18 Однако открытым остается вопрос насколько они готовы регулярно
# использовать эти знания практической деятельности после окончания обучения Ленко Шиманска считает что элективного
# односеместрового курса по использованию корпусов подходов КЛ обучении ИЯ недостаточно для того чтобы будущие
# преподаватели ИЯ могли успешно интегрировать подходы КЛ собственную педагогическую практику 19 234 Исследователь
# предполагает что ситуация улучшится если студенты будут изучать возможности корпусной лингвистики наряду другими
# подходами курсе методики обучения ИЯ использовать их при изучении других теоретических практических лингвистических
# дисциплин Для мотивированных будущих действующих преподавателей ИЯ желающих освоить основы КЛ способы ее применения
# обучении ИЯ самостоятельно доступны разные способы которые мы рассмотрим следующем разделе Обзор открытых
# образовательных ресурсов для повышения квалификации по КЛ Есть целый ряд образовательных ресурсов находящихся
# свободном открытом доступе которые можно использовать для самообразования области корпусной лингвистики Мы
# рассмотрим коллекции YouTube МООК курсы записи вебинаров организованные ведущими центрами по корпусной лингвистике
# Начнем обзора видеоресурсов корпусной лингвистике доступных на YouTube По запросу Corpus linguistics YouTube выдает
# целый ряд ссылок на отдельные ролики на целые серии которых последовательно объясняются основы этой дисциплины
# Например Яссин Иабдунан разместил своем канале за последние года уже 11 роликов продолжительностью от 57 до 24 21
# мин каждый Элен Ле Фолл выложила 10 роликов Наиболее популярными набравшими за год более 1000 просмотров являются
# ролики по освоению Sketch Engine по созданию собственного специального корпуса корпусе COCA Разработчики крупных
# корпусов также имеют свои YouTube каналы Так Sketch Engine разместил 24 ролика Продолжительность обучающих видео
# колеблется от 29 до 25 Антони своем канале разместил 11 видео роликов объясняющих как использовать основные функции
# программы AntConc Версии широкоизвестного корпусного менеджера который он разработал Длительность видео колеблется
# от 15 до 14 38 Ле Фолл призывает активно создавать небольшие видео делясь них собственным опытом применения
# подходов корпусной лингвистики обучении ИЯ скрытыми хитростями работы доступных онлайн корпусах или применения
# корпусных менеджеров русскоязычном сегменте интернета такие материалы практически отсутствуют Массовые открытые
# онлайн курсы массовом сознании являются примером открытых образовательных ресурсов хотя специально проведенный
# анализ сравнения МООК курсов ООР позволил выявить важные отличия между этими категориями ресурсов Тем не менее их
# доступность делает их очень ценным ресурсом для самообразования Наиболее популярные МООК курсы по корпусной
# лингвистике это Corpus Linguistics Method Analysis Interpretation разработанный Ланкастерском университете МакЭнери
# размещенный на платформе FutureLearn Этот МООК является введением КЛ затрагивает вопросы обучения ИЯ использованием
# КЛ знакомит крупными онлайн корпусами новым корпусным менеджером LancsBox разработанным Брезиной Введение корпусную
# лингвистику курс ВШЭ представленный Левинзон Он размещен на Национальной платформе Открытое образование Курс дает
# представление практическом применении достижений современной корпусной лингвистики учит пользоваться существующими
# корпусами русского английского языков позволяет освоить базовые методы корпусного преподавания повседневной работе
# Курс Improving writing through corpora Data driven learning относится категории SPOC small private online course
# маленький частный онлайн курс Разработан Кроссвейтом университете Квинсленда размещен на платформе EdEx Его целью
# является развитие навыков академического письма прямым обращением корпусу Задания разработаны на основе открытого
# корпуса BAWE из коллекции корпусов Sketch Engine Апробация курса описана статье 21 эту же группу ресурсов можно
# включить курс разработанный Ленко Шиманска Corpora in Language Teaching для студентов варшавского университета
# который находится свободном доступе на сайте университета Целью курса является знакомство участников базовыми
# концепциями корпус анализ корпуса применение корпусных подходов обучении иностранным родному языку развитие навыка
# создания учебных материалов на основе корпусного подхода Важно что изучаются только общедоступные корпуса корпусные
# инструменты находящиеся открытом доступе Апробация курса описана Ленко Шиманска статьях 19 22 Серии вебинаров честь
# 50 летия основания магистерской программы по прикладной лингвистике университета Сан Паолу Бразилия руководители
# программы организовали серию вебинаров по корпусной лингвистике пригласив для участия всемирно известных ученых
# Байбера Скотта МакЭнери Ромер Дэвис Реппен др Вебинары проходили еженедельно апреля по сентябрь 2020г включая
# недели интенсива августе сентября течение которых проводилось несколько мастер классов по использованию новых
# программных продуктов или новых версий уже известных программ Например Скотт представил последнюю версию корпусного
# менеджера WordSmith которая на тот момент была свободном доступе Записи вебинаров доступны на канале YouTube LAEL
# Webinars на странице кафедры LAEL 50 years где также размещены презентации докладчиков Осенью 2021г эту инициативу
# продолжили вебинары организованные на базе Школы языков культур университета Квинсленда Австралия по теме
# International Perspectives on Corpus Technology for Language Learning Вебинары проходили октября 2021 по апрель
# 2022г Всего состоялся 21 вебинар Докладчиками также были очень крупные исследователи области корпусной лингвистики
# разработки программного обеспечения Франкенберг Гарсия Ленко Шиманска Болтон Кроссвейт Антони Последний познакомил
# новой версией своего корпусного менеджера Antconc функционал которого существенно расширен по сравнению версией
# AntConc Version Записи вебинаров доступны на канале YouTube Кроссвейта где также собраны презентации автора на ряде
# международных конференций по корпусной лингвистике Например TaLC 2020 EuroCALL 2021 др Развернутое описание
# вебинаров презентации докладчиков размещены на сайте университета Квинсленда Анонсы предстоящих событий публикуются
# социальных сетях таких группах как The Eurocall Corpus SIG на фейсбуке Applied Linguistics LinkedIn русскоязычном
# сегменте интернета корпусной лингвистике посвящены лекции беседы Плунгяна Добровольского Постнауке Бузаджи Захарова
# некоторых других известных исследователей также видеозаписи заседаний конференции Корпусная лингвистика которая
# проходила дистанционном режиме на кафедре Математической лингвистики СПбГУ 2021г Обновленная мае 2022г версия НКРЯ
# содержит существенно расширенный Образовательный портал Национального корпуса русского языка Обзор готовых ООР для
# использования подходов корпусной лингводидактики обучении ИЯ Рассмотрим предложение Вяткиной об эффективности
# привязки планов уроков заданий по работе корпусом конкретным корпусам 17 364 365 На первый взгляд может показаться
# что для больших онлайн корпусов таких как НКРЯ или СОСА проблема неактуальна они снабжены инструкциями пользователя
# внушительного объема инструкция по НИКРЯ содержит 87 стр инструкция по СОСА 27 стр дополнительными инструкциями по
# созданию собственного специального корпуса дополнительным инструментам для режима просмотра KWIC Вяткина указывает
# на то что эти руководства пользователя очень далеки от знакомых учителю планов уроков использованием корпусов 23 По
# ее мнению инструкции для преподавателей должны базироваться на педагогических принципах подразумевающих введение
# материала сопровождение вовлечение идти от простого сложному от большей поддержки со стороны преподавателя заданиям
# выполняемым самостоятельно своих статьях она описывает примеры заданий обращений корпусу немецкого языка DWDS для
# учащихся разным уровнем владения немецким языком от начинающих до продвинутых предполагающих разный формат работы
# индивидуальную работу работу парах малых группах введение материала преподавателем Основным фокусом является
# расширение словарного запаса задания могут включать освоение новых лексико грамматических характеристик слов
# помощью примеров из корпуса верификация примеров употребления слов словосочетаний учебниках примерами из корпуса
# Примеры заданий приведенные статье соответствуют разным инструментам корпуса DWDS базовый поиск временная ось
# визуализация коллокаций через облако слов др 23 Другим блестящим примером создания ООР для преподавания ИЯ на
# основе конкретного корпуса является проект CORPUS FOR SCHOOLS Teaching English Language with Corpus Linguistics
# создаваемый Ланкастерском университете под руководством Габласовой Учебные материалы привязаны большим выборкам
# устной речи BNC 1990 2014 представляющих неформальные беседы носителей британского варианта английского языка Уроки
# разработаны как для носителей английского языка готовящихся сдать итоговый экзамен по курсу средней школы level
# exam так для изучающих английский язык как второй или иностранный Выборки представлены на платформе BNClab Для
# выпускников английских школ задания представлены по следующим рубрикам категориям Language Change Language and
# Gender Language and Region Language and Age Spoken Communication Для изучающих английский язык как второй или
# иностранный разработаны уроки по рубрикам Current English Use Spoken Communication Communicative Skills рамках
# которых изучаются реальные явления современного английского языка не отраженные учебниках английской грамматики
# например изменение функции местоимения лица множественного числа they или способы выражения множественного числа во
# лице Учебные материалы по каждой теме включают раздаточные упражнения задания чтение абзаца иллюстрирующего правило
# анализ конкордансных строк трансформация обсуждение предлагаемых тем обязательным использованием изучаемого
# грамматического явления данном случае they функции лица ед числа По паролю доступен файл ответами комментариями для
# преподавателя Еще одним примером привязки планов уроков корпусу является мультимедийный ресурс EnglishCentral Он
# создан использованием корпусных технологий содержит более 14000 видео 250 млн строк аудиозаписей для развития
# навыков аудирования говорения каждую неделю добавляется по 50 новых видео Контент содержит тысячи отдельных видео
# указанным уровнем сложности более 100 мини курсов категориях Academic English Travel English Business English
# Career English Useful Expressions др Каждый видеофрагмент длится минуты Показ сопровождается субтитрами Видео можно
# остановить любом месте чтобы прослушать незнакомое слово несколько раз увидеть примеры его употребления всплывающем
# окне затем вернуться просмотру видео урока Пользователю предлагают посмотреть тематически близких видео выбранного
# уровня сложности которые подбираются системой автоматически систему интегрирована передовая технология записи речи
# IntelliSpeechSM которая автоматически сравнивает произнесенный фрагмент спектрограммой речи диктора оценивая
# близость попытки процентах Учащийся может неоднократно повторять попытки пытаясь приблизить свое произношение речи
# диктора бесплатной версии такая возможность представляется только для видео месяц Другая возможность платной версии
# касается тестирования незнакомой лексики контексте статьи важно отметить что для каждого видео урока имеется
# интерактивный План урока Lesson Plan Он состоит из заданий Video transcript пропусками нескольких слов которые
# можно заполнить по памяти пользуясь контекстом получить подсказку виде определения из словаря впечатанного пробел
# или прослушать пропущенное слов кликнув по пробелу получить правильный ответ выбрать отдельные предложения для
# последующей практики задании учащиеся должны составить собственные предложения со словами которые тренировались
# задании Предпочтительными являются предложения из видеосюжета Именно они приводятся качестве возможных ответов при
# активации функции Sentence которая по умолчанию деактивирована Задание содержит вопроса на понимание видеосюжета
# формате множественного выбора Ответы даны ниже Задание предлагает вопроса для обсуждения просит кратко
# сформулировать основную идею видеосюжета Please explain what this video is about in few sentences других вопроса
# побуждают высказать собственное мнение на основе информации видео урока Еще одной успешной практикой по
# интегрированию корпусной лингвистики обучение ИЯ является платформа The Corpus Aided Platform for Language Teachers
# CAP созданная на кафедре лингвистики современных языков университете Гонконга под руководством Ma Qing Angel На
# платформе представлены материалы для повышения квалификации самообразования преподавателей области корпусной
# лингвистики лингводидактики небольшие учебные видеоролики продолжительностью минут для грамматики произношения
# развития письменных навыков работе параллельным корпусом др разделе Teaching Activities помещены примеры учебных
# материалов детально разработанных планов уроков продолжительностью 80 120 мин по категориям обучение лексике
# грамматике произношению задания на основе параллельного англо китайского корпуса каждой категории есть подкатегории
# указывающие на категорию обучающихся младшие школьники учащиеся средних классов или вузов Например целью урока по
# развитию письменных навыков формате IELTS является расширение словарного запаса использование близких синонимов
# чтобы уменьшить употребление избыточно используемой лексики данном случае слова people использованием корпуса BNC
# коллекции англоязычных корпусов Дэвиса План урока занимает 22 страницы Элен Ле Фол вместе со своими студентами
# магистрантами будущими преподавателями иностранного языка разработала учебные материалы задания на основе
# материалов открытых онлайн корпусов по разным изучаемым темам разместила их на своем сайте как ООР Ресурс
# создавался течение семестров Важно что начале студентам не удалось избежать типичной ошибки разработанные материалы
# представляли четкие инструкции по поиску разных корпусах не методически обоснованные уроков по использованию
# корпусов классе Эту проблему они решали по ходу своей работы Материалы разработаны для конкретной категории
# учащихся части для начальной средней школы во для старших классов средней школы для использования разработанных
# материалов для английского для специальных целей профессионально ориентированного Каждая глава содержит подробную
# инструкцию поиска материалов конкретном корпусе для составления конкретного задания план урока идеи для
# последующего развития применения выявленные трудности ограничения 24 Например зарегистрированные но не имеющие
# подписки пользователи платформы СОСА часто сталкиваются задержкой выполнении запроса Есть свидетельства что этот
# факт может быть демотивирующим для последующей работы корпусом неподготовленных такому повороту событий учащихся 25
# Мы также сталкивались этим эффектом со своей стороны предложили способ его обойти сократив заложенное время
# ожидания 26 Все материалы созданы на основе доступных онлайн корпусов корпусных инструментов список которых
# приведен приложении пособия По мнению разработчиков это должно способствовать более широкому применению подходов КЛ
# повседневной педагогической практике преподавателей ИЯ Некоторым аналогом этого проекта является размещенные
# разделе сайта НКРИ Studorium результаты проекта Своевольные смыслы направленного на изучение описание изменений
# значении употреблении 30 лексем русского языка на протяжении 19 21 вв выполненный студентами ВШЭ под руководством
# Добрушиной Даниель 2010 2012гг Однако формат представления ближе формату презентаций научных докладов на
# конференции не плану урока НКРЯ содержит детский раздел Верные слова путеводителем по корпусу Инструкция по НКРЯ
# для детей бесплатным курсом Как работать НКРЯ разнообразными заданиями от игровых для младших школьников до
# серьезных олимпиадных задач для 13 15 летних подростков серией игр для старших школьников студентов очень
# информативным блогом Выводы Проведенный анализ показал что тренд на открытое образование науку информацию всемерно
# поддерживаемый ООН ЮНЕСКО может помочь более широкому внедрению методов корпусной лингводидактики повседневную
# педагогическую практику преподавателей иностранных языков Не все доступные онлайн корпуса другие ресурсы являются
# открытыми образовательными ресурсами строгом смысле этого слова обладают базовыми характеристиками ООР описанными
# литературе но свободный доступ ним делает их ценными инструментами для самообразования преподавателей ИЯ желающих
# повысить свой профессиональный уровень понять как можно использовать подходы корпусной лингвистики своей практике
# также как разрабатывать учебные материалы на основе корпусных данных Анализ учебных материалов планов уроков
# созданных как ООР показал что ряд вопросов идей высказанных предложений требует дальнейшего исследования Так очень
# привлекательная идея Вяткиной разработке учебных материалов привязке определенному корпусу реализована из
# рассмотренных ресурсах материалах Вяткиной для DWDS на сайте проекта языкового ресурсного центра канзасского
# университета https corpora ku edu материалах Габласовой по устному компоненту BNC на сайте BNClab планах мини
# уроков каждому видеофрагменту на сайте English Central разделе Верные слова НКРЯ двух других случаях ООР созданных
# под руководством Ле Фолл Ма содержатся учебные материалы созданные на базе разных корпусов для решения определенной
# педагогической задачи определенной категорией обучающихся Требует дальнейшего исследования вопрос том что
# эффективнее методически целесообразнее страничный план мини урока заданиями или план полноценного урока
# продолжительностью 80 120 минут как Ма объемом десятки страниц Думается что созданных ООР недооценивается основной
# как ресурс источник для разработки заданий на основе подходов корпусной лингвистики Авторы анализируют используемые
# ими основные учебники доказательно критикуют их например за отсутствие примеров аутентичных разговорных речевых
# образцов возможностей исследовательской самостоятельной работы обучающихся 24 далее дополняют их заданиями без
# указания по крайней мере явно на то каком виде посредством каких заданий эти темы раскрываются изучаются учебнике
# Думается что разработка заданий использованием подходов корпусной лингвистики для изучения конкретной темы на
# основе определенного учебника может быть весьма эффективной привести ряду планов мини уроков качестве дополнения
# конкретному учебнику по модели реализованной создателями English Central Эти мини уроки легко могут быть
# интегрированы виде корпусных пятиминуток при прохождении самых разных тем обеспечивая тем самым необходимую
# гибкость увеличивая вероятность того что преподаватели не знакомые подходами корпусной лингвистики начнут их
# использовать собственной практике Наконец совершенно очевидно что создание качественных ООР использованием корпусов
# очень трудоемкий процесс Идея вовлечения студентов будущих педагогов их разработке рамках проектной деятельности
# заслуживает всяческого внимания поддержки внедрения разных учебных заведениях особенно условиях когда Российские
# стандарты уделяют первостепенное внимание проектной деятельности студентов

# %%
with open('KeyBERT_top_20_bigram.csv', 'w', encoding='utf-8') as f2:
    for eachkwrd in keywords:
        f2.write(str(eachkwrd[0])+";"+str(eachkwrd[1])+"\n")

# %%
keywords = kw_model.extract_keywords(
    docs=doc,
    stop_words=stop_list,
    keyphrase_ngram_range=(1, 3),
    top_n=20,
    highlight=True
    )
# Out:
# C:\Users\Андрей\AppData\Roaming\Python\Python310\site-packages\sklearn\feature_extraction\text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ак', 'бляха', 'богу', 'бу', 'буль', 'вашему', 'вообще', 'всякому', 'го', 'ей', 'елки', 'иному', 'какая', 'каким', 'каких', 'какое', 'какому', 'кей', 'кис', 'кэй', 'мое', 'моему', 'муха', 'нашему', 'нить', 'палки', 'паф', 'пиф', 'твоему', 'тик', 'тра', 'тс', 'ту', 'чегой', 'черт', 'чик', 'чтой', 'яй'] not in stop_words.
#   warnings.warn(
# Корпусная лингводидактика контексте парадигмы открытых образовательных ресурсов Коган Введение Развитие интернета
# информационного привело появлению важного тренда на открытое образование науку информацию Инициатором этого
# движения считается Майкл Стерн Харт изобретатель электронных книг основатель проекта Гутенберг 60 годы прошлого
# века ХХI веке этот тренд задала Будапештская Инициатива Открытый Доступ которой тех присоединились тысячи
# организаций этом документе Открытый доступ определялся как открытые для всех публикации Интернете которые можно
# читать разгружать копировать распространять распечатывать находить или присоединять полным текстам соответствующих
# статей использовать для составления указателей вводить их как данные программное обеспечение или использовать для
# других законных целей при отсутствии финансовых правовых технических преград при соблюдении целостности работы
# обязательной ссылке на имя автора при использовании цитировании последующие годы Будапештская инициатива получила
# развитие многочисленных документах ООН ЮНЕСКО например рекомендациях по развитию продвижению открытого доступа
# рекомендациях по открытой науке по работе открытыми образовательными ресурсами ООР сфере высшего образования об
# открытых образовательных ресурсах также рекомендациях по развитию практик использования ООР Исследования касающиеся
# влияния открытого образования на изучение преподавание иностранных языков собраны томе находящемся открытом доступе
# Открытые образовательные ресурсы обладают рядом характеристик важнейшими из которых являются бесплатный доступ
# право на использование адаптацию распространение третьими лицами без ограничений или незначительными ограничениями
# Некоторые исследователи дополняют список характеристик понятия открытость до 12 пунктов Обзор исследований
# принципов характеристик ООР можно найти статье Космас коллегами Одна из характеристик открытой науки прозрачность
# контроль критический анализ воспроизводимость результатов целях усиления надежности точности научных результатов
# также воздействия науки на общество 12 Специалисты области прикладной корпусной лингвистики говорят кризисе
# воспроизводимости replication crisis см например Анализируя тенденции развития исследований области обучения ИЯ
# использованием подходов корпусной лингвистики DDL за последние 30 лет на материале 480 публикаций авторитетных
# рецензируемых англоязычных журналах глав монографий материалах авторитетных конференций Болтон Вяткина обнаружили
# полное отсутствие исследований направленных на частичное воспроизведение повторение работ новых условиях другими
# категориями обучающихся 83 Следует заметить что авторы соответствии принципами открытой науки разместили информацию
# всех отобранных для анализа публикациях открытом доступе онлайн репозитории инструментов для исследований области
# иностранных языков IRIS Важность концепции ООР для более широкого использования корпусной лингводидактики обучении
# ИЯ Несмотря на эффективность использования подходов корпусной лингвистики обучении ИЯ как показал мета анализ
# проведенный Болтоном Коббом давно предсказанную революцию методах обучения ИЯ благодаря широкому использованию
# корпусов этого до сих пор не произошло Чамбес статье 2019г обратила внимание на необходимость преодоления разрыва
# между исследованиями области КЛ методикой преподавания ИЯ Разные исследователи называют разные причины сложившейся
# ситуации Наша попытка проанализировать их привела списку из причин 10 контексте парадигмы ООР мы остановимся на
# трех проблемах именно недоступность корпусов описанных статьях недостаточная подготовка преподавателей ИЯ по
# корпусной лингводидактике отсутствие общедоступных заданий созданных на базе находящихся свободном доступе онлайн
# корпусов для непосредственного использования учебном процессе Одним из препятствий более широкому распространению
# подходов описанных статьях является то что многие исследования выполнены на корпусах составленных специально для
# целей исследования потому недоступных для научной педагогической общественности свободном доступе находится
# достаточно большое количество больших корпусов первую очередь национальные корпуса НКРЯ BNC COCA DWDS
# представительный список онлайн корпусов доступен разделе Другие корпуса сайта НКРИ указанием режима обращения
# доступен для онлайн поиска требуется регистрация доступен для скачивания Проблемой однако является отсутствие
# доступного банка упражнений которые преподаватель мог бы использовать при изучении той или иной темы Многочисленные
# примеры использования корпусов обучении ИЯ опубликованы научных статьях материалах конференций но доступ ним
# обычному преподавателю вуза не говоря уже об учителях средней школы затруднен эти публикации нигде не
# каталогизированы не описаны точки зрения имеющихся них корпусных заданий определенного типа качестве примера можно
# сослаться на недавние публикации на материале Национального корпуса русского языка 11 12 13 Изданные
# немногочисленные пособия поисковыми как правило не относятся открытым ресурсам например 14 15 16 находящиеся
# открытом доступе меняют свой адрес Так магистерская диссертация Шоу сайта СОСА где она находилась вплоть до весны
# 2020г переместилась архив университета Бригама Янга Если преподаватель теме то он вынужден метаться между корпусом
# разными источниками упражнениями По мнению Вяткиной доступные онлайн корпуса английского языка других языков не
# содержат как инструкций по их использованию для обучения ИЯ так разработанных заданий системы упражнений
# привязанных конкретному корпусу 17 364 Проблемой является недостаточная подготовка преподавателей ИЯ области
# корпусной лингвистики корпусной лингводидактики Проблема серьезна простых путей ее решения кажется не существует
# нашем исследовании имевшем целью оценить влияние корпусной лингвистики на систему высшего образования России мы
# пришли выводу что на современном этапе соответствии требованиями ФГОС все студенты филологических специальностей
# получают базовые знания корпусной лингвистике некоторые имеют публикации по теме использования подходов корпусной
# лингвистики обучении ИЯ зарегистрированные наукометрических базах данных разного ранга 18 Однако открытым остается
# вопрос насколько они готовы регулярно использовать эти знания практической деятельности после окончания обучения
# Ленко Шиманска считает что элективного односеместрового специального по использованию корпусов подходов КЛ обучении
# ИЯ недостаточно для того чтобы будущие преподаватели ИЯ могли успешно интегрировать подходы КЛ собственную
# педагогическую практику 19 234 Исследователь предполагает что ситуация улучшится если студенты будут изучать
# возможности корпусной лингвистики наряду другими подходами курсе методики обучения ИЯ использовать их при изучении
# других теоретических практических лингвистических дисциплин Для мотивированных будущих действующих преподавателей
# ИЯ желающих освоить основы КЛ способы ее применения обучении ИЯ самостоятельно доступны разные способы которые мы
# рассмотрим следующем разделе Обзор открытых образовательных ресурсов для повышения квалификации по КЛ Есть целый
# ряд образовательных ресурсов находящихся свободном открытом доступе которые можно использовать для самообразования
# области корпусной лингвистики Мы рассмотрим коллекции YouTube МООК курсы записи вебинаров организованные ведущими
# центрами по корпусной лингвистике Начнем обзора видеоресурсов корпусной лингвистике доступных на YouTube По запросу
# Corpus linguistics YouTube выдает целый ряд ссылок на отдельные ролики на целые серии которых последовательно
# объясняются основы этой дисциплины Например Яссин Иабдунан разместил своем канале за последние года уже 11 роликов
# продолжительностью от 57 до 24 21 мин каждый Элен Ле Фолл выложила 10 роликов Наиболее популярными набравшими за
# год более 1000 просмотров являются ролики по освоению Sketch Engine по созданию собственного специального корпуса
# корпусе COCA Разработчики крупных корпусов также имеют свои YouTube каналы Так Sketch Engine разместил 24 ролика
# Продолжительность обучающих видео колеблется от 29 до 25 Антони своем канале разместил 11 видео роликов объясняющих
# как использовать основные функции программы AntConc Версии широкоизвестного корпусного менеджера он разработал
# Длительность видео колеблется от 15 до 14 38 Ле Фолл призывает активно создавать небольшие видео делясь них
# собственным опытом применения подходов корпусной лингвистики обучении ИЯ скрытыми хитростями работы доступных
# онлайн корпусах или применения корпусных менеджеров русскоязычном сегменте интернета такие материалы практически
# отсутствуют Массовые открытые онлайн курсы массовом сознании являются примером открытых образовательных ресурсов
# хотя специально проведенный анализ сравнения МООК курсов ООР позволил выявить важные отличия между этими
# категориями ресурсов 20 Тем не менее их доступность делает их очень ценным ресурсом для самообразования Наиболее
# популярные МООК курсы по корпусной лингвистике это Corpus Linguistics Method Analysis Interpretation разработанный
# Ланкастерском университете МакЭнери размещенный на платформе FutureLearn Этот МООК является введением КЛ
# затрагивает вопросы обучения ИЯ использованием КЛ знакомит крупными онлайн корпусами новым корпусным менеджером
# LancsBox разработанным Брезиной Введение корпусную лингвистику курс ВШЭ представленный Левинзон Он размещен на
# Национальной платформе Открытое образование Курс дает представление практическом применении достижений современной
# корпусной лингвистики учит пользоваться существующими корпусами русского английского языков позволяет освоить
# базовые методы корпусного преподавания повседневной работе Курс Improving writing through corpora Data driven
# learning относится категории SPOC small private online course маленький частный онлайн курс Разработан Кроссвейтом
# университете Квинсленда размещен на платформе EdEx Его целью является развитие навыков академического письма прямым
# обращением корпусу Задания разработаны на основе открытого корпуса BAWE из коллекции корпусов Sketch Engine
# Апробация курса описана статье 21 эту же группу ресурсов можно включить курс разработанный Ленко Шиманска Corpora
# in Language Teaching для студентов варшавского университета который находится свободном доступе на сайте
# университета Целью курса является знакомство участников базовыми концепциями корпус анализ корпуса применение
# корпусных подходов обучении иностранным родному языку развитие навыка создания учебных материалов на основе
# корпусного подхода Важно что изучаются только общедоступные корпуса корпусные инструменты находящиеся открытом
# доступе Апробация курса описана Ленко Шиманска статьях 19 22 Серии вебинаров честь 50 летия основания магистерской
# программы по прикладной лингвистике университета Сан Паолу Бразилия руководители программы организовали серию
# вебинаров по корпусной лингвистике пригласив для участия всемирно известных ученых Байбера Скотта МакЭнери Ромер
# Дэвис Реппен др Вебинары проходили еженедельно апреля по сентябрь 2020г включая недели интенсива августе сентября
# течение которых проводилось несколько мастер классов по использованию новых программных продуктов или новых версий
# уже известных программ Например Скотт представил последнюю версию корпусного менеджера WordSmith которая на тот
# момент была свободном доступе Записи вебинаров доступны на канале YouTube LAEL Webinars на странице кафедры LAEL 50
# years где также размещены презентации докладчиков Осенью 2021г эту инициативу продолжили вебинары организованные на
# базе Школы языков культур университета Квинсленда Австралия по теме International Perspectives on Corpus Technology
# for Language Learning Вебинары проходили октября 2021 по апрель 2022г Всего состоялся 21 вебинар Докладчиками также
# были очень крупные исследователи области корпусной лингвистики разработки программного обеспечения Франкенберг
# Гарсия Ленко Шиманска Болтон Кроссвейт Антони Последний познакомил новой версией своего корпусного менеджера
# Antconc функционал которого существенно расширен по сравнению версией AntConc Version Записи вебинаров доступны на
# канале YouTube Кроссвейта где также собраны презентации автора на ряде международных конференций по корпусной
# лингвистике Например TaLC 2020 EuroCALL 2021 др Развернутое описание вебинаров презентации докладчиков размещены на
# сайте университета Квинсленда Анонсы предстоящих событий публикуются социальных сетях таких группах как The
# Eurocall Corpus SIG на фейсбуке Applied Linguistics LinkedIn русскоязычном сегменте интернета корпусной лингвистике
# посвящены лекции беседы Плунгяна Добровольского Постнауке Бузаджи Захарова некоторых других известных
# исследователей также видеозаписи заседаний конференции Корпусная лингвистика которая проходила дистанционном режиме
# на кафедре Математической лингвистики СПбГУ 2021г Обновленная мае 2022г версия НКРЯ содержит существенно
# расширенный Образовательный портал Национального корпуса русского языка Обзор готовых ООР для использования
# подходов корпусной лингводидактики обучении ИЯ Рассмотрим предложение Вяткиной об эффективности привязки планов
# уроков заданий по работе корпусом конкретным корпусам 17 364 365 На первый взгляд может показаться что для больших
# онлайн корпусов таких как НКРЯ или СОСА проблема неактуальна они снабжены инструкциями пользователя внушительного
# объема инструкция по НИКРЯ содержит 87 стр инструкция по СОСА 27 стр дополнительными инструкциями по созданию
# собственного специального корпуса дополнительным инструментам для режима просмотра KWIC Вяткина указывает на то что
# эти руководства пользователя очень далеки от знакомых учителю планов уроков использованием корпусов 23 По ее мнению
# инструкции для преподавателей должны базироваться на педагогических принципах подразумевающих введение материала
# сопровождение вовлечение идти от простого сложному от большей поддержки со стороны преподавателя заданиям
# выполняемым самостоятельно своих статьях она описывает примеры заданий обращений корпусу немецкого языка DWDS для
# учащихся разным уровнем владения немецким языком от начинающих до продвинутых предполагающих разный формат работы
# индивидуальную работу работу парах малых группах введение материала преподавателем Основным фокусом является
# расширение словарного запаса задания могут включать освоение новых лексико грамматических характеристик слов
# помощью примеров из корпуса верификация примеров употребления слов словосочетаний учебниках примерами из корпуса
# Примеры заданий приведенные статье соответствуют разным инструментам корпуса DWDS базовый поиск временная ось
# визуализация коллокаций через облако слов др 23 Другим блестящим примером создания ООР для преподавания ИЯ на
# основе конкретного корпуса является проект CORPUS FOR SCHOOLS Teaching English Language with Corpus Linguistics
# создаваемый Ланкастерском университете под руководством Габласовой Учебные материалы привязаны большим выборкам
# устной речи BNC 1990 2014 представляющих неформальные беседы носителей британского варианта английского языка Уроки
# разработаны как для носителей английского языка готовящихся сдать итоговый экзамен по курсу средней школы level
# exam так для изучающих английский язык как второй или иностранный Выборки представлены на платформе BNClab Для
# выпускников английских школ задания представлены по следующим рубрикам категориям Language Change Language and
# Gender Language and Region Language and Age Spoken Communication Для изучающих английский язык как второй или
# иностранный разработаны уроки по рубрикам Current English Use Spoken Communication Communicative Skills рамках
# которых изучаются реальные явления современного английского языка не отраженные учебниках английской грамматики
# например изменение функции местоимения лица множественного числа they или способы выражения множественного числа во
# лице Учебные материалы по каждой теме включают раздаточные упражнения задания чтение абзаца иллюстрирующего правило
# анализ конкордансных строк трансформация обсуждение предлагаемых тем обязательным использованием изучаемого
# грамматического явления данном случае they функции лица ед числа По паролю доступен файл ответами комментариями для
# преподавателя Еще одним примером привязки планов уроков корпусу является мультимедийный ресурс EnglishCentral Он
# создан использованием корпусных технологий содержит более 14000 видео 250 млн строк аудиозаписей для развития
# навыков аудирования говорения каждую неделю добавляется по 50 новых видео Контент содержит тысячи отдельных видео
# указанным уровнем сложности более 100 мини курсов категориях Academic English Travel English Business English
# Career English Useful Expressions др Каждый видеофрагмент длится минуты Показ сопровождается субтитрами Видео можно
# остановить любом месте чтобы прослушать незнакомое слово несколько раз увидеть примеры его употребления всплывающем
# окне затем вернуться просмотру видео урока Пользователю предлагают посмотреть тематически близких видео выбранного
# уровня сложности которые подбираются системой автоматически систему интегрирована передовая технология записи речи
# IntelliSpeechSM которая автоматически сравнивает произнесенный фрагмент спектрограммой речи диктора оценивая
# близость попытки процентах Учащийся может неоднократно повторять попытки пытаясь приблизить свое произношение речи
# диктора бесплатной версии такая возможность представляется только для видео месяц Другая возможность платной версии
# касается тестирования незнакомой лексики контексте статьи важно отметить что для каждого видео урока имеется
# интерактивный План урока Lesson Plan Он состоит из заданий Video transcript пропусками нескольких слов которые
# можно заполнить по памяти пользуясь контекстом получить подсказку виде определения из словаря впечатанного пробел
# или прослушать пропущенное слов кликнув по пробелу получить правильный ответ выбрать отдельные предложения для
# последующей практики задании учащиеся должны составить собственные предложения со словами которые тренировались
# задании Предпочтительными являются предложения из видеосюжета Именно они приводятся качестве возможных ответов при
# активации функции Sentence которая по умолчанию деактивирована Задание содержит вопроса на понимание видеосюжета
# формате множественного выбора Ответы даны ниже Задание предлагает вопроса для обсуждения просит кратко
# сформулировать основную идею видеосюжета Please explain what this video is about in few sentences других вопроса
# побуждают высказать собственное мнение на основе информации видео урока Еще одной успешной практикой по
# интегрированию корпусной лингвистики обучение ИЯ является платформа The Corpus Aided Platform for Language Teachers
# CAP созданная на кафедре лингвистики современных языков университете Гонконга под руководством Ma Qing Angel На
# платформе представлены материалы для повышения квалификации самообразования преподавателей области корпусной
# лингвистики лингводидактики небольшие учебные видеоролики продолжительностью минут для грамматики произношения
# развития письменных навыков работе параллельным корпусом др разделе Teaching Activities помещены примеры учебных
# материалов детально разработанных планов уроков продолжительностью 80 120 мин по категориям обучение лексике
# грамматике произношению задания на основе параллельного англо китайского корпуса каждой категории есть подкатегории
# указывающие на категорию обучающихся младшие школьники учащиеся средних классов или вузов Например целью урока по
# развитию письменных навыков формате IELTS является расширение словарного запаса использование близких синонимов
# чтобы уменьшить употребление избыточно используемой лексики данном случае слова people использованием корпуса BNC
# коллекции англоязычных корпусов Дэвиса План урока занимает 22 страницы Элен Ле Фол вместе со своими студентами
# магистрантами будущими преподавателями иностранного языка разработала учебные материалы задания на основе
# материалов открытых онлайн корпусов по разным изучаемым темам разместила их на своем сайте как ООР Ресурс
# создавался течение семестров Важно что начале студентам не удалось избежать типичной ошибки разработанные материалы
# представляли четкие инструкции по поиску разных корпусах не методически обоснованные планы уроков по использованию
# корпусов классе Эту проблему они решали по ходу своей работы Материалы разработаны для конкретной категории
# учащихся части для начальной средней школы во для старших классов средней школы для использования разработанных
# материалов для английского для специальных целей профессионально ориентированного языка Каждая глава содержит
# подробную инструкцию поиска материалов конкретном корпусе для составления конкретного задания план урока идеи для
# последующего развития применения выявленные трудности ограничения 24 Например зарегистрированные но не имеющие
# подписки пользователи платформы СОСА часто сталкиваются задержкой выполнении запроса Есть свидетельства что этот
# факт может быть демотивирующим для последующей работы корпусом неподготовленных такому повороту событий учащихся 25
# Мы также сталкивались этим эффектом со своей стороны предложили способ его обойти сократив заложенное время
# ожидания 26 Все материалы созданы на основе доступных онлайн корпусов корпусных инструментов список которых
# приведен приложении пособия По мнению разработчиков это должно способствовать более широкому применению подходов КЛ
# повседневной педагогической практике преподавателей ИЯ Некоторым аналогом этого проекта является размещенные
# разделе сайта НКРИ Studorium результаты проекта Своевольные смыслы направленного на изучение описание изменений
# значении употреблении 30 лексем русского языка на протяжении 19 21 вв выполненный студентами ВШЭ под руководством
# Добрушиной Даниель 2010 2012гг Однако формат представления ближе формату презентаций научных докладов на
# конференции не плану урока НКРЯ содержит детский раздел Верные слова путеводителем по корпусу Инструкция по НКРЯ
# для детей бесплатным курсом Как работать НКРЯ разнообразными заданиями от игровых для младших школьников до
# серьезных олимпиадных задач для 13 15 летних подростков серией игр для старших школьников студентов очень
# информативным блогом Выводы Проведенный анализ показал что тренд на открытое образование науку информацию всемерно
# поддерживаемый ООН ЮНЕСКО может помочь более широкому внедрению методов корпусной лингводидактики повседневную
# педагогическую практику преподавателей иностранных языков Не все доступные онлайн корпуса другие ресурсы являются
# открытыми образовательными ресурсами строгом смысле этого слова обладают базовыми характеристиками ООР описанными
# литературе но свободный доступ ним делает их ценными инструментами для самообразования преподавателей ИЯ желающих
# повысить свой профессиональный уровень понять как можно использовать подходы корпусной лингвистики своей практике
# также как разрабатывать учебные материалы на основе корпусных данных Анализ учебных материалов планов уроков
# созданных как ООР показал что ряд вопросов идей высказанных предложений требует дальнейшего исследования Так очень
# привлекательная идея Вяткиной разработке учебных материалов привязке определенному корпусу реализована из
# рассмотренных ресурсах материалах Вяткиной для DWDS на сайте проекта языкового ресурсного центра канзасского
# университета https corpora ku edu материалах Габласовой по устному компоненту BNC на сайте BNClab планах мини
# уроков каждому видеофрагменту на сайте English Central разделе Верные слова НКРЯ двух других случаях ООР созданных
# под руководством Ле Фолл Ма содержатся учебные материалы созданные на базе разных корпусов для решения определенной
# педагогической задачи определенной категорией обучающихся дальнейшего исследования вопрос том что эффективнее
# методически целесообразнее страничный план мини урока заданиями или план полноценного урока продолжительностью 80
# 120 минут как Ма объемом десятки страниц Думается что созданных ООР недооценивается учебник как ресурс источник для
# разработки заданий на основе подходов корпусной лингвистики Авторы анализируют используемые ими основные учебники
# доказательно критикуют их например за отсутствие примеров аутентичных разговорных речевых образцов возможностей
# исследовательской самостоятельной работы обучающихся 24 далее дополняют их заданиями без указания по крайней мере
# явно на то каком виде посредством каких заданий эти темы раскрываются изучаются учебнике Думается что разработка
# заданий использованием подходов корпусной лингвистики для изучения конкретной темы на основе определенного учебника
# может быть весьма эффективной привести ряду планов мини уроков качестве дополнения конкретному учебнику по модели
# реализованной создателями English Central Эти мини уроки легко могут быть интегрированы виде корпусных пятиминуток
# при прохождении самых разных тем обеспечивая тем самым необходимую гибкость увеличивая вероятность того что
# преподаватели не знакомые подходами корпусной лингвистики начнут их использовать собственной практике Наконец
# совершенно очевидно что создание качественных ООР использованием корпусов очень трудоемкий процесс Идея вовлечения
# студентов будущих педагогов их разработке рамках проектной деятельности заслуживает всяческого внимания поддержки
# внедрения разных учебных заведениях особенно условиях когда Российские стандарты уделяют первостепенное внимание
# проектной деятельности студентов

# %%
with open('KeyBERT_top_20_trigram.csv', 'w', encoding='utf-8') as f2:
    for eachkwrd in keywords:
        f2.write(str(eachkwrd[0])+";"+str(eachkwrd[1])+"\n")

# %% [markdown]
# # RuTermExtract

# %%
from rutermextract import TermExtractor

# %%
term_extractor = TermExtractor()

# %%
with open('corpus/Kogan_IMS_2022_Abstract_rus.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
for term in term_extractor(text):
    print(term.normalized, term.count)
# Out:
# ия 2
# изучение 2
# два всемирных международных конгрессов 1
# разработка набора заданий/упражнений 1
# открытый доступ корпуса 1
# открытые образовательные ресурсы 1
# недостаточная компетенция преподавателей 1
# корпусная компетенция преподавателей 1
# конкретный доступное корпус 1
# имеющиеся передовые практика 1
# имеющиеся открытые интернет-ресурсы 1
# широкое использование 1
# ценный ресурс 1
# учебные цели 1
# трудоёмкая задача 1
# развитие интернета 1
# педагогическая общественность 1
# открытое образование 1
# научные статьи 1
# лингвистическое анализ 1
# корпусная лингводидактика 1
# корпусная лингвистика 1
# исследовательские цели 1
# информационное общество 1
# иностранные языки 1
# иностранное языки 1
# иностранное язык 1
# документы оон 1
# дидактические материалы 1
# варианты повышения 1
# важное тренд 1
# большинство преподавателей 1
# школа 1
# факт 1
# тенденция 1
# счёт 1
# статья 1
# решения 1
# решение 1
# разработка 1
# развитие 1
# проблемы 1
# проблема 1
# препятствия 1
# появление 1
# подход 1
# основа 1
# область 1
# наука 1
# корпус 1
# информация 1
# вуз 1
# unesco 1

# %%
with open('RuTermExtract_keywords_abstract.csv', 'w', encoding='utf-8') as f2:
    for term in term_extractor(text):
        f2.write(str(term.normalized)+";"+str(term.count)+"\n")

# %% [markdown]
# # SpaCy

# %%
import spacy
from collections import Counter
from nltk.corpus import stopwords

# %%
# Для SpaCy (дополнительно взяли стоп-слова из nltk, с ними результаты улучшились)
spacy_model = spacy.load('ru_core_news_sm')

# %%
spacy_model.max_length = 2400000

# %%
nltk_stopwords = stopwords.words('russian')

# %%
spacy_stopwords = spacy_model.Defaults.stop_words

# %%
def extract_keywords_with_spacy(text):
    keywords = []
    doc = spacy_model(text.read())
    for token in doc:
        # Тексты уже очищены от знаков препинания и лемматизированы, тем не менее, остались некоторые символы,
        # которые нужно удалить
        if token.text not in spacy_stopwords and token.text not in nltk_stopwords and \
                token.text not in "`'«»...—-":
            if token.pos_ in ('ADJ', 'NOUN', 'VERB'):
                keywords.append(token.text)

    freq_word = Counter(keywords)
    max_freq = Counter(keywords).most_common(1)[0][1]
    for w in freq_word:
        freq_word[w] = round(freq_word[w] / max_freq, 3)

    freq_20 = freq_word.most_common(20)

    with open('spacykeywords_abstract.csv', 'w', encoding='utf-8') as f2:
        for term in freq_20:
            f2.write(str(term[0])+";"+str(term[1])+"\n")

    print(freq_20)

# %%
with open('corpus/Kogan_IMS_2022.txt', 'r', encoding='utf-8') as file:
    extract_keywords_with_spacy(file)
# Out:
# [('корпусной', 1.0), ('лингвистики', 0.655), ('корпусов', 0.586), ('корпуса', 0.586), ('является', 0.414), ('видео', 0.414), ('подходов', 0.379), ('ИЯ', 0.379), ('онлайн', 0.345), ('заданий', 0.345), ('языка', 0.345), ('основе', 0.345), ('урока', 0.345), ('использовать', 0.31), ('доступе', 0.31), ('обучении', 0.31), ('материалы', 0.31), ('использования', 0.276), ('области', 0.276), ('использованием', 0.276)]

# %% [markdown]
# # Pullenti

# %%
from pullenti_wrapper.processor import Processor, GEO, ORGANIZATION, PERSON, PHONE, ADDRESS
from collections import Counter

# %%
pullenti_processor = Processor([PERSON, ORGANIZATION, GEO, PHONE, ADDRESS])

# %%
def extract_keywords_with_pullenti(text):
    keywords = []
    for text in text.read().splitlines():
        try:
            result = pullenti_processor(text)
            for match in result.walk():
                for key, value in match.referent.slots:
                    if key not in ('ISRELATIVE', 'SEX', 'NUMBER', 'HIGHER', 'PROFILE',
                                   'ALPHA2', 'POINTER', 'FROM', 'REF', 'ATTRIBUTE'):
                        if 'LASTNAME' in str(match.referent.slots) and 'FIRSTNAME' in str(match.referent.slots):
                            try:
                                keywords.append(f'{match.referent.firstname} {match.referent.lastname}'.lower())
                            except AttributeError:
                                continue
                        keywords.append(str(value).lower())
        except ValueError:
            continue

    freq_word = Counter(keywords)

    freq_20 = freq_word.most_common(20)

    with open('pullenti_keywords_fulltext.csv', 'w', encoding='utf-8') as f2:
        for term in freq_20:
            f2.write(str(term[0])+";"+str(term[1])+"\n")

    print(freq_20)

# %%
with open('corpus/Kogan_IMS_2022.txt', 'r', encoding='utf-8') as file:
    extract_keywords_with_pullenti(file)
# Out:
# [('н вяткина', 12), ('государство', 12), ('университет', 9), ('великобритания', 8), ('британия', 8), ('англия', 8), ('соединенное королевство', 8), ('соединенное королевство великобритании и\xa0северной ирландии', 8), ('н', 7), ('вяткина', 6), ('youtube', 6), ('м', 5), ('а', 5), ('корпус', 5), ('город', 5), ('международная организация', 4), ('ассоциация', 4), ('а болтон', 4), ('национальный корпус русского языка', 4), ('шиманск', 4)]

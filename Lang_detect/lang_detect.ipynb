# %%
#langdetect

# %%
# !pip install langdetect
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=1922f49e36f8e9bcbc483d40721355c977237aea8d88e042cb5bb71d39b3b0eb
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %%
from langdetect import detect

# %%
f = open('Gouvernement.fr.txt', 'r', encoding = 'windows-1251')
text = f.read()
f.close()

detect(text)
# Out:
# 'fr'

# %%
f = open('new.times.txt', 'r', encoding = 'windows-1251')
text = f.read()
f.close()

detect(text)
# Out:
# 'en'

# %%
f = open('9tezis.txt', 'r', encoding = 'windows-1251')
text = f.read()
f.close()

detect(text)
# Out:
# 'ru'

# %%
f = open('forbes1.txt', 'r', encoding = 'windows-1251')
text = f.read()
f.close()

detect(text)
# Out:
# 'ru'

# %%
#langid

# %%
# !pip install langid
# Out:
# Collecting langid
#   Downloading langid-1.1.6.tar.gz (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 22.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from langid) (1.26.4)
# Building wheels for collected packages: langid
#   Building wheel for langid (setup.py) ... done
#   Created wheel for langid: filename=langid-1.1.6-py3-none-any.whl size=1941171 sha256=79ace651103da32af2479635470429f45e05d5bd102b4f286ab5f18faa29adac
#   Stored in directory: /root/.cache/pip/wheels/23/c8/c6/eed80894918490a175677414d40bd7c851413bbe03d4856c3c
# Successfully built langid
# Installing collected packages: langid
# Successfully installed langid-1.1.6

# %%
import langid

# %%
langid.classify('Gouvernement.fr.txt')
# Out:
# ('fr', -33.57415819168091)

# %%
f = open('Gouvernement.fr.txt', 'r', encoding = 'windows-1251')
text = f.read()
f.close()

langid.classify(text)
# Out:
# ('fr', -7561.41561794281)

# %%
langid.classify('new.times.txt')
# Out:
# ('en', 9.061840057373047)

# %%
f = open('new.times.txt', 'r', encoding = 'windows-1251')
text = f.read()
f.close()

langid.classify(text)
# Out:
# ('en', -11440.087631464005)

# %%
f = open('forbes1.txt', 'r', encoding = 'windows-1251')
text = f.read()
f.close()

langid.classify(text)
# Out:
# ('ru', -217695.4144909382)

# %%
langid.classify('9tezis.txt')
# Out:
# ('en', 9.061840057373047)

# %%
f = open('9tezis.txt', 'r', encoding = 'windows-1251')
text = f.read()
f.close()

langid.classify(text)
# Out:
# ('ru', -100196.79723978043)

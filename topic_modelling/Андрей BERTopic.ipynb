# %%
# coding: utf-8
import codecs
import os
import sklearn
import bertopic

# %%
PATH = r'C:\Users\Aндрей\Desktop\Митрофанова\TM\annot'
STW_PATH = r'C:\Users\Aндрей\Desktop\Митрофанова\TM\swl.txt' # путь к документу со стоп-словами

# %%
with codecs.open(STW_PATH, encoding = 'utf-8') as f:
#    stw_list = f.read().split()[1:] # тк первый символ - что-то странное: \ufeffа
    stw_list = f.read().split()

# %%
file_names = os.listdir(PATH) 
documents = []
for name in file_names:
    if name.endswith(".txt"):
        with codecs.open(PATH + "/" + name, encoding = 'utf-8') as f:
            data = []
            for word in f.read().split():
                if word not in stw_list:
                    data.append(word)
            document = ' '.join(data)
            documents.append(document)
            # each document should contain lemmatized words separated by spaces

# %%
# Иначе не запустится
documents = [text.split() for text in documents]
documents = [item for sublist in documents for item in sublist]

# %% [markdown]
# Код выполняется адски долго (занимает 2 часа на ноуте). Как следствие, не доделано.

# %%
from sklearn.feature_extraction.text import CountVectorizer 
from bertopic import BERTopic

vectorizer_model = CountVectorizer(stop_words=stw_list, ngram_range=(1,2), min_df=1, max_df=0.95) 
topic_model = BERTopic(language="multilingual", vectorizer_model=vectorizer_model, calculate_probabilities=True, verbose=True)
topics, probs = topic_model.fit_transform(documents)
# Out:
# Batches:   0%|          | 0/22633 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [23], in <cell line: 6>()
#       4 vectorizer_model = CountVectorizer(stop_words=stw_list, ngram_range=(1,2), min_df=1, max_df=0.95)
#       5 topic_model = BERTopic(language="multilingual", vectorizer_model=vectorizer_model, calculate_probabilities=True, verbose=True)
# ----> 6 topics, probs = topic_model.fit_transform(documents)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\bertopic\_bertopic.py:344, in BERTopic.fit_transform(self, documents, embeddings, y)
#     341 if embeddings is None:
#     342     self.embedding_model = select_backend(self.embedding_model,
#     343                                           language=self.language)
# --> 344     embeddings = self._extract_embeddings(documents.Document,
# ...

# %%
# ЭТО НЕ МОИ РЕЗУЛЬТАТЫ
freq = topic_model.get_topic_info(); freq.head(40)
# Out:
#    Topic  Count                              Name
# 0     -1    109    -1_письмо_сеньор_мужик_штирлиц
# 1      0     37  0_hе_hет_холман_товарищ командир
# 2      1     22          1_мэтт_хелм_анита_сеньор
# 3      2     19        2_дживз_лойош_хэнк_магистр
# 4      3     13           3_зей_зей би_маркус_ким

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('hе', 0.0032895852972669574),
#  ('hет', 0.002297032014462689),
#  ('холман', 0.002264673403874827),
#  ('товарищ командир', 0.0021227428113313146),
#  ('рик', 0.0021101418043088793),
#  ('лэр', 0.001904550331865085),
#  ('скриббл', 0.001904550331865085),
#  ('эл', 0.0018573702522604707),
#  ('бойд', 0.0018313158340839502),
#  ('сергей', 0.0018174167898237328)]

# %%
topic_model.visualize_topics()
# Out:
# <div>                            <div id="56d47bc0-43c3-4081-a2dc-2d1d62b7bb29" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56d47bc0-43c3-4081-a2dc-2d1d62b7bb29")) {                    Plotly.newPlot(                        "56d47bc0-43c3-4081-a2dc-2d1d62b7bb29",                        [{"customdata":[[0,"\u0441\u0435\u043c\u0430\u043d\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439 | \u0435\u0434\u0438\u043d\u0438\u0446\u0430 | \u0441\u0438\u043d\u0442\u0430\u043a\u0441\u0438\u0447\u0435\u0441\u043a\u0438\u0439 | \u043f\u043e\u043d\u044f\u0442\u0438\u0435 | \u0440\u0430\u0437\u043d\u044b\u0439",409],[1,"\u0441\u043b\u043e\u0433 | \u0437\u0432\u0443\u043a | \u0443\u0434\u0430\u0440\u0435\u043d\u0438\u0435 | \u0437\u0432\u0443\u043a\u043e\u0432\
# ...

# %%
topic_model.visualize_barchart()
# Out:
# <div>                            <div id="94d8f1a0-7746-40eb-b79b-ace2e180435e" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94d8f1a0-7746-40eb-b79b-ace2e180435e")) {                    Plotly.newPlot(                        "94d8f1a0-7746-40eb-b79b-ace2e180435e",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.006743666798984231,0.007052758173153853,0.007376774469662115,0.008241297119103198,0.008373535082919218],"y":["\u043f\u043e\u043d\u044f\u0442\u0438\u0435  ","\u0435\u0434\u0438\u043d\u0438\u0446\u0430  ","\u0441\u0438\u043d\u0442\u0430\u043a\u0441\u0438\u0447\u0435\u0441\u043a\u0438\u0439  ","\u0441\u0435\u043c\u0430\u043d\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439  ","\u043e\u0442\u043d\u043e\u0448\u04
# ...

# %%
topic_model.visualize_heatmap()
# Out:
# <div>                            <div id="f77a7f85-3881-410b-9a09-87546a94ba06" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f77a7f85-3881-410b-9a09-87546a94ba06")) {                    Plotly.newPlot(                        "f77a7f85-3881-410b-9a09-87546a94ba06",                        [{"coloraxis":"coloraxis","name":"0","x":["-1_\u0440\u0430\u0437\u043d\u044b\u0439_\u043f\u0438\u0441\u044c\u043c\u043e_\u0438\u0441\u0442\u043e\u0440\u0438\u0447\u0435\u0441\u043a\u0438\u0439","0_\u0441\u0435\u043c\u0430\u043d\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439_\u0435\u0434\u0438\u043d\u0438\u0446\u0430_\u0441\u0438\u043d...","1_\u0441\u043b\u043e\u0433_\u0437\u0432\u0443\u043a_\u0443\u0434\u0430\u0440\u0435\u043d\u0438\u0435","2_\u043f\u0438\u0441\
# ...

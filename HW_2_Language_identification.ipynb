# %%
pip install langid langdetect

# %%
folder_path = "texts_folder"

# %%
print("Начинаем определение языков .....\n")
for filename in files:
    file_path = os.path.join(folder_path, filename)

    with open(file_path, "r", encoding="utf-8") as file:
        text = file.read().strip()

    langid_result = langid.classify(text)[0]
    langdetect_result = detect(text)

    print(f"Название файла: {filename}")
    print(f"Текст: {text[:50]}...")
    print(f"Определения языка с помощью langid: {langid_result}")
    print(f"Определения языка с помощью langdetect: {langdetect_result}")
    print("-" * 40)

print("Все языки определены!")
# Out:
# Начинаем определение языков .....
#
# Название файла: text_in_english.txt
# Текст: The Ant and the Dove
# One hot day, an ant was searc...
# Определения языка с помощью langid: en
# Определения языка с помощью langdetect: en
# ----------------------------------------
# Название файла: text_in_russian.txt
# Текст: Я вас любил: любовь еще, быть может,
# В душе моей у...
# Определения языка с помощью langid: ru
# Определения языка с помощью langdetect: ru
# ----------------------------------------
# Название файла: text_in_arabic.txt
# Текст: يُحكى أن حمامتان جميلتان قررتا السفر والابتعاد عن ...
# Определения языка с помощью langid: ar
# Определения языка с помощью langdetect: ar
# ----------------------------------------
# Все языки определены!

# %%
import pymystem3

# %%
morph = pymystem3.Mystem(disambiguation=True)

# %%
morph.analyze('')
# Out:
# [{'analysis': [{'lex': 'пари',
#     'wt': 0.9801973292,
#     'gr': 'S,сред,неод=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}],
#   'text': 'Пари'},
#  {'text': '.'},
#  {'text': '\n'}]
